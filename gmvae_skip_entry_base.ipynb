# %% [markdown]
# # Imports

# %% [markdown]
# TO RUN:
# - Make sure to select Runtime>Change Runtime Type>T4 GPU to use cuda
# - Install pytorch_lightning
# - clone in repo to read in common files

# %%
# !pip install pytorch_lightning
# Out:
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.6.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (2.9.0+cu126)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.67.1)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2025.3.0)
# Collecting torchmetrics>0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (25.0)
# Requirement already satisfied: typing-extensions>4.5.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.15.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.13.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.10.0->pytorch_lightning) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.5.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics>0.7.0->pytorch_lightning) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.22.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (3.0.3)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.11)
# Downloading pytorch_lightning-2.6.0-py3-none-any.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 30.0 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 66.8 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch_lightning
# Successfully installed lightning-utilities-0.15.2 pytorch_lightning-2.6.0 torchmetrics-1.8.2

# %%
import os
import random
import numpy as np
import torch
from pytorch_lightning import seed_everything

SEED = 42
seed_everything(SEED, workers=True)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

import torch.optim as optim
from torch.distributions import Normal
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import pathlib
from torch.utils.data import DataLoader
from pytorch_lightning import LightningDataModule
import seaborn as sns
import json
from tqdm.notebook import tqdm_notebook
from time import time
import datetime
import pickle
import matplotlib.lines as mlines
import sys
from sklearn.decomposition import PCA
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 42

# %%
# !git clone https://github.com/gcalkins64/piguid_training.git
# Out:
# Cloning into 'piguid_training'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 21 (delta 5), reused 18 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 2.23 MiB | 23.83 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# !cd piguid_training && git pull
# Out:
# Already up to date.

# %%
sys.path.append('/content/piguid_training')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from gmvae_common import *

# %% [markdown]
# # Check Devices

# %%
# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set default tensor type to CUDA tensors
torch.set_default_tensor_type(torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor)
print(device)
# Out:
# cuda
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1275: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)

# %% [markdown]
# # Settings

# %%
n_train = 1024
n_val = 128
n_test = 128
# For testing small batches of data
# n_train = 400
# n_val = 50
# n_test = 50
# THREE LAYERS
hd1 = 36
hd2 = 18
hd3 = 9
hidden_dims = [hd1, hd2, hd3]
hidden_dims_r = [hd3, hd2, hd1]
# TWO LAYERS
# hd1 = 32
# hd2 = 16
# hd3 = None
# hidden_dims = [hd1, hd2]
# hidden_dims_r = [hd2, hd1]
latent_dim = 3
n_clusters = 4
lr = 1e-3
n_epochs = 10_000 # 30_000
batch_size = 128
em_reg = 1e-6
decoder_var = 1e-5

plot_interval = 500
dpi = 300

K = n_clusters
Z = latent_dim
D = 1  #num_modalities
downsampleNum = 64

loadFlag = False  # True to load in old case, False to run a new case
loadpostfix = ''
loaddirname = ''
startEpoch = 10_000

# loadpostfix = '_42_1024_128_128_32_16_7_3_0.001000_128_0.001000_0.000010_10000.000000_'
# loaddirname = 'drive/MyDrive/JP_gmvae_data/gmvae_near_escape_new_20250601_073224_L7_C3'
# startEpoch = 10_000

# data = '1_near_escape_fnpag_2000_data_energy_scaled_downsampled_'
# inds = '1_near_escape_fnpag_1999_inds_energy_scaled_downsampled_'
# tag = 'near_escape'

# data = '1_near_crash_fnpag_2000_data_energy_scaled_downsampled_'
# inds = '1_near_crash_fnpag_2000_inds_energy_scaled_downsampled_'
# tag = 'near_crash'

# data = '1_near_crash_new_2000_data_energy_scaled_downsampled_'
# inds = '1_near_crash_new_2000_inds_energy_scaled_downsampled_'
# tag = 'near_crash_new'

data = 'orion_mars_return_2500_data_alt_range_scaled_downsampled'
inds = 'orion_mars_return_2500_inds_alt_range_scaled_downsampled'
tag = 'orion_mars_return'

# %% [markdown]
# # Set Up Data Loader

# %%
from datetime import datetime
timestr = datetime.strftime(datetime.now(), "%Y%m%d_%H%M%S")

# %%
if loadFlag:  # Load in old data
  dirname = loaddirname
else:  # generate new data
  dirname = os.path.join("drive", "MyDrive", "piguid", "gmvae_"+tag+"_"+timestr+"_L"+str(latent_dim)+"_C"+str(n_clusters))
  os.makedirs(dirname, exist_ok=True)
print("Filepath directory: " + dirname)

if loadFlag:  # load old data
  postfix = loadpostfix
else:  # Generate new suffix
  if hd3 is not None:
    postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:d}_{9:f}_{10:d}_{11:f}_{12:f}_{13:f}_'.format(
          SEED, n_train, n_val, n_test, hd1, hd2, hd3, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
  else:
    postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:f}_{9:d}_{10:f}_{11:f}_{12:f}_'.format(
          SEED, n_train, n_val, n_test, hd1, hd2, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
print("Filepath postfix: " + postfix)
# Out:
# Filepath directory: drive/MyDrive/piguid/gmvae_orion_mars_return_20260111_033635_L3_C4
# Filepath postfix: _42_1024_128_128_36_18_9_3_4_0.001000_128_0.001000_0.000010_10000.000000_

# %%
data_dir = os.path.join("drive", "MyDrive", "piguid", f"{data}.json")

with open(os.path.join("drive", "MyDrive", "piguid", f"{inds}.json"), 'r') as f:
  sample_list_load = json.load(f)
sample_list = [int(sample) for sample in sample_list_load['sample_list']]
print(sample_list)
# Out:
# [1318, 2431, 629, 202, 2259, 1781, 468, 1986, 623, 2118, 2120, 2405, 397, 1770, 1714, 175, 2051, 860, 2106, 895, 854, 2368, 1837, 191, 1804, 951, 2222, 568, 184, 159, 1822, 447, 2337, 1360, 2137, 1800, 1113, 1298, 334, 2215, 986, 1435, 530, 1985, 326, 44, 534, 1989, 767, 2029, 279, 1229, 1427, 109, 734, 2145, 97, 1354, 2310, 1494, 817, 204, 866, 1487, 1291, 648, 944, 2020, 1554, 1139, 1098, 2303, 1984, 1860, 1353, 1170, 777, 2124, 1477, 392, 603, 2231, 810, 2014, 1978, 654, 166, 911, 289, 396, 1728, 1366, 2229, 1527, 1811, 2317, 2475, 1944, 103, 251, 853, 1571, 2411, 1195, 336, 500, 151, 1448, 1202, 39, 394, 1864, 121, 533, 2336, 2028, 1639, 18, 1046, 207, 2499, 1420, 1249, 1121, 1357, 1665, 1885, 269, 1164, 261, 2379, 490, 287, 2050, 1389, 1936, 528, 1694, 1957, 1269, 1760, 1850, 1211, 1475, 1730, 1150, 671, 1874, 1755, 929, 1014, 600, 1542, 1345, 746, 1620, 1495, 730, 1383, 248, 1780, 1387, 1938, 2160, 1982, 260, 2205, 2355, 673, 382, 2010, 1289, 867, 502, 1721, 1840, 1990, 2366, 2059, 464, 1675, 2453, 1897, 914, 322, 2176, 742, 494, 1931, 351, 1839, 1296, 683, 2228, 981, 9, 738, 540, 1685, 633, 2465, 754, 1141, 2463, 615, 380, 472, 1089, 2069, 1991, 65, 122, 1627, 1865, 1866, 1827, 1236, 613, 2003, 2441, 1470, 1607, 697, 1683, 1791, 1310, 1677, 1263, 950, 1939, 124, 2200, 230, 1329, 1433, 2346, 498, 350, 2225, 2078, 254, 137, 1367, 679, 180, 2006, 56, 399, 22, 900, 2497, 2490, 2286, 1725, 2143, 1709, 321, 575, 1023, 1517, 7, 1337, 1881, 1086, 1794, 786, 4, 2340, 2401, 247, 1224, 539, 1523, 717, 2198, 2419, 1574, 1951, 1188, 1441, 1557, 1895, 2406, 1323, 1266, 1142, 926, 576, 765, 1179, 55, 163, 2194, 364, 1782, 1238, 225, 1473, 1451, 640, 1393, 455, 463, 2378, 2391, 1209, 983, 2022, 1703, 1646, 1115, 2159, 2245, 749, 2292, 1649, 784, 2390, 939, 2421, 2443, 1592, 1316, 778, 899, 1455, 1916, 1371, 2454, 1870, 2377, 992, 1347, 1180, 770, 1610, 825, 2212, 59, 1586, 2258, 2474, 424, 1926, 2307, 505, 998, 1022, 1941, 1243, 2271, 1267, 385, 1924, 1563, 67, 649, 118, 2185, 1483, 1072, 2206, 462, 224, 1659, 1786, 1934, 1489, 1381, 1674, 2254, 2480, 1877, 1967, 1020, 1005, 779, 2387, 1060, 132, 655, 1069, 2156, 154, 86, 593, 960, 1273, 1184, 739, 470, 2116, 1538, 2262, 624, 234, 856, 676, 840, 1058, 1421, 2221, 706, 2320, 2306, 790, 1896, 1768, 837, 1821, 689, 452, 2048, 1160, 2086, 2164, 138, 606, 243, 323, 431, 1315, 646, 1949, 2325, 2260, 1698, 410, 904, 1342, 173, 1217, 1632, 119, 91, 2459, 1240, 1614, 1788, 1654, 2151, 2026, 741, 391, 2279, 2060, 62, 1465, 1817, 1206, 1580, 1609, 2153, 1712, 2084, 21, 1532, 1746, 1241, 1643, 112, 1161, 366, 2372, 2252, 563, 1838, 2064, 1964, 328, 1218, 1552, 1486, 1777, 1998, 1106, 2359, 1690, 1438, 1460, 1830, 1409, 1623, 1679, 849, 959, 943, 1884, 2129, 2442, 144, 1880, 418, 2385, 123, 2236, 1686, 2430, 1739, 988, 420, 1596, 771, 1908, 758, 2318, 2109, 548, 924, 1948, 2210, 53, 1275, 521, 493, 409, 1493, 1593, 1929, 1333, 1631, 1002, 1892, 2416, 1648, 1918, 29, 955, 1328, 769, 2322, 1341, 2170, 1215, 2298, 885, 700, 1088, 1006, 763, 580, 1019, 1423, 1729, 2158, 1710, 1030, 516, 677, 1159, 1292, 1570, 2333, 483, 1577, 228, 552, 1028, 1503, 1744, 2438, 1533, 1408, 722, 1650, 1297, 1656, 188, 1566, 1727, 346, 841, 1432, 620, 388, 48, 1611, 1251, 2472, 1719, 2295, 1524, 2451, 1603, 1187, 1288, 1672, 1178, 1994, 1434, 76, 139, 2226, 179, 2081, 1132, 1724, 1506, 227, 2345, 1711, 1752, 414, 2133, 972, 1153, 2038, 1260, 604, 1488, 2488, 256, 2253, 816, 1828, 2470, 785, 1081, 936, 644, 74, 1899, 1111, 370, 1171, 58, 1769, 993, 745, 756, 1068, 176, 2332, 1062, 1390, 449, 1321, 889, 19, 1759, 253, 2104, 2066, 596, 1348, 1736, 1450, 1923, 2189, 1128, 1903, 1995, 581, 1051, 674, 513, 1140, 85, 2249, 332, 2017, 874, 495, 319, 828, 719, 2404, 1074, 31, 2027, 1689, 252, 1617, 2192, 1625, 617, 1301, 1331, 211, 1511, 491, 2209, 2478, 421, 908, 1589, 647, 1754, 619, 918, 307, 973, 2191, 804, 1203, 2021, 222, 1499, 643, 1, 308, 467, 610, 2099, 1462, 750, 2113, 2199, 1101, 20, 1904, 2433, 2331, 2203, 2450, 538, 21 ...

# %%
data_module = AerocaptureDataModuleCUDA(data_dir=data_dir, n_train=n_train, n_val=n_val, n_test=n_test,
                                  train_batch=batch_size, val_batch=batch_size, test_batch=batch_size,
                                  num_workers=0)

data_module.setup("fit", sample_list = sample_list)

train_loader = data_module.train_dataloader()
val_loader = data_module.val_dataloader()
test_loader = data_module.test_dataloader()
data_dim = len(train_loader.dataset[0][0])
true_labels = ['capture', 'escape', 'miss']
label_colors = ['C2', 'C3', 'C4']

num_train_batches = len(train_loader)

ts_plot = np.linspace(0,1,36)
seabornSettings()
fig, ax = plt.subplots(figsize=(4, 4))
for j in range(n_train):
  ax.plot(ts_plot, train_loader.dataset[j][0].cpu(), color=label_colors[train_loader.dataset[j][1].cpu()], alpha=0.3)

eline = mlines.Line2D([], [], color='C2', label='Escape')
cline = mlines.Line2D([], [], color='C3', label='Capture')
iline = mlines.Line2D([], [], color='C4', label='Miss')
plt.legend(handles=[eline, cline, iline])
# plt.hlines(0, 0, ts_plot[-1], colors='r', linestyles='dashed')
plt.xlabel("Downrange")
plt.ylabel("Altitude")
plt.title("Training Data")
plt.tight_layout()
fig.savefig(os.path.join(dirname, 'train_data'+postfix+'.png'), dpi=dpi)

fig, ax = plt.subplots(figsize=(4.5, 4))
for j in range(n_val):
    ax.plot(ts_plot, val_loader.dataset[j][0].cpu(), color=label_colors[val_loader.dataset[j][1].cpu()], alpha=0.3)
plt.title("Validation Data")
fig.savefig(os.path.join(dirname, 'val_data'+postfix+'.png'), dpi=dpi)

fig, ax = plt.subplots(figsize=(4.5, 4))
for j in range(n_test):
    ax.plot(ts_plot, test_loader.dataset[j][0].cpu(), color=label_colors[test_loader.dataset[j][1].cpu()], alpha=0.3)
plt.title("Test Data")
fig.savefig(os.path.join(dirname, 'test_data'+postfix+'.png'), dpi=dpi)
# Out:
# Loading File...
# ...File Loaded
# Sample List: [1318, 2431, 629, 202, 2259, 1781, 468, 1986, 623, 2118, 2120, 2405, 397, 1770, 1714, 175, 2051, 860, 2106, 895, 854, 2368, 1837, 191, 1804, 951, 2222, 568, 184, 159, 1822, 447, 2337, 1360, 2137, 1800, 1113, 1298, 334, 2215, 986, 1435, 530, 1985, 326, 44, 534, 1989, 767, 2029, 279, 1229, 1427, 109, 734, 2145, 97, 1354, 2310, 1494, 817, 204, 866, 1487, 1291, 648, 944, 2020, 1554, 1139, 1098, 2303, 1984, 1860, 1353, 1170, 777, 2124, 1477, 392, 603, 2231, 810, 2014, 1978, 654, 166, 911, 289, 396, 1728, 1366, 2229, 1527, 1811, 2317, 2475, 1944, 103, 251, 853, 1571, 2411, 1195, 336, 500, 151, 1448, 1202, 39, 394, 1864, 121, 533, 2336, 2028, 1639, 18, 1046, 207, 2499, 1420, 1249, 1121, 1357, 1665, 1885, 269, 1164, 261, 2379, 490, 287, 2050, 1389, 1936, 528, 1694, 1957, 1269, 1760, 1850, 1211, 1475, 1730, 1150, 671, 1874, 1755, 929, 1014, 600, 1542, 1345, 746, 1620, 1495, 730, 1383, 248, 1780, 1387, 1938, 2160, 1982, 260, 2205, 2355, 673, 382, 2010, 1289, 867, 502, 1721, 1840, 1990, 2366, 2059, 464, 1675, 2453, 1897, 914, 322, 2176, 742, 494, 1931, 351, 1839, 1296, 683, 2228, 981, 9, 738, 540, 1685, 633, 2465, 754, 1141, 2463, 615, 380, 472, 1089, 2069, 1991, 65, 122, 1627, 1865, 1866, 1827, 1236, 613, 2003, 2441, 1470, 1607, 697, 1683, 1791, 1310, 1677, 1263, 950, 1939, 124, 2200, 230, 1329, 1433, 2346, 498, 350, 2225, 2078, 254, 137, 1367, 679, 180, 2006, 56, 399, 22, 900, 2497, 2490, 2286, 1725, 2143, 1709, 321, 575, 1023, 1517, 7, 1337, 1881, 1086, 1794, 786, 4, 2340, 2401, 247, 1224, 539, 1523, 717, 2198, 2419, 1574, 1951, 1188, 1441, 1557, 1895, 2406, 1323, 1266, 1142, 926, 576, 765, 1179, 55, 163, 2194, 364, 1782, 1238, 225, 1473, 1451, 640, 1393, 455, 463, 2378, 2391, 1209, 983, 2022, 1703, 1646, 1115, 2159, 2245, 749, 2292, 1649, 784, 2390, 939, 2421, 2443, 1592, 1316, 778, 899, 1455, 1916, 1371, 2454, 1870, 2377, 992, 1347, 1180, 770, 1610, 825, 2212, 59, 1586, 2258, 2474, 424, 1926, 2307, 505, 998, 1022, 1941, 1243, 2271, 1267, 385, 1924, 1563, 67, 649, 118, 2185, 1483, 1072, 2206, 462, 224, 1659, 1786, 1934, 1489, 1381, 1674, 2254, 2480, 1877, 1967, 1020, 1005, 779, 2387, 1060, 132, 655, 1069, 2156, 154, 86, 593, 960, 1273, 1184, 739, 470, 2116, 1538, 2262, 624, 234, 856, 676, 840, 1058, 1421, 2221, 706, 2320, 2306, 790, 1896, 1768, 837, 1821, 689, 452, 2048, 1160, 2086, 2164, 138, 606, 243, 323, 431, 1315, 646, 1949, 2325, 2260, 1698, 410, 904, 1342, 173, 1217, 1632, 119, 91, 2459, 1240, 1614, 1788, 1654, 2151, 2026, 741, 391, 2279, 2060, 62, 1465, 1817, 1206, 1580, 1609, 2153, 1712, 2084, 21, 1532, 1746, 1241, 1643, 112, 1161, 366, 2372, 2252, 563, 1838, 2064, 1964, 328, 1218, 1552, 1486, 1777, 1998, 1106, 2359, 1690, 1438, 1460, 1830, 1409, 1623, 1679, 849, 959, 943, 1884, 2129, 2442, 144, 1880, 418, 2385, 123, 2236, 1686, 2430, 1739, 988, 420, 1596, 771, 1908, 758, 2318, 2109, 548, 924, 1948, 2210, 53, 1275, 521, 493, 409, 1493, 1593, 1929, 1333, 1631, 1002, 1892, 2416, 1648, 1918, 29, 955, 1328, 769, 2322, 1341, 2170, 1215, 2298, 885, 700, 1088, 1006, 763, 580, 1019, 1423, 1729, 2158, 1710, 1030, 516, 677, 1159, 1292, 1570, 2333, 483, 1577, 228, 552, 1028, 1503, 1744, 2438, 1533, 1408, 722, 1650, 1297, 1656, 188, 1566, 1727, 346, 841, 1432, 620, 388, 48, 1611, 1251, 2472, 1719, 2295, 1524, 2451, 1603, 1187, 1288, 1672, 1178, 1994, 1434, 76, 139, 2226, 179, 2081, 1132, 1724, 1506, 227, 2345, 1711, 1752, 414, 2133, 972, 1153, 2038, 1260, 604, 1488, 2488, 256, 2253, 816, 1828, 2470, 785, 1081, 936, 644, 74, 1899, 1111, 370, 1171, 58, 1769, 993, 745, 756, 1068, 176, 2332, 1062, 1390, 449, 1321, 889, 19, 1759, 253, 2104, 2066, 596, 1348, 1736, 1450, 1923, 2189, 1128, 1903, 1995, 581, 1051, 674, 513, 1140, 85, 2249, 332, 2017, 874, 495, 319, 828, 719, 2404, 1074, 31, 2027, 1689, 252, 1617, 2192, 1625, 617, 1301, 1331, 211, 1511, 491, 2209, 2478, 421, 908, 1589, 647, 1754, 619, 918, 307, 973, 2191, 804, 1203, 2021, 222, 1499, 643, 1, 308, 467, 610, 2099, 1462, 750, 2113, 2199, 1101, 20, 1904, 2433, 2331, 2203,  ...
#   0%|          | 0/1280 [00:00<?, ?it/s]

# %% [markdown]
# # Run GMVAE

# %%
if not loadFlag:
  # initialize latent GMM model parameters
  params = {}
  pi_variables = torch.zeros(K).clone().detach().requires_grad_(True)
  params['pi_c'] = torch.ones(K) / K
  params['mu_c'] = torch.rand((K, Z)) * 2.0 - 1.0
  params['logsigmasq_c'] = torch.zeros((K, Z))

  # initialize neural networks
  encoder_list = []
  decoder_list = []
  trainable_parameters = []
  trainable_parameters.append(pi_variables)

  for _ in range(D):
      encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims)
      decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var)
      encoder_list.append(encoder)
      decoder_list.append(decoder)
      trainable_parameters += list(encoder.parameters()) + list(decoder.parameters())

  train_loss = torch.zeros(n_epochs)
  train_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
  val_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
  val_loss = torch.zeros(n_epochs)
  pi_history = torch.zeros((n_epochs, K))
  train_mse_history = torch.zeros(n_epochs)
  val_mse_history = torch.zeros(n_epochs)
  min_val_loss = torch.inf
  trainEpochs = np.arange(0,n_epochs,1)

else:  # Load in old models and figure out what epoch to start training from
  params = {}
  pi_variables = torch.zeros(K).clone().detach().requires_grad_(True)
  params['pi_c'] = torch.load(os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
  params['mu_c'] = torch.load(os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
  params['logsigmasq_c'] = torch.load(os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))

  # initialize neural networks
  encoder_list = []
  decoder_list = []
  trainable_parameters = []
  trainable_parameters.append(pi_variables)

  for _ in range(D):
      encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims)
      decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var)
      encoder.load_state_dict(torch.load(os.path.join(dirname, 'encoder'+ postfix + '.pt')))
      decoder.load_state_dict(torch.load(os.path.join(dirname, 'decoder'+ postfix + '.pt')))
      encoder_list.append(encoder)
      decoder_list.append(decoder)
      trainable_parameters += list(encoder.parameters()) + list(decoder.parameters())

  train_loss = torch.zeros(n_epochs)
  train_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
  val_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
  val_loss = torch.zeros(n_epochs)
  pi_history = torch.zeros((n_epochs, K))
  train_mse_history = torch.zeros(n_epochs)
  val_mse_history = torch.zeros(n_epochs)

  train_loss[:startEpoch] = torch.load(os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
  train_elbo_terms[:startEpoch] = torch.load(os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
  val_elbo_terms[:startEpoch] = torch.load(os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
  val_loss[:startEpoch] = torch.load(os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
  pi_history[:startEpoch] = torch.load(os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
  train_mse_history[:startEpoch] = torch.load(os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
  val_mse_history[:startEpoch] = torch.load(os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))
  min_val_loss = torch.min(val_loss)
  trainEpochs = np.arange(startEpoch,n_epochs,1)

print(trainEpochs)


# Training
seabornSettings()
text_labels = [f'Cluster {i}' for i in range((n_clusters))]
label_colors = [f'C{i+1}' for i in range((n_clusters))]

optimizer = optim.Adam(trainable_parameters, lr=lr)

import time
ts = time.time()
tic = time.perf_counter()

for epoch in trainEpochs:
    ti = time.time()
    for encoder in encoder_list:
        encoder.train()
    for decoder in decoder_list:
        decoder.train()

    train_elbo = 0
    train_mse = 0
    train_elbo_term = np.zeros(4)
    params['hist_weights'] = torch.zeros((K, 1))
    params['hist_mu_c'] = torch.zeros((K, latent_dim))
    params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))

    for (batch_idx, batch) in enumerate(train_loader):
        batch_x, _ = batch
        x_list = [batch_x]  # assume D=2 and each modality has data_dim
        optimizer.zero_grad()
        pi_c = torch.exp(pi_variables) / torch.sum(torch.exp(pi_variables))
        params['pi_c'] = pi_c

        mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
        sigma = torch.exp(0.5 * logsigmasq)
        eps = Normal(0, 1).sample(mu.shape)
        z = mu + eps * sigma

        with torch.no_grad():
            gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
        params['mu_c'] = mu_c
        params['logsigmasq_c'] = logsigmasq_c

        elbo, sse, elbo_terms = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
        train_elbo += elbo.item()
        train_elbo_term += elbo_terms
        train_mse += sse.item()
        loss = - elbo / batch_x.shape[0]
        loss.backward()
        optimizer.step()

    for encoder in encoder_list:
        encoder.eval()
    for decoder in decoder_list:
        decoder.eval()

    if epoch % plot_interval == 0 or epoch == n_epochs:
        # Plot the first two dimensions of the latents
        with torch.no_grad():
            means = []
            samples = []
            labels = []
            for batch in train_loader:
                batch_x, batch_label = batch
                x_list = [batch_x]
                mean, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                sigma = torch.exp(0.5 * logsigmasq)
                eps = Normal(0, 1).sample(mean.shape)
                z = mean + eps * sigma
                means.append(mean)
                samples.append(z)
                labels.append(batch_label)

        means = torch.vstack(means).cpu()
        samples = torch.vstack(samples).cpu()
        labels = torch.hstack(labels).cpu()

        savepath = os.path.join(dirname, "latent_samples_epoch_" + str(epoch) + postfix)
        plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)

        savepath = os.path.join(dirname, "latent_means_epoch_" + str(epoch) + postfix)
        plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)


        # plot samples from generative model
        n_gen = n_train
        cluster_probs = params['pi_c'].cpu().detach().numpy() #
        fig, ax = plt.subplots(figsize=(4.5, 4))
        for j in range(n_gen):
            c = np.random.choice(K, p=cluster_probs)
            mu_c = params['mu_c'][c].clone().detach()
            sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).clone().detach()
            z = Normal(0, 1).sample(mu_c.shape) * sigma_c + mu_c
            mu_x = decoder.forward(z)[0]
            ax.plot(mu_x.cpu().detach().numpy())
        fig.savefig(os.path.join(dirname, "generate_samples_" + str(epoch) + postfix+ '.png'), dpi=dpi)
        plt.close()


    val_elbo = 0
    val_mse = 0
    val_elbo_term = np.zeros(4)
    with torch.no_grad():
        for (batch_idx, batch) in enumerate(val_loader):
            batch_x, _ = batch
            x_list = [batch_x]
            mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
            sigma = torch.exp(0.5 * logsigmasq)
            eps = Normal(0, 1).sample(mu.shape)
            z = mu + eps * sigma
            with torch.no_grad():
                gamma_c, _, _ = em_step(z, mu, logsigmasq, params, em_reg)
            elbo, sse, elbo_items = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
            val_elbo += elbo.item()
            val_mse += sse.item()
            val_elbo_term += elbo_items

    train_elbo /= len(train_loader.dataset)
    train_elbo_term = torch.tensor(train_elbo_term) / len(train_loader.dataset)
    val_elbo /= len(val_loader.dataset)
    val_elbo_term = torch.tensor(val_elbo_term) / len(val_loader.dataset)
    train_mse /= len(train_loader.dataset)
    val_mse /= len(val_loader.dataset)

    tf = time.time()
    toc = time.perf_counter()
    print('====> Epoch: {} Train ELBO: {:.4f} Val ELBO: {:.4f}, Epoch Time (s): {:.2f}, Total Time (hrs): {:.4f}'.format(epoch, train_elbo, val_elbo, tf-ti, (toc-tic)/60/60))

    train_loss[epoch] = - train_elbo
    val_loss[epoch] = - val_elbo
    train_elbo_terms[epoch,:] = - train_elbo_term
    val_elbo_terms[epoch,:] = - val_elbo_term
    pi_history[epoch] = params['pi_c']
    train_mse_history[epoch] = train_mse
    val_mse_history[epoch] = val_mse

    if - val_elbo < min_val_loss:
        min_val_loss = - val_elbo
        torch.save(params['pi_c'], os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
        torch.save(params['mu_c'], os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
        torch.save(params['logsigmasq_c'], os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
        torch.save(encoder.state_dict(), os.path.join(dirname, 'encoder'+ postfix + '.pt'))
        torch.save(decoder.state_dict(), os.path.join(dirname, 'decoder'+ postfix + '.pt'))

    if epoch % plot_interval == 0 or epoch == n_epochs:
      # Plot the training and validation loss vs. epoch number
      plt.figure(figsize=(4.5, 4))
      # const = min(min(train_loss), min(val_loss))
      train_loss_adjusted = train_loss
      val_loss_adjusted = val_loss
      plt.plot(train_loss_adjusted.cpu()[:epoch], label='train')
      # print(train_loss_adjusted.cpu()[:epoch])
      plt.plot(val_loss_adjusted.cpu()[:epoch], label='val')
      plt.yscale('symlog')
      plt.xlabel("number of epochs")
      plt.ylabel("loss")
      plt.title("Negative Loss")
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      plt.close()

      # Plot each term of the training loss and validation loss
      plt.figure(figsize=(4.5, 4))
      labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
      for ii in range(4):
        train_loss_adjusted = train_elbo_terms[:epoch, ii]
        val_loss_adjusted = val_elbo_terms[:epoch, ii]
        plt.plot(train_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Train")
        plt.plot(val_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Val", linestyle='--')
      plt.xlabel("number of epochs")
      plt.yscale('symlog')
      plt.ylabel("loss")
      plt.title("Negative Loss Terms")
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      plt.close()

      # Plot the training and validation mse vs. epoch number
      plt.figure(figsize=(4.5, 4))
      plt.semilogy(train_mse_history.cpu().detach().numpy()[:epoch], label='train')
      plt.semilogy(val_mse_history.cpu().detach().numpy()[:epoch], label='val')
      plt.xlabel("number of epochs")
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      plt.close()

      # Plot the history of pi
      plt.figure(figsize=(4.5, 4))
      for i in range(K):
          plt.plot(pi_history[:, i].cpu().detach().numpy()[:epoch], label=r'$\pi$' + str(i+1))
      plt.xlabel("number of epochs")
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      plt.close()


te = time.time()
import datetime
duration = datetime.timedelta(seconds=te - ts)
print("Training took ", duration)

# Save off pi_history, train_loss, val_loss, train_mse_history, val_mse_history
torch.save(pi_history, os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
torch.save(train_loss, os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
torch.save(val_loss, os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
torch.save(train_elbo_terms, os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
torch.save(val_elbo_terms, os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
torch.save(train_mse_history, os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
torch.save(val_mse_history, os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))
# Out:
# Streaming output truncated to the last 5000 lines.
# ====> Epoch: 1711 Train ELBO: 116.8305 Val ELBO: 130.5243, Epoch Time (s): 0.10, Total Time (hrs): 0.0586
# ====> Epoch: 1712 Train ELBO: 120.8176 Val ELBO: 120.8523, Epoch Time (s): 0.08, Total Time (hrs): 0.0587
# ====> Epoch: 1713 Train ELBO: 118.4881 Val ELBO: 130.9864, Epoch Time (s): 0.09, Total Time (hrs): 0.0587
# ====> Epoch: 1714 Train ELBO: 118.3041 Val ELBO: 128.7309, Epoch Time (s): 0.09, Total Time (hrs): 0.0587
# ====> Epoch: 1715 Train ELBO: 114.3653 Val ELBO: 120.1132, Epoch Time (s): 0.09, Total Time (hrs): 0.0587
# ====> Epoch: 1716 Train ELBO: 111.8451 Val ELBO: 127.4173, Epoch Time (s): 0.09, Total Time (hrs): 0.0588
# ====> Epoch: 1717 Train ELBO: 112.3545 Val ELBO: 116.5720, Epoch Time (s): 0.09, Total Time (hrs): 0.0588
# ====> Epoch: 1718 Train ELBO: 115.3609 Val ELBO: 126.1169, Epoch Time (s): 0.10, Total Time (hrs): 0.0588
# ====> Epoch: 1719 Train ELBO: 117.8912 Val ELBO: 124.1059, Epoch Time (s): 0.08, Total Time (hrs): 0.0588
# ====> Epoch: 1720 Train ELBO: 116.0284 Val ELBO: 123.5206, Epoch Time (s): 0.09, Total Time (hrs): 0.0589
# ====> Epoch: 1721 Train ELBO: 113.2776 Val ELBO: 124.3192, Epoch Time (s): 0.09, Total Time (hrs): 0.0589
# ====> Epoch: 1722 Train ELBO: 116.8159 Val ELBO: 130.7916, Epoch Time (s): 0.09, Total Time (hrs): 0.0589
# ====> Epoch: 1723 Train ELBO: 119.2479 Val ELBO: 129.5546, Epoch Time (s): 0.10, Total Time (hrs): 0.0589
# ====> Epoch: 1724 Train ELBO: 115.5075 Val ELBO: 117.0186, Epoch Time (s): 0.09, Total Time (hrs): 0.0590
# ====> Epoch: 1725 Train ELBO: 111.8495 Val ELBO: 109.4110, Epoch Time (s): 0.08, Total Time (hrs): 0.0590
# ====> Epoch: 1726 Train ELBO: 111.2149 Val ELBO: 128.7783, Epoch Time (s): 0.09, Total Time (hrs): 0.0590
# ====> Epoch: 1727 Train ELBO: 110.4874 Val ELBO: 128.1217, Epoch Time (s): 0.08, Total Time (hrs): 0.0590
# ====> Epoch: 1728 Train ELBO: 115.0917 Val ELBO: 126.5099, Epoch Time (s): 0.09, Total Time (hrs): 0.0591
# ====> Epoch: 1729 Train ELBO: 113.7173 Val ELBO: 106.2321, Epoch Time (s): 0.09, Total Time (hrs): 0.0591
# ====> Epoch: 1730 Train ELBO: 116.2229 Val ELBO: 125.3779, Epoch Time (s): 0.10, Total Time (hrs): 0.0591
# ====> Epoch: 1731 Train ELBO: 119.5340 Val ELBO: 129.1063, Epoch Time (s): 0.08, Total Time (hrs): 0.0591
# ====> Epoch: 1732 Train ELBO: 118.2793 Val ELBO: 123.7684, Epoch Time (s): 0.09, Total Time (hrs): 0.0592
# ====> Epoch: 1733 Train ELBO: 119.0330 Val ELBO: 130.0010, Epoch Time (s): 0.08, Total Time (hrs): 0.0592
# ====> Epoch: 1734 Train ELBO: 112.6603 Val ELBO: 117.9229, Epoch Time (s): 0.08, Total Time (hrs): 0.0592
# ====> Epoch: 1735 Train ELBO: 113.7144 Val ELBO: 127.8234, Epoch Time (s): 0.09, Total Time (hrs): 0.0592
# ====> Epoch: 1736 Train ELBO: 114.8293 Val ELBO: 129.6000, Epoch Time (s): 0.08, Total Time (hrs): 0.0593
# ====> Epoch: 1737 Train ELBO: 117.8281 Val ELBO: 131.3882, Epoch Time (s): 0.09, Total Time (hrs): 0.0593
# ====> Epoch: 1738 Train ELBO: 119.7439 Val ELBO: 126.3218, Epoch Time (s): 0.08, Total Time (hrs): 0.0593
# ====> Epoch: 1739 Train ELBO: 121.2321 Val ELBO: 128.0306, Epoch Time (s): 0.09, Total Time (hrs): 0.0593
# ====> Epoch: 1740 Train ELBO: 113.9327 Val ELBO: 124.7408, Epoch Time (s): 0.09, Total Time (hrs): 0.0594
# ====> Epoch: 1741 Train ELBO: 111.6010 Val ELBO: 109.3081, Epoch Time (s): 0.11, Total Time (hrs): 0.0594
# ====> Epoch: 1742 Train ELBO: 112.6947 Val ELBO: 127.0601, Epoch Time (s): 0.08, Total Time (hrs): 0.0594
# ====> Epoch: 1743 Train ELBO: 115.0353 Val ELBO: 125.8479, Epoch Time (s): 0.09, Total Time (hrs): 0.0594
# ====> Epoch: 1744 Train ELBO: 115.3476 Val ELBO: 125.5643, Epoch Time (s): 0.15, Total Time (hrs): 0.0595
# ====> Epoch: 1745 Train ELBO: 110.1318 Val ELBO: 124.6919, Epoch Time (s): 0.13, Total Time (hrs): 0.0595
# ====> Epoch: 1746 Train ELBO: 115.4092 Val ELBO: 117.4004, Epoch Time (s): 0.13, Total Time (hrs): 0.0596
# ====> Epoch: 1747 Train ELBO: 116.1039 Val ELBO: 128.5306, Epoch Time (s): 0.13, Total Time (hrs): 0.0596
# ====> Epoch: 1748 Train ELBO: 117.7386 Val ELBO: 128.8882, Epoch Time (s): 0.13, Total Time (hrs): 0.0596
# ====> Epoch: 1749 Train ELBO: 119.1562 Val ELBO: 130.1354, Epoch Time (s): 0.13, Total Time (hrs): 0.0597
# ====> Epoch: 1750 Train ELBO: 120.8118 Val ELBO: 131.7683, Epoch Time (s): 0.15, Total Time (hrs): 0.0597
# ====> Epoch: 1751 Train ELBO: 109.2989 Val ELBO: 119.3865, Epoch Time (s): 0.12, Total Time (hrs): 0.0598
# ====> Epoch: 1752 Train ELBO: 107.6806 Val ELBO: 124.6846, Epoch Time (s): 0.14, Total Time (hrs): 0.0598
# ====> Epoch: 1753 Train ELBO: 117.7364 Val ELBO: 127.2129, Epoch Time (s): 0.12, Total Time (hrs): 0.0598
# ====> Epoch: 1754 Train ELBO: 118.9840 Val ELBO: 127.9993, Epoch Time (s): 0.13, Total Time (hrs): 0.0599
# ====> Epoch: 1755 Train ELBO: 121.6732 Val ELBO: 126.7200, Epoch Time (s): 0.13, Total Time (hrs): 0.0599
# ====> Epoch: 1756 Train ELBO: 118.6245 Val ELBO: 128.9693, Epoch Time (s): 0.13, Total Time (hrs): 0.0599
# ====> Epoch: 1757 Train ELBO: 118.1865 Val ELBO: 128.1418, Epoch Time (s): 0.13, Total Time (hrs): 0.0600
# ====> Epoch: 1758 Train ELBO: 117.1083 Val ELBO: 122.8790, Epoch Time (s): 0.15, Total Time (hrs): 0.0600
# ====> Epoch: 1759 Train ELBO: 118.4652 Val ELBO: 128.2240, Epoch Time (s): 0.13, Total Time (hrs): 0.0600
# ====> Epoch: 1760 Train ELBO: 120.9839 Val ELBO: 132.0972, Epoch Time (s): 0.13, Total Time (hrs): 0.0601
# ====> Epoch: 1761 Train ELBO: 120.2116 Val ELBO: 122.9931, Epoch Time (s): 0.13, Total Time (hrs): 0.0601
# ====> Epoch: 1762 Train ELBO: 117.6624 Val ELBO: 120.0184, Epoch Time (s): 0.14, Total Time (hrs): 0.0602
# ====> Epoch: 1763 Train ELBO: 117.8125 Val ELBO: 127.7803, Epoch Time (s): 0.14, Total Time (hrs): 0.0602
# ====> Epoch: 1764 Train ELBO: 113.3008 Val ELBO: 130.9298, Epoch Time (s): 0.15, Total Time (hrs): 0.0603
# ====> Epoch: 1765 Train ELBO: 115.2060 Val ELBO: 118.0612, Epoch Time (s): 0.14, Total Time (hrs): 0.0603
# ====> Epoch: 1766 Train ELBO: 114.3163 Val ELBO: 131.7138, Epoch Time (s): 0.15, Total Time (hrs): 0.0603
# ====> Epoch: 1767 Train ELBO: 121.8649 Val ELBO: 130.7578, Epoch Time (s): 0.14, Total Time (hrs): 0.0604
# ====> Epoch: 1768 Train ELBO: 121.7796 Val ELBO: 130.3462, Epoch Time (s): 0.15, Total Time (hrs): 0.0604
# ====> Epoch: 1769 Train ELBO: 122.5855 Val ELBO: 130.1202, Epoch Time (s): 0.15, Total Time (hrs): 0.0605
# ====> Epoch: 1770 Train ELBO: 121.3162 Val ELBO: 131.3492, Epoch Time (s): 0.09, Total Time (hrs): 0.0605
# ====> Epoch: 1771 Train ELBO: 121.9634 Val ELBO: 129.9178, Epoch Time (s): 0.08, Total Time (hrs): 0.0605
# ====> Epoch: 1772 Train ELBO: 121.3698 Val ELBO: 127.2196, Epoch Time (s): 0.08, Total Time (hrs): 0.0605
# ====> Epoch: 1773 Train ELBO: 118.2372 Val ELBO: 126.7844, Epoch Time (s): 0.09, Total Time (hrs): 0.0606
# ====> Epoch: 1774 Train ELBO: 118.3172 Val ELBO: 131.2950, Epoch Time (s): 0.09, Total Time (hrs): 0.0606
# ====> Epoch: 1775 Train ELBO: 121.1365 Val ELBO: 126.0748, Epoch Time (s): 0.10, Total Time (hrs): 0.0606
# ====> Epoch: 1776 Train ELBO: 120.7144 Val ELBO: 130.4045, Epoch Time (s): 0.09, Total Time (hrs): 0.0606
# ====> Epoch: 1777 Train ELBO: 123.8564 Val ELBO: 130.4718, Epoch Time (s): 0.08, Total Time (hrs): 0.0607
# ====> Epoch: 1778 Train ELBO: 120.2627 Val ELBO: 124.8081, Epoch Time (s): 0.09, Total Time (hrs): 0.0607
# ====> Epoch: 1779 Train ELBO: 120.7377 Val ELBO: 131.8567, Epoch Time (s): 0.09, Total Time (hrs): 0.0607
# ====> Epoch: 1780 Train ELBO: 121.4880 Val ELBO: 132.0427, Epoch Time (s): 0.08, Total Time (hrs): 0.0607
# ====> Epoch: 1781 Train ELBO: 123.6083 Val ELBO: 130.2428, Epoch Time (s): 0.08, Total Time (hrs): 0.0607
# ====> Epoch: 1782 Train ELBO: 121.9088 Val ELBO: 131.8262, Epoch Time (s): 0.09, Total Time (hrs): 0.0608
# ====> Epoch: 1783 Train ELBO: 120.4780 Val ELBO: 124.7471, Epoch Time (s): 0.09, Total Time (hrs): 0.0608
# ====> Epoch: 1784 Train ELBO: 118.6725 Val ELBO: 126.2580, Epoch Time (s): 0.08, Total Time (hrs): 0.0608
# ====> Epoch: 1785 Train ELBO: 120.2756 Val ELBO: 125.1724, Epoch Time (s): 0.10, Total Time (hrs): 0.0608
# ====> Epoch: 1786 Train ELBO: 116.8093 Val ELBO: 129.7665, Epoch Time (s): 0.09, Total Time (hrs): 0.0609
# ====> Epoch: 1787 Train ELBO: 119.7005 Val ELBO: 127.9882, Epoch Time (s): 0.10, Total Time (hrs): 0.0609
# ====> Epoch: 1788 Train ELBO: 116.6972 Val ELBO: 125.1838, Epoch Time (s): 0.09, Total Time (hrs): 0.0609
# ====> Epoch: 1789 Train ELBO: 110.2907 Val ELBO: 122.4157, Epoch Time (s): 0.08, Total Time (hrs): 0.0609
# ====> Epoch: 1790 Train ELBO: 116.4660 Val ELBO: 132.4753, Epoch Time (s): 0.08, Total Time (hrs): 0.0610
# ====> Epoch: 1791 Train ELBO: 118.9698 Val ELBO: 128.6278, Epoch Time (s): 0.09, Total Time (hrs): 0.0610
# ====> Epoch: 1792 Train ELBO: 113.5006 Val ELBO: 122.1947, Epoch Time (s): 0.09, Total Time (hrs): 0.0610
# ====> Epoch: 1793 Train ELBO: 107.6251 Val ELBO: 119.0577, Epoch Time (s): 0.08, Total Time (hrs): 0.0611
# ====> Epoch: 1794 Train ELBO: 116.1719 Val ELBO: 129.6847, Epoch Time (s): 0.09, Total Time (hrs): 0.0611
# ====> Epoch: 1795 Train ELBO: 116.7888 Val ELBO: 116.1352, Epoch Time (s): 0.08, Total Time (hrs): 0.0611
# ====> Epoch: 1796 Train ELBO: 111.5204 Val ELBO: 127.4154, Epoch Time (s): 0.08, Total Time (hrs): 0.0611
# ====> Epoch: 1797 Train ELBO: 114.5897 Val ELBO: 118.0586, Epoch Time (s): 0.10, Total Time (hrs): 0.0612
# ====> Epoch: 1798 Train ELBO: 117.9619 Val ELBO: 128.4893, Epoch Time (s): 0.10, Total Time (hrs): 0.0612
# ====> Epoch: 1799 Train ELBO: 114.3061 Val ELBO: 118.9178, Epoch Time (s): 0.09, Total Time (hrs): 0.0612
# ====> Epoch: 1800 Train ELBO: 111.3904 Val ELBO: 116.0923, Epoch Time (s): 0.09, Total Time (hrs): 0.0612
# ====> Epoch: 1801 Train ELBO: 116.6079 Val ELBO: 126.6099, Epoch Time (s): 0.08, Total Time (hrs): 0.0613
# ====> Epoch: 1802 Train ELBO: 120.0888 Val ELBO: 128.7448, Epoch Time (s): 0.08, Total Time (hrs): 0.0613
# ====> Epoch: 1803 Train ELBO: 122.5717 Val ELBO: 130.2381, Epoch Time (s): 0.09, Total Time (hrs): 0.0613
# ====> Epoch: 1804 Train ELBO: 113.9280 Val ELBO: 123.8046, Epoch Time (s): 0.08, Total Time (hrs): 0.0613
# ====> Epoch: 1805 Train ELBO: 112.4242 Val ELBO: 115.9752, Epoch Time (s): 0.08, Total Time (hrs): 0.0614
# ====> Epoch: 1806 Train ELBO: 113.5032 Val ELBO: 123.8178, Epoch Time (s): 0.09, Total Time (hrs): 0.0614
# ====> Epoch: 1807 Train ELBO: 118.2744 Val ELBO: 129.9620, Epoch Time (s): 0.08, Total Time (hrs): 0.0614
# ====> Epoch: 1808 Train ELBO: 122.7342 Val ELBO: 128.8479, Epoch Time (s): 0.08, Total Time (hrs): 0.0614
# ====> Epoch: 1809 Train ELBO: 122.7627 Val ELBO: 132.4874, Epoch Time (s): 0.10, Total Time (hrs): 0.0615
# ====> Epoch: 1810 Train ELBO: 120.4475 Val ELBO: 123.6952, Epoch Time (s): 0.09, Total Time (hrs): 0.0615
# ====> Epoch: 1811 Train ELBO: 110.9687 Val ELBO: 111.7312, Epoch Time (s): 0.09, Total Time (hrs): 0.0615
# ====> Epoch: 1812 Train ELBO: 114.3421 Val ELBO: 133.0045, Epoch Time (s): 0.09, Total Time (hrs): 0.0615
# ====> Epoch: 1813 Train ELBO: 117.0993 Val ELBO: 123.0342, Epoch Time (s): 0.09, Total Time (hrs): 0.0616
# ====> Epoch: 1814 Train ELBO: 118.2461 Val ELBO: 114.0896, Epoch Time (s): 0.09, Total Time (hrs): 0.0616
# ====> Epoch: 1815 Train ELBO: 115.5564 Val ELBO: 129.1451, Epoch Time (s): 0.08, Total Time (hrs): 0.0616
# ====> Epoch: 1816 Train ELBO: 118.1568 Val ELBO: 125.9956, Epoch Time (s): 0.09, Total Time (hrs): 0.0616
# ====> Epoch: 1817 Train ELBO: 111.9462 Val ELBO: 99.1762, Epoch Time (s): 0.09, Total Time (hrs): 0.0617
# ====> Epoch: 1818 Train ELBO: 92.4768 Val ELBO: 128.3938, Epoch Time (s): 0.09, Total Time (hrs): 0.0617
# ====> Epoch: 1819 Train ELBO: 106.3722 Val ELBO: 112.5593, Epoch Time (s): 0.09, Total Time (hrs): 0.0617
# ====> Epoch: 1820 Train ELBO: 115.7874 Val ELBO: 129.5697, Epoch Time (s): 0.10, Total Time (hrs): 0.0617
# ====> Epoch: 1821 Train ELBO: 118.9823 Val ELBO: 127.6061, Epoch Time (s): 0.09, Total Time (hrs): 0.0618
# ====> Epoch: 1822 Train ELBO: 120.6949 Val ELBO: 129.7900, Epoch Time (s): 0.09, Total Time (hrs): 0.0618
# ====> Epoch: 1823 Train ELBO: 122.8817 Val ELBO: 128.5797, Epoch Time (s): 0.09, Total Time (hrs): 0.0618
# ====> Epoch: 1824 Train ELBO: 119.8402 Val ELBO: 128.6392, Epoch Time (s): 0.09, Total Time (hrs): 0.0618
# ====> Epoch: 1825 Train ELBO: 118.5348 Val ELBO: 126.4725, Epoch Time (s): 0.09, Total Time (hrs): 0.0619
# ====> Epoch: 1826 Train ELBO: 119.3728 Val ELBO: 128.0985, Epoch Time (s): 0.09, Total Time (hrs): 0.0619
# ====> Epoch: 1827 Train ELBO: 120.5799 Val ELBO: 127.9212, Epoch Time (s): 0.08, Total Time (hrs): 0.0619
# ====> Epoch: 1828 Train ELBO: 114.7569 Val ELBO: 129.8925, Epoch Time (s): 0.09, Total Time (hrs): 0.0619
# ====> Epoch: 1829 Train ELBO: 117.6821 Val ELBO: 126.4849, Epoch Time (s): 0.08, Total Time (hrs): 0.0620
# ====> Epoch: 1830 Train ELBO: 114.8446 Val ELBO: 118.7867, Epoch Time (s): 0.09, Total Time (hrs): 0.0620
# ====> Epoch: 1831 Train ELBO: 110.4596 Val ELBO: 131.3791, Epoch Time (s): 0.10, Total Time (hrs): 0.0620
# ====> Epoch: 1832 Train ELBO: 118.5692 Val ELBO: 126.0153, Epoch Time (s): 0.10, Total Time (hrs): 0.0620
# ====> Epoch: 1833 Train ELBO: 120.6380 Val ELBO: 126.1198, Epoch Time (s): 0.08, Total Time (hrs): 0.0621
# ====> Epoch: 1834 Train ELBO: 117.1655 Val ELBO: 122.9316, Epoch Time (s): 0.09, Total Time (hrs): 0.0621
# ====> Epoch: 1835 Train ELBO: 112.2735 Val ELBO: 117.8233, Epoch Time (s): 0.09, Total Time (hrs): 0.0621
# ====> Epoch: 1836 Train ELBO: 116.9313 Val ELBO: 108.8680, Epoch Time (s): 0.09, Total Time (hrs): 0.0621
# ====> Epoch: 1837 Train ELBO: 111.0885 Val ELBO: 122.9914, Epoch Time (s): 0.09, Total Time (hrs): 0.0622
# ====> Epoch: 1838 Train ELBO: 112.2427 Val ELBO: 126.6663, Epoch Time (s): 0.09, Total Time (hrs): 0.0622
# ====> Epoch: 1839 Train ELBO: 116.9342 Val ELBO: 129.1469, Epoch Time (s): 0.08, Total Time (hrs): 0.0622
# ====> Epoch: 1840 Train ELBO: 122.4970 Val ELBO: 130.2455, Epoch Time (s): 0.09, Total Time (hrs): 0.0622
# ====> Epoch: 1841 Train ELBO: 119.9176 Val ELBO: 129.3396, Epoch Time (s): 0.08, Total Time (hrs): 0.0623
# ====> Epoch: 1842 Train ELBO: 120.3537 Val ELBO: 128.6841, Epoch Time (s): 0.09, Total Time (hrs): 0.0623
# ====> Epoch: 1843 Train ELBO: 121.1058 Val ELBO: 133.2387, Epoch Time (s): 0.10, Total Time (hrs): 0.0623
# ====> Epoch: 1844 Train ELBO: 116.6906 Val ELBO: 123.8275, Epoch Time (s): 0.09, Total Time (hrs): 0.0624
# ====> Epoch: 1845 Train ELBO: 119.6551 Val ELBO: 126.6367, Epoch Time (s): 0.09, Total Time (hrs): 0.0624
# ====> Epoch: 1846 Train ELBO: 115.9073 Val ELBO: 132.2232, Epoch Time (s): 0.09, Total Time (hrs): 0.0624
# ====> Epoch: 1847 Train ELBO: 118.7818 Val ELBO: 125.6891, Epoch Time (s): 0.08, Total Time (hrs): 0.0624
# ====> Epoch: 1848 Train ELBO: 120.9064 Val ELBO: 133.5376, Epoch Time (s): 0.09, Total Time (hrs): 0.0625
# ====> Epoch: 1849 Train ELBO: 118.5550 Val ELBO: 129.8715, Epoch Time (s): 0.08, Total Time (hrs): 0.0625
# ====> Epoch: 1850 Train ELBO: 121.8543 Val ELBO: 127.7101, Epoch Time (s): 0.09, Total Time (hrs): 0.0625
# ====> Epoch: 1851 Train ELBO: 122.0972 Val ELBO: 128.2483, Epoch Time (s): 0.09, Total Time (hrs): 0.0625
# ====> Epoch: 1852 Train ELBO: 120.9849 Val ELBO: 129.8796, Epoch Time (s): 0.09, Total Time (hrs): 0.0626
# ====> Epoch: 1853 Train ELBO: 117.4866 Val ELBO: 124.4365, Epoch Time (s): 0.10, Total Time (hrs): 0.0626
# ====> Epoch: 1854 Train ELBO: 121.7622 Val ELBO: 131.9105, Epoch Time (s): 0.10, Total Time (hrs): 0.0626
# ====> Epoch: 1855 Train ELBO: 122.9036 Val ELBO: 132.8988, Epoch Time (s): 0.09, Total Time (hrs): 0.0626
# ====> Epoch: 1856 Train ELBO: 119.0396 Val ELBO: 122.7584, Epoch Time (s): 0.09, Total Time (hrs): 0.0627
# ====> Epoch: 1857 Train ELBO: 120.2843 Val ELBO: 130.0631, Epoch Time (s): 0.09, Total Time (hrs): 0.0627
# ====> Epoch: 1858 Train ELBO: 120.8234 Val ELBO: 133.1825, Epoch Time (s): 0.09, Total Time (hrs): 0.0627
# ====> Epoch: 1859 Train ELBO: 119.4756 Val ELBO: 120.0202, Epoch Time (s): 0.09, Total Time (hrs): 0.0627
# ====> Epoch: 1860 Train ELBO: 118.1495 Val ELBO: 133.0484, Epoch Time (s): 0.09, Total Time (hrs): 0.0628
# ====> Epoch: 1861 Train ELBO: 121.6617 Val ELBO: 132.6714, Epoch Time (s): 0.09, Total Time (hrs): 0.0628
# ====> Epoch: 1862 Train ELBO: 114.5261 Val ELBO: 114.6394, Epoch Time (s): 0.09, Total Time (hrs): 0.0628
# ====> Epoch: 1863 Train ELBO: 107.4215 Val ELBO: 122.4046, Epoch Time (s): 0.08, Total Time (hrs): 0.0628
# ====> Epoch: 1864 Train ELBO: 119.9230 Val ELBO: 129.0962, Epoch Time (s): 0.09, Total Time (hrs): 0.0629
# ====> Epoch: 1865 Train ELBO: 121.4791 Val ELBO: 131.1362, Epoch Time (s): 0.10, Total Time (hrs): 0.0629
# ====> Epoch: 1866 Train ELBO: 120.7341 Val ELBO: 128.5694, Epoch Time (s): 0.09, Total Time (hrs): 0.0629
# ====> Epoch: 1867 Train ELBO: 121.0315 Val ELBO: 129.5894, Epoch Time (s): 0.09, Total Time (hrs): 0.0629
# ====> Epoch: 1868 Train ELBO: 119.3122 Val ELBO: 125.9601, Epoch Time (s): 0.09, Total Time (hrs): 0.0630
# ====> Epoch: 1869 Train ELBO: 119.9698 Val ELBO: 132.9309, Epoch Time (s): 0.10, Total Time (hrs): 0.0630
# ====> Epoch: 1870 Train ELBO: 121.5501 Val ELBO: 125.0274, Epoch Time (s): 0.09, Total Time (hrs): 0.0630
# ====> Epoch: 1871 Train ELBO: 119.9975 Val ELBO: 130.5334, Epoch Time (s): 0.09, Total Time (hrs): 0.0630
# ====> Epoch: 1872 Train ELBO: 121.8300 Val ELBO: 126.7243, Epoch Time (s): 0.09, Total Time (hrs): 0.0631
# ====> Epoch: 1873 Train ELBO: 120.4790 Val ELBO: 130.0602, Epoch Time (s): 0.09, Total Time (hrs): 0.0631
# ====> Epoch: 1874 Train ELBO: 121.3508 Val ELBO: 129.3490, Epoch Time (s): 0.09, Total Time (hrs): 0.0631
# ====> Epoch: 1875 Train ELBO: 121.6057 Val ELBO: 132.4048, Epoch Time (s): 0.09, Total Time (hrs): 0.0631
# ====> Epoch: 1876 Train ELBO: 125.4196 Val ELBO: 132.5487, Epoch Time (s): 0.09, Total Time (hrs): 0.0632
# ====> Epoch: 1877 Train ELBO: 124.5063 Val ELBO: 128.6154, Epoch Time (s): 0.10, Total Time (hrs): 0.0632
# ====> Epoch: 1878 Train ELBO: 124.1634 Val ELBO: 130.1537, Epoch Time (s): 0.09, Total Time (hrs): 0.0632
# ====> Epoch: 1879 Train ELBO: 123.1881 Val ELBO: 125.4472, Epoch Time (s): 0.12, Total Time (hrs): 0.0633
# ====> Epoch: 1880 Train ELBO: 122.1375 Val ELBO: 131.1889, Epoch Time (s): 0.14, Total Time (hrs): 0.0633
# ====> Epoch: 1881 Train ELBO: 123.1893 Val ELBO: 130.6240, Epoch Time (s): 0.13, Total Time (hrs): 0.0633
# ====> Epoch: 1882 Train ELBO: 123.3428 Val ELBO: 130.6700, Epoch Time (s): 0.13, Total Time (hrs): 0.0634
# ====> Epoch: 1883 Train ELBO: 119.6626 Val ELBO: 119.4859, Epoch Time (s): 0.14, Total Time (hrs): 0.0634
# ====> Epoch: 1884 Train ELBO: 118.4817 Val ELBO: 130.8139, Epoch Time (s): 0.13, Total Time (hrs): 0.0634
# ====> Epoch: 1885 Train ELBO: 117.7448 Val ELBO: 104.7238, Epoch Time (s): 0.15, Total Time (hrs): 0.0635
# ====> Epoch: 1886 Train ELBO: 103.3984 Val ELBO: 120.2684, Epoch Time (s): 0.13, Total Time (hrs): 0.0635
# ====> Epoch: 1887 Train ELBO: 92.3630 Val ELBO: 116.9691, Epoch Time (s): 0.13, Total Time (hrs): 0.0636
# ====> Epoch: 1888 Train ELBO: 111.6434 Val ELBO: 123.7024, Epoch Time (s): 0.12, Total Time (hrs): 0.0636
# ====> Epoch: 1889 Train ELBO: 109.7732 Val ELBO: 132.1837, Epoch Time (s): 0.13, Total Time (hrs): 0.0636
# ====> Epoch: 1890 Train ELBO: 113.2848 Val ELBO: 123.3046, Epoch Time (s): 0.13, Total Time (hrs): 0.0637
# ====> Epoch: 1891 Train ELBO: 117.4432 Val ELBO: 118.8271, Epoch Time (s): 0.14, Total Time (hrs): 0.0637
# ====> Epoch: 1892 Train ELBO: 117.1509 Val ELBO: 128.0935, Epoch Time (s): 0.13, Total Time (hrs): 0.0637
# ====> Epoch: 1893 Train ELBO: 118.7084 Val ELBO: 115.2773, Epoch Time (s): 0.15, Total Time (hrs): 0.0638
# ====> Epoch: 1894 Train ELBO: 117.6808 Val ELBO: 133.1032, Epoch Time (s): 0.13, Total Time (hrs): 0.0638
# ====> Epoch: 1895 Train ELBO: 116.8492 Val ELBO: 121.0521, Epoch Time (s): 0.14, Total Time (hrs): 0.0639
# ====> Epoch: 1896 Train ELBO: 120.9120 Val ELBO: 132.7572, Epoch Time (s): 0.12, Total Time (hrs): 0.0639
# ====> Epoch: 1897 Train ELBO: 123.1167 Val ELBO: 129.4804, Epoch Time (s): 0.13, Total Time (hrs): 0.0639
# ====> Epoch: 1898 Train ELBO: 121.1316 Val ELBO: 130.2154, Epoch Time (s): 0.13, Total Time (hrs): 0.0640
# ====> Epoch: 1899 Train ELBO: 121.4751 Val ELBO: 132.7289, Epoch Time (s): 0.14, Total Time (hrs): 0.0640
# ====> Epoch: 1900 Train ELBO: 121.9285 Val ELBO: 127.8022, Epoch Time (s): 0.13, Total Time (hrs): 0.0640
# ====> Epoch: 1901 Train ELBO: 123.8407 Val ELBO: 133.5973, Epoch Time (s): 0.16, Total Time (hrs): 0.0641
# ====> Epoch: 1902 Train ELBO: 122.6706 Val ELBO: 121.1317, Epoch Time (s): 0.13, Total Time (hrs): 0.0641
# ====> Epoch: 1903 Train ELBO: 115.4007 Val ELBO: 131.9917, Epoch Time (s): 0.15, Total Time (hrs): 0.0642
# ====> Epoch: 1904 Train ELBO: 120.6390 Val ELBO: 128.1140, Epoch Time (s): 0.15, Total Time (hrs): 0.0642
# ====> Epoch: 1905 Train ELBO: 119.2862 Val ELBO: 132.2532, Epoch Time (s): 0.16, Total Time (hrs): 0.0643
# ====> Epoch: 1906 Train ELBO: 121.7259 Val ELBO: 124.3224, Epoch Time (s): 0.11, Total Time (hrs): 0.0643
# ====> Epoch: 1907 Train ELBO: 122.1949 Val ELBO: 132.0800, Epoch Time (s): 0.09, Total Time (hrs): 0.0643
# ====> Epoch: 1908 Train ELBO: 122.4307 Val ELBO: 133.6938, Epoch Time (s): 0.10, Total Time (hrs): 0.0643
# ====> Epoch: 1909 Train ELBO: 122.2839 Val ELBO: 125.0694, Epoch Time (s): 0.11, Total Time (hrs): 0.0644
# ====> Epoch: 1910 Train ELBO: 121.4191 Val ELBO: 131.0647, Epoch Time (s): 0.10, Total Time (hrs): 0.0644
# ====> Epoch: 1911 Train ELBO: 122.8395 Val ELBO: 131.2359, Epoch Time (s): 0.09, Total Time (hrs): 0.0644
# ====> Epoch: 1912 Train ELBO: 121.3372 Val ELBO: 132.8437, Epoch Time (s): 0.09, Total Time (hrs): 0.0645
# ====> Epoch: 1913 Train ELBO: 119.9772 Val ELBO: 131.2262, Epoch Time (s): 0.09, Total Time (hrs): 0.0645
# ====> Epoch: 1914 Train ELBO: 125.1087 Val ELBO: 134.4923, Epoch Time (s): 0.09, Total Time (hrs): 0.0645
# ====> Epoch: 1915 Train ELBO: 125.8647 Val ELBO: 132.1855, Epoch Time (s): 0.09, Total Time (hrs): 0.0645
# ====> Epoch: 1916 Train ELBO: 122.1340 Val ELBO: 133.0877, Epoch Time (s): 0.09, Total Time (hrs): 0.0646
# ====> Epoch: 1917 Train ELBO: 121.3446 Val ELBO: 125.8473, Epoch Time (s): 0.08, Total Time (hrs): 0.0646
# ====> Epoch: 1918 Train ELBO: 120.4591 Val ELBO: 124.6791, Epoch Time (s): 0.09, Total Time (hrs): 0.0646
# ====> Epoch: 1919 Train ELBO: 111.6699 Val ELBO: 125.9138, Epoch Time (s): 0.09, Total Time (hrs): 0.0646
# ====> Epoch: 1920 Train ELBO: 118.1516 Val ELBO: 126.1719, Epoch Time (s): 0.10, Total Time (hrs): 0.0647
# ====> Epoch: 1921 Train ELBO: 120.6026 Val ELBO: 134.2171, Epoch Time (s): 0.09, Total Time (hrs): 0.0647
# ====> Epoch: 1922 Train ELBO: 115.5600 Val ELBO: 129.4879, Epoch Time (s): 0.08, Total Time (hrs): 0.0647
# ====> Epoch: 1923 Train ELBO: 113.0473 Val ELBO: 133.7881, Epoch Time (s): 0.09, Total Time (hrs): 0.0647
# ====> Epoch: 1924 Train ELBO: 119.0744 Val ELBO: 116.2709, Epoch Time (s): 0.10, Total Time (hrs): 0.0648
# ====> Epoch: 1925 Train ELBO: 115.3077 Val ELBO: 121.3983, Epoch Time (s): 0.09, Total Time (hrs): 0.0648
# ====> Epoch: 1926 Train ELBO: 117.3363 Val ELBO: 131.7759, Epoch Time (s): 0.09, Total Time (hrs): 0.0648
# ====> Epoch: 1927 Train ELBO: 124.0119 Val ELBO: 131.8779, Epoch Time (s): 0.09, Total Time (hrs): 0.0648
# ====> Epoch: 1928 Train ELBO: 119.9998 Val ELBO: 130.7782, Epoch Time (s): 0.09, Total Time (hrs): 0.0649
# ====> Epoch: 1929 Train ELBO: 121.6465 Val ELBO: 128.7831, Epoch Time (s): 0.09, Total Time (hrs): 0.0649
# ====> Epoch: 1930 Train ELBO: 121.9171 Val ELBO: 132.8136, Epoch Time (s): 0.09, Total Time (hrs): 0.0649
# ====> Epoch: 1931 Train ELBO: 117.1842 Val ELBO: 132.0125, Epoch Time (s): 0.10, Total Time (hrs): 0.0649
# ====> Epoch: 1932 Train ELBO: 119.5391 Val ELBO: 127.1905, Epoch Time (s): 0.09, Total Time (hrs): 0.0650
# ====> Epoch: 1933 Train ELBO: 122.7353 Val ELBO: 132.7686, Epoch Time (s): 0.09, Total Time (hrs): 0.0650
# ====> Epoch: 1934 Train ELBO: 125.0174 Val ELBO: 135.3275, Epoch Time (s): 0.09, Total Time (hrs): 0.0650
# ====> Epoch: 1935 Train ELBO: 125.4072 Val ELBO: 122.5254, Epoch Time (s): 0.10, Total Time (hrs): 0.0651
# ====> Epoch: 1936 Train ELBO: 120.4344 Val ELBO: 131.5437, Epoch Time (s): 0.09, Total Time (hrs): 0.0651
# ====> Epoch: 1937 Train ELBO: 123.4588 Val ELBO: 132.8349, Epoch Time (s): 0.09, Total Time (hrs): 0.0651
# ====> Epoch: 1938 Train ELBO: 124.3538 Val ELBO: 134.4827, Epoch Time (s): 0.09, Total Time (hrs): 0.0651
# ====> Epoch: 1939 Train ELBO: 124.4831 Val ELBO: 125.5378, Epoch Time (s): 0.09, Total Time (hrs): 0.0652
# ====> Epoch: 1940 Train ELBO: 123.2441 Val ELBO: 131.9799, Epoch Time (s): 0.09, Total Time (hrs): 0.0652
# ====> Epoch: 1941 Train ELBO: 124.6778 Val ELBO: 132.7018, Epoch Time (s): 0.09, Total Time (hrs): 0.0652
# ====> Epoch: 1942 Train ELBO: 125.6703 Val ELBO: 128.4639, Epoch Time (s): 0.10, Total Time (hrs): 0.0652
# ====> Epoch: 1943 Train ELBO: 121.7960 Val ELBO: 135.1748, Epoch Time (s): 0.08, Total Time (hrs): 0.0653
# ====> Epoch: 1944 Train ELBO: 121.9886 Val ELBO: 114.6874, Epoch Time (s): 0.09, Total Time (hrs): 0.0653
# ====> Epoch: 1945 Train ELBO: 115.2708 Val ELBO: 127.2749, Epoch Time (s): 0.09, Total Time (hrs): 0.0653
# ====> Epoch: 1946 Train ELBO: 109.5372 Val ELBO: 124.4107, Epoch Time (s): 0.09, Total Time (hrs): 0.0653
# ====> Epoch: 1947 Train ELBO: 108.4123 Val ELBO: 86.1518, Epoch Time (s): 0.10, Total Time (hrs): 0.0654
# ====> Epoch: 1948 Train ELBO: 104.8104 Val ELBO: 132.0355, Epoch Time (s): 0.13, Total Time (hrs): 0.0654
# ====> Epoch: 1949 Train ELBO: 120.2601 Val ELBO: 118.7042, Epoch Time (s): 0.09, Total Time (hrs): 0.0654
# ====> Epoch: 1950 Train ELBO: 111.4412 Val ELBO: 106.8757, Epoch Time (s): 0.09, Total Time (hrs): 0.0654
# ====> Epoch: 1951 Train ELBO: 113.2596 Val ELBO: 128.2513, Epoch Time (s): 0.09, Total Time (hrs): 0.0655
# ====> Epoch: 1952 Train ELBO: 116.8054 Val ELBO: 133.6189, Epoch Time (s): 0.10, Total Time (hrs): 0.0655
# ====> Epoch: 1953 Train ELBO: 117.2773 Val ELBO: 125.6807, Epoch Time (s): 0.11, Total Time (hrs): 0.0655
# ====> Epoch: 1954 Train ELBO: 120.0642 Val ELBO: 115.7791, Epoch Time (s): 0.10, Total Time (hrs): 0.0656
# ====> Epoch: 1955 Train ELBO: 115.4173 Val ELBO: 130.0155, Epoch Time (s): 0.09, Total Time (hrs): 0.0656
# ====> Epoch: 1956 Train ELBO: 125.5643 Val ELBO: 131.8711, Epoch Time (s): 0.08, Total Time (hrs): 0.0656
# ====> Epoch: 1957 Train ELBO: 124.7638 Val ELBO: 133.8537, Epoch Time (s): 0.10, Total Time (hrs): 0.0656
# ====> Epoch: 1958 Train ELBO: 122.9251 Val ELBO: 131.2230, Epoch Time (s): 0.09, Total Time (hrs): 0.0657
# ====> Epoch: 1959 Train ELBO: 125.8737 Val ELBO: 133.1795, Epoch Time (s): 0.09, Total Time (hrs): 0.0657
# ====> Epoch: 1960 Train ELBO: 124.5973 Val ELBO: 131.0102, Epoch Time (s): 0.09, Total Time (hrs): 0.0657
# ====> Epoch: 1961 Train ELBO: 121.9688 Val ELBO: 133.0083, Epoch Time (s): 0.09, Total Time (hrs): 0.0657
# ====> Epoch: 1962 Train ELBO: 122.8882 Val ELBO: 134.8202, Epoch Time (s): 0.09, Total Time (hrs): 0.0658
# ====> Epoch: 1963 Train ELBO: 120.6841 Val ELBO: 134.3983, Epoch Time (s): 0.09, Total Time (hrs): 0.0658
# ====> Epoch: 1964 Train ELBO: 121.8178 Val ELBO: 131.5847, Epoch Time (s): 0.09, Total Time (hrs): 0.0658
# ====> Epoch: 1965 Train ELBO: 125.2030 Val ELBO: 133.2540, Epoch Time (s): 0.09, Total Time (hrs): 0.0658
# ====> Epoch: 1966 Train ELBO: 125.9173 Val ELBO: 132.3517, Epoch Time (s): 0.10, Total Time (hrs): 0.0659
# ====> Epoch: 1967 Train ELBO: 125.1972 Val ELBO: 134.9018, Epoch Time (s): 0.09, Total Time (hrs): 0.0659
# ====> Epoch: 1968 Train ELBO: 123.8313 Val ELBO: 124.4313, Epoch Time (s): 0.09, Total Time (hrs): 0.0659
# ====> Epoch: 1969 Train ELBO: 120.6593 Val ELBO: 129.8383, Epoch Time (s): 0.09, Total Time (hrs): 0.0659
# ====> Epoch: 1970 Train ELBO: 121.7402 Val ELBO: 131.1970, Epoch Time (s): 0.09, Total Time (hrs): 0.0660
# ====> Epoch: 1971 Train ELBO: 122.5636 Val ELBO: 132.0377, Epoch Time (s): 0.09, Total Time (hrs): 0.0660
# ====> Epoch: 1972 Train ELBO: 116.5682 Val ELBO: 128.8222, Epoch Time (s): 0.09, Total Time (hrs): 0.0660
# ====> Epoch: 1973 Train ELBO: 121.3427 Val ELBO: 122.7727, Epoch Time (s): 0.09, Total Time (hrs): 0.0660
# ====> Epoch: 1974 Train ELBO: 122.2330 Val ELBO: 131.7842, Epoch Time (s): 0.09, Total Time (hrs): 0.0661
# ====> Epoch: 1975 Train ELBO: 118.7865 Val ELBO: 128.0141, Epoch Time (s): 0.09, Total Time (hrs): 0.0661
# ====> Epoch: 1976 Train ELBO: 116.7127 Val ELBO: 134.1430, Epoch Time (s): 0.11, Total Time (hrs): 0.0661
# ====> Epoch: 1977 Train ELBO: 122.7668 Val ELBO: 126.5167, Epoch Time (s): 0.09, Total Time (hrs): 0.0661
# ====> Epoch: 1978 Train ELBO: 119.9622 Val ELBO: 120.4546, Epoch Time (s): 0.10, Total Time (hrs): 0.0662
# ====> Epoch: 1979 Train ELBO: 117.8582 Val ELBO: 127.9099, Epoch Time (s): 0.08, Total Time (hrs): 0.0662
# ====> Epoch: 1980 Train ELBO: 122.5758 Val ELBO: 134.2039, Epoch Time (s): 0.08, Total Time (hrs): 0.0662
# ====> Epoch: 1981 Train ELBO: 120.9256 Val ELBO: 126.0362, Epoch Time (s): 0.09, Total Time (hrs): 0.0662
# ====> Epoch: 1982 Train ELBO: 112.1795 Val ELBO: 128.5037, Epoch Time (s): 0.08, Total Time (hrs): 0.0663
# ====> Epoch: 1983 Train ELBO: 118.1852 Val ELBO: 116.0737, Epoch Time (s): 0.08, Total Time (hrs): 0.0663
# ====> Epoch: 1984 Train ELBO: 117.7539 Val ELBO: 128.9925, Epoch Time (s): 0.09, Total Time (hrs): 0.0663
# ====> Epoch: 1985 Train ELBO: 121.1646 Val ELBO: 126.8754, Epoch Time (s): 0.09, Total Time (hrs): 0.0663
# ====> Epoch: 1986 Train ELBO: 116.6701 Val ELBO: 123.6159, Epoch Time (s): 0.09, Total Time (hrs): 0.0664
# ====> Epoch: 1987 Train ELBO: 120.5486 Val ELBO: 133.8071, Epoch Time (s): 0.10, Total Time (hrs): 0.0664
# ====> Epoch: 1988 Train ELBO: 122.0304 Val ELBO: 130.5903, Epoch Time (s): 0.10, Total Time (hrs): 0.0664
# ====> Epoch: 1989 Train ELBO: 121.2667 Val ELBO: 134.8287, Epoch Time (s): 0.09, Total Time (hrs): 0.0664
# ====> Epoch: 1990 Train ELBO: 117.8162 Val ELBO: 126.7331, Epoch Time (s): 0.10, Total Time (hrs): 0.0665
# ====> Epoch: 1991 Train ELBO: 115.9081 Val ELBO: 107.1225, Epoch Time (s): 0.09, Total Time (hrs): 0.0665
# ====> Epoch: 1992 Train ELBO: 116.2786 Val ELBO: 131.1364, Epoch Time (s): 0.08, Total Time (hrs): 0.0665
# ====> Epoch: 1993 Train ELBO: 123.1626 Val ELBO: 133.1929, Epoch Time (s): 0.09, Total Time (hrs): 0.0665
# ====> Epoch: 1994 Train ELBO: 126.1299 Val ELBO: 126.7099, Epoch Time (s): 0.08, Total Time (hrs): 0.0666
# ====> Epoch: 1995 Train ELBO: 122.2034 Val ELBO: 130.6303, Epoch Time (s): 0.09, Total Time (hrs): 0.0666
# ====> Epoch: 1996 Train ELBO: 122.0884 Val ELBO: 129.9824, Epoch Time (s): 0.09, Total Time (hrs): 0.0666
# ====> Epoch: 1997 Train ELBO: 123.8867 Val ELBO: 134.1061, Epoch Time (s): 0.08, Total Time (hrs): 0.0666
# ====> Epoch: 1998 Train ELBO: 126.3695 Val ELBO: 134.8745, Epoch Time (s): 0.09, Total Time (hrs): 0.0667
# ====> Epoch: 1999 Train ELBO: 126.3679 Val ELBO: 133.8592, Epoch Time (s): 0.10, Total Time (hrs): 0.0667
# 3
# 0
# 1
# 2
# 3
# 0
# 1
# 2
# ====> Epoch: 2000 Train ELBO: 121.1497 Val ELBO: 119.7690, Epoch Time (s): 4.86, Total Time (hrs): 0.0680
# ====> Epoch: 2001 Train ELBO: 119.6713 Val ELBO: 132.6190, Epoch Time (s): 0.10, Total Time (hrs): 0.0687
# ====> Epoch: 2002 Train ELBO: 118.7142 Val ELBO: 127.5416, Epoch Time (s): 0.09, Total Time (hrs): 0.0688
# ====> Epoch: 2003 Train ELBO: 122.4182 Val ELBO: 125.8525, Epoch Time (s): 0.09, Total Time (hrs): 0.0688
# ====> Epoch: 2004 Train ELBO: 119.9151 Val ELBO: 130.7122, Epoch Time (s): 0.10, Total Time (hrs): 0.0688
# ====> Epoch: 2005 Train ELBO: 126.1860 Val ELBO: 132.4311, Epoch Time (s): 0.08, Total Time (hrs): 0.0688
# ====> Epoch: 2006 Train ELBO: 125.6980 Val ELBO: 132.5628, Epoch Time (s): 0.08, Total Time (hrs): 0.0689
# ====> Epoch: 2007 Train ELBO: 124.6225 Val ELBO: 131.5435, Epoch Time (s): 0.10, Total Time (hrs): 0.0689
# ====> Epoch: 2008 Train ELBO: 121.6148 Val ELBO: 128.2676, Epoch Time (s): 0.09, Total Time (hrs): 0.0689
# ====> Epoch: 2009 Train ELBO: 120.8045 Val ELBO: 128.9947, Epoch Time (s): 0.09, Total Time (hrs): 0.0689
# ====> Epoch: 2010 Train ELBO: 115.3547 Val ELBO: 107.2247, Epoch Time (s): 0.10, Total Time (hrs): 0.0690
# ====> Epoch: 2011 Train ELBO: 117.9579 Val ELBO: 133.6120, Epoch Time (s): 0.09, Total Time (hrs): 0.0690
# ====> Epoch: 2012 Train ELBO: 126.1559 Val ELBO: 130.2007, Epoch Time (s): 0.09, Total Time (hrs): 0.0690
# ====> Epoch: 2013 Train ELBO: 124.6152 Val ELBO: 131.9446, Epoch Time (s): 0.10, Total Time (hrs): 0.0690
# ====> Epoch: 2014 Train ELBO: 118.7318 Val ELBO: 126.4094, Epoch Time (s): 0.08, Total Time (hrs): 0.0691
# ====> Epoch: 2015 Train ELBO: 123.6064 Val ELBO: 127.4977, Epoch Time (s): 0.08, Total Time (hrs): 0.0691
# ====> Epoch: 2016 Train ELBO: 123.9427 Val ELBO: 135.3534, Epoch Time (s): 0.09, Total Time (hrs): 0.0691
# ====> Epoch: 2017 Train ELBO: 125.2236 Val ELBO: 134.8479, Epoch Time (s): 0.09, Total Time (hrs): 0.0691
# ====> Epoch: 2018 Train ELBO: 126.6153 Val ELBO: 135.6376, Epoch Time (s): 0.09, Total Time (hrs): 0.0692
# ====> Epoch: 2019 Train ELBO: 124.6886 Val ELBO: 133.8162, Epoch Time (s): 0.09, Total Time (hrs): 0.0692
# ====> Epoch: 2020 Train ELBO: 125.8191 Val ELBO: 133.3071, Epoch Time (s): 0.09, Total Time (hrs): 0.0692
# ====> Epoch: 2021 Train ELBO: 125.3901 Val ELBO: 128.4189, Epoch Time (s): 0.09, Total Time (hrs): 0.0693
# ====> Epoch: 2022 Train ELBO: 121.2327 Val ELBO: 133.5642, Epoch Time (s): 0.09, Total Time (hrs): 0.0693
# ====> Epoch: 2023 Train ELBO: 119.8090 Val ELBO: 129.3789, Epoch Time (s): 0.10, Total Time (hrs): 0.0693
# ====> Epoch: 2024 Train ELBO: 119.8696 Val ELBO: 129.7749, Epoch Time (s): 0.09, Total Time (hrs): 0.0693
# ====> Epoch: 2025 Train ELBO: 118.5842 Val ELBO: 126.4163, Epoch Time (s): 0.09, Total Time (hrs): 0.0694
# ====> Epoch: 2026 Train ELBO: 113.2282 Val ELBO: 126.2564, Epoch Time (s): 0.10, Total Time (hrs): 0.0694
# ====> Epoch: 2027 Train ELBO: 120.0238 Val ELBO: 123.6953, Epoch Time (s): 0.09, Total Time (hrs): 0.0694
# ====> Epoch: 2028 Train ELBO: 120.4490 Val ELBO: 127.4242, Epoch Time (s): 0.09, Total Time (hrs): 0.0694
# ====> Epoch: 2029 Train ELBO: 118.6438 Val ELBO: 131.6374, Epoch Time (s): 0.09, Total Time (hrs): 0.0695
# ====> Epoch: 2030 Train ELBO: 122.0987 Val ELBO: 131.2653, Epoch Time (s): 0.09, Total Time (hrs): 0.0695
# ====> Epoch: 2031 Train ELBO: 123.8087 Val ELBO: 131.3960, Epoch Time (s): 0.09, Total Time (hrs): 0.0695
# ====> Epoch: 2032 Train ELBO: 121.4943 Val ELBO: 134.3850, Epoch Time (s): 0.10, Total Time (hrs): 0.0695
# ====> Epoch: 2033 Train ELBO: 124.1682 Val ELBO: 124.0713, Epoch Time (s): 0.09, Total Time (hrs): 0.0696
# ====> Epoch: 2034 Train ELBO: 122.6219 Val ELBO: 129.3279, Epoch Time (s): 0.08, Total Time (hrs): 0.0696
# ====> Epoch: 2035 Train ELBO: 124.0439 Val ELBO: 129.3894, Epoch Time (s): 0.11, Total Time (hrs): 0.0696
# ====> Epoch: 2036 Train ELBO: 120.3190 Val ELBO: 131.1006, Epoch Time (s): 0.09, Total Time (hrs): 0.0696
# ====> Epoch: 2037 Train ELBO: 125.8871 Val ELBO: 131.3986, Epoch Time (s): 0.09, Total Time (hrs): 0.0697
# ====> Epoch: 2038 Train ELBO: 124.2237 Val ELBO: 133.9662, Epoch Time (s): 0.09, Total Time (hrs): 0.0697
# ====> Epoch: 2039 Train ELBO: 121.9201 Val ELBO: 127.2747, Epoch Time (s): 0.09, Total Time (hrs): 0.0697
# ====> Epoch: 2040 Train ELBO: 124.7210 Val ELBO: 134.2777, Epoch Time (s): 0.09, Total Time (hrs): 0.0697
# ====> Epoch: 2041 Train ELBO: 126.4749 Val ELBO: 133.1816, Epoch Time (s): 0.10, Total Time (hrs): 0.0698
# ====> Epoch: 2042 Train ELBO: 127.0471 Val ELBO: 131.5824, Epoch Time (s): 0.09, Total Time (hrs): 0.0698
# ====> Epoch: 2043 Train ELBO: 123.1042 Val ELBO: 125.5339, Epoch Time (s): 0.09, Total Time (hrs): 0.0698
# ====> Epoch: 2044 Train ELBO: 122.9224 Val ELBO: 126.6468, Epoch Time (s): 0.09, Total Time (hrs): 0.0698
# ====> Epoch: 2045 Train ELBO: 124.1196 Val ELBO: 131.7305, Epoch Time (s): 0.09, Total Time (hrs): 0.0699
# ====> Epoch: 2046 Train ELBO: 121.7424 Val ELBO: 126.1627, Epoch Time (s): 0.10, Total Time (hrs): 0.0699
# ====> Epoch: 2047 Train ELBO: 123.4764 Val ELBO: 133.5775, Epoch Time (s): 0.09, Total Time (hrs): 0.0699
# ====> Epoch: 2048 Train ELBO: 124.1650 Val ELBO: 133.9300, Epoch Time (s): 0.09, Total Time (hrs): 0.0699
# ====> Epoch: 2049 Train ELBO: 126.9817 Val ELBO: 134.7313, Epoch Time (s): 0.08, Total Time (hrs): 0.0700
# ====> Epoch: 2050 Train ELBO: 124.4665 Val ELBO: 133.7808, Epoch Time (s): 0.09, Total Time (hrs): 0.0700
# ====> Epoch: 2051 Train ELBO: 124.5436 Val ELBO: 123.8033, Epoch Time (s): 0.09, Total Time (hrs): 0.0700
# ====> Epoch: 2052 Train ELBO: 112.5449 Val ELBO: 95.6658, Epoch Time (s): 0.09, Total Time (hrs): 0.0700
# ====> Epoch: 2053 Train ELBO: 116.6268 Val ELBO: 136.9794, Epoch Time (s): 0.10, Total Time (hrs): 0.0701
# ====> Epoch: 2054 Train ELBO: 127.5535 Val ELBO: 135.2541, Epoch Time (s): 0.09, Total Time (hrs): 0.0701
# ====> Epoch: 2055 Train ELBO: 125.5397 Val ELBO: 134.8918, Epoch Time (s): 0.09, Total Time (hrs): 0.0701
# ====> Epoch: 2056 Train ELBO: 125.1304 Val ELBO: 133.7657, Epoch Time (s): 0.08, Total Time (hrs): 0.0702
# ====> Epoch: 2057 Train ELBO: 126.7758 Val ELBO: 132.0233, Epoch Time (s): 0.11, Total Time (hrs): 0.0702
# ====> Epoch: 2058 Train ELBO: 123.8354 Val ELBO: 132.1819, Epoch Time (s): 0.09, Total Time (hrs): 0.0702
# ====> Epoch: 2059 Train ELBO: 112.0674 Val ELBO: 133.0159, Epoch Time (s): 0.08, Total Time (hrs): 0.0702
# ====> Epoch: 2060 Train ELBO: 121.0714 Val ELBO: 133.2910, Epoch Time (s): 0.08, Total Time (hrs): 0.0703
# ====> Epoch: 2061 Train ELBO: 123.5035 Val ELBO: 122.0227, Epoch Time (s): 0.09, Total Time (hrs): 0.0703
# ====> Epoch: 2062 Train ELBO: 109.3484 Val ELBO: 121.4080, Epoch Time (s): 0.09, Total Time (hrs): 0.0703
# ====> Epoch: 2063 Train ELBO: 113.8936 Val ELBO: 121.1525, Epoch Time (s): 0.09, Total Time (hrs): 0.0703
# ====> Epoch: 2064 Train ELBO: 119.6575 Val ELBO: 115.0953, Epoch Time (s): 0.09, Total Time (hrs): 0.0704
# ====> Epoch: 2065 Train ELBO: 112.3500 Val ELBO: 125.3734, Epoch Time (s): 0.09, Total Time (hrs): 0.0704
# ====> Epoch: 2066 Train ELBO: 118.3895 Val ELBO: 130.6336, Epoch Time (s): 0.09, Total Time (hrs): 0.0704
# ====> Epoch: 2067 Train ELBO: 120.0126 Val ELBO: 135.5271, Epoch Time (s): 0.09, Total Time (hrs): 0.0704
# ====> Epoch: 2068 Train ELBO: 124.3343 Val ELBO: 135.8210, Epoch Time (s): 0.09, Total Time (hrs): 0.0705
# ====> Epoch: 2069 Train ELBO: 121.8876 Val ELBO: 115.3280, Epoch Time (s): 0.10, Total Time (hrs): 0.0705
# ====> Epoch: 2070 Train ELBO: 117.4594 Val ELBO: 129.6599, Epoch Time (s): 0.09, Total Time (hrs): 0.0705
# ====> Epoch: 2071 Train ELBO: 122.2427 Val ELBO: 125.6138, Epoch Time (s): 0.08, Total Time (hrs): 0.0705
# ====> Epoch: 2072 Train ELBO: 119.6635 Val ELBO: 125.9828, Epoch Time (s): 0.08, Total Time (hrs): 0.0706
# ====> Epoch: 2073 Train ELBO: 121.3608 Val ELBO: 131.6470, Epoch Time (s): 0.09, Total Time (hrs): 0.0706
# ====> Epoch: 2074 Train ELBO: 114.8844 Val ELBO: 123.7872, Epoch Time (s): 0.09, Total Time (hrs): 0.0706
# ====> Epoch: 2075 Train ELBO: 121.9738 Val ELBO: 135.7881, Epoch Time (s): 0.09, Total Time (hrs): 0.0706
# ====> Epoch: 2076 Train ELBO: 125.7260 Val ELBO: 132.0244, Epoch Time (s): 0.09, Total Time (hrs): 0.0707
# ====> Epoch: 2077 Train ELBO: 124.3560 Val ELBO: 132.2862, Epoch Time (s): 0.09, Total Time (hrs): 0.0707
# ====> Epoch: 2078 Train ELBO: 127.0438 Val ELBO: 129.4601, Epoch Time (s): 0.08, Total Time (hrs): 0.0707
# ====> Epoch: 2079 Train ELBO: 121.7363 Val ELBO: 123.7025, Epoch Time (s): 0.09, Total Time (hrs): 0.0707
# ====> Epoch: 2080 Train ELBO: 120.9061 Val ELBO: 132.5562, Epoch Time (s): 0.10, Total Time (hrs): 0.0708
# ====> Epoch: 2081 Train ELBO: 116.2463 Val ELBO: 121.9879, Epoch Time (s): 0.09, Total Time (hrs): 0.0708
# ====> Epoch: 2082 Train ELBO: 103.7111 Val ELBO: 117.4543, Epoch Time (s): 0.09, Total Time (hrs): 0.0708
# ====> Epoch: 2083 Train ELBO: 111.2789 Val ELBO: 127.7179, Epoch Time (s): 0.08, Total Time (hrs): 0.0708
# ====> Epoch: 2084 Train ELBO: 118.7740 Val ELBO: 134.4453, Epoch Time (s): 0.09, Total Time (hrs): 0.0708
# ====> Epoch: 2085 Train ELBO: 121.2536 Val ELBO: 132.7714, Epoch Time (s): 0.14, Total Time (hrs): 0.0709
# ====> Epoch: 2086 Train ELBO: 124.5454 Val ELBO: 128.0446, Epoch Time (s): 0.13, Total Time (hrs): 0.0709
# ====> Epoch: 2087 Train ELBO: 122.9324 Val ELBO: 134.0546, Epoch Time (s): 0.14, Total Time (hrs): 0.0710
# ====> Epoch: 2088 Train ELBO: 124.2358 Val ELBO: 132.4411, Epoch Time (s): 0.12, Total Time (hrs): 0.0710
# ====> Epoch: 2089 Train ELBO: 124.2746 Val ELBO: 121.6199, Epoch Time (s): 0.15, Total Time (hrs): 0.0710
# ====> Epoch: 2090 Train ELBO: 118.0813 Val ELBO: 132.0754, Epoch Time (s): 0.14, Total Time (hrs): 0.0711
# ====> Epoch: 2091 Train ELBO: 121.2241 Val ELBO: 128.5736, Epoch Time (s): 0.13, Total Time (hrs): 0.0711
# ====> Epoch: 2092 Train ELBO: 123.3734 Val ELBO: 134.0110, Epoch Time (s): 0.13, Total Time (hrs): 0.0712
# ====> Epoch: 2093 Train ELBO: 126.8351 Val ELBO: 134.5215, Epoch Time (s): 0.13, Total Time (hrs): 0.0712
# ====> Epoch: 2094 Train ELBO: 125.9764 Val ELBO: 133.4861, Epoch Time (s): 0.12, Total Time (hrs): 0.0712
# ====> Epoch: 2095 Train ELBO: 128.3016 Val ELBO: 135.1276, Epoch Time (s): 0.12, Total Time (hrs): 0.0713
# ====> Epoch: 2096 Train ELBO: 126.0747 Val ELBO: 130.1394, Epoch Time (s): 0.12, Total Time (hrs): 0.0713
# ====> Epoch: 2097 Train ELBO: 120.1796 Val ELBO: 133.2643, Epoch Time (s): 0.14, Total Time (hrs): 0.0713
# ====> Epoch: 2098 Train ELBO: 121.1597 Val ELBO: 133.2791, Epoch Time (s): 0.14, Total Time (hrs): 0.0714
# ====> Epoch: 2099 Train ELBO: 122.1983 Val ELBO: 129.0996, Epoch Time (s): 0.13, Total Time (hrs): 0.0714
# ====> Epoch: 2100 Train ELBO: 124.3712 Val ELBO: 135.3374, Epoch Time (s): 0.12, Total Time (hrs): 0.0714
# ====> Epoch: 2101 Train ELBO: 128.4905 Val ELBO: 135.8123, Epoch Time (s): 0.13, Total Time (hrs): 0.0715
# ====> Epoch: 2102 Train ELBO: 126.8356 Val ELBO: 133.6085, Epoch Time (s): 0.12, Total Time (hrs): 0.0715
# ====> Epoch: 2103 Train ELBO: 127.3416 Val ELBO: 135.6704, Epoch Time (s): 0.13, Total Time (hrs): 0.0715
# ====> Epoch: 2104 Train ELBO: 128.5372 Val ELBO: 136.3600, Epoch Time (s): 0.12, Total Time (hrs): 0.0716
# ====> Epoch: 2105 Train ELBO: 127.3537 Val ELBO: 132.3702, Epoch Time (s): 0.15, Total Time (hrs): 0.0716
# ====> Epoch: 2106 Train ELBO: 127.4855 Val ELBO: 134.5837, Epoch Time (s): 0.14, Total Time (hrs): 0.0717
# ====> Epoch: 2107 Train ELBO: 125.6218 Val ELBO: 127.6534, Epoch Time (s): 0.16, Total Time (hrs): 0.0717
# ====> Epoch: 2108 Train ELBO: 125.5894 Val ELBO: 132.2112, Epoch Time (s): 0.13, Total Time (hrs): 0.0717
# ====> Epoch: 2109 Train ELBO: 125.4131 Val ELBO: 131.9026, Epoch Time (s): 0.15, Total Time (hrs): 0.0718
# ====> Epoch: 2110 Train ELBO: 125.1462 Val ELBO: 134.2393, Epoch Time (s): 0.14, Total Time (hrs): 0.0718
# ====> Epoch: 2111 Train ELBO: 125.7879 Val ELBO: 126.2903, Epoch Time (s): 0.16, Total Time (hrs): 0.0719
# ====> Epoch: 2112 Train ELBO: 120.6827 Val ELBO: 134.1092, Epoch Time (s): 0.13, Total Time (hrs): 0.0719
# ====> Epoch: 2113 Train ELBO: 125.6855 Val ELBO: 129.6677, Epoch Time (s): 0.09, Total Time (hrs): 0.0719
# ====> Epoch: 2114 Train ELBO: 124.9345 Val ELBO: 136.2668, Epoch Time (s): 0.10, Total Time (hrs): 0.0720
# ====> Epoch: 2115 Train ELBO: 128.6369 Val ELBO: 133.1113, Epoch Time (s): 0.09, Total Time (hrs): 0.0720
# ====> Epoch: 2116 Train ELBO: 128.2144 Val ELBO: 134.7295, Epoch Time (s): 0.09, Total Time (hrs): 0.0720
# ====> Epoch: 2117 Train ELBO: 125.7394 Val ELBO: 132.6156, Epoch Time (s): 0.09, Total Time (hrs): 0.0720
# ====> Epoch: 2118 Train ELBO: 126.4329 Val ELBO: 131.3499, Epoch Time (s): 0.09, Total Time (hrs): 0.0721
# ====> Epoch: 2119 Train ELBO: 125.9259 Val ELBO: 135.3651, Epoch Time (s): 0.09, Total Time (hrs): 0.0721
# ====> Epoch: 2120 Train ELBO: 127.8518 Val ELBO: 135.0508, Epoch Time (s): 0.08, Total Time (hrs): 0.0721
# ====> Epoch: 2121 Train ELBO: 123.9001 Val ELBO: 124.1778, Epoch Time (s): 0.08, Total Time (hrs): 0.0721
# ====> Epoch: 2122 Train ELBO: 123.5914 Val ELBO: 125.8393, Epoch Time (s): 0.09, Total Time (hrs): 0.0722
# ====> Epoch: 2123 Train ELBO: 124.6427 Val ELBO: 136.8957, Epoch Time (s): 0.09, Total Time (hrs): 0.0722
# ====> Epoch: 2124 Train ELBO: 126.7863 Val ELBO: 130.5894, Epoch Time (s): 0.09, Total Time (hrs): 0.0722
# ====> Epoch: 2125 Train ELBO: 123.4038 Val ELBO: 133.0408, Epoch Time (s): 0.10, Total Time (hrs): 0.0722
# ====> Epoch: 2126 Train ELBO: 126.0647 Val ELBO: 134.1065, Epoch Time (s): 0.11, Total Time (hrs): 0.0723
# ====> Epoch: 2127 Train ELBO: 125.6530 Val ELBO: 124.1576, Epoch Time (s): 0.09, Total Time (hrs): 0.0723
# ====> Epoch: 2128 Train ELBO: 118.0393 Val ELBO: 130.7926, Epoch Time (s): 0.09, Total Time (hrs): 0.0723
# ====> Epoch: 2129 Train ELBO: 118.2084 Val ELBO: 119.5024, Epoch Time (s): 0.09, Total Time (hrs): 0.0723
# ====> Epoch: 2130 Train ELBO: 116.3372 Val ELBO: 124.3826, Epoch Time (s): 0.09, Total Time (hrs): 0.0724
# ====> Epoch: 2131 Train ELBO: 122.7235 Val ELBO: 130.0794, Epoch Time (s): 0.09, Total Time (hrs): 0.0724
# ====> Epoch: 2132 Train ELBO: 124.9490 Val ELBO: 135.6246, Epoch Time (s): 0.09, Total Time (hrs): 0.0724
# ====> Epoch: 2133 Train ELBO: 126.9218 Val ELBO: 132.8975, Epoch Time (s): 0.10, Total Time (hrs): 0.0724
# ====> Epoch: 2134 Train ELBO: 123.8048 Val ELBO: 128.9155, Epoch Time (s): 0.08, Total Time (hrs): 0.0725
# ====> Epoch: 2135 Train ELBO: 123.1449 Val ELBO: 130.0963, Epoch Time (s): 0.09, Total Time (hrs): 0.0725
# ====> Epoch: 2136 Train ELBO: 125.8300 Val ELBO: 134.0438, Epoch Time (s): 0.10, Total Time (hrs): 0.0725
# ====> Epoch: 2137 Train ELBO: 126.2978 Val ELBO: 131.5389, Epoch Time (s): 0.10, Total Time (hrs): 0.0725
# ====> Epoch: 2138 Train ELBO: 126.0822 Val ELBO: 130.2921, Epoch Time (s): 0.09, Total Time (hrs): 0.0726
# ====> Epoch: 2139 Train ELBO: 126.2567 Val ELBO: 128.0474, Epoch Time (s): 0.09, Total Time (hrs): 0.0726
# ====> Epoch: 2140 Train ELBO: 126.4811 Val ELBO: 135.0210, Epoch Time (s): 0.09, Total Time (hrs): 0.0726
# ====> Epoch: 2141 Train ELBO: 111.1983 Val ELBO: 110.7841, Epoch Time (s): 0.09, Total Time (hrs): 0.0726
# ====> Epoch: 2142 Train ELBO: 114.0548 Val ELBO: 124.9571, Epoch Time (s): 0.09, Total Time (hrs): 0.0727
# ====> Epoch: 2143 Train ELBO: 117.0214 Val ELBO: 126.3956, Epoch Time (s): 0.09, Total Time (hrs): 0.0727
# ====> Epoch: 2144 Train ELBO: 121.0136 Val ELBO: 131.5040, Epoch Time (s): 0.09, Total Time (hrs): 0.0727
# ====> Epoch: 2145 Train ELBO: 124.9452 Val ELBO: 129.1153, Epoch Time (s): 0.09, Total Time (hrs): 0.0727
# ====> Epoch: 2146 Train ELBO: 123.2692 Val ELBO: 132.6298, Epoch Time (s): 0.09, Total Time (hrs): 0.0728
# ====> Epoch: 2147 Train ELBO: 126.8246 Val ELBO: 134.0875, Epoch Time (s): 0.09, Total Time (hrs): 0.0728
# ====> Epoch: 2148 Train ELBO: 127.3098 Val ELBO: 134.1108, Epoch Time (s): 0.11, Total Time (hrs): 0.0728
# ====> Epoch: 2149 Train ELBO: 128.1512 Val ELBO: 135.5470, Epoch Time (s): 0.09, Total Time (hrs): 0.0728
# ====> Epoch: 2150 Train ELBO: 123.8481 Val ELBO: 130.1234, Epoch Time (s): 0.08, Total Time (hrs): 0.0729
# ====> Epoch: 2151 Train ELBO: 116.0704 Val ELBO: 101.7004, Epoch Time (s): 0.09, Total Time (hrs): 0.0729
# ====> Epoch: 2152 Train ELBO: 104.9100 Val ELBO: 123.7665, Epoch Time (s): 0.09, Total Time (hrs): 0.0729
# ====> Epoch: 2153 Train ELBO: 113.4601 Val ELBO: 127.6168, Epoch Time (s): 0.09, Total Time (hrs): 0.0729
# ====> Epoch: 2154 Train ELBO: 117.9581 Val ELBO: 115.5779, Epoch Time (s): 0.09, Total Time (hrs): 0.0730
# ====> Epoch: 2155 Train ELBO: 114.9020 Val ELBO: 122.2523, Epoch Time (s): 0.09, Total Time (hrs): 0.0730
# ====> Epoch: 2156 Train ELBO: 112.8349 Val ELBO: 134.4985, Epoch Time (s): 0.08, Total Time (hrs): 0.0730
# ====> Epoch: 2157 Train ELBO: 123.9793 Val ELBO: 130.0561, Epoch Time (s): 0.09, Total Time (hrs): 0.0730
# ====> Epoch: 2158 Train ELBO: 124.4067 Val ELBO: 131.6481, Epoch Time (s): 0.09, Total Time (hrs): 0.0731
# ====> Epoch: 2159 Train ELBO: 124.1562 Val ELBO: 125.8332, Epoch Time (s): 0.09, Total Time (hrs): 0.0731
# ====> Epoch: 2160 Train ELBO: 112.9161 Val ELBO: 127.6000, Epoch Time (s): 0.11, Total Time (hrs): 0.0731
# ====> Epoch: 2161 Train ELBO: 113.8670 Val ELBO: 114.8832, Epoch Time (s): 0.09, Total Time (hrs): 0.0732
# ====> Epoch: 2162 Train ELBO: 109.3977 Val ELBO: 128.3414, Epoch Time (s): 0.09, Total Time (hrs): 0.0732
# ...
# ====> Epoch: 6481 Train ELBO: 140.8850 Val ELBO: 144.4729, Epoch Time (s): 0.09, Total Time (hrs): 0.2081
# ====> Epoch: 6482 Train ELBO: 141.9255 Val ELBO: 138.7203, Epoch Time (s): 0.09, Total Time (hrs): 0.2081
# ====> Epoch: 6483 Train ELBO: 140.8160 Val ELBO: 144.2599, Epoch Time (s): 0.10, Total Time (hrs): 0.2081
# ====> Epoch: 6484 Train ELBO: 140.1076 Val ELBO: 144.0206, Epoch Time (s): 0.09, Total Time (hrs): 0.2082
# ====> Epoch: 6485 Train ELBO: 140.5604 Val ELBO: 144.3621, Epoch Time (s): 0.09, Total Time (hrs): 0.2082
# ====> Epoch: 6486 Train ELBO: 143.8376 Val ELBO: 148.1023, Epoch Time (s): 0.09, Total Time (hrs): 0.2082
# ====> Epoch: 6487 Train ELBO: 143.7922 Val ELBO: 146.1796, Epoch Time (s): 0.08, Total Time (hrs): 0.2082
# ====> Epoch: 6488 Train ELBO: 142.2201 Val ELBO: 145.2146, Epoch Time (s): 0.08, Total Time (hrs): 0.2083
# ====> Epoch: 6489 Train ELBO: 143.4373 Val ELBO: 145.0565, Epoch Time (s): 0.09, Total Time (hrs): 0.2083
# ====> Epoch: 6490 Train ELBO: 142.2745 Val ELBO: 144.8988, Epoch Time (s): 0.09, Total Time (hrs): 0.2083
# ====> Epoch: 6491 Train ELBO: 142.0767 Val ELBO: 146.1814, Epoch Time (s): 0.10, Total Time (hrs): 0.2083
# ====> Epoch: 6492 Train ELBO: 141.9771 Val ELBO: 145.7490, Epoch Time (s): 0.11, Total Time (hrs): 0.2084
# ====> Epoch: 6493 Train ELBO: 143.1224 Val ELBO: 147.9297, Epoch Time (s): 0.09, Total Time (hrs): 0.2084
# ====> Epoch: 6494 Train ELBO: 142.6206 Val ELBO: 146.0655, Epoch Time (s): 0.09, Total Time (hrs): 0.2084
# ====> Epoch: 6495 Train ELBO: 140.7884 Val ELBO: 144.7127, Epoch Time (s): 0.10, Total Time (hrs): 0.2084
# ====> Epoch: 6496 Train ELBO: 137.1334 Val ELBO: 143.6952, Epoch Time (s): 0.08, Total Time (hrs): 0.2085
# ====> Epoch: 6497 Train ELBO: 141.5111 Val ELBO: 144.6631, Epoch Time (s): 0.09, Total Time (hrs): 0.2085
# ====> Epoch: 6498 Train ELBO: 140.7304 Val ELBO: 136.6333, Epoch Time (s): 0.09, Total Time (hrs): 0.2085
# ====> Epoch: 6499 Train ELBO: 140.6961 Val ELBO: 145.9896, Epoch Time (s): 0.09, Total Time (hrs): 0.2085
# 3
# 0
# 1
# 2
# 3
# 0
# 1
# 2
# ====> Epoch: 6500 Train ELBO: 137.0038 Val ELBO: 138.9011, Epoch Time (s): 5.78, Total Time (hrs): 0.2101
# ====> Epoch: 6501 Train ELBO: 140.0883 Val ELBO: 146.6712, Epoch Time (s): 0.09, Total Time (hrs): 0.2108
# ====> Epoch: 6502 Train ELBO: 140.8779 Val ELBO: 142.9529, Epoch Time (s): 0.09, Total Time (hrs): 0.2108
# ====> Epoch: 6503 Train ELBO: 137.8815 Val ELBO: 142.8527, Epoch Time (s): 0.09, Total Time (hrs): 0.2108
# ====> Epoch: 6504 Train ELBO: 142.0625 Val ELBO: 146.7633, Epoch Time (s): 0.10, Total Time (hrs): 0.2109
# ====> Epoch: 6505 Train ELBO: 137.9386 Val ELBO: 131.2605, Epoch Time (s): 0.09, Total Time (hrs): 0.2109
# ====> Epoch: 6506 Train ELBO: 136.8692 Val ELBO: 137.1736, Epoch Time (s): 0.09, Total Time (hrs): 0.2109
# ====> Epoch: 6507 Train ELBO: 139.9180 Val ELBO: 143.7682, Epoch Time (s): 0.09, Total Time (hrs): 0.2109
# ====> Epoch: 6508 Train ELBO: 141.0851 Val ELBO: 141.1153, Epoch Time (s): 0.09, Total Time (hrs): 0.2110
# ====> Epoch: 6509 Train ELBO: 137.6869 Val ELBO: 146.1034, Epoch Time (s): 0.10, Total Time (hrs): 0.2110
# ====> Epoch: 6510 Train ELBO: 133.7757 Val ELBO: 126.4600, Epoch Time (s): 0.09, Total Time (hrs): 0.2110
# ====> Epoch: 6511 Train ELBO: 130.8393 Val ELBO: 101.5103, Epoch Time (s): 0.09, Total Time (hrs): 0.2110
# ====> Epoch: 6512 Train ELBO: 117.5135 Val ELBO: 121.2591, Epoch Time (s): 0.09, Total Time (hrs): 0.2111
# ====> Epoch: 6513 Train ELBO: 130.4593 Val ELBO: 142.8024, Epoch Time (s): 0.09, Total Time (hrs): 0.2111
# ====> Epoch: 6514 Train ELBO: 136.9574 Val ELBO: 140.8213, Epoch Time (s): 0.09, Total Time (hrs): 0.2111
# ====> Epoch: 6515 Train ELBO: 139.4987 Val ELBO: 146.0331, Epoch Time (s): 0.09, Total Time (hrs): 0.2111
# ====> Epoch: 6516 Train ELBO: 142.1326 Val ELBO: 147.2497, Epoch Time (s): 0.10, Total Time (hrs): 0.2112
# ====> Epoch: 6517 Train ELBO: 140.7844 Val ELBO: 141.7989, Epoch Time (s): 0.09, Total Time (hrs): 0.2112
# ====> Epoch: 6518 Train ELBO: 141.2542 Val ELBO: 143.3472, Epoch Time (s): 0.09, Total Time (hrs): 0.2112
# ====> Epoch: 6519 Train ELBO: 140.7850 Val ELBO: 143.6609, Epoch Time (s): 0.10, Total Time (hrs): 0.2112
# ====> Epoch: 6520 Train ELBO: 140.9149 Val ELBO: 145.8166, Epoch Time (s): 0.11, Total Time (hrs): 0.2113
# ====> Epoch: 6521 Train ELBO: 143.8738 Val ELBO: 140.0771, Epoch Time (s): 0.09, Total Time (hrs): 0.2113
# ====> Epoch: 6522 Train ELBO: 140.8801 Val ELBO: 143.3818, Epoch Time (s): 0.09, Total Time (hrs): 0.2113
# ====> Epoch: 6523 Train ELBO: 142.1502 Val ELBO: 145.2431, Epoch Time (s): 0.08, Total Time (hrs): 0.2113
# ====> Epoch: 6524 Train ELBO: 141.8862 Val ELBO: 144.9995, Epoch Time (s): 0.09, Total Time (hrs): 0.2114
# ====> Epoch: 6525 Train ELBO: 141.3068 Val ELBO: 142.7444, Epoch Time (s): 0.09, Total Time (hrs): 0.2114
# ====> Epoch: 6526 Train ELBO: 141.8288 Val ELBO: 143.7914, Epoch Time (s): 0.09, Total Time (hrs): 0.2114
# ====> Epoch: 6527 Train ELBO: 142.0930 Val ELBO: 142.1500, Epoch Time (s): 0.09, Total Time (hrs): 0.2114
# ====> Epoch: 6528 Train ELBO: 140.8495 Val ELBO: 145.5295, Epoch Time (s): 0.10, Total Time (hrs): 0.2115
# ====> Epoch: 6529 Train ELBO: 142.7223 Val ELBO: 147.8148, Epoch Time (s): 0.09, Total Time (hrs): 0.2115
# ====> Epoch: 6530 Train ELBO: 137.6077 Val ELBO: 140.6429, Epoch Time (s): 0.08, Total Time (hrs): 0.2115
# ====> Epoch: 6531 Train ELBO: 141.2148 Val ELBO: 146.0576, Epoch Time (s): 0.11, Total Time (hrs): 0.2115
# ====> Epoch: 6532 Train ELBO: 143.1836 Val ELBO: 145.3013, Epoch Time (s): 0.09, Total Time (hrs): 0.2116
# ====> Epoch: 6533 Train ELBO: 143.3522 Val ELBO: 147.2826, Epoch Time (s): 0.08, Total Time (hrs): 0.2116
# ====> Epoch: 6534 Train ELBO: 143.0375 Val ELBO: 147.3577, Epoch Time (s): 0.09, Total Time (hrs): 0.2116
# ====> Epoch: 6535 Train ELBO: 140.6138 Val ELBO: 143.9432, Epoch Time (s): 0.10, Total Time (hrs): 0.2116
# ====> Epoch: 6536 Train ELBO: 137.0133 Val ELBO: 141.6765, Epoch Time (s): 0.09, Total Time (hrs): 0.2117
# ====> Epoch: 6537 Train ELBO: 129.5191 Val ELBO: 125.6541, Epoch Time (s): 0.10, Total Time (hrs): 0.2117
# ====> Epoch: 6538 Train ELBO: 136.2711 Val ELBO: 141.3648, Epoch Time (s): 0.09, Total Time (hrs): 0.2117
# ====> Epoch: 6539 Train ELBO: 140.1173 Val ELBO: 143.9850, Epoch Time (s): 0.08, Total Time (hrs): 0.2117
# ====> Epoch: 6540 Train ELBO: 133.2180 Val ELBO: 142.1113, Epoch Time (s): 0.10, Total Time (hrs): 0.2118
# ====> Epoch: 6541 Train ELBO: 134.3546 Val ELBO: 146.4911, Epoch Time (s): 0.08, Total Time (hrs): 0.2118
# ====> Epoch: 6542 Train ELBO: 137.3604 Val ELBO: 142.5103, Epoch Time (s): 0.08, Total Time (hrs): 0.2118
# ====> Epoch: 6543 Train ELBO: 137.4368 Val ELBO: 145.7052, Epoch Time (s): 0.11, Total Time (hrs): 0.2119
# ====> Epoch: 6544 Train ELBO: 140.0007 Val ELBO: 139.0289, Epoch Time (s): 0.09, Total Time (hrs): 0.2119
# ====> Epoch: 6545 Train ELBO: 141.3479 Val ELBO: 144.6783, Epoch Time (s): 0.09, Total Time (hrs): 0.2119
# ====> Epoch: 6546 Train ELBO: 142.9680 Val ELBO: 145.5663, Epoch Time (s): 0.10, Total Time (hrs): 0.2119
# ====> Epoch: 6547 Train ELBO: 142.9064 Val ELBO: 147.3212, Epoch Time (s): 0.08, Total Time (hrs): 0.2120
# ====> Epoch: 6548 Train ELBO: 143.2156 Val ELBO: 147.9245, Epoch Time (s): 0.09, Total Time (hrs): 0.2120
# ====> Epoch: 6549 Train ELBO: 144.2351 Val ELBO: 145.4059, Epoch Time (s): 0.10, Total Time (hrs): 0.2120
# ====> Epoch: 6550 Train ELBO: 142.2265 Val ELBO: 145.3976, Epoch Time (s): 0.10, Total Time (hrs): 0.2120
# ====> Epoch: 6551 Train ELBO: 141.1724 Val ELBO: 139.3058, Epoch Time (s): 0.09, Total Time (hrs): 0.2121
# ====> Epoch: 6552 Train ELBO: 139.8673 Val ELBO: 144.7993, Epoch Time (s): 0.09, Total Time (hrs): 0.2121
# ====> Epoch: 6553 Train ELBO: 141.4405 Val ELBO: 143.0735, Epoch Time (s): 0.09, Total Time (hrs): 0.2121
# ====> Epoch: 6554 Train ELBO: 141.4061 Val ELBO: 142.0510, Epoch Time (s): 0.10, Total Time (hrs): 0.2121
# ====> Epoch: 6555 Train ELBO: 142.3604 Val ELBO: 145.7058, Epoch Time (s): 0.09, Total Time (hrs): 0.2122
# ====> Epoch: 6556 Train ELBO: 143.8161 Val ELBO: 147.7363, Epoch Time (s): 0.09, Total Time (hrs): 0.2122
# ====> Epoch: 6557 Train ELBO: 142.6550 Val ELBO: 145.0112, Epoch Time (s): 0.08, Total Time (hrs): 0.2122
# ====> Epoch: 6558 Train ELBO: 140.7207 Val ELBO: 136.9597, Epoch Time (s): 0.09, Total Time (hrs): 0.2122
# ====> Epoch: 6559 Train ELBO: 137.3865 Val ELBO: 145.3746, Epoch Time (s): 0.09, Total Time (hrs): 0.2123
# ====> Epoch: 6560 Train ELBO: 138.9582 Val ELBO: 135.8164, Epoch Time (s): 0.09, Total Time (hrs): 0.2123
# ====> Epoch: 6561 Train ELBO: 132.4763 Val ELBO: 132.7633, Epoch Time (s): 0.10, Total Time (hrs): 0.2123
# ====> Epoch: 6562 Train ELBO: 130.5021 Val ELBO: 143.6506, Epoch Time (s): 0.09, Total Time (hrs): 0.2123
# ====> Epoch: 6563 Train ELBO: 131.1957 Val ELBO: 142.2465, Epoch Time (s): 0.08, Total Time (hrs): 0.2124
# ====> Epoch: 6564 Train ELBO: 137.0406 Val ELBO: 144.5800, Epoch Time (s): 0.09, Total Time (hrs): 0.2124
# ====> Epoch: 6565 Train ELBO: 140.9112 Val ELBO: 147.4898, Epoch Time (s): 0.10, Total Time (hrs): 0.2124
# ====> Epoch: 6566 Train ELBO: 142.2135 Val ELBO: 145.6711, Epoch Time (s): 0.09, Total Time (hrs): 0.2124
# ====> Epoch: 6567 Train ELBO: 143.1225 Val ELBO: 142.7504, Epoch Time (s): 0.09, Total Time (hrs): 0.2125
# ====> Epoch: 6568 Train ELBO: 143.6451 Val ELBO: 147.3453, Epoch Time (s): 0.08, Total Time (hrs): 0.2125
# ====> Epoch: 6569 Train ELBO: 143.6266 Val ELBO: 147.3938, Epoch Time (s): 0.09, Total Time (hrs): 0.2125
# ====> Epoch: 6570 Train ELBO: 139.8445 Val ELBO: 137.7065, Epoch Time (s): 0.15, Total Time (hrs): 0.2125
# ====> Epoch: 6571 Train ELBO: 137.4170 Val ELBO: 133.1540, Epoch Time (s): 0.14, Total Time (hrs): 0.2126
# ====> Epoch: 6572 Train ELBO: 138.2037 Val ELBO: 133.6017, Epoch Time (s): 0.14, Total Time (hrs): 0.2126
# ====> Epoch: 6573 Train ELBO: 137.0095 Val ELBO: 134.1843, Epoch Time (s): 0.13, Total Time (hrs): 0.2127
# ====> Epoch: 6574 Train ELBO: 134.8836 Val ELBO: 134.9853, Epoch Time (s): 0.14, Total Time (hrs): 0.2127
# ====> Epoch: 6575 Train ELBO: 136.5544 Val ELBO: 133.7772, Epoch Time (s): 0.14, Total Time (hrs): 0.2127
# ====> Epoch: 6576 Train ELBO: 136.7549 Val ELBO: 139.9647, Epoch Time (s): 0.13, Total Time (hrs): 0.2128
# ====> Epoch: 6577 Train ELBO: 139.0410 Val ELBO: 139.4218, Epoch Time (s): 0.13, Total Time (hrs): 0.2128
# ====> Epoch: 6578 Train ELBO: 139.1385 Val ELBO: 138.9592, Epoch Time (s): 0.14, Total Time (hrs): 0.2128
# ====> Epoch: 6579 Train ELBO: 137.0125 Val ELBO: 137.2408, Epoch Time (s): 0.13, Total Time (hrs): 0.2129
# ====> Epoch: 6580 Train ELBO: 139.9289 Val ELBO: 145.7746, Epoch Time (s): 0.12, Total Time (hrs): 0.2129
# ====> Epoch: 6581 Train ELBO: 142.2628 Val ELBO: 146.1898, Epoch Time (s): 0.12, Total Time (hrs): 0.2130
# ====> Epoch: 6582 Train ELBO: 143.2203 Val ELBO: 145.6832, Epoch Time (s): 0.12, Total Time (hrs): 0.2130
# ====> Epoch: 6583 Train ELBO: 142.4288 Val ELBO: 145.5603, Epoch Time (s): 0.16, Total Time (hrs): 0.2130
# ====> Epoch: 6584 Train ELBO: 144.0490 Val ELBO: 145.6802, Epoch Time (s): 0.14, Total Time (hrs): 0.2131
# ====> Epoch: 6585 Train ELBO: 143.6686 Val ELBO: 147.6017, Epoch Time (s): 0.13, Total Time (hrs): 0.2131
# ====> Epoch: 6586 Train ELBO: 142.7551 Val ELBO: 142.2695, Epoch Time (s): 0.13, Total Time (hrs): 0.2131
# ====> Epoch: 6587 Train ELBO: 140.3822 Val ELBO: 143.9522, Epoch Time (s): 0.12, Total Time (hrs): 0.2132
# ====> Epoch: 6588 Train ELBO: 141.0909 Val ELBO: 146.5838, Epoch Time (s): 0.12, Total Time (hrs): 0.2132
# ====> Epoch: 6589 Train ELBO: 142.3827 Val ELBO: 144.0189, Epoch Time (s): 0.12, Total Time (hrs): 0.2132
# ====> Epoch: 6590 Train ELBO: 140.8307 Val ELBO: 147.5515, Epoch Time (s): 0.13, Total Time (hrs): 0.2133
# ====> Epoch: 6591 Train ELBO: 142.8528 Val ELBO: 147.3739, Epoch Time (s): 0.15, Total Time (hrs): 0.2133
# ====> Epoch: 6592 Train ELBO: 143.3128 Val ELBO: 147.4011, Epoch Time (s): 0.16, Total Time (hrs): 0.2134
# ====> Epoch: 6593 Train ELBO: 143.9477 Val ELBO: 143.5704, Epoch Time (s): 0.16, Total Time (hrs): 0.2134
# ====> Epoch: 6594 Train ELBO: 139.3218 Val ELBO: 147.1331, Epoch Time (s): 0.13, Total Time (hrs): 0.2134
# ====> Epoch: 6595 Train ELBO: 141.9725 Val ELBO: 146.8784, Epoch Time (s): 0.15, Total Time (hrs): 0.2135
# ====> Epoch: 6596 Train ELBO: 142.0864 Val ELBO: 142.2537, Epoch Time (s): 0.14, Total Time (hrs): 0.2135
# ====> Epoch: 6597 Train ELBO: 140.7908 Val ELBO: 145.9834, Epoch Time (s): 0.15, Total Time (hrs): 0.2136
# ====> Epoch: 6598 Train ELBO: 141.4540 Val ELBO: 139.8812, Epoch Time (s): 0.15, Total Time (hrs): 0.2136
# ====> Epoch: 6599 Train ELBO: 137.2612 Val ELBO: 137.9251, Epoch Time (s): 0.09, Total Time (hrs): 0.2136
# ====> Epoch: 6600 Train ELBO: 140.7357 Val ELBO: 142.6874, Epoch Time (s): 0.09, Total Time (hrs): 0.2137
# ====> Epoch: 6601 Train ELBO: 139.6796 Val ELBO: 144.6103, Epoch Time (s): 0.10, Total Time (hrs): 0.2137
# ====> Epoch: 6602 Train ELBO: 142.6681 Val ELBO: 144.3643, Epoch Time (s): 0.09, Total Time (hrs): 0.2137
# ====> Epoch: 6603 Train ELBO: 142.4541 Val ELBO: 143.0428, Epoch Time (s): 0.09, Total Time (hrs): 0.2137
# ====> Epoch: 6604 Train ELBO: 141.0849 Val ELBO: 145.2068, Epoch Time (s): 0.09, Total Time (hrs): 0.2138
# ====> Epoch: 6605 Train ELBO: 141.1676 Val ELBO: 142.9534, Epoch Time (s): 0.08, Total Time (hrs): 0.2138
# ====> Epoch: 6606 Train ELBO: 140.8570 Val ELBO: 145.6559, Epoch Time (s): 0.08, Total Time (hrs): 0.2138
# ====> Epoch: 6607 Train ELBO: 141.5145 Val ELBO: 145.5168, Epoch Time (s): 0.09, Total Time (hrs): 0.2138
# ====> Epoch: 6608 Train ELBO: 142.5035 Val ELBO: 145.4154, Epoch Time (s): 0.09, Total Time (hrs): 0.2139
# ====> Epoch: 6609 Train ELBO: 141.8013 Val ELBO: 144.6626, Epoch Time (s): 0.08, Total Time (hrs): 0.2139
# ====> Epoch: 6610 Train ELBO: 143.1207 Val ELBO: 145.6143, Epoch Time (s): 0.11, Total Time (hrs): 0.2139
# ====> Epoch: 6611 Train ELBO: 142.9219 Val ELBO: 146.7502, Epoch Time (s): 0.09, Total Time (hrs): 0.2139
# ====> Epoch: 6612 Train ELBO: 144.3410 Val ELBO: 147.8537, Epoch Time (s): 0.09, Total Time (hrs): 0.2140
# ====> Epoch: 6613 Train ELBO: 144.8690 Val ELBO: 147.3540, Epoch Time (s): 0.09, Total Time (hrs): 0.2140
# ====> Epoch: 6614 Train ELBO: 144.3245 Val ELBO: 145.6417, Epoch Time (s): 0.09, Total Time (hrs): 0.2140
# ====> Epoch: 6615 Train ELBO: 143.2399 Val ELBO: 145.0177, Epoch Time (s): 0.08, Total Time (hrs): 0.2140
# ====> Epoch: 6616 Train ELBO: 140.4087 Val ELBO: 137.2568, Epoch Time (s): 0.09, Total Time (hrs): 0.2141
# ====> Epoch: 6617 Train ELBO: 140.4980 Val ELBO: 142.1954, Epoch Time (s): 0.09, Total Time (hrs): 0.2141
# ====> Epoch: 6618 Train ELBO: 142.1905 Val ELBO: 144.6790, Epoch Time (s): 0.08, Total Time (hrs): 0.2141
# ====> Epoch: 6619 Train ELBO: 142.6905 Val ELBO: 144.5846, Epoch Time (s): 0.09, Total Time (hrs): 0.2141
# ====> Epoch: 6620 Train ELBO: 140.0424 Val ELBO: 145.3658, Epoch Time (s): 0.08, Total Time (hrs): 0.2142
# ====> Epoch: 6621 Train ELBO: 136.1446 Val ELBO: 146.6586, Epoch Time (s): 0.10, Total Time (hrs): 0.2142
# ====> Epoch: 6622 Train ELBO: 133.0865 Val ELBO: 111.9988, Epoch Time (s): 0.10, Total Time (hrs): 0.2142
# ====> Epoch: 6623 Train ELBO: 123.2761 Val ELBO: 144.3217, Epoch Time (s): 0.09, Total Time (hrs): 0.2142
# ====> Epoch: 6624 Train ELBO: 136.9273 Val ELBO: 144.0507, Epoch Time (s): 0.09, Total Time (hrs): 0.2143
# ====> Epoch: 6625 Train ELBO: 140.2645 Val ELBO: 144.7547, Epoch Time (s): 0.09, Total Time (hrs): 0.2143
# ====> Epoch: 6626 Train ELBO: 142.0593 Val ELBO: 145.4220, Epoch Time (s): 0.08, Total Time (hrs): 0.2143
# ====> Epoch: 6627 Train ELBO: 143.7942 Val ELBO: 147.2955, Epoch Time (s): 0.09, Total Time (hrs): 0.2143
# ====> Epoch: 6628 Train ELBO: 143.0948 Val ELBO: 142.9786, Epoch Time (s): 0.09, Total Time (hrs): 0.2144
# ====> Epoch: 6629 Train ELBO: 140.6326 Val ELBO: 146.7716, Epoch Time (s): 0.08, Total Time (hrs): 0.2144
# ====> Epoch: 6630 Train ELBO: 139.4425 Val ELBO: 131.4955, Epoch Time (s): 0.08, Total Time (hrs): 0.2144

# %% [markdown]
# # Load and Plot Results

# %%
# if loadFlag:
#   path = dirname
#   epoch = n_epochs - 1
params = {}
encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims).to("cuda")
decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var).to("cuda")

# Use if you need to load in the data
# if loadFlag:
#   suffix = postfix
#   encoder.load_state_dict(torch.load(os.path.join(path, f'encoder_{suffix}.pt'),map_location=torch.device('cpu')))
#   decoder.load_state_dict(torch.load(os.path.join(path, f'decoder_{suffix}.pt'),map_location=torch.device('cpu')))
#   logsigmasq = torch.load(os.path.join(path, f'gmm_params_logsigmasq_{suffix}.pt'),map_location=torch.device('cpu'))
#   mu = torch.load(os.path.join(path, f'gmm_params_mu_{suffix}.pt'),map_location=torch.device('cpu'))
#   pi = torch.load(os.path.join(path, f'gmm_params_pi_{suffix}.pt'),map_location=torch.device('cpu'))

encoder_list = [encoder]
decoder_list = [decoder]

device = next(encoder.parameters()).device
# Load in training history metrics
pi_history = torch.load(os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
train_loss = torch.load(os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
val_loss = torch.load(os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
train_elbo_terms = torch.load(os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
val_elbo_terms = torch.load(os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
train_mse_history = torch.load(os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
val_mse_history = torch.load(os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))


text_labels = [f'Cluster {i}' for i in range((n_clusters))]
label_colors = [f'C{i+1}' for i in range((n_clusters))]
data_colors = label_colors

# Plot training history
# Plot the training and validation loss vs. epoch number
plt.figure(figsize=(4, 4))
const = min(min(train_loss), min(val_loss))
# const = min(10, const)
train_loss_adjusted = train_loss
val_loss_adjusted = val_loss
plt.plot(train_loss_adjusted.cpu(), label='Training')
plt.plot(val_loss_adjusted.cpu(), label='Validation')
plt.xlabel("Number of Epochs")
plt.ylabel("Negative Loss")
# plt.title("Negative Loss")
plt.yscale('symlog')
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
# plt.close()


 # Plot each term of the training loss and validation loss
plt.figure(figsize=(4.5, 4))
labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
for ii in range(4):
  # print(train_elbo_terms.cpu()[ii, :epoch])
  # print(len(train_elbo_terms.cpu()[ii, :epoch]))
  train_loss_adjusted = train_elbo_terms[:, ii]
  val_loss_adjusted = val_elbo_terms[:, ii]
  plt.plot(train_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Train")
  plt.plot(val_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Val", linestyle='--')
plt.xlabel("number of epochs")
plt.ylabel("loss")
plt.title("Negative Loss Terms")
plt.yscale('symlog')
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
# plt.close()


 # Plot the sum of each term of the training loss and validation loss
plt.figure(figsize=(4.5, 4))
  # print(train_elbo_terms.cpu()[ii, :epoch])
  # print(len(train_elbo_terms.cpu()[ii, :epoch]))
train_loss_adjusted = train_elbo_terms.sum(axis=1)
val_loss_adjusted = val_elbo_terms.sum(axis=1)
plt.plot(train_loss_adjusted.cpu()[:], label=f"Train")
plt.plot(val_loss_adjusted.cpu()[:], label=f"Val", linestyle='--')
plt.xlabel("number of epochs")
plt.ylabel("loss")
plt.title("Sum of ELBO Terms")
plt.yscale('symlog')
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(dirname, 'elbo_terms_sum_'+ str(epoch)+postfix+'.png'), dpi=dpi)
# plt.close()

# Plot the training and validation mse vs. epoch number
plt.figure(figsize=(4.5, 4))
plt.semilogy(train_mse_history.cpu().detach().numpy(), label='train')
plt.semilogy(val_mse_history.cpu().detach().numpy(), label='val')
plt.xlabel("number of epochs")
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
# plt.close()

# Plot the history of pi
plt.figure(figsize=(4, 4))
for i in range(K):
    plt.plot(pi_history[:, i].cpu().detach().numpy(), label=text_labels[i]+r' $\pi$', color=label_colors[i])
plt.xlabel("Number of Epochs")
plt.ylabel("Predicted Cluster Probability")
plt.axhline(y=0.05, color='C1', linestyle='--', label='True Escape Probability')
plt.axhline(y=0.95, color='C3', linestyle='--', label='True Capture Probability')
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
# plt.close()

# Load best model saved
params['pi_c'] = torch.load(os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
params['mu_c'] = torch.load(os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
params['logsigmasq_c'] = torch.load(os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
encoder.load_state_dict(torch.load(os.path.join(dirname, 'encoder'+ postfix + '.pt')))
decoder.load_state_dict(torch.load(os.path.join(dirname, 'decoder'+ postfix + '.pt')))

encoder.eval()
decoder.eval()

# run one last EM step and plot training data in latent space
for encoder in encoder_list:
    encoder.eval()

with torch.no_grad():
    means = []
    samples = []
    labels = []
    params['hist_weights'] = torch.zeros((K, 1))
    params['hist_mu_c'] = torch.zeros((K, latent_dim))
    params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))
    for batch in train_loader:
        batch_x, batch_label = batch
        x_list = [batch_x]
        mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
        sigma = torch.exp(0.5 * logsigmasq)
        eps = Normal(0, 1).sample(mu.shape)
        z = mu + eps * sigma
        with torch.no_grad():
            gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
        params['mu_c'] = mu_c
        params['logsigmasq_c'] = logsigmasq_c

        means.append(mu)
        samples.append(z)
        labels.append(batch_label)

means = torch.vstack(means).cpu()
samples = torch.vstack(samples).cpu()
labels = torch.hstack(labels).cpu()


savepath = os.path.join(dirname, "BEST_latent_samples"+postfix)
plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

savepath = os.path.join(dirname, "BEST_latent_means"+postfix)
plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

# plot test data in latent space
with torch.no_grad():
    test_means = []
    test_labels = []
    for batch in test_loader:
        batch_x, batch_label = batch
        x_list = [batch_x]
        mean, _ = encoder_step(x_list, encoder_list, decoder_list)
        test_means.append(mean)
        test_labels.append(batch_label)

test_means = torch.vstack(test_means).cpu()
test_labels = torch.hstack(test_labels).cpu()


savepath = os.path.join(dirname, "BEST_test_latent_samples"+postfix)
plot_latent_space_with_clusters(test_means, test_labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

# plot decoding results from cluster means # todo: expand this function for multi-modal data
fig, ax = plt.subplots(figsize=(4.5, 4))
for i in range(K):
    # with torch.no_grad:
    x_mean = decoder.forward(params['mu_c'][i])[0]
    ax.plot(x_mean.cpu().detach().numpy(), label="decoded $\mu$"+str(i+1))
ax.legend()
plt.title("Decoded Means")
fig.savefig(os.path.join(dirname, "BEST_decoded_means"+postfix+'.png'), dpi=dpi)
# plt.close()

# plot samples from generative model
n_gen = n_train
cluster_probs = params['pi_c'].cpu().detach().numpy()
fig, ax = plt.subplots(figsize=(4.5, 4))
for j in range(n_gen):
    c = np.random.choice(K, p=cluster_probs)
    # print(c)
    mu_c = params['mu_c'][c].cpu().clone().detach()
    sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).cpu().clone().detach()
    z = Normal(0, 1).sample(mu_c.shape).cpu().clone().detach() * sigma_c + mu_c
    # print(z)
    mu_x = decoder.forward(z.cuda())[0].cpu().clone().detach()
    sigma_x = torch.exp(0.5 * decoder.forward(z.cuda())[1])
    sample_x = Normal(0, 1).sample(mu_x.shape).cpu().clone().detach() * sigma_x.cpu().clone().detach() + mu_x
    ax.plot(sample_x.cpu().detach().numpy())
plt.title("Generated Samples")
fig.savefig(os.path.join(dirname, "BEST_generate_samples"+postfix+'.png'), dpi=dpi)
# plt.close()

np.savez(dirname + postfix, train_loss=train_loss.cpu().detach().numpy(), val_loss=val_loss.cpu().detach().numpy(),
      train_mse=train_mse_history.cpu().detach().numpy(), val_mse=val_mse_history.cpu().detach().numpy(),
      pi_history=pi_history.cpu().detach().numpy(),
      cluster_probs=params['pi_c'].cpu().detach().numpy(),
      cluster_means=params['mu_c'].cpu().detach().numpy(),
      cluster_vars=torch.exp(params['logsigmasq_c']).cpu().detach().numpy())


print("Training data size", n_train)
print("Fraction of downward curves:", (torch.sum(labels == 0) / n_train).item())
print("Cluster 1 probability:", cluster_probs.min().item())
