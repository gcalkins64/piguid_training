# %% [markdown]
# # Imports

# %% [markdown]
# TO RUN:
# - Make sure to select Runtime>Change Runtime Type>T4 GPU to use cuda
# - Install pytorch_lightning
# - clone in repo to read in common files

# %%
# !pip install pytorch_lightning
# Out:
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.6.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (2.9.0+cu126)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.67.1)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2025.3.0)
# Collecting torchmetrics>0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (25.0)
# Requirement already satisfied: typing-extensions>4.5.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.15.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.13.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.10.0->pytorch_lightning) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.5.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics>0.7.0->pytorch_lightning) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.22.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (3.0.3)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.11)
# Downloading pytorch_lightning-2.6.0-py3-none-any.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 15.8 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 16.3 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch_lightning
# Successfully installed lightning-utilities-0.15.2 pytorch_lightning-2.6.0 torchmetrics-1.8.2

# %%
import os
import random
import numpy as np
import torch
from pytorch_lightning import seed_everything

SEED = 42
seed_everything(SEED, workers=True)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

import torch.optim as optim
from torch.distributions import Normal
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import pathlib
from torch.utils.data import DataLoader
from pytorch_lightning import LightningDataModule
import seaborn as sns
import json
from tqdm.notebook import tqdm_notebook
from time import time
import time
import datetime
import pickle
import matplotlib.lines as mlines
import sys
from sklearn.decomposition import PCA
from datetime import datetime
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 42

# %%
# !git clone https://github.com/gcalkins64/piguid_training.git
# Out:
# Cloning into 'piguid_training'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 42 (delta 17), reused 31 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (42/42), 2.90 MiB | 7.95 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# !cd piguid_training && git pull
# Out:
# Already up to date.

# %%
sys.path.append('/content/piguid_training')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from gmvae_common import *

# %% [markdown]
# # Check Devices

# %%
# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set default tensor type to CUDA tensors
torch.set_default_tensor_type(torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor)
print(device)
# Out:
# cuda
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1275: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)

# %% [markdown]
# # Settings

# %%
n_train = 1024
n_val = 128
n_test = 128
# For testing small batches of data
# n_train = 400
# n_val = 50
# n_test = 50
# THREE LAYERS
hd1 = 36
hd2 = 18
hd3 = 9
hidden_dims = [hd1, hd2, hd3]
hidden_dims_r = [hd3, hd2, hd1]
# TWO LAYERS
# hd1 = 32
# hd2 = 16
# hd3 = None
# hidden_dims = [hd1, hd2]
# hidden_dims_r = [hd2, hd1]
lr = 1e-3
n_epochs = 10_000 # 30_000
batch_size = 128
em_reg = 1e-6
decoder_var = 1e-5

latent_dims = [3,4,5]
n_clustersS = [3,4,5,6]
skip_combos = []

plot_interval = 500
dpi = 300

D = 1  #num_modalities
downsampleNum = 36

loadFlag = False  # True to load in old case, False to run a new case

data = 'orion_mars_return_2500_data_alt_range_scaled_downsampled'
inds = 'orion_mars_return_2500_inds_alt_range_scaled_downsampled'
tag = 'orion_mars_return'

# %% [markdown]
# # LOOP GMVAE TRAINING

# %%
for latent_dim in latent_dims:
  for n_clusters in n_clustersS:
    if [latent_dim, n_clusters] in skip_combos:
      continue
    else:
      K = n_clusters
      Z = latent_dim

      timestr = datetime.strftime(datetime.now(), "%Y%m%d_%H%M%S")

      if loadFlag:  # Load in old data
          dirname = loaddirname
      else:  # generate new data
          dirname = os.path.join("drive", "MyDrive", "piguid", "gmvae_"+tag+"_"+timestr+"_L"+str(latent_dim)+"_C"+str(n_clusters))
      os.makedirs(dirname, exist_ok=True)
      print("Filepath directory: " + dirname)

      if loadFlag:  # load old data
          postfix = loadpostfix
      else:  # Generate new suffix
          if hd3 is not None:
              postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:d}_{9:f}_{10:d}_{11:f}_{12:f}_{13:f}_'.format(
                  SEED, n_train, n_val, n_test, hd1, hd2, hd3, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
          else:
              postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:f}_{9:d}_{10:f}_{11:f}_{12:f}_'.format(
                  SEED, n_train, n_val, n_test, hd1, hd2, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
      print("Filepath postfix: " + postfix)

      data_dir = os.path.join("drive", "MyDrive", "piguid", f"{data}.json")

      with open(os.path.join("drive", "MyDrive", "piguid", f"{inds}.json"), 'r') as f:
          sample_list_load = json.load(f)
          sample_list = [int(sample) for sample in sample_list_load['sample_list']]
      print(sample_list)

      data_module = AerocaptureDataModuleCUDA(data_dir=data_dir, n_train=n_train, n_val=n_val, n_test=n_test,
                                      train_batch=batch_size, val_batch=batch_size, test_batch=batch_size,
                                      num_workers=0)

      data_module.setup("fit", sample_list = sample_list)

      train_loader = data_module.train_dataloader()
      val_loader = data_module.val_dataloader()
      test_loader = data_module.test_dataloader()
      data_dim = len(train_loader.dataset[0][0])
      true_labels = ['capture', 'escape', 'miss']
      label_colors = ['C2', 'C3', 'C4']

      num_train_batches = len(train_loader)

      ts_plot = np.linspace(0,1,downsampleNum)
      seabornSettings()
      fig, ax = plt.subplots(figsize=(4, 4))
      for j in range(n_train):
          ax.plot(ts_plot, train_loader.dataset[j][0].cpu(), color=label_colors[train_loader.dataset[j][1].cpu()], alpha=0.3)

      eline = mlines.Line2D([], [], color='C2', label='Escape')
      cline = mlines.Line2D([], [], color='C3', label='Capture')
      iline = mlines.Line2D([], [], color='C4', label='Miss')
      plt.legend(handles=[eline, cline, iline])
      # plt.hlines(0, 0, ts_plot[-1], colors='r', linestyles='dashed')
      plt.xlabel("Downrange")
      plt.ylabel("Altitude")
      plt.title("Training Data")
      plt.tight_layout()
      fig.savefig(os.path.join(dirname, 'train_data'+postfix+'.png'), dpi=dpi)

      fig, ax = plt.subplots(figsize=(4.5, 4))
      for j in range(n_val):
          ax.plot(ts_plot, val_loader.dataset[j][0].cpu(), color=label_colors[val_loader.dataset[j][1].cpu()], alpha=0.3)
      plt.title("Validation Data")
      fig.savefig(os.path.join(dirname, 'val_data'+postfix+'.png'), dpi=dpi)

      fig, ax = plt.subplots(figsize=(4.5, 4))
      for j in range(n_test):
          ax.plot(ts_plot, test_loader.dataset[j][0].cpu(), color=label_colors[test_loader.dataset[j][1].cpu()], alpha=0.3)
      plt.title("Test Data")
      fig.savefig(os.path.join(dirname, 'test_data'+postfix+'.png'), dpi=dpi)


      # initialize latent GMM model parameters
      params = {}
      pi_variables = torch.zeros(K).clone().detach().requires_grad_(True)
      params['pi_c'] = torch.ones(K) / K
      params['mu_c'] = torch.rand((K, Z)) * 2.0 - 1.0
      params['logsigmasq_c'] = torch.zeros((K, Z))

      # initialize neural networks
      encoder_list = []
      decoder_list = []
      trainable_parameters = []
      trainable_parameters.append(pi_variables)

      for _ in range(D):
          encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims)
          decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var)
          encoder_list.append(encoder)
          decoder_list.append(decoder)
          trainable_parameters += list(encoder.parameters()) + list(decoder.parameters())

      train_loss = torch.zeros(n_epochs)
      train_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
      val_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
      val_loss = torch.zeros(n_epochs)
      pi_history = torch.zeros((n_epochs, K))
      train_mse_history = torch.zeros(n_epochs)
      val_mse_history = torch.zeros(n_epochs)
      min_val_loss = torch.inf
      trainEpochs = np.arange(0,n_epochs,1)


      # Training
      seabornSettings()
      text_labels = [f'Cluster {i}' for i in range((n_clusters))]
      label_colors = [f'C{i+1}' for i in range((n_clusters))]

      optimizer = optim.Adam(trainable_parameters, lr=lr)

      ts = time.time()
      tic = time.perf_counter()

      for epoch in trainEpochs:
          ti = time.time()
          for encoder in encoder_list:
              encoder.train()
          for decoder in decoder_list:
              decoder.train()

          train_elbo = 0
          train_mse = 0
          train_elbo_term = np.zeros(4)
          params['hist_weights'] = torch.zeros((K, 1))
          params['hist_mu_c'] = torch.zeros((K, latent_dim))
          params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))

          for (batch_idx, batch) in enumerate(train_loader):
              batch_x, _ = batch
              x_list = [batch_x]  # assume D=2 and each modality has data_dim
              optimizer.zero_grad()
              pi_c = torch.exp(pi_variables) / torch.sum(torch.exp(pi_variables))
              params['pi_c'] = pi_c

              mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
              sigma = torch.exp(0.5 * logsigmasq)
              eps = Normal(0, 1).sample(mu.shape)
              z = mu + eps * sigma

              with torch.no_grad():
                  gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
              params['mu_c'] = mu_c
              params['logsigmasq_c'] = logsigmasq_c

              elbo, sse, elbo_terms = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
              train_elbo += elbo.item()
              train_elbo_term += elbo_terms
              train_mse += sse.item()
              loss = - elbo / batch_x.shape[0]
              loss.backward()
              optimizer.step()

          for encoder in encoder_list:
              encoder.eval()
          for decoder in decoder_list:
              decoder.eval()

          if epoch % plot_interval == 0 or epoch == n_epochs:
              # Plot the first two dimensions of the latents
              with torch.no_grad():
                  means = []
                  samples = []
                  labels = []
                  for batch in train_loader:
                      batch_x, batch_label = batch
                      x_list = [batch_x]
                      mean, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                      sigma = torch.exp(0.5 * logsigmasq)
                      eps = Normal(0, 1).sample(mean.shape)
                      z = mean + eps * sigma
                      means.append(mean)
                      samples.append(z)
                      labels.append(batch_label)

              means = torch.vstack(means).cpu()
              samples = torch.vstack(samples).cpu()
              labels = torch.hstack(labels).cpu()

              savepath = os.path.join(dirname, "latent_samples_epoch_" + str(epoch) + postfix)
              plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)

              savepath = os.path.join(dirname, "latent_means_epoch_" + str(epoch) + postfix)
              plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)


              # plot samples from generative model
              n_gen = n_train
              cluster_probs = params['pi_c'].cpu().detach().numpy() #
              fig, ax = plt.subplots(figsize=(4.5, 4))
              for j in range(n_gen):
                  c = np.random.choice(K, p=cluster_probs)
                  mu_c = params['mu_c'][c].clone().detach()
                  sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).clone().detach()
                  z = Normal(0, 1).sample(mu_c.shape) * sigma_c + mu_c
                  mu_x = decoder.forward(z)[0]
                  ax.plot(mu_x.cpu().detach().numpy())
              fig.savefig(os.path.join(dirname, "generate_samples_" + str(epoch) + postfix+ '.png'), dpi=dpi)
              plt.close()


          val_elbo = 0
          val_mse = 0
          val_elbo_term = np.zeros(4)
          with torch.no_grad():
              for (batch_idx, batch) in enumerate(val_loader):
                  batch_x, _ = batch
                  x_list = [batch_x]
                  mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                  sigma = torch.exp(0.5 * logsigmasq)
                  eps = Normal(0, 1).sample(mu.shape)
                  z = mu + eps * sigma
                  with torch.no_grad():
                      gamma_c, _, _ = em_step(z, mu, logsigmasq, params, em_reg)
                  elbo, sse, elbo_items = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
                  val_elbo += elbo.item()
                  val_mse += sse.item()
                  val_elbo_term += elbo_items

          train_elbo /= len(train_loader.dataset)
          train_elbo_term = torch.tensor(train_elbo_term) / len(train_loader.dataset)
          val_elbo /= len(val_loader.dataset)
          val_elbo_term = torch.tensor(val_elbo_term) / len(val_loader.dataset)
          train_mse /= len(train_loader.dataset)
          val_mse /= len(val_loader.dataset)

          tf = time.time()
          toc = time.perf_counter()
          print('====> Epoch: {} Train ELBO: {:.4f} Val ELBO: {:.4f}, Epoch Time (s): {:.2f}, Total Time (hrs): {:.4f}'.format(epoch, train_elbo, val_elbo, tf-ti, (toc-tic)/60/60))

          train_loss[epoch] = - train_elbo
          val_loss[epoch] = - val_elbo
          train_elbo_terms[epoch,:] = - train_elbo_term
          val_elbo_terms[epoch,:] = - val_elbo_term
          pi_history[epoch] = params['pi_c']
          train_mse_history[epoch] = train_mse
          val_mse_history[epoch] = val_mse

          if - val_elbo < min_val_loss:
              min_val_loss = - val_elbo
              torch.save(params['pi_c'], os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
              torch.save(params['mu_c'], os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
              torch.save(params['logsigmasq_c'], os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
              torch.save(encoder.state_dict(), os.path.join(dirname, 'encoder'+ postfix + '.pt'))
              torch.save(decoder.state_dict(), os.path.join(dirname, 'decoder'+ postfix + '.pt'))

          if epoch % plot_interval == 0 or epoch == n_epochs:
            # Plot the training and validation loss vs. epoch number
            plt.figure(figsize=(4.5, 4))
            # const = min(min(train_loss), min(val_loss))
            train_loss_adjusted = train_loss
            val_loss_adjusted = val_loss
            plt.plot(train_loss_adjusted.cpu()[:epoch], label='train')
            # print(train_loss_adjusted.cpu()[:epoch])
            plt.plot(val_loss_adjusted.cpu()[:epoch], label='val')
            plt.yscale('symlog')
            plt.xlabel("number of epochs")
            plt.ylabel("loss")
            plt.title("Negative Loss")
            plt.legend()
            plt.tight_layout()
            plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
            plt.close()

            # Plot each term of the training loss and validation loss
            plt.figure(figsize=(4.5, 4))
            labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
            for ii in range(4):
                train_loss_adjusted = train_elbo_terms[:epoch, ii]
                val_loss_adjusted = val_elbo_terms[:epoch, ii]
                plt.plot(train_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Train")
                plt.plot(val_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Val", linestyle='--')
            plt.xlabel("number of epochs")
            plt.yscale('symlog')
            plt.ylabel("loss")
            plt.title("Negative Loss Terms")
            plt.legend()
            plt.tight_layout()
            plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
            plt.close()

            # Plot the training and validation mse vs. epoch number
            plt.figure(figsize=(4.5, 4))
            plt.semilogy(train_mse_history.cpu().detach().numpy()[:epoch], label='train')
            plt.semilogy(val_mse_history.cpu().detach().numpy()[:epoch], label='val')
            plt.xlabel("number of epochs")
            plt.legend()
            plt.tight_layout()
            plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
            plt.close()

            # Plot the history of pi
            plt.figure(figsize=(4.5, 4))
            for i in range(K):
                plt.plot(pi_history[:, i].cpu().detach().numpy()[:epoch], label=r'$\pi$' + str(i+1))
            plt.xlabel("number of epochs")
            plt.legend()
            plt.tight_layout()
            plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
            plt.close()


      te = time.time()
      duration = datetime.timedelta(seconds=te - ts)
      print("Training took ", duration)

      # Save off pi_history, train_loss, val_loss, train_mse_history, val_mse_history
      torch.save(pi_history, os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
      torch.save(train_loss, os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
      torch.save(val_loss, os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
      torch.save(train_elbo_terms, os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
      torch.save(val_elbo_terms, os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
      torch.save(train_mse_history, os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
      torch.save(val_mse_history, os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))

      params = {}
      encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims).to("cuda")
      decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var).to("cuda")


      encoder_list = [encoder]
      decoder_list = [decoder]

      device = next(encoder.parameters()).device
      # Load in training history metrics
      pi_history = torch.load(os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
      train_loss = torch.load(os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
      val_loss = torch.load(os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
      train_elbo_terms = torch.load(os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
      val_elbo_terms = torch.load(os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
      train_mse_history = torch.load(os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
      val_mse_history = torch.load(os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))


      text_labels = [f'Cluster {i}' for i in range((n_clusters))]
      label_colors = [f'C{i+1}' for i in range((n_clusters))]
      data_colors = label_colors

      # Plot training history
      # Plot the training and validation loss vs. epoch number
      plt.figure(figsize=(4, 4))
      const = min(min(train_loss), min(val_loss))
      # const = min(10, const)
      train_loss_adjusted = train_loss
      val_loss_adjusted = val_loss
      plt.plot(train_loss_adjusted.cpu(), label='Training')
      plt.plot(val_loss_adjusted.cpu(), label='Validation')
      plt.xlabel("Number of Epochs")
      plt.ylabel("Negative Loss")
      # plt.title("Negative Loss")
      plt.yscale('symlog')
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      # plt.close()


      # Plot each term of the training loss and validation loss
      plt.figure(figsize=(4.5, 4))
      labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
      for ii in range(4):
          # print(train_elbo_terms.cpu()[ii, :epoch])
          # print(len(train_elbo_terms.cpu()[ii, :epoch]))
          train_loss_adjusted = train_elbo_terms[:, ii]
          val_loss_adjusted = val_elbo_terms[:, ii]
      plt.plot(train_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Train")
      plt.plot(val_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Val", linestyle='--')
      plt.xlabel("number of epochs")
      plt.ylabel("loss")
      plt.title("Negative Loss Terms")
      plt.yscale('symlog')
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      # plt.close()


      # Plot the sum of each term of the training loss and validation loss
      plt.figure(figsize=(4.5, 4))
      # print(train_elbo_terms.cpu()[ii, :epoch])
      # print(len(train_elbo_terms.cpu()[ii, :epoch]))
      train_loss_adjusted = train_elbo_terms.sum(axis=1)
      val_loss_adjusted = val_elbo_terms.sum(axis=1)
      plt.plot(train_loss_adjusted.cpu()[:], label=f"Train")
      plt.plot(val_loss_adjusted.cpu()[:], label=f"Val", linestyle='--')
      plt.xlabel("number of epochs")
      plt.ylabel("loss")
      plt.title("Sum of ELBO Terms")
      plt.yscale('symlog')
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'elbo_terms_sum_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      # plt.close()

      # Plot the training and validation mse vs. epoch number
      plt.figure(figsize=(4.5, 4))
      plt.semilogy(train_mse_history.cpu().detach().numpy(), label='train')
      plt.semilogy(val_mse_history.cpu().detach().numpy(), label='val')
      plt.xlabel("number of epochs")
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      # plt.close()

      # Plot the history of pi
      plt.figure(figsize=(4, 4))
      for i in range(K):
          plt.plot(pi_history[:, i].cpu().detach().numpy(), label=text_labels[i]+r' $\pi$', color=label_colors[i])
      plt.xlabel("Number of Epochs")
      plt.ylabel("Predicted Cluster Probability")
      plt.axhline(y=0.05, color='C1', linestyle='--', label='True Escape Probability')
      plt.axhline(y=0.95, color='C3', linestyle='--', label='True Capture Probability')
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      # plt.close()

      # Load best model saved
      params['pi_c'] = torch.load(os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
      params['mu_c'] = torch.load(os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
      params['logsigmasq_c'] = torch.load(os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
      encoder.load_state_dict(torch.load(os.path.join(dirname, 'encoder'+ postfix + '.pt')))
      decoder.load_state_dict(torch.load(os.path.join(dirname, 'decoder'+ postfix + '.pt')))

      encoder.eval()
      decoder.eval()

      # run one last EM step and plot training data in latent space
      for encoder in encoder_list:
          encoder.eval()

      with torch.no_grad():
          means = []
          samples = []
          labels = []
          params['hist_weights'] = torch.zeros((K, 1))
          params['hist_mu_c'] = torch.zeros((K, latent_dim))
          params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))
          for batch in train_loader:
              batch_x, batch_label = batch
              x_list = [batch_x]
              mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
              sigma = torch.exp(0.5 * logsigmasq)
              eps = Normal(0, 1).sample(mu.shape)
              z = mu + eps * sigma
              with torch.no_grad():
                  gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
              params['mu_c'] = mu_c
              params['logsigmasq_c'] = logsigmasq_c

              means.append(mu)
              samples.append(z)
              labels.append(batch_label)

      means = torch.vstack(means).cpu()
      samples = torch.vstack(samples).cpu()
      labels = torch.hstack(labels).cpu()


      savepath = os.path.join(dirname, "BEST_latent_samples"+postfix)
      plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

      savepath = os.path.join(dirname, "BEST_latent_means"+postfix)
      plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

      # plot test data in latent space
      with torch.no_grad():
          test_means = []
          test_labels = []
          for batch in test_loader:
              batch_x, batch_label = batch
              x_list = [batch_x]
              mean, _ = encoder_step(x_list, encoder_list, decoder_list)
              test_means.append(mean)
              test_labels.append(batch_label)

      test_means = torch.vstack(test_means).cpu()
      test_labels = torch.hstack(test_labels).cpu()


      savepath = os.path.join(dirname, "BEST_test_latent_samples"+postfix)
      plot_latent_space_with_clusters(test_means, test_labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

      # plot decoding results from cluster means # todo: expand this function for multi-modal data
      fig, ax = plt.subplots(figsize=(4.5, 4))
      for i in range(K):
          # with torch.no_grad:
          x_mean = decoder.forward(params['mu_c'][i])[0]
          ax.plot(x_mean.cpu().detach().numpy(), label="decoded $\mu$"+str(i+1))
      ax.legend()
      plt.title("Decoded Means")
      fig.savefig(os.path.join(dirname, "BEST_decoded_means"+postfix+'.png'), dpi=dpi)
      # plt.close()

      # plot samples from generative model
      n_gen = n_train
      cluster_probs = params['pi_c'].cpu().detach().numpy()
      fig, ax = plt.subplots(figsize=(4.5, 4))
      for j in range(n_gen):
          c = np.random.choice(K, p=cluster_probs)
          # print(c)
          mu_c = params['mu_c'][c].cpu().clone().detach()
          sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).cpu().clone().detach()
          z = Normal(0, 1).sample(mu_c.shape).cpu().clone().detach() * sigma_c + mu_c
          # print(z)
          mu_x = decoder.forward(z.cuda())[0].cpu().clone().detach()
          sigma_x = torch.exp(0.5 * decoder.forward(z.cuda())[1])
          sample_x = Normal(0, 1).sample(mu_x.shape).cpu().clone().detach() * sigma_x.cpu().clone().detach() + mu_x
          ax.plot(sample_x.cpu().detach().numpy())
      plt.title("Generated Samples")
      fig.savefig(os.path.join(dirname, "BEST_generate_samples"+postfix+'.png'), dpi=dpi)
      # plt.close()

      np.savez(dirname + postfix, train_loss=train_loss.cpu().detach().numpy(), val_loss=val_loss.cpu().detach().numpy(),
          train_mse=train_mse_history.cpu().detach().numpy(), val_mse=val_mse_history.cpu().detach().numpy(),
          pi_history=pi_history.cpu().detach().numpy(),
          cluster_probs=params['pi_c'].cpu().detach().numpy(),
          cluster_means=params['mu_c'].cpu().detach().numpy(),
          cluster_vars=torch.exp(params['logsigmasq_c']).cpu().detach().numpy())


      print("Training data size", n_train)
      print("Fraction of downward curves:", (torch.sum(labels == 0) / n_train).item())
      print("Cluster 1 probability:", cluster_probs.min().item())
# Out:
# <>:496: SyntaxWarning: invalid escape sequence '\m'
# <>:496: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipython-input-568840050.py:496: SyntaxWarning: invalid escape sequence '\m'
#   ax.plot(x_mean.cpu().detach().numpy(), label="decoded $\mu$"+str(i+1))
# Filepath directory: drive/MyDrive/piguid/gmvae_orion_mars_return_20260111_164344_L3_C3
# Filepath postfix: _42_1024_128_128_36_18_9_3_3_0.001000_128_0.001000_0.000010_10000.000000_
# [1318, 2431, 629, 202, 2259, 1781, 468, 1986, 623, 2118, 2120, 2405, 397, 1770, 1714, 175, 2051, 860, 2106, 895, 854, 2368, 1837, 191, 1804, 951, 2222, 568, 184, 159, 1822, 447, 2337, 1360, 2137, 1800, 1113, 1298, 334, 2215, 986, 1435, 530, 1985, 326, 44, 534, 1989, 767, 2029, 279, 1229, 1427, 109, 734, 2145, 97, 1354, 2310, 1494, 817, 204, 866, 1487, 1291, 648, 944, 2020, 1554, 1139, 1098, 2303, 1984, 1860, 1353, 1170, 777, 2124, 1477, 392, 603, 2231, 810, 2014, 1978, 654, 166, 911, 289, 396, 1728, 1366, 2229, 1527, 1811, 2317, 2475, 1944, 103, 251, 853, 1571, 2411, 1195, 336, 500, 151, 1448, 1202, 39, 394, 1864, 121, 533, 2336, 2028, 1639, 18, 1046, 207, 2499, 1420, 1249, 1121, 1357, 1665, 1885, 269, 1164, 261, 2379, 490, 287, 2050, 1389, 1936, 528, 1694, 1957, 1269, 1760, 1850, 1211, 1475, 1730, 1150, 671, 1874, 1755, 929, 1014, 600, 1542, 1345, 746, 1620, 1495, 730, 1383, 248, 1780, 1387, 1938, 2160, 1982, 260, 2205, 2355, 673, 382, 2010, 1289, 867, 502, 1721, 1840, 1990, 2366, 2059, 464, 1675, 2453, 1897, 914, 322, 2176, 742, 494, 1931, 351, 1839, 1296, 683, 2228, 981, 9, 738, 540, 1685, 633, 2465, 754, 1141, 2463, 615, 380, 472, 1089, 2069, 1991, 65, 122, 1627, 1865, 1866, 1827, 1236, 613, 2003, 2441, 1470, 1607, 697, 1683, 1791, 1310, 1677, 1263, 950, 1939, 124, 2200, 230, 1329, 1433, 2346, 498, 350, 2225, 2078, 254, 137, 1367, 679, 180, 2006, 56, 399, 22, 900, 2497, 2490, 2286, 1725, 2143, 1709, 321, 575, 1023, 1517, 7, 1337, 1881, 1086, 1794, 786, 4, 2340, 2401, 247, 1224, 539, 1523, 717, 2198, 2419, 1574, 1951, 1188, 1441, 1557, 1895, 2406, 1323, 1266, 1142, 926, 576, 765, 1179, 55, 163, 2194, 364, 1782, 1238, 225, 1473, 1451, 640, 1393, 455, 463, 2378, 2391, 1209, 983, 2022, 1703, 1646, 1115, 2159, 2245, 749, 2292, 1649, 784, 2390, 939, 2421, 2443, 1592, 1316, 778, 899, 1455, 1916, 1371, 2454, 1870, 2377, 992, 1347, 1180, 770, 1610, 825, 2212, 59, 1586, 2258, 2474, 424, 1926, 2307, 505, 998, 1022, 1941, 1243, 2271, 1267, 385, 1924, 1563, 67, 649, 118, 2185, 1483, 1072, 2206, 462, 224, 1659, 1786, 1934, 1489, 1381, 1674, 2254, 2480, 1877, 1967, 1020, 1005, 779, 2387, 1060, 132, 655, 1069, 2156, 154, 86, 593, 960, 1273, 1184, 739, 470, 2116, 1538, 2262, 624, 234, 856, 676, 840, 1058, 1421, 2221, 706, 2320, 2306, 790, 1896, 1768, 837, 1821, 689, 452, 2048, 1160, 2086, 2164, 138, 606, 243, 323, 431, 1315, 646, 1949, 2325, 2260, 1698, 410, 904, 1342, 173, 1217, 1632, 119, 91, 2459, 1240, 1614, 1788, 1654, 2151, 2026, 741, 391, 2279, 2060, 62, 1465, 1817, 1206, 1580, 1609, 2153, 1712, 2084, 21, 1532, 1746, 1241, 1643, 112, 1161, 366, 2372, 2252, 563, 1838, 2064, 1964, 328, 1218, 1552, 1486, 1777, 1998, 1106, 2359, 1690, 1438, 1460, 1830, 1409, 1623, 1679, 849, 959, 943, 1884, 2129, 2442, 144, 1880, 418, 2385, 123, 2236, 1686, 2430, 1739, 988, 420, 1596, 771, 1908, 758, 2318, 2109, 548, 924, 1948, 2210, 53, 1275, 521, 493, 409, 1493, 1593, 1929, 1333, 1631, 1002, 1892, 2416, 1648, 1918, 29, 955, 1328, 769, 2322, 1341, 2170, 1215, 2298, 885, 700, 1088, 1006, 763, 580, 1019, 1423, 1729, 2158, 1710, 1030, 516, 677, 1159, 1292, 1570, 2333, 483, 1577, 228, 552, 1028, 1503, 1744, 2438, 1533, 1408, 722, 1650, 1297, 1656, 188, 1566, 1727, 346, 841, 1432, 620, 388, 48, 1611, 1251, 2472, 1719, 2295, 1524, 2451, 1603, 1187, 1288, 1672, 1178, 1994, 1434, 76, 139, 2226, 179, 2081, 1132, 1724, 1506, 227, 2345, 1711, 1752, 414, 2133, 972, 1153, 2038, 1260, 604, 1488, 2488, 256, 2253, 816, 1828, 2470, 785, 1081, 936, 644, 74, 1899, 1111, 370, 1171, 58, 1769, 993, 745, 756, 1068, 176, 2332, 1062, 1390, 449, 1321, 889, 19, 1759, 253, 2104, 2066, 596, 1348, 1736, 1450, 1923, 2189, 1128, 1903, 1995, 581, 1051, 674, 513, 1140, 85, 2249, 332, 2017, 874, 495, 319, 828, 719, 2404, 1074, 31, 2027, 1689, 252, 1617, 2192, 1625, 617, 1301, 1331, 211, 1511, 491, 2209, 2478, 421, 908, 1589, 647, 1754, 619, 918, 307, 973, 2191, 804, 1203, 2021, 222, 1499, 643, 1, 308, 467, 610, 2099, 1462, 750, 2113, 2199, 1101, 20, 1904, 2433, 2331, 2203, 2450, 538, 21 ...
# Loading File...
# ...File Loaded
# Sample List: [1318, 2431, 629, 202, 2259, 1781, 468, 1986, 623, 2118, 2120, 2405, 397, 1770, 1714, 175, 2051, 860, 2106, 895, 854, 2368, 1837, 191, 1804, 951, 2222, 568, 184, 159, 1822, 447, 2337, 1360, 2137, 1800, 1113, 1298, 334, 2215, 986, 1435, 530, 1985, 326, 44, 534, 1989, 767, 2029, 279, 1229, 1427, 109, 734, 2145, 97, 1354, 2310, 1494, 817, 204, 866, 1487, 1291, 648, 944, 2020, 1554, 1139, 1098, 2303, 1984, 1860, 1353, 1170, 777, 2124, 1477, 392, 603, 2231, 810, 2014, 1978, 654, 166, 911, 289, 396, 1728, 1366, 2229, 1527, 1811, 2317, 2475, 1944, 103, 251, 853, 1571, 2411, 1195, 336, 500, 151, 1448, 1202, 39, 394, 1864, 121, 533, 2336, 2028, 1639, 18, 1046, 207, 2499, 1420, 1249, 1121, 1357, 1665, 1885, 269, 1164, 261, 2379, 490, 287, 2050, 1389, 1936, 528, 1694, 1957, 1269, 1760, 1850, 1211, 1475, 1730, 1150, 671, 1874, 1755, 929, 1014, 600, 1542, 1345, 746, 1620, 1495, 730, 1383, 248, 1780, 1387, 1938, 2160, 1982, 260, 2205, 2355, 673, 382, 2010, 1289, 867, 502, 1721, 1840, 1990, 2366, 2059, 464, 1675, 2453, 1897, 914, 322, 2176, 742, 494, 1931, 351, 1839, 1296, 683, 2228, 981, 9, 738, 540, 1685, 633, 2465, 754, 1141, 2463, 615, 380, 472, 1089, 2069, 1991, 65, 122, 1627, 1865, 1866, 1827, 1236, 613, 2003, 2441, 1470, 1607, 697, 1683, 1791, 1310, 1677, 1263, 950, 1939, 124, 2200, 230, 1329, 1433, 2346, 498, 350, 2225, 2078, 254, 137, 1367, 679, 180, 2006, 56, 399, 22, 900, 2497, 2490, 2286, 1725, 2143, 1709, 321, 575, 1023, 1517, 7, 1337, 1881, 1086, 1794, 786, 4, 2340, 2401, 247, 1224, 539, 1523, 717, 2198, 2419, 1574, 1951, 1188, 1441, 1557, 1895, 2406, 1323, 1266, 1142, 926, 576, 765, 1179, 55, 163, 2194, 364, 1782, 1238, 225, 1473, 1451, 640, 1393, 455, 463, 2378, 2391, 1209, 983, 2022, 1703, 1646, 1115, 2159, 2245, 749, 2292, 1649, 784, 2390, 939, 2421, 2443, 1592, 1316, 778, 899, 1455, 1916, 1371, 2454, 1870, 2377, 992, 1347, 1180, 770, 1610, 825, 2212, 59, 1586, 2258, 2474, 424, 1926, 2307, 505, 998, 1022, 1941, 1243, 2271, 1267, 385, 1924, 1563, 67, 649, 118, 2185, 1483, 1072, 2206, 462, 224, 1659, 1786, 1934, 1489, 1381, 1674, 2254, 2480, 1877, 1967, 1020, 1005, 779, 2387, 1060, 132, 655, 1069, 2156, 154, 86, 593, 960, 1273, 1184, 739, 470, 2116, 1538, 2262, 624, 234, 856, 676, 840, 1058, 1421, 2221, 706, 2320, 2306, 790, 1896, 1768, 837, 1821, 689, 452, 2048, 1160, 2086, 2164, 138, 606, 243, 323, 431, 1315, 646, 1949, 2325, 2260, 1698, 410, 904, 1342, 173, 1217, 1632, 119, 91, 2459, 1240, 1614, 1788, 1654, 2151, 2026, 741, 391, 2279, 2060, 62, 1465, 1817, 1206, 1580, 1609, 2153, 1712, 2084, 21, 1532, 1746, 1241, 1643, 112, 1161, 366, 2372, 2252, 563, 1838, 2064, 1964, 328, 1218, 1552, 1486, 1777, 1998, 1106, 2359, 1690, 1438, 1460, 1830, 1409, 1623, 1679, 849, 959, 943, 1884, 2129, 2442, 144, 1880, 418, 2385, 123, 2236, 1686, 2430, 1739, 988, 420, 1596, 771, 1908, 758, 2318, 2109, 548, 924, 1948, 2210, 53, 1275, 521, 493, 409, 1493, 1593, 1929, 1333, 1631, 1002, 1892, 2416, 1648, 1918, 29, 955, 1328, 769, 2322, 1341, 2170, 1215, 2298, 885, 700, 1088, 1006, 763, 580, 1019, 1423, 1729, 2158, 1710, 1030, 516, 677, 1159, 1292, 1570, 2333, 483, 1577, 228, 552, 1028, 1503, 1744, 2438, 1533, 1408, 722, 1650, 1297, 1656, 188, 1566, 1727, 346, 841, 1432, 620, 388, 48, 1611, 1251, 2472, 1719, 2295, 1524, 2451, 1603, 1187, 1288, 1672, 1178, 1994, 1434, 76, 139, 2226, 179, 2081, 1132, 1724, 1506, 227, 2345, 1711, 1752, 414, 2133, 972, 1153, 2038, 1260, 604, 1488, 2488, 256, 2253, 816, 1828, 2470, 785, 1081, 936, 644, 74, 1899, 1111, 370, 1171, 58, 1769, 993, 745, 756, 1068, 176, 2332, 1062, 1390, 449, 1321, 889, 19, 1759, 253, 2104, 2066, 596, 1348, 1736, 1450, 1923, 2189, 1128, 1903, 1995, 581, 1051, 674, 513, 1140, 85, 2249, 332, 2017, 874, 495, 319, 828, 719, 2404, 1074, 31, 2027, 1689, 252, 1617, 2192, 1625, 617, 1301, 1331, 211, 1511, 491, 2209, 2478, 421, 908, 1589, 647, 1754, 619, 918, 307, 973, 2191, 804, 1203, 2021, 222, 1499, 643, 1, 308, 467, 610, 2099, 1462, 750, 2113, 2199, 1101, 20, 1904, 2433, 2331, 2203,  ...
#   0%|          | 0/1280 [00:00<?, ?it/s]
# /content/piguid_training/gmvae_common.py:265: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   elbo_terms[0] = Normal(mu_, torch.exp(0.5 * logsigmasq_)).log_prob(x_list[d]).sum()
# ====> Epoch: 0 Train ELBO: -886670.8047 Val ELBO: -839368.5000, Epoch Time (s): 6.90, Total Time (hrs): 0.0019
# ====> Epoch: 1 Train ELBO: -792890.1250 Val ELBO: -737234.9375, Epoch Time (s): 0.09, Total Time (hrs): 0.0023
# ====> Epoch: 2 Train ELBO: -688625.9531 Val ELBO: -630936.5000, Epoch Time (s): 0.09, Total Time (hrs): 0.0023
# ====> Epoch: 3 Train ELBO: -556375.5938 Val ELBO: -475948.6562, Epoch Time (s): 0.10, Total Time (hrs): 0.0023
# ====> Epoch: 4 Train ELBO: -391500.5195 Val ELBO: -293078.7812, Epoch Time (s): 0.09, Total Time (hrs): 0.0024
# ====> Epoch: 5 Train ELBO: -234131.6836 Val ELBO: -183637.0469, Epoch Time (s): 0.09, Total Time (hrs): 0.0024
# ====> Epoch: 6 Train ELBO: -144250.3857 Val ELBO: -113101.7656, Epoch Time (s): 0.09, Total Time (hrs): 0.0024
# ====> Epoch: 7 Train ELBO: -91983.7324 Val ELBO: -62529.7305, Epoch Time (s): 0.09, Total Time (hrs): 0.0025
# ====> Epoch: 8 Train ELBO: -52951.0742 Val ELBO: -38434.6914, Epoch Time (s): 0.08, Total Time (hrs): 0.0025
# ====> Epoch: 9 Train ELBO: -36565.8579 Val ELBO: -31012.5742, Epoch Time (s): 0.09, Total Time (hrs): 0.0025
# ====> Epoch: 10 Train ELBO: -31235.4744 Val ELBO: -28846.4219, Epoch Time (s): 0.09, Total Time (hrs): 0.0026
# ====> Epoch: 11 Train ELBO: -28967.7563 Val ELBO: -27138.2812, Epoch Time (s): 0.09, Total Time (hrs): 0.0026
# ====> Epoch: 12 Train ELBO: -27328.1687 Val ELBO: -25608.1328, Epoch Time (s): 0.09, Total Time (hrs): 0.0026
# ====> Epoch: 13 Train ELBO: -26276.8943 Val ELBO: -24691.6406, Epoch Time (s): 0.09, Total Time (hrs): 0.0027
# ====> Epoch: 14 Train ELBO: -25115.3950 Val ELBO: -23524.8184, Epoch Time (s): 0.08, Total Time (hrs): 0.0027
# ====> Epoch: 15 Train ELBO: -24090.1013 Val ELBO: -22296.1426, Epoch Time (s): 0.09, Total Time (hrs): 0.0028
# ====> Epoch: 16 Train ELBO: -23442.1865 Val ELBO: -22324.9707, Epoch Time (s): 0.08, Total Time (hrs): 0.0028
# ====> Epoch: 17 Train ELBO: -22371.1973 Val ELBO: -21071.0664, Epoch Time (s): 0.08, Total Time (hrs): 0.0028
# ====> Epoch: 18 Train ELBO: -21341.0466 Val ELBO: -20391.8828, Epoch Time (s): 0.09, Total Time (hrs): 0.0028
# ====> Epoch: 19 Train ELBO: -20418.3867 Val ELBO: -18943.0820, Epoch Time (s): 0.09, Total Time (hrs): 0.0029
# ====> Epoch: 20 Train ELBO: -19454.9862 Val ELBO: -18019.2031, Epoch Time (s): 0.09, Total Time (hrs): 0.0029
# ====> Epoch: 21 Train ELBO: -18382.1908 Val ELBO: -17285.3477, Epoch Time (s): 0.08, Total Time (hrs): 0.0029
# ====> Epoch: 22 Train ELBO: -17650.4805 Val ELBO: -16508.7480, Epoch Time (s): 0.09, Total Time (hrs): 0.0030
# ====> Epoch: 23 Train ELBO: -16896.3470 Val ELBO: -15748.2246, Epoch Time (s): 0.10, Total Time (hrs): 0.0030
# ====> Epoch: 24 Train ELBO: -16146.3706 Val ELBO: -15173.1504, Epoch Time (s): 0.09, Total Time (hrs): 0.0031
# ====> Epoch: 25 Train ELBO: -15462.9156 Val ELBO: -14403.6670, Epoch Time (s): 0.08, Total Time (hrs): 0.0031
# ====> Epoch: 26 Train ELBO: -14622.6534 Val ELBO: -13544.0449, Epoch Time (s): 0.09, Total Time (hrs): 0.0031
# ====> Epoch: 27 Train ELBO: -13728.7980 Val ELBO: -12670.0391, Epoch Time (s): 0.09, Total Time (hrs): 0.0032
# ====> Epoch: 28 Train ELBO: -12792.7003 Val ELBO: -11641.3535, Epoch Time (s): 0.09, Total Time (hrs): 0.0032
# ====> Epoch: 29 Train ELBO: -11695.7083 Val ELBO: -10696.7266, Epoch Time (s): 0.09, Total Time (hrs): 0.0032
# ====> Epoch: 30 Train ELBO: -10513.5092 Val ELBO: -9497.4824, Epoch Time (s): 0.09, Total Time (hrs): 0.0033
# ====> Epoch: 31 Train ELBO: -9229.2963 Val ELBO: -8221.0615, Epoch Time (s): 0.10, Total Time (hrs): 0.0033
# ====> Epoch: 32 Train ELBO: -7854.0084 Val ELBO: -6730.3555, Epoch Time (s): 0.09, Total Time (hrs): 0.0033
# ====> Epoch: 33 Train ELBO: -6423.4177 Val ELBO: -5453.8521, Epoch Time (s): 0.08, Total Time (hrs): 0.0034
# ====> Epoch: 34 Train ELBO: -5113.1080 Val ELBO: -4325.1997, Epoch Time (s): 0.09, Total Time (hrs): 0.0034
# ====> Epoch: 35 Train ELBO: -4072.7685 Val ELBO: -3508.5762, Epoch Time (s): 0.09, Total Time (hrs): 0.0034
# ====> Epoch: 36 Train ELBO: -3329.4399 Val ELBO: -2943.0527, Epoch Time (s): 0.09, Total Time (hrs): 0.0035
# ====> Epoch: 37 Train ELBO: -2807.6591 Val ELBO: -2547.8962, Epoch Time (s): 0.09, Total Time (hrs): 0.0035
# ====> Epoch: 38 Train ELBO: -2423.1675 Val ELBO: -2219.3855, Epoch Time (s): 0.09, Total Time (hrs): 0.0036
# ====> Epoch: 39 Train ELBO: -2160.3847 Val ELBO: -2016.6313, Epoch Time (s): 0.10, Total Time (hrs): 0.0036
# ====> Epoch: 40 Train ELBO: -1965.8270 Val ELBO: -1877.3966, Epoch Time (s): 0.09, Total Time (hrs): 0.0036
# ====> Epoch: 41 Train ELBO: -1844.1505 Val ELBO: -1768.4525, Epoch Time (s): 0.09, Total Time (hrs): 0.0037
# ====> Epoch: 42 Train ELBO: -1768.3629 Val ELBO: -1714.1361, Epoch Time (s): 0.09, Total Time (hrs): 0.0037
# ====> Epoch: 43 Train ELBO: -1714.2502 Val ELBO: -1670.2617, Epoch Time (s): 0.09, Total Time (hrs): 0.0037
# ====> Epoch: 44 Train ELBO: -1671.7951 Val ELBO: -1646.5018, Epoch Time (s): 0.09, Total Time (hrs): 0.0038
# ====> Epoch: 45 Train ELBO: -1632.5000 Val ELBO: -1627.4291, Epoch Time (s): 0.08, Total Time (hrs): 0.0038
# ====> Epoch: 46 Train ELBO: -1622.6131 Val ELBO: -1627.4008, Epoch Time (s): 0.09, Total Time (hrs): 0.0038
# ====> Epoch: 47 Train ELBO: -1592.6209 Val ELBO: -1600.2163, Epoch Time (s): 0.09, Total Time (hrs): 0.0039
# ====> Epoch: 48 Train ELBO: -1589.1794 Val ELBO: -1597.2201, Epoch Time (s): 0.09, Total Time (hrs): 0.0039
# ====> Epoch: 49 Train ELBO: -1586.9396 Val ELBO: -1580.9435, Epoch Time (s): 0.08, Total Time (hrs): 0.0039
# ====> Epoch: 50 Train ELBO: -1580.5381 Val ELBO: -1581.8289, Epoch Time (s): 0.09, Total Time (hrs): 0.0040
# ====> Epoch: 51 Train ELBO: -1570.8090 Val ELBO: -1583.8964, Epoch Time (s): 0.09, Total Time (hrs): 0.0040
# ====> Epoch: 52 Train ELBO: -1567.9868 Val ELBO: -1555.7762, Epoch Time (s): 0.08, Total Time (hrs): 0.0040
# ====> Epoch: 53 Train ELBO: -1558.0010 Val ELBO: -1552.3785, Epoch Time (s): 0.08, Total Time (hrs): 0.0040
# ====> Epoch: 54 Train ELBO: -1553.5361 Val ELBO: -1547.6042, Epoch Time (s): 0.10, Total Time (hrs): 0.0041
# ====> Epoch: 55 Train ELBO: -1542.8341 Val ELBO: -1554.4091, Epoch Time (s): 0.14, Total Time (hrs): 0.0041
# ====> Epoch: 56 Train ELBO: -1548.5736 Val ELBO: -1557.6143, Epoch Time (s): 0.14, Total Time (hrs): 0.0042
# ====> Epoch: 57 Train ELBO: -1537.7649 Val ELBO: -1540.8147, Epoch Time (s): 0.13, Total Time (hrs): 0.0042
# ====> Epoch: 58 Train ELBO: -1538.9618 Val ELBO: -1559.1021, Epoch Time (s): 0.13, Total Time (hrs): 0.0043
# ====> Epoch: 59 Train ELBO: -1532.8369 Val ELBO: -1542.7412, Epoch Time (s): 0.13, Total Time (hrs): 0.0043
# ====> Epoch: 60 Train ELBO: -1533.8418 Val ELBO: -1539.1456, Epoch Time (s): 0.12, Total Time (hrs): 0.0043
# ====> Epoch: 61 Train ELBO: -1530.2838 Val ELBO: -1533.7609, Epoch Time (s): 0.14, Total Time (hrs): 0.0044
# ====> Epoch: 62 Train ELBO: -1525.5783 Val ELBO: -1544.1500, Epoch Time (s): 0.12, Total Time (hrs): 0.0044
# ====> Epoch: 63 Train ELBO: -1518.4838 Val ELBO: -1538.2383, Epoch Time (s): 0.12, Total Time (hrs): 0.0045
# ====> Epoch: 64 Train ELBO: -1515.9442 Val ELBO: -1519.6979, Epoch Time (s): 0.13, Total Time (hrs): 0.0045
# ====> Epoch: 65 Train ELBO: -1514.6173 Val ELBO: -1518.7028, Epoch Time (s): 0.14, Total Time (hrs): 0.0045
# ====> Epoch: 66 Train ELBO: -1513.9912 Val ELBO: -1533.3739, Epoch Time (s): 0.12, Total Time (hrs): 0.0046
# ====> Epoch: 67 Train ELBO: -1512.2702 Val ELBO: -1525.6802, Epoch Time (s): 0.12, Total Time (hrs): 0.0046
# ====> Epoch: 68 Train ELBO: -1509.5355 Val ELBO: -1519.3617, Epoch Time (s): 0.12, Total Time (hrs): 0.0047
# ====> Epoch: 69 Train ELBO: -1506.3303 Val ELBO: -1504.0579, Epoch Time (s): 0.13, Total Time (hrs): 0.0047
# ====> Epoch: 70 Train ELBO: -1503.0855 Val ELBO: -1517.8224, Epoch Time (s): 0.12, Total Time (hrs): 0.0047
# ====> Epoch: 71 Train ELBO: -1508.8657 Val ELBO: -1517.1975, Epoch Time (s): 0.12, Total Time (hrs): 0.0048
# ====> Epoch: 72 Train ELBO: -1504.4924 Val ELBO: -1519.2623, Epoch Time (s): 0.13, Total Time (hrs): 0.0048
# ====> Epoch: 73 Train ELBO: -1502.2613 Val ELBO: -1507.8925, Epoch Time (s): 0.14, Total Time (hrs): 0.0048
# ====> Epoch: 74 Train ELBO: -1506.1622 Val ELBO: -1515.4735, Epoch Time (s): 0.13, Total Time (hrs): 0.0049
# ====> Epoch: 75 Train ELBO: -1499.2650 Val ELBO: -1500.7725, Epoch Time (s): 0.13, Total Time (hrs): 0.0049
# ====> Epoch: 76 Train ELBO: -1493.3082 Val ELBO: -1505.4769, Epoch Time (s): 0.14, Total Time (hrs): 0.0050
# ====> Epoch: 77 Train ELBO: -1496.1988 Val ELBO: -1501.3188, Epoch Time (s): 0.14, Total Time (hrs): 0.0050
# ====> Epoch: 78 Train ELBO: -1492.5161 Val ELBO: -1499.8035, Epoch Time (s): 0.14, Total Time (hrs): 0.0050
# ====> Epoch: 79 Train ELBO: -1484.4151 Val ELBO: -1487.3926, Epoch Time (s): 0.13, Total Time (hrs): 0.0051
# ====> Epoch: 80 Train ELBO: -1484.1636 Val ELBO: -1496.1587, Epoch Time (s): 0.08, Total Time (hrs): 0.0051
# ====> Epoch: 81 Train ELBO: -1477.9405 Val ELBO: -1485.0825, Epoch Time (s): 0.08, Total Time (hrs): 0.0052
# ====> Epoch: 82 Train ELBO: -1484.1234 Val ELBO: -1492.0341, Epoch Time (s): 0.09, Total Time (hrs): 0.0052
# ====> Epoch: 83 Train ELBO: -1481.0291 Val ELBO: -1491.9674, Epoch Time (s): 0.08, Total Time (hrs): 0.0052
# ====> Epoch: 84 Train ELBO: -1477.6780 Val ELBO: -1492.3970, Epoch Time (s): 0.08, Total Time (hrs): 0.0052
# ====> Epoch: 85 Train ELBO: -1477.3297 Val ELBO: -1485.1077, Epoch Time (s): 0.08, Total Time (hrs): 0.0053
# ====> Epoch: 86 Train ELBO: -1472.2124 Val ELBO: -1487.8618, Epoch Time (s): 0.08, Total Time (hrs): 0.0053
# ====> Epoch: 87 Train ELBO: -1478.8762 Val ELBO: -1487.0728, Epoch Time (s): 0.08, Total Time (hrs): 0.0053
# ====> Epoch: 88 Train ELBO: -1470.6674 Val ELBO: -1483.7634, Epoch Time (s): 0.08, Total Time (hrs): 0.0053
# ====> Epoch: 89 Train ELBO: -1470.3385 Val ELBO: -1476.4988, Epoch Time (s): 0.09, Total Time (hrs): 0.0054
# ====> Epoch: 90 Train ELBO: -1467.1223 Val ELBO: -1477.3915, Epoch Time (s): 0.09, Total Time (hrs): 0.0054
# ====> Epoch: 91 Train ELBO: -1466.9229 Val ELBO: -1487.9493, Epoch Time (s): 0.08, Total Time (hrs): 0.0054
# ====> Epoch: 92 Train ELBO: -1470.0312 Val ELBO: -1482.7379, Epoch Time (s): 0.08, Total Time (hrs): 0.0054
# ====> Epoch: 93 Train ELBO: -1464.3468 Val ELBO: -1484.0789, Epoch Time (s): 0.09, Total Time (hrs): 0.0055
# ====> Epoch: 94 Train ELBO: -1462.1081 Val ELBO: -1464.6736, Epoch Time (s): 0.09, Total Time (hrs): 0.0055
# ====> Epoch: 95 Train ELBO: -1456.7902 Val ELBO: -1473.0576, Epoch Time (s): 0.09, Total Time (hrs): 0.0055
# ====> Epoch: 96 Train ELBO: -1465.3645 Val ELBO: -1474.9213, Epoch Time (s): 0.08, Total Time (hrs): 0.0056
# ====> Epoch: 97 Train ELBO: -1463.5692 Val ELBO: -1471.1891, Epoch Time (s): 0.08, Total Time (hrs): 0.0056
# ====> Epoch: 98 Train ELBO: -1460.1108 Val ELBO: -1470.0281, Epoch Time (s): 0.09, Total Time (hrs): 0.0056
# ====> Epoch: 99 Train ELBO: -1453.8009 Val ELBO: -1465.2992, Epoch Time (s): 0.09, Total Time (hrs): 0.0056
# ====> Epoch: 100 Train ELBO: -1454.1247 Val ELBO: -1466.5304, Epoch Time (s): 0.10, Total Time (hrs): 0.0057
# ====> Epoch: 101 Train ELBO: -1454.1321 Val ELBO: -1464.9521, Epoch Time (s): 0.09, Total Time (hrs): 0.0057
# ====> Epoch: 102 Train ELBO: -1456.0231 Val ELBO: -1463.6212, Epoch Time (s): 0.08, Total Time (hrs): 0.0057
# ====> Epoch: 103 Train ELBO: -1449.6173 Val ELBO: -1465.5618, Epoch Time (s): 0.09, Total Time (hrs): 0.0057
# ====> Epoch: 104 Train ELBO: -1452.2393 Val ELBO: -1467.2816, Epoch Time (s): 0.09, Total Time (hrs): 0.0058
# ====> Epoch: 105 Train ELBO: -1445.3979 Val ELBO: -1458.1312, Epoch Time (s): 0.08, Total Time (hrs): 0.0058
# ====> Epoch: 106 Train ELBO: -1445.0371 Val ELBO: -1453.8623, Epoch Time (s): 0.08, Total Time (hrs): 0.0058
# ====> Epoch: 107 Train ELBO: -1441.7386 Val ELBO: -1466.0430, Epoch Time (s): 0.08, Total Time (hrs): 0.0058
# ====> Epoch: 108 Train ELBO: -1445.1212 Val ELBO: -1455.4679, Epoch Time (s): 0.08, Total Time (hrs): 0.0059
# ====> Epoch: 109 Train ELBO: -1450.6459 Val ELBO: -1453.5763, Epoch Time (s): 0.09, Total Time (hrs): 0.0059
# ====> Epoch: 110 Train ELBO: -1442.6568 Val ELBO: -1447.1761, Epoch Time (s): 0.09, Total Time (hrs): 0.0059
# ====> Epoch: 111 Train ELBO: -1437.3466 Val ELBO: -1462.3958, Epoch Time (s): 0.09, Total Time (hrs): 0.0060
# ====> Epoch: 112 Train ELBO: -1439.0963 Val ELBO: -1448.6777, Epoch Time (s): 0.08, Total Time (hrs): 0.0060
# ====> Epoch: 113 Train ELBO: -1436.0307 Val ELBO: -1447.0802, Epoch Time (s): 0.08, Total Time (hrs): 0.0060
# ====> Epoch: 114 Train ELBO: -1434.6183 Val ELBO: -1441.8691, Epoch Time (s): 0.08, Total Time (hrs): 0.0060
# ====> Epoch: 115 Train ELBO: -1431.6721 Val ELBO: -1449.2722, Epoch Time (s): 0.08, Total Time (hrs): 0.0061
# ====> Epoch: 116 Train ELBO: -1430.3372 Val ELBO: -1440.4935, Epoch Time (s): 0.08, Total Time (hrs): 0.0061
# ====> Epoch: 117 Train ELBO: -1424.1357 Val ELBO: -1442.7084, Epoch Time (s): 0.08, Total Time (hrs): 0.0061
# ====> Epoch: 118 Train ELBO: -1428.7736 Val ELBO: -1445.5482, Epoch Time (s): 0.08, Total Time (hrs): 0.0062
# ====> Epoch: 119 Train ELBO: -1424.4812 Val ELBO: -1437.0071, Epoch Time (s): 0.08, Total Time (hrs): 0.0062
# ====> Epoch: 120 Train ELBO: -1427.8691 Val ELBO: -1439.9047, Epoch Time (s): 0.09, Total Time (hrs): 0.0062
# ====> Epoch: 121 Train ELBO: -1432.7336 Val ELBO: -1432.6108, Epoch Time (s): 0.10, Total Time (hrs): 0.0062
# ====> Epoch: 122 Train ELBO: -1431.9748 Val ELBO: -1447.1910, Epoch Time (s): 0.09, Total Time (hrs): 0.0063
# ====> Epoch: 123 Train ELBO: -1425.9849 Val ELBO: -1434.2620, Epoch Time (s): 0.08, Total Time (hrs): 0.0063
# ====> Epoch: 124 Train ELBO: -1421.6634 Val ELBO: -1433.5361, Epoch Time (s): 0.08, Total Time (hrs): 0.0063
# ====> Epoch: 125 Train ELBO: -1422.2099 Val ELBO: -1433.4226, Epoch Time (s): 0.09, Total Time (hrs): 0.0064
# ====> Epoch: 126 Train ELBO: -1415.4469 Val ELBO: -1434.0701, Epoch Time (s): 0.08, Total Time (hrs): 0.0064
# ====> Epoch: 127 Train ELBO: -1415.0045 Val ELBO: -1428.6589, Epoch Time (s): 0.08, Total Time (hrs): 0.0064
# ====> Epoch: 128 Train ELBO: -1413.9592 Val ELBO: -1429.5873, Epoch Time (s): 0.08, Total Time (hrs): 0.0064
# ====> Epoch: 129 Train ELBO: -1409.5854 Val ELBO: -1426.2800, Epoch Time (s): 0.08, Total Time (hrs): 0.0065
# ====> Epoch: 130 Train ELBO: -1409.2557 Val ELBO: -1421.8501, Epoch Time (s): 0.09, Total Time (hrs): 0.0065
# ====> Epoch: 131 Train ELBO: -1406.3887 Val ELBO: -1423.5015, Epoch Time (s): 0.10, Total Time (hrs): 0.0065
# ====> Epoch: 132 Train ELBO: -1409.9752 Val ELBO: -1427.0923, Epoch Time (s): 0.09, Total Time (hrs): 0.0065
# ====> Epoch: 133 Train ELBO: -1413.1910 Val ELBO: -1418.6842, Epoch Time (s): 0.08, Total Time (hrs): 0.0066
# ====> Epoch: 134 Train ELBO: -1410.8347 Val ELBO: -1421.5975, Epoch Time (s): 0.09, Total Time (hrs): 0.0066
# ====> Epoch: 135 Train ELBO: -1403.1531 Val ELBO: -1418.6666, Epoch Time (s): 0.08, Total Time (hrs): 0.0066
# ====> Epoch: 136 Train ELBO: -1400.7025 Val ELBO: -1418.2574, Epoch Time (s): 0.09, Total Time (hrs): 0.0067
# ====> Epoch: 137 Train ELBO: -1404.0372 Val ELBO: -1414.1624, Epoch Time (s): 0.08, Total Time (hrs): 0.0067
# ====> Epoch: 138 Train ELBO: -1401.1315 Val ELBO: -1415.4500, Epoch Time (s): 0.09, Total Time (hrs): 0.0067
# ====> Epoch: 139 Train ELBO: -1397.7727 Val ELBO: -1411.1879, Epoch Time (s): 0.09, Total Time (hrs): 0.0068
# ====> Epoch: 140 Train ELBO: -1394.0145 Val ELBO: -1396.7593, Epoch Time (s): 0.09, Total Time (hrs): 0.0068
# ====> Epoch: 141 Train ELBO: -1392.4952 Val ELBO: -1408.2546, Epoch Time (s): 0.09, Total Time (hrs): 0.0068
# ====> Epoch: 142 Train ELBO: -1394.7237 Val ELBO: -1398.8549, Epoch Time (s): 0.09, Total Time (hrs): 0.0069
# ====> Epoch: 143 Train ELBO: -1390.9483 Val ELBO: -1398.9371, Epoch Time (s): 0.08, Total Time (hrs): 0.0069
# ====> Epoch: 144 Train ELBO: -1391.5520 Val ELBO: -1404.9790, Epoch Time (s): 0.08, Total Time (hrs): 0.0069
# ====> Epoch: 145 Train ELBO: -1384.7656 Val ELBO: -1398.1490, Epoch Time (s): 0.08, Total Time (hrs): 0.0069
# ====> Epoch: 146 Train ELBO: -1382.7562 Val ELBO: -1398.3051, Epoch Time (s): 0.09, Total Time (hrs): 0.0069
# ====> Epoch: 147 Train ELBO: -1380.2937 Val ELBO: -1394.1733, Epoch Time (s): 0.08, Total Time (hrs): 0.0070
# ====> Epoch: 148 Train ELBO: -1374.7879 Val ELBO: -1391.5692, Epoch Time (s): 0.09, Total Time (hrs): 0.0070
# ====> Epoch: 149 Train ELBO: -1372.1451 Val ELBO: -1391.0773, Epoch Time (s): 0.09, Total Time (hrs): 0.0070
# ====> Epoch: 150 Train ELBO: -1370.4988 Val ELBO: -1387.1967, Epoch Time (s): 0.08, Total Time (hrs): 0.0071
# ====> Epoch: 151 Train ELBO: -1367.0132 Val ELBO: -1380.8983, Epoch Time (s): 0.09, Total Time (hrs): 0.0071
# ====> Epoch: 152 Train ELBO: -1376.0485 Val ELBO: -1390.8574, Epoch Time (s): 0.09, Total Time (hrs): 0.0071
# ====> Epoch: 153 Train ELBO: -1373.7886 Val ELBO: -1381.8633, Epoch Time (s): 0.08, Total Time (hrs): 0.0072
# ====> Epoch: 154 Train ELBO: -1368.3499 Val ELBO: -1395.4568, Epoch Time (s): 0.08, Total Time (hrs): 0.0072
# ====> Epoch: 155 Train ELBO: -1364.7446 Val ELBO: -1374.3828, Epoch Time (s): 0.08, Total Time (hrs): 0.0072
# ====> Epoch: 156 Train ELBO: -1360.4871 Val ELBO: -1376.9672, Epoch Time (s): 0.09, Total Time (hrs): 0.0072
# ====> Epoch: 157 Train ELBO: -1363.4022 Val ELBO: -1385.5966, Epoch Time (s): 0.09, Total Time (hrs): 0.0073
# ====> Epoch: 158 Train ELBO: -1361.0002 Val ELBO: -1374.7747, Epoch Time (s): 0.08, Total Time (hrs): 0.0073
# ====> Epoch: 159 Train ELBO: -1355.8441 Val ELBO: -1370.7029, Epoch Time (s): 0.09, Total Time (hrs): 0.0073
# ====> Epoch: 160 Train ELBO: -1349.5479 Val ELBO: -1369.7048, Epoch Time (s): 0.09, Total Time (hrs): 0.0074
# ====> Epoch: 161 Train ELBO: -1346.1395 Val ELBO: -1360.8992, Epoch Time (s): 0.11, Total Time (hrs): 0.0074
# ====> Epoch: 162 Train ELBO: -1347.3221 Val ELBO: -1372.9642, Epoch Time (s): 0.09, Total Time (hrs): 0.0074
# ====> Epoch: 163 Train ELBO: -1357.6633 Val ELBO: -1369.8202, Epoch Time (s): 0.08, Total Time (hrs): 0.0075
# ====> Epoch: 164 Train ELBO: -1350.3061 Val ELBO: -1351.8649, Epoch Time (s): 0.08, Total Time (hrs): 0.0075
# ====> Epoch: 165 Train ELBO: -1340.6524 Val ELBO: -1354.2025, Epoch Time (s): 0.09, Total Time (hrs): 0.0075
# ====> Epoch: 166 Train ELBO: -1338.3896 Val ELBO: -1351.4885, Epoch Time (s): 0.08, Total Time (hrs): 0.0075
# ====> Epoch: 167 Train ELBO: -1336.3986 Val ELBO: -1346.9906, Epoch Time (s): 0.09, Total Time (hrs): 0.0076
# ====> Epoch: 168 Train ELBO: -1328.4692 Val ELBO: -1345.6945, Epoch Time (s): 0.10, Total Time (hrs): 0.0076
# ====> Epoch: 169 Train ELBO: -1325.7826 Val ELBO: -1343.0743, Epoch Time (s): 0.09, Total Time (hrs): 0.0076
# ====> Epoch: 170 Train ELBO: -1326.0273 Val ELBO: -1334.1125, Epoch Time (s): 0.10, Total Time (hrs): 0.0077
# ====> Epoch: 171 Train ELBO: -1323.4064 Val ELBO: -1342.0027, Epoch Time (s): 0.09, Total Time (hrs): 0.0077
# ====> Epoch: 172 Train ELBO: -1316.7548 Val ELBO: -1330.6345, Epoch Time (s): 0.08, Total Time (hrs): 0.0077
# ====> Epoch: 173 Train ELBO: -1315.0966 Val ELBO: -1332.2533, Epoch Time (s): 0.09, Total Time (hrs): 0.0078
# ====> Epoch: 174 Train ELBO: -1312.6973 Val ELBO: -1325.3320, Epoch Time (s): 0.08, Total Time (hrs): 0.0078
# ====> Epoch: 175 Train ELBO: -1307.2216 Val ELBO: -1324.1167, Epoch Time (s): 0.08, Total Time (hrs): 0.0078
# ====> Epoch: 176 Train ELBO: -1309.0053 Val ELBO: -1320.1544, Epoch Time (s): 0.09, Total Time (hrs): 0.0079
# ====> Epoch: 177 Train ELBO: -1299.6392 Val ELBO: -1314.7439, Epoch Time (s): 0.14, Total Time (hrs): 0.0079
# ====> Epoch: 178 Train ELBO: -1297.6381 Val ELBO: -1313.7520, Epoch Time (s): 0.14, Total Time (hrs): 0.0080
# ====> Epoch: 179 Train ELBO: -1296.9976 Val ELBO: -1308.2673, Epoch Time (s): 0.12, Total Time (hrs): 0.0080
# ====> Epoch: 180 Train ELBO: -1302.1617 Val ELBO: -1313.6115, Epoch Time (s): 0.12, Total Time (hrs): 0.0081
# ====> Epoch: 181 Train ELBO: -1294.8260 Val ELBO: -1306.5918, Epoch Time (s): 0.12, Total Time (hrs): 0.0081
# ====> Epoch: 182 Train ELBO: -1285.4678 Val ELBO: -1296.9453, Epoch Time (s): 0.14, Total Time (hrs): 0.0081
# ====> Epoch: 183 Train ELBO: -1279.5633 Val ELBO: -1297.9927, Epoch Time (s): 0.12, Total Time (hrs): 0.0082
# ====> Epoch: 184 Train ELBO: -1282.3655 Val ELBO: -1293.3763, Epoch Time (s): 0.12, Total Time (hrs): 0.0082
# ====> Epoch: 185 Train ELBO: -1273.8748 Val ELBO: -1297.9489, Epoch Time (s): 0.13, Total Time (hrs): 0.0083
# ====> Epoch: 186 Train ELBO: -1275.0516 Val ELBO: -1289.8047, Epoch Time (s): 0.13, Total Time (hrs): 0.0083
# ====> Epoch: 187 Train ELBO: -1270.2572 Val ELBO: -1281.2555, Epoch Time (s): 0.12, Total Time (hrs): 0.0084
# ====> Epoch: 188 Train ELBO: -1267.9413 Val ELBO: -1304.4232, Epoch Time (s): 0.12, Total Time (hrs): 0.0084
# ====> Epoch: 189 Train ELBO: -1270.0075 Val ELBO: -1272.7281, Epoch Time (s): 0.13, Total Time (hrs): 0.0084
# ====> Epoch: 190 Train ELBO: -1259.1844 Val ELBO: -1279.1337, Epoch Time (s): 0.12, Total Time (hrs): 0.0085
# ====> Epoch: 191 Train ELBO: -1263.4371 Val ELBO: -1292.6757, Epoch Time (s): 0.12, Total Time (hrs): 0.0085
# ====> Epoch: 192 Train ELBO: -1261.2365 Val ELBO: -1265.4481, Epoch Time (s): 0.13, Total Time (hrs): 0.0085
# ====> Epoch: 193 Train ELBO: -1259.4136 Val ELBO: -1291.4548, Epoch Time (s): 0.14, Total Time (hrs): 0.0086
# ====> Epoch: 194 Train ELBO: -1250.3254 Val ELBO: -1256.9281, Epoch Time (s): 0.15, Total Time (hrs): 0.0086
# ====> Epoch: 195 Train ELBO: -1235.9037 Val ELBO: -1249.6461, Epoch Time (s): 0.13, Total Time (hrs): 0.0087
# ====> Epoch: 196 Train ELBO: -1231.2882 Val ELBO: -1251.2395, Epoch Time (s): 0.15, Total Time (hrs): 0.0087
# ====> Epoch: 197 Train ELBO: -1232.0546 Val ELBO: -1254.7310, Epoch Time (s): 0.14, Total Time (hrs): 0.0088
# ====> Epoch: 198 Train ELBO: -1228.0219 Val ELBO: -1237.8241, Epoch Time (s): 0.16, Total Time (hrs): 0.0088
# ====> Epoch: 199 Train ELBO: -1223.3981 Val ELBO: -1251.9414, Epoch Time (s): 0.12, Total Time (hrs): 0.0089
# ====> Epoch: 200 Train ELBO: -1220.1277 Val ELBO: -1231.8953, Epoch Time (s): 0.09, Total Time (hrs): 0.0089
# ====> Epoch: 201 Train ELBO: -1212.7002 Val ELBO: -1225.1572, Epoch Time (s): 0.08, Total Time (hrs): 0.0089
# ====> Epoch: 202 Train ELBO: -1205.9918 Val ELBO: -1219.2611, Epoch Time (s): 0.09, Total Time (hrs): 0.0090
# ====> Epoch: 203 Train ELBO: -1199.7719 Val ELBO: -1214.9938, Epoch Time (s): 0.09, Total Time (hrs): 0.0090
# ====> Epoch: 204 Train ELBO: -1196.7204 Val ELBO: -1207.9070, Epoch Time (s): 0.09, Total Time (hrs): 0.0090
# ====> Epoch: 205 Train ELBO: -1191.6968 Val ELBO: -1208.7286, Epoch Time (s): 0.08, Total Time (hrs): 0.0091
# ====> Epoch: 206 Train ELBO: -1186.9633 Val ELBO: -1197.9305, Epoch Time (s): 0.09, Total Time (hrs): 0.0091
# ====> Epoch: 207 Train ELBO: -1182.0750 Val ELBO: -1203.6794, Epoch Time (s): 0.09, Total Time (hrs): 0.0091
# ====> Epoch: 208 Train ELBO: -1182.3237 Val ELBO: -1198.0905, Epoch Time (s): 0.10, Total Time (hrs): 0.0092
# ====> Epoch: 209 Train ELBO: -1173.2762 Val ELBO: -1185.4993, Epoch Time (s): 0.08, Total Time (hrs): 0.0092
# ====> Epoch: 210 Train ELBO: -1173.6385 Val ELBO: -1183.3142, Epoch Time (s): 0.09, Total Time (hrs): 0.0092
# ====> Epoch: 211 Train ELBO: -1171.5513 Val ELBO: -1181.3569, Epoch Time (s): 0.08, Total Time (hrs): 0.0092
# ====> Epoch: 212 Train ELBO: -1159.4263 Val ELBO: -1179.4353, Epoch Time (s): 0.09, Total Time (hrs): 0.0093
# ====> Epoch: 213 Train ELBO: -1174.4514 Val ELBO: -1180.2743, Epoch Time (s): 0.09, Total Time (hrs): 0.0093
# ====> Epoch: 214 Train ELBO: -1162.3515 Val ELBO: -1181.4788, Epoch Time (s): 0.08, Total Time (hrs): 0.0093
# ====> Epoch: 215 Train ELBO: -1151.7525 Val ELBO: -1165.0927, Epoch Time (s): 0.08, Total Time (hrs): 0.0094
# ====> Epoch: 216 Train ELBO: -1153.1878 Val ELBO: -1169.8141, Epoch Time (s): 0.09, Total Time (hrs): 0.0094
# ====> Epoch: 217 Train ELBO: -1147.3065 Val ELBO: -1194.2462, Epoch Time (s): 0.08, Total Time (hrs): 0.0094
# ====> Epoch: 218 Train ELBO: -1156.6677 Val ELBO: -1158.3551, Epoch Time (s): 0.10, Total Time (hrs): 0.0094
# ====> Epoch: 219 Train ELBO: -1133.6522 Val ELBO: -1142.7437, Epoch Time (s): 0.08, Total Time (hrs): 0.0095
# ====> Epoch: 220 Train ELBO: -1123.8935 Val ELBO: -1136.0261, Epoch Time (s): 0.08, Total Time (hrs): 0.0095
# ====> Epoch: 221 Train ELBO: -1122.4852 Val ELBO: -1131.9951, Epoch Time (s): 0.10, Total Time (hrs): 0.0096
# ====> Epoch: 222 Train ELBO: -1124.0061 Val ELBO: -1134.3998, Epoch Time (s): 0.09, Total Time (hrs): 0.0096
# ====> Epoch: 223 Train ELBO: -1110.6412 Val ELBO: -1119.1866, Epoch Time (s): 0.09, Total Time (hrs): 0.0096
# ====> Epoch: 224 Train ELBO: -1105.4862 Val ELBO: -1116.6229, Epoch Time (s): 0.09, Total Time (hrs): 0.0096
# ====> Epoch: 225 Train ELBO: -1103.2255 Val ELBO: -1117.4987, Epoch Time (s): 0.09, Total Time (hrs): 0.0097
# ====> Epoch: 226 Train ELBO: -1098.1935 Val ELBO: -1113.6422, Epoch Time (s): 0.08, Total Time (hrs): 0.0097
# ====> Epoch: 227 Train ELBO: -1096.0191 Val ELBO: -1101.0701, Epoch Time (s): 0.10, Total Time (hrs): 0.0097
# ====> Epoch: 228 Train ELBO: -1090.9672 Val ELBO: -1097.0992, Epoch Time (s): 0.08, Total Time (hrs): 0.0098
# ====> Epoch: 229 Train ELBO: -1082.8517 Val ELBO: -1098.1350, Epoch Time (s): 0.10, Total Time (hrs): 0.0098
# ====> Epoch: 230 Train ELBO: -1084.3847 Val ELBO: -1087.4971, Epoch Time (s): 0.09, Total Time (hrs): 0.0098
# ====> Epoch: 231 Train ELBO: -1078.5546 Val ELBO: -1115.4766, Epoch Time (s): 0.09, Total Time (hrs): 0.0099
# ====> Epoch: 232 Train ELBO: -1081.4086 Val ELBO: -1080.8496, Epoch Time (s): 0.08, Total Time (hrs): 0.0099
# ====> Epoch: 233 Train ELBO: -1062.0963 Val ELBO: -1072.8826, Epoch Time (s): 0.09, Total Time (hrs): 0.0099
# ====> Epoch: 234 Train ELBO: -1055.2059 Val ELBO: -1092.7545, Epoch Time (s): 0.09, Total Time (hrs): 0.0100
# ====> Epoch: 235 Train ELBO: -1057.5436 Val ELBO: -1070.4017, Epoch Time (s): 0.09, Total Time (hrs): 0.0100
# ====> Epoch: 236 Train ELBO: -1052.6701 Val ELBO: -1079.7347, Epoch Time (s): 0.10, Total Time (hrs): 0.0100
# ====> Epoch: 237 Train ELBO: -1055.4411 Val ELBO: -1055.3260, Epoch Time (s): 0.08, Total Time (hrs): 0.0101
# ====> Epoch: 238 Train ELBO: -1055.2816 Val ELBO: -1053.3730, Epoch Time (s): 0.09, Total Time (hrs): 0.0101
# ====> Epoch: 239 Train ELBO: -1031.0952 Val ELBO: -1048.6089, Epoch Time (s): 0.08, Total Time (hrs): 0.0101
# ====> Epoch: 240 Train ELBO: -1027.6455 Val ELBO: -1035.9618, Epoch Time (s): 0.09, Total Time (hrs): 0.0102
# ====> Epoch: 241 Train ELBO: -1036.8157 Val ELBO: -1057.0359, Epoch Time (s): 0.09, Total Time (hrs): 0.0102
# ====> Epoch: 242 Train ELBO: -1026.8827 Val ELBO: -1023.8212, Epoch Time (s): 0.09, Total Time (hrs): 0.0102
# ====> Epoch: 243 Train ELBO: -1008.2928 Val ELBO: -1026.7920, Epoch Time (s): 0.09, Total Time (hrs): 0.0103
# ====> Epoch: 244 Train ELBO: -1001.8176 Val ELBO: -1028.3788, Epoch Time (s): 0.09, Total Time (hrs): 0.0103
# ====> Epoch: 245 Train ELBO: -1001.2535 Val ELBO: -1019.3482, Epoch Time (s): 0.11, Total Time (hrs): 0.0103
# ====> Epoch: 246 Train ELBO: -994.0806 Val ELBO: -1015.2740, Epoch Time (s): 0.09, Total Time (hrs): 0.0103
# ====> Epoch: 247 Train ELBO: -990.5240 Val ELBO: -1039.0945, Epoch Time (s): 0.10, Total Time (hrs): 0.0104
# ====> Epoch: 248 Train ELBO: -1009.0026 Val ELBO: -1039.5038, Epoch Time (s): 0.08, Total Time (hrs): 0.0104
# ====> Epoch: 249 Train ELBO: -989.9827 Val ELBO: -998.4078, Epoch Time (s): 0.08, Total Time (hrs): 0.0104
# ====> Epoch: 250 Train ELBO: -968.0495 Val ELBO: -990.4984, Epoch Time (s): 0.08, Total Time (hrs): 0.0105
# ====> Epoch: 251 Train ELBO: -959.5858 Val ELBO: -973.6542, Epoch Time (s): 0.09, Total Time (hrs): 0.0105
# ====> Epoch: 252 Train ELBO: -939.9850 Val ELBO: -968.9575, Epoch Time (s): 0.09, Total Time (hrs): 0.0105
# ====> Epoch: 253 Train ELBO: -937.3077 Val ELBO: -952.1956, Epoch Time (s): 0.08, Total Time (hrs): 0.0106
# ====> Epoch: 254 Train ELBO: -919.7913 Val ELBO: -941.8605, Epoch Time (s): 0.10, Total Time (hrs): 0.0106
# ====> Epoch: 255 Train ELBO: -929.2754 Val ELBO: -937.6406, Epoch Time (s): 0.09, Total Time (hrs): 0.0106
# ====> Epoch: 256 Train ELBO: -925.9287 Val ELBO: -913.2100, Epoch Time (s): 0.09, Total Time (hrs): 0.0107
# ====> Epoch: 257 Train ELBO: -909.2541 Val ELBO: -920.9373, Epoch Time (s): 0.09, Total Time (hrs): 0.0107
# ====> Epoch: 258 Train ELBO: -908.2103 Val ELBO: -897.8499, Epoch Time (s): 0.37, Total Time (hrs): 0.0108
# ====> Epoch: 259 Train ELBO: -869.2903 Val ELBO: -895.7763, Epoch Time (s): 0.08, Total Time (hrs): 0.0109
# ====> Epoch: 260 Train ELBO: -856.2913 Val ELBO: -887.1271, Epoch Time (s): 0.11, Total Time (hrs): 0.0109
# ====> Epoch: 261 Train ELBO: -843.6524 Val ELBO: -856.2296, Epoch Time (s): 0.09, Total Time (hrs): 0.0109
# ====> Epoch: 262 Train ELBO: -833.1875 Val ELBO: -852.3906, Epoch Time (s): 0.09, Total Time (hrs): 0.0110
# ====> Epoch: 263 Train ELBO: -824.0269 Val ELBO: -838.5506, Epoch Time (s): 0.08, Total Time (hrs): 0.0110
# ====> Epoch: 264 Train ELBO: -799.0343 Val ELBO: -815.8114, Epoch Time (s): 0.09, Total Time (hrs): 0.0110
# ====> Epoch: 265 Train ELBO: -782.8236 Val ELBO: -794.8079, Epoch Time (s): 0.08, Total Time (hrs): 0.0111
# ====> Epoch: 266 Train ELBO: -759.5177 Val ELBO: -763.3278, Epoch Time (s): 0.09, Total Time (hrs): 0.0111
# ====> Epoch: 267 Train ELBO: -734.7324 Val ELBO: -752.1416, Epoch Time (s): 0.08, Total Time (hrs): 0.0111
# ====> Epoch: 268 Train ELBO: -711.1190 Val ELBO: -727.9658, Epoch Time (s): 0.10, Total Time (hrs): 0.0112
# ====> Epoch: 269 Train ELBO: -695.1504 Val ELBO: -690.2707, Epoch Time (s): 0.09, Total Time (hrs): 0.0112
# ====> Epoch: 270 Train ELBO: -682.4433 Val ELBO: -693.9471, Epoch Time (s): 0.09, Total Time (hrs): 0.0112
# ====> Epoch: 271 Train ELBO: -673.9553 Val ELBO: -679.1761, Epoch Time (s): 0.08, Total Time (hrs): 0.0113
# ====> Epoch: 272 Train ELBO: -652.2920 Val ELBO: -647.8254, Epoch Time (s): 0.08, Total Time (hrs): 0.0113
# ====> Epoch: 273 Train ELBO: -617.5693 Val ELBO: -609.2822, Epoch Time (s): 0.09, Total Time (hrs): 0.0113
# ====> Epoch: 274 Train ELBO: -611.4480 Val ELBO: -571.5419, Epoch Time (s): 0.09, Total Time (hrs): 0.0114
# ====> Epoch: 275 Train ELBO: -584.1876 Val ELBO: -537.0803, Epoch Time (s): 0.09, Total Time (hrs): 0.0114
# ====> Epoch: 276 Train ELBO: -560.6682 Val ELBO: -536.3530, Epoch Time (s): 0.08, Total Time (hrs): 0.0114
# ====> Epoch: 277 Train ELBO: -540.0456 Val ELBO: -574.9818, Epoch Time (s): 0.09, Total Time (hrs): 0.0115
# ====> Epoch: 278 Train ELBO: -558.1312 Val ELBO: -475.3860, Epoch Time (s): 0.09, Total Time (hrs): 0.0115
# ====> Epoch: 279 Train ELBO: -511.6871 Val ELBO: -480.1580, Epoch Time (s): 0.09, Total Time (hrs): 0.0115
# ====> Epoch: 280 Train ELBO: -475.6392 Val ELBO: -433.3956, Epoch Time (s): 0.08, Total Time (hrs): 0.0116
# ====> Epoch: 281 Train ELBO: -451.3628 Val ELBO: -431.9119, Epoch Time (s): 0.09, Total Time (hrs): 0.0116
# ====> Epoch: 282 Train ELBO: -461.3194 Val ELBO: -509.0507, Epoch Time (s): 0.10, Total Time (hrs): 0.0116
# ====> Epoch: 283 Train ELBO: -468.4849 Val ELBO: -460.5427, Epoch Time (s): 0.15, Total Time (hrs): 0.0117
# ====> Epoch: 284 Train ELBO: -438.9148 Val ELBO: -390.2277, Epoch Time (s): 0.13, Total Time (hrs): 0.0117
# ====> Epoch: 285 Train ELBO: -407.3857 Val ELBO: -364.7559, Epoch Time (s): 0.14, Total Time (hrs): 0.0118
# ====> Epoch: 286 Train ELBO: -391.0566 Val ELBO: -352.1074, Epoch Time (s): 0.12, Total Time (hrs): 0.0118
# ====> Epoch: 287 Train ELBO: -382.3939 Val ELBO: -368.6383, Epoch Time (s): 0.13, Total Time (hrs): 0.0119
# ====> Epoch: 288 Train ELBO: -389.5051 Val ELBO: -329.5026, Epoch Time (s): 0.13, Total Time (hrs): 0.0119
# ====> Epoch: 289 Train ELBO: -373.7095 Val ELBO: -392.6415, Epoch Time (s): 0.12, Total Time (hrs): 0.0119
# ====> Epoch: 290 Train ELBO: -378.3802 Val ELBO: -313.8148, Epoch Time (s): 0.12, Total Time (hrs): 0.0120
# ====> Epoch: 291 Train ELBO: -361.1444 Val ELBO: -306.1339, Epoch Time (s): 0.11, Total Time (hrs): 0.0120
# ====> Epoch: 292 Train ELBO: -353.6772 Val ELBO: -319.5752, Epoch Time (s): 0.14, Total Time (hrs): 0.0121
# ====> Epoch: 293 Train ELBO: -346.0707 Val ELBO: -294.2310, Epoch Time (s): 0.12, Total Time (hrs): 0.0121
# ====> Epoch: 294 Train ELBO: -354.1159 Val ELBO: -398.7395, Epoch Time (s): 0.12, Total Time (hrs): 0.0121
# ====> Epoch: 295 Train ELBO: -387.7857 Val ELBO: -401.2187, Epoch Time (s): 0.12, Total Time (hrs): 0.0122
# ====> Epoch: 296 Train ELBO: -348.8571 Val ELBO: -293.1596, Epoch Time (s): 0.12, Total Time (hrs): 0.0122
# ====> Epoch: 297 Train ELBO: -320.7386 Val ELBO: -279.7504, Epoch Time (s): 0.11, Total Time (hrs): 0.0122
# ====> Epoch: 298 Train ELBO: -326.9202 Val ELBO: -264.2715, Epoch Time (s): 0.12, Total Time (hrs): 0.0123
# ====> Epoch: 299 Train ELBO: -316.0195 Val ELBO: -263.5317, Epoch Time (s): 0.14, Total Time (hrs): 0.0123
# ====> Epoch: 300 Train ELBO: -307.8434 Val ELBO: -269.8611, Epoch Time (s): 0.13, Total Time (hrs): 0.0124
# ====> Epoch: 301 Train ELBO: -307.7556 Val ELBO: -273.6537, Epoch Time (s): 0.14, Total Time (hrs): 0.0124
# ====> Epoch: 302 Train ELBO: -300.1562 Val ELBO: -253.0256, Epoch Time (s): 0.12, Total Time (hrs): 0.0125
# ====> Epoch: 303 Train ELBO: -298.7001 Val ELBO: -258.6626, Epoch Time (s): 0.12, Total Time (hrs): 0.0125
# ====> Epoch: 304 Train ELBO: -294.6403 Val ELBO: -252.6008, Epoch Time (s): 0.14, Total Time (hrs): 0.0125
# ====> Epoch: 305 Train ELBO: -298.5265 Val ELBO: -265.6199, Epoch Time (s): 0.13, Total Time (hrs): 0.0126
# ====> Epoch: 306 Train ELBO: -312.6941 Val ELBO: -257.5136, Epoch Time (s): 0.09, Total Time (hrs): 0.0126
# ====> Epoch: 307 Train ELBO: -298.5882 Val ELBO: -257.2632, Epoch Time (s): 0.09, Total Time (hrs): 0.0126
# ====> Epoch: 308 Train ELBO: -294.5704 Val ELBO: -237.0980, Epoch Time (s): 0.08, Total Time (hrs): 0.0127
# ====> Epoch: 309 Train ELBO: -290.8148 Val ELBO: -240.4567, Epoch Time (s): 0.08, Total Time (hrs): 0.0127
# ====> Epoch: 310 Train ELBO: -300.5683 Val ELBO: -239.1866, Epoch Time (s): 0.08, Total Time (hrs): 0.0127
# ====> Epoch: 311 Train ELBO: -305.6611 Val ELBO: -299.8749, Epoch Time (s): 0.08, Total Time (hrs): 0.0127
# ====> Epoch: 312 Train ELBO: -304.0079 Val ELBO: -264.7156, Epoch Time (s): 0.09, Total Time (hrs): 0.0128
# ====> Epoch: 313 Train ELBO: -283.5984 Val ELBO: -267.5744, Epoch Time (s): 0.08, Total Time (hrs): 0.0128
# ====> Epoch: 314 Train ELBO: -288.2198 Val ELBO: -239.3082, Epoch Time (s): 0.08, Total Time (hrs): 0.0128
# ====> Epoch: 315 Train ELBO: -263.4523 Val ELBO: -231.0179, Epoch Time (s): 0.09, Total Time (hrs): 0.0128
# ====> Epoch: 316 Train ELBO: -262.0843 Val ELBO: -218.4656, Epoch Time (s): 0.09, Total Time (hrs): 0.0129
# ====> Epoch: 317 Train ELBO: -264.6739 Val ELBO: -230.2348, Epoch Time (s): 0.09, Total Time (hrs): 0.0129
# ====> Epoch: 318 Train ELBO: -263.0955 Val ELBO: -208.6351, Epoch Time (s): 0.10, Total Time (hrs): 0.0129
# ====> Epoch: 319 Train ELBO: -254.9476 Val ELBO: -220.5668, Epoch Time (s): 0.09, Total Time (hrs): 0.0130
# ====> Epoch: 320 Train ELBO: -254.5305 Val ELBO: -212.8942, Epoch Time (s): 0.08, Total Time (hrs): 0.0130
# ====> Epoch: 321 Train ELBO: -255.1515 Val ELBO: -211.6465, Epoch Time (s): 0.09, Total Time (hrs): 0.0130
# ====> Epoch: 322 Train ELBO: -272.8531 Val ELBO: -209.5570, Epoch Time (s): 0.08, Total Time (hrs): 0.0130
# ====> Epoch: 323 Train ELBO: -264.3049 Val ELBO: -208.1724, Epoch Time (s): 0.08, Total Time (hrs): 0.0131
# ====> Epoch: 324 Train ELBO: -246.4720 Val ELBO: -219.2144, Epoch Time (s): 0.10, Total Time (hrs): 0.0131
# ====> Epoch: 325 Train ELBO: -252.4989 Val ELBO: -211.1478, Epoch Time (s): 0.08, Total Time (hrs): 0.0131
# ====> Epoch: 326 Train ELBO: -249.9261 Val ELBO: -198.7903, Epoch Time (s): 0.09, Total Time (hrs): 0.0132
# ====> Epoch: 327 Train ELBO: -249.3760 Val ELBO: -207.0594, Epoch Time (s): 0.09, Total Time (hrs): 0.0132
# ====> Epoch: 328 Train ELBO: -241.3687 Val ELBO: -203.7855, Epoch Time (s): 0.09, Total Time (hrs): 0.0132
# ====> Epoch: 329 Train ELBO: -241.7587 Val ELBO: -206.0420, Epoch Time (s): 0.09, Total Time (hrs): 0.0132
# ====> Epoch: 330 Train ELBO: -238.9356 Val ELBO: -195.5065, Epoch Time (s): 0.09, Total Time (hrs): 0.0133
# ====> Epoch: 331 Train ELBO: -243.1241 Val ELBO: -206.8260, Epoch Time (s): 0.08, Total Time (hrs): 0.0133
# ====> Epoch: 332 Train ELBO: -236.6060 Val ELBO: -195.3593, Epoch Time (s): 0.08, Total Time (hrs): 0.0133
# ====> Epoch: 333 Train ELBO: -235.1858 Val ELBO: -201.7387, Epoch Time (s): 0.08, Total Time (hrs): 0.0134
# ====> Epoch: 334 Train ELBO: -239.4817 Val ELBO: -199.1866, Epoch Time (s): 0.08, Total Time (hrs): 0.0134
# ====> Epoch: 335 Train ELBO: -251.9536 Val ELBO: -255.8705, Epoch Time (s): 0.08, Total Time (hrs): 0.0134
# ====> Epoch: 336 Train ELBO: -264.2654 Val ELBO: -234.6835, Epoch Time (s): 0.08, Total Time (hrs): 0.0134
# ====> Epoch: 337 Train ELBO: -261.7720 Val ELBO: -196.2521, Epoch Time (s): 0.09, Total Time (hrs): 0.0134
# ====> Epoch: 338 Train ELBO: -236.3041 Val ELBO: -204.1084, Epoch Time (s): 0.09, Total Time (hrs): 0.0135
# ====> Epoch: 339 Train ELBO: -240.1007 Val ELBO: -194.7310, Epoch Time (s): 0.08, Total Time (hrs): 0.0135
# ====> Epoch: 340 Train ELBO: -238.4067 Val ELBO: -184.8779, Epoch Time (s): 0.08, Total Time (hrs): 0.0135
# ====> Epoch: 341 Train ELBO: -239.9319 Val ELBO: -188.4231, Epoch Time (s): 0.08, Total Time (hrs): 0.0136
# ====> Epoch: 342 Train ELBO: -234.9616 Val ELBO: -188.7321, Epoch Time (s): 0.08, Total Time (hrs): 0.0136
# ====> Epoch: 343 Train ELBO: -243.6251 Val ELBO: -194.6250, Epoch Time (s): 0.08, Total Time (hrs): 0.0136
# ====> Epoch: 344 Train ELBO: -235.6436 Val ELBO: -194.6348, Epoch Time (s): 0.08, Total Time (hrs): 0.0136
# ====> Epoch: 345 Train ELBO: -222.5455 Val ELBO: -188.3595, Epoch Time (s): 0.08, Total Time (hrs): 0.0137
# ====> Epoch: 346 Train ELBO: -222.2833 Val ELBO: -188.9350, Epoch Time (s): 0.08, Total Time (hrs): 0.0137
# ====> Epoch: 347 Train ELBO: -234.3546 Val ELBO: -190.1825, Epoch Time (s): 0.08, Total Time (hrs): 0.0137
# ====> Epoch: 348 Train ELBO: -237.8123 Val ELBO: -194.4095, Epoch Time (s): 0.09, Total Time (hrs): 0.0137
# ====> Epoch: 349 Train ELBO: -222.3188 Val ELBO: -187.2492, Epoch Time (s): 0.08, Total Time (hrs): 0.0137
# ====> Epoch: 350 Train ELBO: -218.6134 Val ELBO: -175.9491, Epoch Time (s): 0.08, Total Time (hrs): 0.0138
# ====> Epoch: 351 Train ELBO: -221.4679 Val ELBO: -198.2883, Epoch Time (s): 0.09, Total Time (hrs): 0.0138
# ====> Epoch: 352 Train ELBO: -217.5980 Val ELBO: -176.6173, Epoch Time (s): 0.09, Total Time (hrs): 0.0138
# ====> Epoch: 353 Train ELBO: -219.8878 Val ELBO: -183.0228, Epoch Time (s): 0.08, Total Time (hrs): 0.0139
# ====> Epoch: 354 Train ELBO: -216.3401 Val ELBO: -172.6764, Epoch Time (s): 0.09, Total Time (hrs): 0.0139
# ====> Epoch: 355 Train ELBO: -208.5573 Val ELBO: -173.9052, Epoch Time (s): 0.09, Total Time (hrs): 0.0139
# ====> Epoch: 356 Train ELBO: -208.3231 Val ELBO: -177.9232, Epoch Time (s): 0.09, Total Time (hrs): 0.0139
# ====> Epoch: 357 Train ELBO: -209.8490 Val ELBO: -190.1060, Epoch Time (s): 0.09, Total Time (hrs): 0.0140
# ====> Epoch: 358 Train ELBO: -210.9112 Val ELBO: -173.6075, Epoch Time (s): 0.09, Total Time (hrs): 0.0140
# ====> Epoch: 359 Train ELBO: -207.3933 Val ELBO: -169.6883, Epoch Time (s): 0.09, Total Time (hrs): 0.0140
# ====> Epoch: 360 Train ELBO: -202.6397 Val ELBO: -182.7741, Epoch Time (s): 0.08, Total Time (hrs): 0.0140
# ...
# ====> Epoch: 714 Train ELBO: 10.0656 Val ELBO: 56.3716, Epoch Time (s): 0.09, Total Time (hrs): 0.0264
# ====> Epoch: 715 Train ELBO: 13.8004 Val ELBO: 57.0335, Epoch Time (s): 0.09, Total Time (hrs): 0.0264
# ====> Epoch: 716 Train ELBO: -13.4392 Val ELBO: 21.4077, Epoch Time (s): 0.09, Total Time (hrs): 0.0264
# ====> Epoch: 717 Train ELBO: -3.8296 Val ELBO: 34.5242, Epoch Time (s): 0.08, Total Time (hrs): 0.0264
# ====> Epoch: 718 Train ELBO: 2.2330 Val ELBO: 20.7640, Epoch Time (s): 0.08, Total Time (hrs): 0.0265
# ====> Epoch: 719 Train ELBO: 2.2842 Val ELBO: 47.9803, Epoch Time (s): 0.09, Total Time (hrs): 0.0265
# ====> Epoch: 720 Train ELBO: 13.3954 Val ELBO: 53.4964, Epoch Time (s): 0.08, Total Time (hrs): 0.0265
# ====> Epoch: 721 Train ELBO: 14.5573 Val ELBO: 42.9944, Epoch Time (s): 0.09, Total Time (hrs): 0.0265
# ====> Epoch: 722 Train ELBO: 15.6380 Val ELBO: 46.2100, Epoch Time (s): 0.11, Total Time (hrs): 0.0266
# ====> Epoch: 723 Train ELBO: 20.0434 Val ELBO: 34.7969, Epoch Time (s): 0.09, Total Time (hrs): 0.0266
# ====> Epoch: 724 Train ELBO: 4.4638 Val ELBO: 19.0397, Epoch Time (s): 0.09, Total Time (hrs): 0.0266
# ====> Epoch: 725 Train ELBO: 11.9652 Val ELBO: 44.7919, Epoch Time (s): 0.09, Total Time (hrs): 0.0266
# ====> Epoch: 726 Train ELBO: 12.1461 Val ELBO: 44.7221, Epoch Time (s): 0.09, Total Time (hrs): 0.0267
# ====> Epoch: 727 Train ELBO: 12.9473 Val ELBO: 55.6092, Epoch Time (s): 0.09, Total Time (hrs): 0.0267
# ====> Epoch: 728 Train ELBO: 16.5240 Val ELBO: 48.6606, Epoch Time (s): 0.09, Total Time (hrs): 0.0267
# ====> Epoch: 729 Train ELBO: 9.6466 Val ELBO: 22.6028, Epoch Time (s): 0.12, Total Time (hrs): 0.0268
# ====> Epoch: 730 Train ELBO: 3.5909 Val ELBO: 23.9414, Epoch Time (s): 0.15, Total Time (hrs): 0.0268
# ====> Epoch: 731 Train ELBO: 9.3154 Val ELBO: 57.3666, Epoch Time (s): 0.13, Total Time (hrs): 0.0268
# ====> Epoch: 732 Train ELBO: 23.4522 Val ELBO: 53.3723, Epoch Time (s): 0.15, Total Time (hrs): 0.0269
# ====> Epoch: 733 Train ELBO: 18.9167 Val ELBO: 45.9159, Epoch Time (s): 0.14, Total Time (hrs): 0.0269
# ====> Epoch: 734 Train ELBO: 20.4392 Val ELBO: 54.7971, Epoch Time (s): 0.13, Total Time (hrs): 0.0270
# ====> Epoch: 735 Train ELBO: 23.7344 Val ELBO: 56.6884, Epoch Time (s): 0.12, Total Time (hrs): 0.0270
# ====> Epoch: 736 Train ELBO: 20.2966 Val ELBO: 46.1975, Epoch Time (s): 0.12, Total Time (hrs): 0.0270
# ====> Epoch: 737 Train ELBO: 14.5688 Val ELBO: 48.5777, Epoch Time (s): 0.12, Total Time (hrs): 0.0271
# ====> Epoch: 738 Train ELBO: 17.6701 Val ELBO: 58.4130, Epoch Time (s): 0.12, Total Time (hrs): 0.0271
# ====> Epoch: 739 Train ELBO: 22.8568 Val ELBO: 53.3577, Epoch Time (s): 0.12, Total Time (hrs): 0.0271
# ====> Epoch: 740 Train ELBO: 20.4451 Val ELBO: 53.6872, Epoch Time (s): 0.15, Total Time (hrs): 0.0272
# ====> Epoch: 741 Train ELBO: 18.5567 Val ELBO: 52.3526, Epoch Time (s): 0.12, Total Time (hrs): 0.0272
# ====> Epoch: 742 Train ELBO: 15.7476 Val ELBO: 33.1771, Epoch Time (s): 0.13, Total Time (hrs): 0.0272
# ====> Epoch: 743 Train ELBO: 15.7753 Val ELBO: 49.9620, Epoch Time (s): 0.12, Total Time (hrs): 0.0273
# ====> Epoch: 744 Train ELBO: 23.6431 Val ELBO: 59.2358, Epoch Time (s): 0.13, Total Time (hrs): 0.0273
# ====> Epoch: 745 Train ELBO: 21.9370 Val ELBO: 59.0133, Epoch Time (s): 0.12, Total Time (hrs): 0.0274
# ====> Epoch: 746 Train ELBO: 20.1595 Val ELBO: 56.8967, Epoch Time (s): 0.12, Total Time (hrs): 0.0274
# ====> Epoch: 747 Train ELBO: 18.7380 Val ELBO: 44.2205, Epoch Time (s): 0.12, Total Time (hrs): 0.0274
# ====> Epoch: 748 Train ELBO: 14.6343 Val ELBO: 58.4505, Epoch Time (s): 0.16, Total Time (hrs): 0.0275
# ====> Epoch: 749 Train ELBO: 14.1282 Val ELBO: 32.0572, Epoch Time (s): 0.14, Total Time (hrs): 0.0275
# ====> Epoch: 750 Train ELBO: 17.2031 Val ELBO: 61.8439, Epoch Time (s): 0.14, Total Time (hrs): 0.0276
# ====> Epoch: 751 Train ELBO: 25.3491 Val ELBO: 62.5516, Epoch Time (s): 0.15, Total Time (hrs): 0.0276
# ====> Epoch: 752 Train ELBO: 25.1384 Val ELBO: 60.8110, Epoch Time (s): 0.14, Total Time (hrs): 0.0277
# ====> Epoch: 753 Train ELBO: 23.7224 Val ELBO: 52.0629, Epoch Time (s): 0.14, Total Time (hrs): 0.0277
# ====> Epoch: 754 Train ELBO: 15.9121 Val ELBO: 49.2530, Epoch Time (s): 0.12, Total Time (hrs): 0.0277
# ====> Epoch: 755 Train ELBO: 17.3896 Val ELBO: 55.0489, Epoch Time (s): 0.10, Total Time (hrs): 0.0278
# ====> Epoch: 756 Train ELBO: 17.6862 Val ELBO: 60.2346, Epoch Time (s): 0.09, Total Time (hrs): 0.0278
# ====> Epoch: 757 Train ELBO: 21.8756 Val ELBO: 56.2447, Epoch Time (s): 0.09, Total Time (hrs): 0.0278
# ====> Epoch: 758 Train ELBO: 23.5414 Val ELBO: 58.2516, Epoch Time (s): 0.08, Total Time (hrs): 0.0278
# ====> Epoch: 759 Train ELBO: 24.9472 Val ELBO: 62.3986, Epoch Time (s): 0.08, Total Time (hrs): 0.0279
# ====> Epoch: 760 Train ELBO: 28.0234 Val ELBO: 64.2294, Epoch Time (s): 0.09, Total Time (hrs): 0.0279
# ====> Epoch: 761 Train ELBO: 25.0608 Val ELBO: 57.2883, Epoch Time (s): 0.08, Total Time (hrs): 0.0279
# ====> Epoch: 762 Train ELBO: 23.7438 Val ELBO: 60.2508, Epoch Time (s): 0.09, Total Time (hrs): 0.0279
# ====> Epoch: 763 Train ELBO: 27.8901 Val ELBO: 63.1652, Epoch Time (s): 0.09, Total Time (hrs): 0.0280
# ====> Epoch: 764 Train ELBO: 26.0519 Val ELBO: 62.6661, Epoch Time (s): 0.09, Total Time (hrs): 0.0280
# ====> Epoch: 765 Train ELBO: 22.3883 Val ELBO: 54.6252, Epoch Time (s): 0.09, Total Time (hrs): 0.0280
# ====> Epoch: 766 Train ELBO: 23.3610 Val ELBO: 59.0413, Epoch Time (s): 0.10, Total Time (hrs): 0.0280
# ====> Epoch: 767 Train ELBO: 26.0861 Val ELBO: 61.8675, Epoch Time (s): 0.10, Total Time (hrs): 0.0281
# ====> Epoch: 768 Train ELBO: 30.1914 Val ELBO: 65.2601, Epoch Time (s): 0.09, Total Time (hrs): 0.0281
# ====> Epoch: 769 Train ELBO: 31.7227 Val ELBO: 68.5406, Epoch Time (s): 0.09, Total Time (hrs): 0.0281
# ====> Epoch: 770 Train ELBO: 31.1862 Val ELBO: 60.8889, Epoch Time (s): 0.10, Total Time (hrs): 0.0282
# ====> Epoch: 771 Train ELBO: 24.0865 Val ELBO: 64.1887, Epoch Time (s): 0.09, Total Time (hrs): 0.0282
# ====> Epoch: 772 Train ELBO: 26.6444 Val ELBO: 59.5480, Epoch Time (s): 0.09, Total Time (hrs): 0.0282
# ====> Epoch: 773 Train ELBO: 28.3470 Val ELBO: 67.7979, Epoch Time (s): 0.09, Total Time (hrs): 0.0282
# ====> Epoch: 774 Train ELBO: 29.5012 Val ELBO: 62.2264, Epoch Time (s): 0.09, Total Time (hrs): 0.0283
# ====> Epoch: 775 Train ELBO: 28.4821 Val ELBO: 64.1013, Epoch Time (s): 0.09, Total Time (hrs): 0.0283
# ====> Epoch: 776 Train ELBO: 28.4043 Val ELBO: 60.6318, Epoch Time (s): 0.08, Total Time (hrs): 0.0283
# ====> Epoch: 777 Train ELBO: 27.2786 Val ELBO: 56.1122, Epoch Time (s): 0.10, Total Time (hrs): 0.0283
# ====> Epoch: 778 Train ELBO: 24.8158 Val ELBO: 50.7082, Epoch Time (s): 0.08, Total Time (hrs): 0.0284
# ====> Epoch: 779 Train ELBO: 26.4779 Val ELBO: 64.6716, Epoch Time (s): 0.08, Total Time (hrs): 0.0284
# ====> Epoch: 780 Train ELBO: 30.7242 Val ELBO: 69.4942, Epoch Time (s): 0.08, Total Time (hrs): 0.0284
# ====> Epoch: 781 Train ELBO: 32.8991 Val ELBO: 65.2014, Epoch Time (s): 0.09, Total Time (hrs): 0.0285
# ====> Epoch: 782 Train ELBO: 28.2566 Val ELBO: 59.8914, Epoch Time (s): 0.09, Total Time (hrs): 0.0285
# ====> Epoch: 783 Train ELBO: 28.3913 Val ELBO: 63.8491, Epoch Time (s): 0.08, Total Time (hrs): 0.0285
# ====> Epoch: 784 Train ELBO: 24.0819 Val ELBO: 48.4026, Epoch Time (s): 0.08, Total Time (hrs): 0.0285
# ====> Epoch: 785 Train ELBO: 26.7697 Val ELBO: 52.5245, Epoch Time (s): 0.09, Total Time (hrs): 0.0286
# ====> Epoch: 786 Train ELBO: 26.6562 Val ELBO: 39.5108, Epoch Time (s): 0.09, Total Time (hrs): 0.0286
# ====> Epoch: 787 Train ELBO: 27.0871 Val ELBO: 65.3888, Epoch Time (s): 0.08, Total Time (hrs): 0.0286
# ====> Epoch: 788 Train ELBO: 31.3449 Val ELBO: 65.2211, Epoch Time (s): 0.10, Total Time (hrs): 0.0286
# ====> Epoch: 789 Train ELBO: 28.0836 Val ELBO: 50.0848, Epoch Time (s): 0.08, Total Time (hrs): 0.0286
# ====> Epoch: 790 Train ELBO: 27.9703 Val ELBO: 60.8886, Epoch Time (s): 0.08, Total Time (hrs): 0.0287
# ====> Epoch: 791 Train ELBO: 29.5200 Val ELBO: 45.6462, Epoch Time (s): 0.09, Total Time (hrs): 0.0287
# ====> Epoch: 792 Train ELBO: 21.0818 Val ELBO: 67.3063, Epoch Time (s): 0.09, Total Time (hrs): 0.0287
# ====> Epoch: 793 Train ELBO: 28.1107 Val ELBO: 67.8715, Epoch Time (s): 0.08, Total Time (hrs): 0.0287
# ====> Epoch: 794 Train ELBO: 21.8465 Val ELBO: 46.0014, Epoch Time (s): 0.09, Total Time (hrs): 0.0288
# ====> Epoch: 795 Train ELBO: 24.1295 Val ELBO: 71.1894, Epoch Time (s): 0.08, Total Time (hrs): 0.0288
# ====> Epoch: 796 Train ELBO: 31.6642 Val ELBO: 60.8800, Epoch Time (s): 0.09, Total Time (hrs): 0.0288
# ====> Epoch: 797 Train ELBO: 27.3713 Val ELBO: 59.7982, Epoch Time (s): 0.09, Total Time (hrs): 0.0289
# ====> Epoch: 798 Train ELBO: 31.6078 Val ELBO: 61.9743, Epoch Time (s): 0.08, Total Time (hrs): 0.0289
# ====> Epoch: 799 Train ELBO: 31.1897 Val ELBO: 66.1530, Epoch Time (s): 0.09, Total Time (hrs): 0.0289
# ====> Epoch: 800 Train ELBO: 31.3668 Val ELBO: 69.8995, Epoch Time (s): 0.10, Total Time (hrs): 0.0289
# ====> Epoch: 801 Train ELBO: 34.5415 Val ELBO: 62.8581, Epoch Time (s): 0.09, Total Time (hrs): 0.0290
# ====> Epoch: 802 Train ELBO: 35.2856 Val ELBO: 68.6009, Epoch Time (s): 0.09, Total Time (hrs): 0.0290
# ====> Epoch: 803 Train ELBO: 30.6384 Val ELBO: 72.6709, Epoch Time (s): 0.09, Total Time (hrs): 0.0290
# ====> Epoch: 804 Train ELBO: 32.7918 Val ELBO: 71.1968, Epoch Time (s): 0.09, Total Time (hrs): 0.0290
# ====> Epoch: 805 Train ELBO: 35.4218 Val ELBO: 70.5960, Epoch Time (s): 0.08, Total Time (hrs): 0.0291
# ====> Epoch: 806 Train ELBO: 35.1535 Val ELBO: 66.9553, Epoch Time (s): 0.08, Total Time (hrs): 0.0291
# ====> Epoch: 807 Train ELBO: 36.3700 Val ELBO: 74.2241, Epoch Time (s): 0.09, Total Time (hrs): 0.0291
# ====> Epoch: 808 Train ELBO: 31.6682 Val ELBO: 68.5030, Epoch Time (s): 0.09, Total Time (hrs): 0.0291
# ====> Epoch: 809 Train ELBO: 37.7285 Val ELBO: 65.0832, Epoch Time (s): 0.09, Total Time (hrs): 0.0292
# ====> Epoch: 810 Train ELBO: 33.8480 Val ELBO: 68.6699, Epoch Time (s): 0.08, Total Time (hrs): 0.0292
# ====> Epoch: 811 Train ELBO: 36.0236 Val ELBO: 68.8480, Epoch Time (s): 0.09, Total Time (hrs): 0.0292
# ====> Epoch: 812 Train ELBO: 36.4134 Val ELBO: 65.8897, Epoch Time (s): 0.09, Total Time (hrs): 0.0292
# ====> Epoch: 813 Train ELBO: 35.9175 Val ELBO: 72.3590, Epoch Time (s): 0.09, Total Time (hrs): 0.0293
# ====> Epoch: 814 Train ELBO: 36.7918 Val ELBO: 70.5498, Epoch Time (s): 0.08, Total Time (hrs): 0.0293
# ====> Epoch: 815 Train ELBO: 36.7270 Val ELBO: 76.0732, Epoch Time (s): 0.08, Total Time (hrs): 0.0293
# ====> Epoch: 816 Train ELBO: 33.5259 Val ELBO: 67.2128, Epoch Time (s): 0.10, Total Time (hrs): 0.0293
# ====> Epoch: 817 Train ELBO: 33.6784 Val ELBO: 70.9960, Epoch Time (s): 0.09, Total Time (hrs): 0.0294
# ====> Epoch: 818 Train ELBO: 21.8548 Val ELBO: 36.5821, Epoch Time (s): 0.08, Total Time (hrs): 0.0294
# ====> Epoch: 819 Train ELBO: 21.4932 Val ELBO: 68.2652, Epoch Time (s): 0.08, Total Time (hrs): 0.0294
# ====> Epoch: 820 Train ELBO: 38.2263 Val ELBO: 73.9132, Epoch Time (s): 0.09, Total Time (hrs): 0.0294
# ====> Epoch: 821 Train ELBO: 41.0468 Val ELBO: 74.1744, Epoch Time (s): 0.09, Total Time (hrs): 0.0295
# ====> Epoch: 822 Train ELBO: 38.9699 Val ELBO: 72.8409, Epoch Time (s): 0.10, Total Time (hrs): 0.0295
# ====> Epoch: 823 Train ELBO: 30.1364 Val ELBO: 63.8588, Epoch Time (s): 0.09, Total Time (hrs): 0.0295
# ====> Epoch: 824 Train ELBO: 28.0616 Val ELBO: 57.6352, Epoch Time (s): 0.09, Total Time (hrs): 0.0295
# ====> Epoch: 825 Train ELBO: 32.8135 Val ELBO: 65.5364, Epoch Time (s): 0.09, Total Time (hrs): 0.0296
# ====> Epoch: 826 Train ELBO: 25.9821 Val ELBO: 76.8262, Epoch Time (s): 0.09, Total Time (hrs): 0.0296
# ====> Epoch: 827 Train ELBO: 35.5815 Val ELBO: 51.5551, Epoch Time (s): 0.09, Total Time (hrs): 0.0296
# ====> Epoch: 828 Train ELBO: 32.0984 Val ELBO: 68.4437, Epoch Time (s): 0.09, Total Time (hrs): 0.0297
# ====> Epoch: 829 Train ELBO: 38.8340 Val ELBO: 69.7769, Epoch Time (s): 0.09, Total Time (hrs): 0.0297
# ====> Epoch: 830 Train ELBO: 41.2369 Val ELBO: 63.7354, Epoch Time (s): 0.09, Total Time (hrs): 0.0297
# ====> Epoch: 831 Train ELBO: 34.9779 Val ELBO: 71.7173, Epoch Time (s): 0.09, Total Time (hrs): 0.0297
# ====> Epoch: 832 Train ELBO: 38.8788 Val ELBO: 73.8078, Epoch Time (s): 0.09, Total Time (hrs): 0.0298
# ====> Epoch: 833 Train ELBO: 42.1235 Val ELBO: 70.7905, Epoch Time (s): 0.11, Total Time (hrs): 0.0298
# ====> Epoch: 834 Train ELBO: 34.0808 Val ELBO: 61.4943, Epoch Time (s): 0.13, Total Time (hrs): 0.0298
# ====> Epoch: 835 Train ELBO: 22.1052 Val ELBO: 58.1861, Epoch Time (s): 0.09, Total Time (hrs): 0.0298
# ====> Epoch: 836 Train ELBO: 28.8187 Val ELBO: 76.2784, Epoch Time (s): 0.09, Total Time (hrs): 0.0299
# ====> Epoch: 837 Train ELBO: 35.4686 Val ELBO: 71.6010, Epoch Time (s): 0.09, Total Time (hrs): 0.0299
# ====> Epoch: 838 Train ELBO: 37.5480 Val ELBO: 70.2539, Epoch Time (s): 0.08, Total Time (hrs): 0.0299
# ====> Epoch: 839 Train ELBO: 33.9010 Val ELBO: 64.2423, Epoch Time (s): 0.09, Total Time (hrs): 0.0299
# ====> Epoch: 840 Train ELBO: 36.3225 Val ELBO: 71.7946, Epoch Time (s): 0.09, Total Time (hrs): 0.0300
# ====> Epoch: 841 Train ELBO: 39.1407 Val ELBO: 75.4748, Epoch Time (s): 0.09, Total Time (hrs): 0.0300
# ====> Epoch: 842 Train ELBO: 37.5784 Val ELBO: 70.9112, Epoch Time (s): 0.08, Total Time (hrs): 0.0300
# ====> Epoch: 843 Train ELBO: 33.1679 Val ELBO: 55.3421, Epoch Time (s): 0.09, Total Time (hrs): 0.0300
# ====> Epoch: 844 Train ELBO: 31.4345 Val ELBO: 72.8699, Epoch Time (s): 0.10, Total Time (hrs): 0.0301
# ====> Epoch: 845 Train ELBO: 39.3347 Val ELBO: 76.4689, Epoch Time (s): 0.09, Total Time (hrs): 0.0301
# ====> Epoch: 846 Train ELBO: 41.6493 Val ELBO: 78.9387, Epoch Time (s): 0.09, Total Time (hrs): 0.0301
# ====> Epoch: 847 Train ELBO: 44.1089 Val ELBO: 77.5269, Epoch Time (s): 0.09, Total Time (hrs): 0.0302
# ====> Epoch: 848 Train ELBO: 43.4296 Val ELBO: 79.3926, Epoch Time (s): 0.09, Total Time (hrs): 0.0302
# ====> Epoch: 849 Train ELBO: 43.4679 Val ELBO: 79.9661, Epoch Time (s): 0.08, Total Time (hrs): 0.0302
# ====> Epoch: 850 Train ELBO: 40.9912 Val ELBO: 76.9531, Epoch Time (s): 0.09, Total Time (hrs): 0.0302
# ====> Epoch: 851 Train ELBO: 44.9970 Val ELBO: 79.0143, Epoch Time (s): 0.08, Total Time (hrs): 0.0303
# ====> Epoch: 852 Train ELBO: 42.8804 Val ELBO: 79.6446, Epoch Time (s): 0.08, Total Time (hrs): 0.0303
# ====> Epoch: 853 Train ELBO: 43.2982 Val ELBO: 74.4200, Epoch Time (s): 0.09, Total Time (hrs): 0.0303
# ====> Epoch: 854 Train ELBO: 40.2896 Val ELBO: 76.5727, Epoch Time (s): 0.08, Total Time (hrs): 0.0303
# ====> Epoch: 855 Train ELBO: 41.2077 Val ELBO: 71.8772, Epoch Time (s): 0.09, Total Time (hrs): 0.0304
# ====> Epoch: 856 Train ELBO: 41.8220 Val ELBO: 78.4975, Epoch Time (s): 0.09, Total Time (hrs): 0.0304
# ====> Epoch: 857 Train ELBO: 42.9683 Val ELBO: 67.1781, Epoch Time (s): 0.09, Total Time (hrs): 0.0304
# ====> Epoch: 858 Train ELBO: 39.1662 Val ELBO: 80.0837, Epoch Time (s): 0.09, Total Time (hrs): 0.0304
# ====> Epoch: 859 Train ELBO: 36.4064 Val ELBO: 29.9479, Epoch Time (s): 0.09, Total Time (hrs): 0.0305
# ====> Epoch: 860 Train ELBO: 23.3121 Val ELBO: 71.9210, Epoch Time (s): 0.09, Total Time (hrs): 0.0305
# ====> Epoch: 861 Train ELBO: 36.1468 Val ELBO: 67.2170, Epoch Time (s): 0.15, Total Time (hrs): 0.0305
# ====> Epoch: 862 Train ELBO: 38.9276 Val ELBO: 77.5143, Epoch Time (s): 0.13, Total Time (hrs): 0.0306
# ====> Epoch: 863 Train ELBO: 38.4050 Val ELBO: 78.3593, Epoch Time (s): 0.13, Total Time (hrs): 0.0306
# ====> Epoch: 864 Train ELBO: 46.3435 Val ELBO: 76.6695, Epoch Time (s): 0.14, Total Time (hrs): 0.0307
# ====> Epoch: 865 Train ELBO: 43.0285 Val ELBO: 79.0126, Epoch Time (s): 0.13, Total Time (hrs): 0.0307
# ====> Epoch: 866 Train ELBO: 42.3459 Val ELBO: 78.9750, Epoch Time (s): 0.12, Total Time (hrs): 0.0307
# ====> Epoch: 867 Train ELBO: 42.2708 Val ELBO: 78.7628, Epoch Time (s): 0.13, Total Time (hrs): 0.0308
# ====> Epoch: 868 Train ELBO: 43.4169 Val ELBO: 71.1113, Epoch Time (s): 0.12, Total Time (hrs): 0.0308
