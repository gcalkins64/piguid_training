# %% [markdown]
# # Imports

# %% [markdown]
# TO RUN:
# - Make sure to select Runtime>Change Runtime Type>T4 GPU to use cuda
# - Install pytorch_lightning
# - clone in repo to read in common files

# %%
# !pip install pytorch_lightning
# Out:
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.6.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (2.9.0+cu126)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.67.1)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2025.3.0)
# Collecting torchmetrics>0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (25.0)
# Requirement already satisfied: typing-extensions>4.5.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.15.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.13.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.10.0->pytorch_lightning) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.20.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.5.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics>0.7.0->pytorch_lightning) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.22.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (3.0.3)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.11)
# Downloading pytorch_lightning-2.6.0-py3-none-any.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 17.4 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 56.9 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch_lightning
# Successfully installed lightning-utilities-0.15.2 pytorch_lightning-2.6.0 torchmetrics-1.8.2

# %%
import os
import random
import numpy as np
import torch
from pytorch_lightning import seed_everything

SEED = 42
seed_everything(SEED, workers=True)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

import torch.optim as optim
from torch.distributions import Normal
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import pathlib
from torch.utils.data import DataLoader
from pytorch_lightning import LightningDataModule
import seaborn as sns
import json
from tqdm.notebook import tqdm_notebook
from time import time
import time
from datetime import datetime, timedelta
import pickle
import matplotlib.lines as mlines
import sys
from sklearn.decomposition import PCA
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 42

# %%
# !git clone https://github.com/gcalkins64/piguid_training.git
# Out:
# Cloning into 'piguid_training'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 51 (delta 23), reused 30 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (51/51), 3.01 MiB | 6.90 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# !cd piguid_training && git pull
# Out:
# Already up to date.

# %%
sys.path.append('/content/piguid_training')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from gmvae_common import *

# %% [markdown]
# # Check Devices

# %%
# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set default tensor type to CUDA tensors
torch.set_default_tensor_type(torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor)
print(device)
# Out:
# cuda
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1275: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)

# %% [markdown]
# # Settings

# %%
n_train = 1024
n_val = 128
n_test = 128
# For testing small batches of data
# n_train = 400
# n_val = 50
# n_test = 50
# THREE LAYERS
hd1 = 36
hd2 = 18
hd3 = 9
hidden_dims = [hd1, hd2, hd3]
hidden_dims_r = [hd3, hd2, hd1]
# TWO LAYERS
# hd1 = 32
# hd2 = 16
# hd3 = None
# hidden_dims = [hd1, hd2]
# hidden_dims_r = [hd2, hd1]
lr = 1e-3
n_epochs = 10_000 # 30_000
batch_size = 128
em_reg = 1e-6
decoder_var = 1e-5

latent_dims = [3,4,5]
n_clustersS = [3,4,5]
skip_combos = []

plot_interval = 500
dpi = 300

D = 1  #num_modalities
downsampleNum = 36

loadFlag = False  # True to load in old case, False to run a new case

# data = 'orion_mars_return_2500_data_alt_range_scaled_downsampled'
# inds = 'orion_mars_return_2500_inds_alt_range_scaled_downsampled'
# tag = 'orion_mars_return'
data = 'orion_mars_return_2500_data_energy_huntest_scaled_downsampled'
inds = 'orion_mars_return_2500_inds_energy_huntest_scaled_downsampled'
tag = 'orion_mars_return_huntest'

# %% [markdown]
# # LOOP GMVAE TRAINING

# %%
for latent_dim in latent_dims:
  for n_clusters in n_clustersS:
    if [latent_dim, n_clusters] in skip_combos:
      continue
    else:
      K = n_clusters
      Z = latent_dim

      timestr = datetime.strftime(datetime.now(), "%Y%m%d_%H%M%S")

      if loadFlag:  # Load in old data
          dirname = loaddirname
      else:  # generate new data
          dirname = os.path.join("drive", "MyDrive", "piguid", "gmvae_"+tag+"_"+timestr+"_L"+str(latent_dim)+"_C"+str(n_clusters))
      os.makedirs(dirname, exist_ok=True)
      print("Filepath directory: " + dirname)

      if loadFlag:  # load old data
          postfix = loadpostfix
      else:  # Generate new suffix
          if hd3 is not None:
              postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:d}_{9:f}_{10:d}_{11:f}_{12:f}_{13:f}_'.format(
                  SEED, n_train, n_val, n_test, hd1, hd2, hd3, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
          else:
              postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:f}_{9:d}_{10:f}_{11:f}_{12:f}_'.format(
                  SEED, n_train, n_val, n_test, hd1, hd2, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
      print("Filepath postfix: " + postfix)

      data_dir = os.path.join("drive", "MyDrive", "piguid", f"{data}.json")

      with open(os.path.join("drive", "MyDrive", "piguid", f"{inds}.json"), 'r') as f:
          sample_list_load = json.load(f)
          sample_list = [int(sample) for sample in sample_list_load['sample_list']]
      print(sample_list)

      data_module = AerocaptureDataModuleCUDA(data_dir=data_dir, n_train=n_train, n_val=n_val, n_test=n_test,
                                      train_batch=batch_size, val_batch=batch_size, test_batch=batch_size,
                                      num_workers=0)

      data_module.setup("fit", sample_list = sample_list)

      train_loader = data_module.train_dataloader()
      val_loader = data_module.val_dataloader()
      test_loader = data_module.test_dataloader()
      data_dim = len(train_loader.dataset[0][0])
      true_labels = ['capture', 'escape', 'miss']
      label_colors = ['C2', 'C3', 'C4']

      num_train_batches = len(train_loader)

      ts_plot = np.linspace(0,1,downsampleNum)
      seabornSettings()
      fig, ax = plt.subplots(figsize=(4, 4))
      for j in range(n_train):
          ax.plot(ts_plot, train_loader.dataset[j][0].cpu(), color=label_colors[train_loader.dataset[j][1].cpu()], alpha=0.3)

      eline = mlines.Line2D([], [], color='C2', label='Escape')
      cline = mlines.Line2D([], [], color='C3', label='Capture')
      iline = mlines.Line2D([], [], color='C4', label='Miss')
      plt.legend(handles=[eline, cline, iline])
      # plt.hlines(0, 0, ts_plot[-1], colors='r', linestyles='dashed')
      plt.xlabel("Downrange")
      plt.ylabel("Altitude")
      plt.title("Training Data")
      plt.tight_layout()
      fig.savefig(os.path.join(dirname, 'train_data'+postfix+'.png'), dpi=dpi)

      fig, ax = plt.subplots(figsize=(4.5, 4))
      for j in range(n_val):
          ax.plot(ts_plot, val_loader.dataset[j][0].cpu(), color=label_colors[val_loader.dataset[j][1].cpu()], alpha=0.3)
      plt.title("Validation Data")
      fig.savefig(os.path.join(dirname, 'val_data'+postfix+'.png'), dpi=dpi)

      fig, ax = plt.subplots(figsize=(4.5, 4))
      for j in range(n_test):
          ax.plot(ts_plot, test_loader.dataset[j][0].cpu(), color=label_colors[test_loader.dataset[j][1].cpu()], alpha=0.3)
      plt.title("Test Data")
      fig.savefig(os.path.join(dirname, 'test_data'+postfix+'.png'), dpi=dpi)


      # initialize latent GMM model parameters
      params = {}
      pi_variables = torch.zeros(K).clone().detach().requires_grad_(True)
      params['pi_c'] = torch.ones(K) / K
      params['mu_c'] = torch.rand((K, Z)) * 2.0 - 1.0
      params['logsigmasq_c'] = torch.zeros((K, Z))

      # initialize neural networks
      encoder_list = []
      decoder_list = []
      trainable_parameters = []
      trainable_parameters.append(pi_variables)

      for _ in range(D):
          encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims)
          decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var)
          encoder_list.append(encoder)
          decoder_list.append(decoder)
          trainable_parameters += list(encoder.parameters()) + list(decoder.parameters())

      train_loss = torch.zeros(n_epochs)
      train_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
      val_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
      val_loss = torch.zeros(n_epochs)
      pi_history = torch.zeros((n_epochs, K))
      train_mse_history = torch.zeros(n_epochs)
      val_mse_history = torch.zeros(n_epochs)
      min_val_loss = torch.inf
      trainEpochs = np.arange(0,n_epochs,1)


      # Training
      seabornSettings()
      text_labels = [f'Cluster {i}' for i in range((n_clusters))]
      label_colors = [f'C{i+1}' for i in range((n_clusters))]

      optimizer = optim.Adam(trainable_parameters, lr=lr)

      ts = time.time()
      tic = time.perf_counter()

      for epoch in trainEpochs:
          ti = time.time()
          for encoder in encoder_list:
              encoder.train()
          for decoder in decoder_list:
              decoder.train()

          train_elbo = 0
          train_mse = 0
          train_elbo_term = np.zeros(4)
          params['hist_weights'] = torch.zeros((K, 1))
          params['hist_mu_c'] = torch.zeros((K, latent_dim))
          params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))

          for (batch_idx, batch) in enumerate(train_loader):
              batch_x, _ = batch
              x_list = [batch_x]  # assume D=2 and each modality has data_dim
              optimizer.zero_grad()
              pi_c = torch.exp(pi_variables) / torch.sum(torch.exp(pi_variables))
              params['pi_c'] = pi_c

              mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
              sigma = torch.exp(0.5 * logsigmasq)
              eps = Normal(0, 1).sample(mu.shape)
              z = mu + eps * sigma

              with torch.no_grad():
                  gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
              params['mu_c'] = mu_c
              params['logsigmasq_c'] = logsigmasq_c

              elbo, sse, elbo_terms = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
              train_elbo += elbo.item()
              train_elbo_term += elbo_terms
              train_mse += sse.item()
              loss = - elbo / batch_x.shape[0]
              loss.backward()
              optimizer.step()

          for encoder in encoder_list:
              encoder.eval()
          for decoder in decoder_list:
              decoder.eval()

          if epoch % plot_interval == 0 or epoch == n_epochs:
              # Plot the first two dimensions of the latents
              with torch.no_grad():
                  means = []
                  samples = []
                  labels = []
                  for batch in train_loader:
                      batch_x, batch_label = batch
                      x_list = [batch_x]
                      mean, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                      sigma = torch.exp(0.5 * logsigmasq)
                      eps = Normal(0, 1).sample(mean.shape)
                      z = mean + eps * sigma
                      means.append(mean)
                      samples.append(z)
                      labels.append(batch_label)

              means = torch.vstack(means).cpu()
              samples = torch.vstack(samples).cpu()
              labels = torch.hstack(labels).cpu()

              savepath = os.path.join(dirname, "latent_samples_epoch_" + str(epoch) + postfix)
              plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)

              savepath = os.path.join(dirname, "latent_means_epoch_" + str(epoch) + postfix)
              plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)


              # plot samples from generative model
              n_gen = n_train
              cluster_probs = params['pi_c'].cpu().detach().numpy() #
              fig, ax = plt.subplots(figsize=(4.5, 4))
              for j in range(n_gen):
                  c = np.random.choice(K, p=cluster_probs)
                  mu_c = params['mu_c'][c].clone().detach()
                  sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).clone().detach()
                  z = Normal(0, 1).sample(mu_c.shape) * sigma_c + mu_c
                  mu_x = decoder.forward(z)[0]
                  ax.plot(mu_x.cpu().detach().numpy())
              fig.savefig(os.path.join(dirname, "generate_samples_" + str(epoch) + postfix+ '.png'), dpi=dpi)
              plt.close()


          val_elbo = 0
          val_mse = 0
          val_elbo_term = np.zeros(4)
          with torch.no_grad():
              for (batch_idx, batch) in enumerate(val_loader):
                  batch_x, _ = batch
                  x_list = [batch_x]
                  mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                  sigma = torch.exp(0.5 * logsigmasq)
                  eps = Normal(0, 1).sample(mu.shape)
                  z = mu + eps * sigma
                  with torch.no_grad():
                      gamma_c, _, _ = em_step(z, mu, logsigmasq, params, em_reg)
                  elbo, sse, elbo_items = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
                  val_elbo += elbo.item()
                  val_mse += sse.item()
                  val_elbo_term += elbo_items

          train_elbo /= len(train_loader.dataset)
          train_elbo_term = torch.tensor(train_elbo_term) / len(train_loader.dataset)
          val_elbo /= len(val_loader.dataset)
          val_elbo_term = torch.tensor(val_elbo_term) / len(val_loader.dataset)
          train_mse /= len(train_loader.dataset)
          val_mse /= len(val_loader.dataset)

          tf = time.time()
          toc = time.perf_counter()
          print('====> Epoch: {} Train ELBO: {:.4f} Val ELBO: {:.4f}, Epoch Time (s): {:.2f}, Total Time (hrs): {:.4f}'.format(epoch, train_elbo, val_elbo, tf-ti, (toc-tic)/60/60))

          train_loss[epoch] = - train_elbo
          val_loss[epoch] = - val_elbo
          train_elbo_terms[epoch,:] = - train_elbo_term
          val_elbo_terms[epoch,:] = - val_elbo_term
          pi_history[epoch] = params['pi_c']
          train_mse_history[epoch] = train_mse
          val_mse_history[epoch] = val_mse

          if - val_elbo < min_val_loss:
              min_val_loss = - val_elbo
              torch.save(params['pi_c'], os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
              torch.save(params['mu_c'], os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
              torch.save(params['logsigmasq_c'], os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
              torch.save(encoder.state_dict(), os.path.join(dirname, 'encoder'+ postfix + '.pt'))
              torch.save(decoder.state_dict(), os.path.join(dirname, 'decoder'+ postfix + '.pt'))

          if epoch % plot_interval == 0 or epoch == n_epochs:
            # Plot the training and validation loss vs. epoch number
            plt.figure(figsize=(4.5, 4))
            # const = min(min(train_loss), min(val_loss))
            train_loss_adjusted = train_loss
            val_loss_adjusted = val_loss
            plt.plot(train_loss_adjusted.cpu()[:epoch], label='train')
            # print(train_loss_adjusted.cpu()[:epoch])
            plt.plot(val_loss_adjusted.cpu()[:epoch], label='val')
            plt.yscale('symlog')
            plt.xlabel("number of epochs")
            plt.ylabel("loss")
            plt.title("Negative Loss")
            plt.legend()
            plt.tight_layout()
            plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
            plt.close()

            # Plot each term of the training loss and validation loss
            plt.figure(figsize=(4.5, 4))
            labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
            for ii in range(4):
                train_loss_adjusted = train_elbo_terms[:epoch, ii]
                val_loss_adjusted = val_elbo_terms[:epoch, ii]
                plt.plot(train_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Train")
                plt.plot(val_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Val", linestyle='--')
            plt.xlabel("number of epochs")
            plt.yscale('symlog')
            plt.ylabel("loss")
            plt.title("Negative Loss Terms")
            plt.legend()
            plt.tight_layout()
            plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
            plt.close()

            # Plot the training and validation mse vs. epoch number
            plt.figure(figsize=(4.5, 4))
            plt.semilogy(train_mse_history.cpu().detach().numpy()[:epoch], label='train')
            plt.semilogy(val_mse_history.cpu().detach().numpy()[:epoch], label='val')
            plt.xlabel("number of epochs")
            plt.legend()
            plt.tight_layout()
            plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
            plt.close()

            # Plot the history of pi
            plt.figure(figsize=(4.5, 4))
            for i in range(K):
                plt.plot(pi_history[:, i].cpu().detach().numpy()[:epoch], label=r'$\pi$' + str(i+1))
            plt.xlabel("number of epochs")
            plt.legend()
            plt.tight_layout()
            plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
            plt.close()


      te = time.time()
      duration = timedelta(seconds=te - ts)
      print("Training took ", duration)

      # Save off pi_history, train_loss, val_loss, train_mse_history, val_mse_history
      torch.save(pi_history, os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
      torch.save(train_loss, os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
      torch.save(val_loss, os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
      torch.save(train_elbo_terms, os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
      torch.save(val_elbo_terms, os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
      torch.save(train_mse_history, os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
      torch.save(val_mse_history, os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))

      params = {}
      encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims).to("cuda")
      decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var).to("cuda")


      encoder_list = [encoder]
      decoder_list = [decoder]

      device = next(encoder.parameters()).device
      # Load in training history metrics
      pi_history = torch.load(os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
      train_loss = torch.load(os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
      val_loss = torch.load(os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
      train_elbo_terms = torch.load(os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
      val_elbo_terms = torch.load(os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
      train_mse_history = torch.load(os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
      val_mse_history = torch.load(os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))


      text_labels = [f'Cluster {i}' for i in range((n_clusters))]
      label_colors = [f'C{i+1}' for i in range((n_clusters))]
      data_colors = label_colors

      # Plot training history
      # Plot the training and validation loss vs. epoch number
      plt.figure(figsize=(4, 4))
      const = min(min(train_loss), min(val_loss))
      # const = min(10, const)
      train_loss_adjusted = train_loss
      val_loss_adjusted = val_loss
      plt.plot(train_loss_adjusted.cpu(), label='Training')
      plt.plot(val_loss_adjusted.cpu(), label='Validation')
      plt.xlabel("Number of Epochs")
      plt.ylabel("Negative Loss")
      # plt.title("Negative Loss")
      plt.yscale('symlog')
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      # plt.close()


      # Plot each term of the training loss and validation loss
      plt.figure(figsize=(4.5, 4))
      labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
      for ii in range(4):
          # print(train_elbo_terms.cpu()[ii, :epoch])
          # print(len(train_elbo_terms.cpu()[ii, :epoch]))
          train_loss_adjusted = train_elbo_terms[:, ii]
          val_loss_adjusted = val_elbo_terms[:, ii]
      plt.plot(train_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Train")
      plt.plot(val_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Val", linestyle='--')
      plt.xlabel("number of epochs")
      plt.ylabel("loss")
      plt.title("Negative Loss Terms")
      plt.yscale('symlog')
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      # plt.close()


      # Plot the sum of each term of the training loss and validation loss
      plt.figure(figsize=(4.5, 4))
      # print(train_elbo_terms.cpu()[ii, :epoch])
      # print(len(train_elbo_terms.cpu()[ii, :epoch]))
      train_loss_adjusted = train_elbo_terms.sum(axis=1)
      val_loss_adjusted = val_elbo_terms.sum(axis=1)
      plt.plot(train_loss_adjusted.cpu()[:], label=f"Train")
      plt.plot(val_loss_adjusted.cpu()[:], label=f"Val", linestyle='--')
      plt.xlabel("number of epochs")
      plt.ylabel("loss")
      plt.title("Sum of ELBO Terms")
      plt.yscale('symlog')
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'elbo_terms_sum_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      # plt.close()

      # Plot the training and validation mse vs. epoch number
      plt.figure(figsize=(4.5, 4))
      plt.semilogy(train_mse_history.cpu().detach().numpy(), label='train')
      plt.semilogy(val_mse_history.cpu().detach().numpy(), label='val')
      plt.xlabel("number of epochs")
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      # plt.close()

      # Plot the history of pi
      plt.figure(figsize=(4, 4))
      for i in range(K):
          plt.plot(pi_history[:, i].cpu().detach().numpy(), label=text_labels[i]+r' $\pi$', color=label_colors[i])
      plt.xlabel("Number of Epochs")
      plt.ylabel("Predicted Cluster Probability")
      plt.axhline(y=0.05, color='C1', linestyle='--', label='True Escape Probability')
      plt.axhline(y=0.95, color='C3', linestyle='--', label='True Capture Probability')
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      # plt.close()

      # Load best model saved
      params['pi_c'] = torch.load(os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
      params['mu_c'] = torch.load(os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
      params['logsigmasq_c'] = torch.load(os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
      encoder.load_state_dict(torch.load(os.path.join(dirname, 'encoder'+ postfix + '.pt')))
      decoder.load_state_dict(torch.load(os.path.join(dirname, 'decoder'+ postfix + '.pt')))

      encoder.eval()
      decoder.eval()

      # run one last EM step and plot training data in latent space
      for encoder in encoder_list:
          encoder.eval()

      with torch.no_grad():
          means = []
          samples = []
          labels = []
          params['hist_weights'] = torch.zeros((K, 1))
          params['hist_mu_c'] = torch.zeros((K, latent_dim))
          params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))
          for batch in train_loader:
              batch_x, batch_label = batch
              x_list = [batch_x]
              mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
              sigma = torch.exp(0.5 * logsigmasq)
              eps = Normal(0, 1).sample(mu.shape)
              z = mu + eps * sigma
              with torch.no_grad():
                  gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
              params['mu_c'] = mu_c
              params['logsigmasq_c'] = logsigmasq_c

              means.append(mu)
              samples.append(z)
              labels.append(batch_label)

      means = torch.vstack(means).cpu()
      samples = torch.vstack(samples).cpu()
      labels = torch.hstack(labels).cpu()


      savepath = os.path.join(dirname, "BEST_latent_samples"+postfix)
      plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

      savepath = os.path.join(dirname, "BEST_latent_means"+postfix)
      plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

      # plot test data in latent space
      with torch.no_grad():
          test_means = []
          test_labels = []
          for batch in test_loader:
              batch_x, batch_label = batch
              x_list = [batch_x]
              mean, _ = encoder_step(x_list, encoder_list, decoder_list)
              test_means.append(mean)
              test_labels.append(batch_label)

      test_means = torch.vstack(test_means).cpu()
      test_labels = torch.hstack(test_labels).cpu()


      savepath = os.path.join(dirname, "BEST_test_latent_samples"+postfix)
      plot_latent_space_with_clusters(test_means, test_labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

      # plot decoding results from cluster means # todo: expand this function for multi-modal data
      fig, ax = plt.subplots(figsize=(4.5, 4))
      for i in range(K):
          # with torch.no_grad:
          x_mean = decoder.forward(params['mu_c'][i])[0]
          ax.plot(x_mean.cpu().detach().numpy(), label="decoded $\mu$"+str(i+1))
      ax.legend()
      plt.title("Decoded Means")
      fig.savefig(os.path.join(dirname, "BEST_decoded_means"+postfix+'.png'), dpi=dpi)
      # plt.close()

      # plot samples from generative model
      n_gen = n_train
      cluster_probs = params['pi_c'].cpu().detach().numpy()
      fig, ax = plt.subplots(figsize=(4.5, 4))
      for j in range(n_gen):
          c = np.random.choice(K, p=cluster_probs)
          # print(c)
          mu_c = params['mu_c'][c].cpu().clone().detach()
          sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).cpu().clone().detach()
          z = Normal(0, 1).sample(mu_c.shape).cpu().clone().detach() * sigma_c + mu_c
          # print(z)
          mu_x = decoder.forward(z.cuda())[0].cpu().clone().detach()
          sigma_x = torch.exp(0.5 * decoder.forward(z.cuda())[1])
          sample_x = Normal(0, 1).sample(mu_x.shape).cpu().clone().detach() * sigma_x.cpu().clone().detach() + mu_x
          ax.plot(sample_x.cpu().detach().numpy())
      plt.title("Generated Samples")
      fig.savefig(os.path.join(dirname, "BEST_generate_samples"+postfix+'.png'), dpi=dpi)
      # plt.close()

      np.savez(dirname + postfix, train_loss=train_loss.cpu().detach().numpy(), val_loss=val_loss.cpu().detach().numpy(),
          train_mse=train_mse_history.cpu().detach().numpy(), val_mse=val_mse_history.cpu().detach().numpy(),
          pi_history=pi_history.cpu().detach().numpy(),
          cluster_probs=params['pi_c'].cpu().detach().numpy(),
          cluster_means=params['mu_c'].cpu().detach().numpy(),
          cluster_vars=torch.exp(params['logsigmasq_c']).cpu().detach().numpy())


      print("Training data size", n_train)
      print("Fraction of downward curves:", (torch.sum(labels == 0) / n_train).item())
      print("Cluster 1 probability:", cluster_probs.min().item())
# Out:
# <>:496: SyntaxWarning: invalid escape sequence '\m'
# <>:496: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipython-input-2101880448.py:496: SyntaxWarning: invalid escape sequence '\m'
#   ax.plot(x_mean.cpu().detach().numpy(), label="decoded $\mu$"+str(i+1))
# Filepath directory: drive/MyDrive/piguid/gmvae_orion_mars_return_20260112_174616_L2_C4
# Filepath postfix: _42_1024_128_128_36_18_9_2_4_0.001000_128_0.001000_0.000010_10000.000000_
# [1318, 2431, 629, 202, 2259, 1781, 468, 1986, 623, 2118, 2120, 2405, 397, 1770, 1714, 175, 2051, 860, 2106, 895, 854, 2368, 1837, 191, 1804, 951, 2222, 568, 184, 159, 1822, 447, 2337, 1360, 2137, 1800, 1113, 1298, 334, 2215, 986, 1435, 530, 1985, 326, 44, 534, 1989, 767, 2029, 279, 1229, 1427, 109, 734, 2145, 97, 1354, 2310, 1494, 817, 204, 866, 1487, 1291, 648, 944, 2020, 1554, 1139, 1098, 2303, 1984, 1860, 1353, 1170, 777, 2124, 1477, 392, 603, 2231, 810, 2014, 1978, 654, 166, 911, 289, 396, 1728, 1366, 2229, 1527, 1811, 2317, 2475, 1944, 103, 251, 853, 1571, 2411, 1195, 336, 500, 151, 1448, 1202, 39, 394, 1864, 121, 533, 2336, 2028, 1639, 18, 1046, 207, 2499, 1420, 1249, 1121, 1357, 1665, 1885, 269, 1164, 261, 2379, 490, 287, 2050, 1389, 1936, 528, 1694, 1957, 1269, 1760, 1850, 1211, 1475, 1730, 1150, 671, 1874, 1755, 929, 1014, 600, 1542, 1345, 746, 1620, 1495, 730, 1383, 248, 1780, 1387, 1938, 2160, 1982, 260, 2205, 2355, 673, 382, 2010, 1289, 867, 502, 1721, 1840, 1990, 2366, 2059, 464, 1675, 2453, 1897, 914, 322, 2176, 742, 494, 1931, 351, 1839, 1296, 683, 2228, 981, 9, 738, 540, 1685, 633, 2465, 754, 1141, 2463, 615, 380, 472, 1089, 2069, 1991, 65, 122, 1627, 1865, 1866, 1827, 1236, 613, 2003, 2441, 1470, 1607, 697, 1683, 1791, 1310, 1677, 1263, 950, 1939, 124, 2200, 230, 1329, 1433, 2346, 498, 350, 2225, 2078, 254, 137, 1367, 679, 180, 2006, 56, 399, 22, 900, 2497, 2490, 2286, 1725, 2143, 1709, 321, 575, 1023, 1517, 7, 1337, 1881, 1086, 1794, 786, 4, 2340, 2401, 247, 1224, 539, 1523, 717, 2198, 2419, 1574, 1951, 1188, 1441, 1557, 1895, 2406, 1323, 1266, 1142, 926, 576, 765, 1179, 55, 163, 2194, 364, 1782, 1238, 225, 1473, 1451, 640, 1393, 455, 463, 2378, 2391, 1209, 983, 2022, 1703, 1646, 1115, 2159, 2245, 749, 2292, 1649, 784, 2390, 939, 2421, 2443, 1592, 1316, 778, 899, 1455, 1916, 1371, 2454, 1870, 2377, 992, 1347, 1180, 770, 1610, 825, 2212, 59, 1586, 2258, 2474, 424, 1926, 2307, 505, 998, 1022, 1941, 1243, 2271, 1267, 385, 1924, 1563, 67, 649, 118, 2185, 1483, 1072, 2206, 462, 224, 1659, 1786, 1934, 1489, 1381, 1674, 2254, 2480, 1877, 1967, 1020, 1005, 779, 2387, 1060, 132, 655, 1069, 2156, 154, 86, 593, 960, 1273, 1184, 739, 470, 2116, 1538, 2262, 624, 234, 856, 676, 840, 1058, 1421, 2221, 706, 2320, 2306, 790, 1896, 1768, 837, 1821, 689, 452, 2048, 1160, 2086, 2164, 138, 606, 243, 323, 431, 1315, 646, 1949, 2325, 2260, 1698, 410, 904, 1342, 173, 1217, 1632, 119, 91, 2459, 1240, 1614, 1788, 1654, 2151, 2026, 741, 391, 2279, 2060, 62, 1465, 1817, 1206, 1580, 1609, 2153, 1712, 2084, 21, 1532, 1746, 1241, 1643, 112, 1161, 366, 2372, 2252, 563, 1838, 2064, 1964, 328, 1218, 1552, 1486, 1777, 1998, 1106, 2359, 1690, 1438, 1460, 1830, 1409, 1623, 1679, 849, 959, 943, 1884, 2129, 2442, 144, 1880, 418, 2385, 123, 2236, 1686, 2430, 1739, 988, 420, 1596, 771, 1908, 758, 2318, 2109, 548, 924, 1948, 2210, 53, 1275, 521, 493, 409, 1493, 1593, 1929, 1333, 1631, 1002, 1892, 2416, 1648, 1918, 29, 955, 1328, 769, 2322, 1341, 2170, 1215, 2298, 885, 700, 1088, 1006, 763, 580, 1019, 1423, 1729, 2158, 1710, 1030, 516, 677, 1159, 1292, 1570, 2333, 483, 1577, 228, 552, 1028, 1503, 1744, 2438, 1533, 1408, 722, 1650, 1297, 1656, 188, 1566, 1727, 346, 841, 1432, 620, 388, 48, 1611, 1251, 2472, 1719, 2295, 1524, 2451, 1603, 1187, 1288, 1672, 1178, 1994, 1434, 76, 139, 2226, 179, 2081, 1132, 1724, 1506, 227, 2345, 1711, 1752, 414, 2133, 972, 1153, 2038, 1260, 604, 1488, 2488, 256, 2253, 816, 1828, 2470, 785, 1081, 936, 644, 74, 1899, 1111, 370, 1171, 58, 1769, 993, 745, 756, 1068, 176, 2332, 1062, 1390, 449, 1321, 889, 19, 1759, 253, 2104, 2066, 596, 1348, 1736, 1450, 1923, 2189, 1128, 1903, 1995, 581, 1051, 674, 513, 1140, 85, 2249, 332, 2017, 874, 495, 319, 828, 719, 2404, 1074, 31, 2027, 1689, 252, 1617, 2192, 1625, 617, 1301, 1331, 211, 1511, 491, 2209, 2478, 421, 908, 1589, 647, 1754, 619, 918, 307, 973, 2191, 804, 1203, 2021, 222, 1499, 643, 1, 308, 467, 610, 2099, 1462, 750, 2113, 2199, 1101, 20, 1904, 2433, 2331, 2203, 2450, 538, 21 ...
# Loading File...
# ...File Loaded
# Sample List: [1318, 2431, 629, 202, 2259, 1781, 468, 1986, 623, 2118, 2120, 2405, 397, 1770, 1714, 175, 2051, 860, 2106, 895, 854, 2368, 1837, 191, 1804, 951, 2222, 568, 184, 159, 1822, 447, 2337, 1360, 2137, 1800, 1113, 1298, 334, 2215, 986, 1435, 530, 1985, 326, 44, 534, 1989, 767, 2029, 279, 1229, 1427, 109, 734, 2145, 97, 1354, 2310, 1494, 817, 204, 866, 1487, 1291, 648, 944, 2020, 1554, 1139, 1098, 2303, 1984, 1860, 1353, 1170, 777, 2124, 1477, 392, 603, 2231, 810, 2014, 1978, 654, 166, 911, 289, 396, 1728, 1366, 2229, 1527, 1811, 2317, 2475, 1944, 103, 251, 853, 1571, 2411, 1195, 336, 500, 151, 1448, 1202, 39, 394, 1864, 121, 533, 2336, 2028, 1639, 18, 1046, 207, 2499, 1420, 1249, 1121, 1357, 1665, 1885, 269, 1164, 261, 2379, 490, 287, 2050, 1389, 1936, 528, 1694, 1957, 1269, 1760, 1850, 1211, 1475, 1730, 1150, 671, 1874, 1755, 929, 1014, 600, 1542, 1345, 746, 1620, 1495, 730, 1383, 248, 1780, 1387, 1938, 2160, 1982, 260, 2205, 2355, 673, 382, 2010, 1289, 867, 502, 1721, 1840, 1990, 2366, 2059, 464, 1675, 2453, 1897, 914, 322, 2176, 742, 494, 1931, 351, 1839, 1296, 683, 2228, 981, 9, 738, 540, 1685, 633, 2465, 754, 1141, 2463, 615, 380, 472, 1089, 2069, 1991, 65, 122, 1627, 1865, 1866, 1827, 1236, 613, 2003, 2441, 1470, 1607, 697, 1683, 1791, 1310, 1677, 1263, 950, 1939, 124, 2200, 230, 1329, 1433, 2346, 498, 350, 2225, 2078, 254, 137, 1367, 679, 180, 2006, 56, 399, 22, 900, 2497, 2490, 2286, 1725, 2143, 1709, 321, 575, 1023, 1517, 7, 1337, 1881, 1086, 1794, 786, 4, 2340, 2401, 247, 1224, 539, 1523, 717, 2198, 2419, 1574, 1951, 1188, 1441, 1557, 1895, 2406, 1323, 1266, 1142, 926, 576, 765, 1179, 55, 163, 2194, 364, 1782, 1238, 225, 1473, 1451, 640, 1393, 455, 463, 2378, 2391, 1209, 983, 2022, 1703, 1646, 1115, 2159, 2245, 749, 2292, 1649, 784, 2390, 939, 2421, 2443, 1592, 1316, 778, 899, 1455, 1916, 1371, 2454, 1870, 2377, 992, 1347, 1180, 770, 1610, 825, 2212, 59, 1586, 2258, 2474, 424, 1926, 2307, 505, 998, 1022, 1941, 1243, 2271, 1267, 385, 1924, 1563, 67, 649, 118, 2185, 1483, 1072, 2206, 462, 224, 1659, 1786, 1934, 1489, 1381, 1674, 2254, 2480, 1877, 1967, 1020, 1005, 779, 2387, 1060, 132, 655, 1069, 2156, 154, 86, 593, 960, 1273, 1184, 739, 470, 2116, 1538, 2262, 624, 234, 856, 676, 840, 1058, 1421, 2221, 706, 2320, 2306, 790, 1896, 1768, 837, 1821, 689, 452, 2048, 1160, 2086, 2164, 138, 606, 243, 323, 431, 1315, 646, 1949, 2325, 2260, 1698, 410, 904, 1342, 173, 1217, 1632, 119, 91, 2459, 1240, 1614, 1788, 1654, 2151, 2026, 741, 391, 2279, 2060, 62, 1465, 1817, 1206, 1580, 1609, 2153, 1712, 2084, 21, 1532, 1746, 1241, 1643, 112, 1161, 366, 2372, 2252, 563, 1838, 2064, 1964, 328, 1218, 1552, 1486, 1777, 1998, 1106, 2359, 1690, 1438, 1460, 1830, 1409, 1623, 1679, 849, 959, 943, 1884, 2129, 2442, 144, 1880, 418, 2385, 123, 2236, 1686, 2430, 1739, 988, 420, 1596, 771, 1908, 758, 2318, 2109, 548, 924, 1948, 2210, 53, 1275, 521, 493, 409, 1493, 1593, 1929, 1333, 1631, 1002, 1892, 2416, 1648, 1918, 29, 955, 1328, 769, 2322, 1341, 2170, 1215, 2298, 885, 700, 1088, 1006, 763, 580, 1019, 1423, 1729, 2158, 1710, 1030, 516, 677, 1159, 1292, 1570, 2333, 483, 1577, 228, 552, 1028, 1503, 1744, 2438, 1533, 1408, 722, 1650, 1297, 1656, 188, 1566, 1727, 346, 841, 1432, 620, 388, 48, 1611, 1251, 2472, 1719, 2295, 1524, 2451, 1603, 1187, 1288, 1672, 1178, 1994, 1434, 76, 139, 2226, 179, 2081, 1132, 1724, 1506, 227, 2345, 1711, 1752, 414, 2133, 972, 1153, 2038, 1260, 604, 1488, 2488, 256, 2253, 816, 1828, 2470, 785, 1081, 936, 644, 74, 1899, 1111, 370, 1171, 58, 1769, 993, 745, 756, 1068, 176, 2332, 1062, 1390, 449, 1321, 889, 19, 1759, 253, 2104, 2066, 596, 1348, 1736, 1450, 1923, 2189, 1128, 1903, 1995, 581, 1051, 674, 513, 1140, 85, 2249, 332, 2017, 874, 495, 319, 828, 719, 2404, 1074, 31, 2027, 1689, 252, 1617, 2192, 1625, 617, 1301, 1331, 211, 1511, 491, 2209, 2478, 421, 908, 1589, 647, 1754, 619, 918, 307, 973, 2191, 804, 1203, 2021, 222, 1499, 643, 1, 308, 467, 610, 2099, 1462, 750, 2113, 2199, 1101, 20, 1904, 2433, 2331, 2203,  ...
#   0%|          | 0/1280 [00:00<?, ?it/s]
# /content/piguid_training/gmvae_common.py:265: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   elbo_terms[0] = Normal(mu_, torch.exp(0.5 * logsigmasq_)).log_prob(x_list[d]).sum()
# Streaming output truncated to the last 5000 lines.
# ====> Epoch: 5010 Train ELBO: 67.9548 Val ELBO: 102.1227, Epoch Time (s): 0.12, Total Time (hrs): 0.1479
# ====> Epoch: 5011 Train ELBO: 66.1524 Val ELBO: 101.1072, Epoch Time (s): 0.11, Total Time (hrs): 0.1479
# ====> Epoch: 5012 Train ELBO: 65.0298 Val ELBO: 102.9287, Epoch Time (s): 0.12, Total Time (hrs): 0.1480
# ====> Epoch: 5013 Train ELBO: 66.9299 Val ELBO: 98.1096, Epoch Time (s): 0.11, Total Time (hrs): 0.1480
# ====> Epoch: 5014 Train ELBO: 61.7676 Val ELBO: 100.2319, Epoch Time (s): 0.12, Total Time (hrs): 0.1480
# ====> Epoch: 5015 Train ELBO: 65.4113 Val ELBO: 100.3932, Epoch Time (s): 0.12, Total Time (hrs): 0.1481
# ====> Epoch: 5016 Train ELBO: 63.0411 Val ELBO: 87.0334, Epoch Time (s): 0.12, Total Time (hrs): 0.1481
# ====> Epoch: 5017 Train ELBO: 53.6949 Val ELBO: 97.6333, Epoch Time (s): 0.12, Total Time (hrs): 0.1481
# ====> Epoch: 5018 Train ELBO: 60.2887 Val ELBO: 96.7701, Epoch Time (s): 0.11, Total Time (hrs): 0.1482
# ====> Epoch: 5019 Train ELBO: 64.1734 Val ELBO: 101.0811, Epoch Time (s): 0.12, Total Time (hrs): 0.1482
# ====> Epoch: 5020 Train ELBO: 65.3047 Val ELBO: 99.8130, Epoch Time (s): 0.12, Total Time (hrs): 0.1482
# ====> Epoch: 5021 Train ELBO: 66.8405 Val ELBO: 103.1586, Epoch Time (s): 0.11, Total Time (hrs): 0.1483
# ====> Epoch: 5022 Train ELBO: 67.2779 Val ELBO: 103.5403, Epoch Time (s): 0.13, Total Time (hrs): 0.1483
# ====> Epoch: 5023 Train ELBO: 64.5614 Val ELBO: 104.1309, Epoch Time (s): 0.11, Total Time (hrs): 0.1483
# ====> Epoch: 5024 Train ELBO: 65.5606 Val ELBO: 102.9704, Epoch Time (s): 0.15, Total Time (hrs): 0.1484
# ====> Epoch: 5025 Train ELBO: 62.6689 Val ELBO: 104.3582, Epoch Time (s): 0.12, Total Time (hrs): 0.1484
# ====> Epoch: 5026 Train ELBO: 61.4881 Val ELBO: 102.6049, Epoch Time (s): 0.13, Total Time (hrs): 0.1485
# ====> Epoch: 5027 Train ELBO: 65.6452 Val ELBO: 97.1202, Epoch Time (s): 0.12, Total Time (hrs): 0.1485
# ====> Epoch: 5028 Train ELBO: 58.9424 Val ELBO: 76.7605, Epoch Time (s): 0.14, Total Time (hrs): 0.1485
# ====> Epoch: 5029 Train ELBO: 53.5448 Val ELBO: 101.2745, Epoch Time (s): 0.13, Total Time (hrs): 0.1486
# ====> Epoch: 5030 Train ELBO: 55.0268 Val ELBO: 84.3062, Epoch Time (s): 0.16, Total Time (hrs): 0.1486
# ====> Epoch: 5031 Train ELBO: 46.6283 Val ELBO: 93.1095, Epoch Time (s): 0.09, Total Time (hrs): 0.1486
# ====> Epoch: 5032 Train ELBO: 45.5548 Val ELBO: 87.4262, Epoch Time (s): 0.10, Total Time (hrs): 0.1487
# ====> Epoch: 5033 Train ELBO: 51.4566 Val ELBO: 87.8377, Epoch Time (s): 0.09, Total Time (hrs): 0.1487
# ====> Epoch: 5034 Train ELBO: 60.0533 Val ELBO: 95.1347, Epoch Time (s): 0.08, Total Time (hrs): 0.1487
# ====> Epoch: 5035 Train ELBO: 56.7941 Val ELBO: 62.7986, Epoch Time (s): 0.08, Total Time (hrs): 0.1487
# ====> Epoch: 5036 Train ELBO: 45.0259 Val ELBO: -4.8246, Epoch Time (s): 0.09, Total Time (hrs): 0.1487
# ====> Epoch: 5037 Train ELBO: -23.8735 Val ELBO: -80.4777, Epoch Time (s): 0.08, Total Time (hrs): 0.1488
# ====> Epoch: 5038 Train ELBO: -8.8616 Val ELBO: 80.5642, Epoch Time (s): 0.08, Total Time (hrs): 0.1488
# ====> Epoch: 5039 Train ELBO: 37.4487 Val ELBO: 79.0614, Epoch Time (s): 0.08, Total Time (hrs): 0.1488
# ====> Epoch: 5040 Train ELBO: 51.4606 Val ELBO: 96.4299, Epoch Time (s): 0.09, Total Time (hrs): 0.1488
# ====> Epoch: 5041 Train ELBO: 53.7182 Val ELBO: 96.3479, Epoch Time (s): 0.08, Total Time (hrs): 0.1489
# ====> Epoch: 5042 Train ELBO: 56.3365 Val ELBO: 94.8711, Epoch Time (s): 0.09, Total Time (hrs): 0.1489
# ====> Epoch: 5043 Train ELBO: 52.8556 Val ELBO: 83.3204, Epoch Time (s): 0.08, Total Time (hrs): 0.1489
# ====> Epoch: 5044 Train ELBO: 58.2471 Val ELBO: 99.2597, Epoch Time (s): 0.09, Total Time (hrs): 0.1489
# ====> Epoch: 5045 Train ELBO: 65.0599 Val ELBO: 102.7637, Epoch Time (s): 0.09, Total Time (hrs): 0.1490
# ====> Epoch: 5046 Train ELBO: 64.4169 Val ELBO: 103.7177, Epoch Time (s): 0.08, Total Time (hrs): 0.1490
# ====> Epoch: 5047 Train ELBO: 65.7880 Val ELBO: 104.6793, Epoch Time (s): 0.08, Total Time (hrs): 0.1490
# ====> Epoch: 5048 Train ELBO: 68.1822 Val ELBO: 99.1935, Epoch Time (s): 0.09, Total Time (hrs): 0.1490
# ====> Epoch: 5049 Train ELBO: 64.6713 Val ELBO: 101.9013, Epoch Time (s): 0.08, Total Time (hrs): 0.1490
# ====> Epoch: 5050 Train ELBO: 63.5340 Val ELBO: 101.5878, Epoch Time (s): 0.08, Total Time (hrs): 0.1491
# ====> Epoch: 5051 Train ELBO: 68.2901 Val ELBO: 103.0755, Epoch Time (s): 0.08, Total Time (hrs): 0.1491
# ====> Epoch: 5052 Train ELBO: 64.5396 Val ELBO: 95.1977, Epoch Time (s): 0.08, Total Time (hrs): 0.1491
# ====> Epoch: 5053 Train ELBO: 63.0717 Val ELBO: 93.1704, Epoch Time (s): 0.08, Total Time (hrs): 0.1491
# ====> Epoch: 5054 Train ELBO: 58.8139 Val ELBO: 86.5060, Epoch Time (s): 0.09, Total Time (hrs): 0.1492
# ====> Epoch: 5055 Train ELBO: 51.7646 Val ELBO: 101.3572, Epoch Time (s): 0.08, Total Time (hrs): 0.1492
# ====> Epoch: 5056 Train ELBO: 62.1702 Val ELBO: 101.0128, Epoch Time (s): 0.07, Total Time (hrs): 0.1492
# ====> Epoch: 5057 Train ELBO: 65.4131 Val ELBO: 104.0157, Epoch Time (s): 0.10, Total Time (hrs): 0.1492
# ====> Epoch: 5058 Train ELBO: 66.8801 Val ELBO: 104.2643, Epoch Time (s): 0.08, Total Time (hrs): 0.1492
# ====> Epoch: 5059 Train ELBO: 66.7909 Val ELBO: 103.7004, Epoch Time (s): 0.08, Total Time (hrs): 0.1493
# ====> Epoch: 5060 Train ELBO: 65.4905 Val ELBO: 95.5286, Epoch Time (s): 0.09, Total Time (hrs): 0.1493
# ====> Epoch: 5061 Train ELBO: 65.2096 Val ELBO: 102.0401, Epoch Time (s): 0.08, Total Time (hrs): 0.1493
# ====> Epoch: 5062 Train ELBO: 67.3824 Val ELBO: 101.4328, Epoch Time (s): 0.08, Total Time (hrs): 0.1493
# ====> Epoch: 5063 Train ELBO: 68.8672 Val ELBO: 104.2591, Epoch Time (s): 0.09, Total Time (hrs): 0.1494
# ====> Epoch: 5064 Train ELBO: 68.4550 Val ELBO: 105.9144, Epoch Time (s): 0.08, Total Time (hrs): 0.1494
# ====> Epoch: 5065 Train ELBO: 66.0214 Val ELBO: 102.0348, Epoch Time (s): 0.08, Total Time (hrs): 0.1494
# ====> Epoch: 5066 Train ELBO: 67.3660 Val ELBO: 105.7732, Epoch Time (s): 0.08, Total Time (hrs): 0.1494
# ====> Epoch: 5067 Train ELBO: 69.4709 Val ELBO: 101.8600, Epoch Time (s): 0.08, Total Time (hrs): 0.1495
# ====> Epoch: 5068 Train ELBO: 69.6585 Val ELBO: 106.5172, Epoch Time (s): 0.08, Total Time (hrs): 0.1495
# ====> Epoch: 5069 Train ELBO: 67.3445 Val ELBO: 102.0882, Epoch Time (s): 0.09, Total Time (hrs): 0.1495
# ====> Epoch: 5070 Train ELBO: 64.9474 Val ELBO: 101.6233, Epoch Time (s): 0.08, Total Time (hrs): 0.1495
# ====> Epoch: 5071 Train ELBO: 62.5552 Val ELBO: 102.3534, Epoch Time (s): 0.08, Total Time (hrs): 0.1496
# ====> Epoch: 5072 Train ELBO: 66.9057 Val ELBO: 101.2227, Epoch Time (s): 0.08, Total Time (hrs): 0.1496
# ====> Epoch: 5073 Train ELBO: 63.4629 Val ELBO: 87.2496, Epoch Time (s): 0.09, Total Time (hrs): 0.1496
# ====> Epoch: 5074 Train ELBO: 62.2471 Val ELBO: 98.3835, Epoch Time (s): 0.08, Total Time (hrs): 0.1496
# ====> Epoch: 5075 Train ELBO: 62.2552 Val ELBO: 98.7514, Epoch Time (s): 0.09, Total Time (hrs): 0.1497
# ====> Epoch: 5076 Train ELBO: 63.1254 Val ELBO: 95.8583, Epoch Time (s): 0.09, Total Time (hrs): 0.1497
# ====> Epoch: 5077 Train ELBO: 64.9806 Val ELBO: 103.8732, Epoch Time (s): 0.09, Total Time (hrs): 0.1497
# ====> Epoch: 5078 Train ELBO: 68.0155 Val ELBO: 105.3797, Epoch Time (s): 0.08, Total Time (hrs): 0.1497
# ====> Epoch: 5079 Train ELBO: 69.2073 Val ELBO: 102.2317, Epoch Time (s): 0.08, Total Time (hrs): 0.1498
# ====> Epoch: 5080 Train ELBO: 66.8841 Val ELBO: 105.9116, Epoch Time (s): 0.08, Total Time (hrs): 0.1498
# ====> Epoch: 5081 Train ELBO: 66.5678 Val ELBO: 97.5747, Epoch Time (s): 0.09, Total Time (hrs): 0.1498
# ====> Epoch: 5082 Train ELBO: 63.7086 Val ELBO: 100.4983, Epoch Time (s): 0.08, Total Time (hrs): 0.1498
# ====> Epoch: 5083 Train ELBO: 68.0913 Val ELBO: 106.1678, Epoch Time (s): 0.08, Total Time (hrs): 0.1499
# ====> Epoch: 5084 Train ELBO: 67.8863 Val ELBO: 103.9149, Epoch Time (s): 0.08, Total Time (hrs): 0.1499
# ====> Epoch: 5085 Train ELBO: 68.9386 Val ELBO: 105.2691, Epoch Time (s): 0.08, Total Time (hrs): 0.1499
# ====> Epoch: 5086 Train ELBO: 70.4773 Val ELBO: 104.2066, Epoch Time (s): 0.08, Total Time (hrs): 0.1499
# ====> Epoch: 5087 Train ELBO: 69.6174 Val ELBO: 105.3436, Epoch Time (s): 0.08, Total Time (hrs): 0.1499
# ====> Epoch: 5088 Train ELBO: 68.4776 Val ELBO: 103.5905, Epoch Time (s): 0.09, Total Time (hrs): 0.1500
# ====> Epoch: 5089 Train ELBO: 64.0725 Val ELBO: 102.1555, Epoch Time (s): 0.08, Total Time (hrs): 0.1500
# ====> Epoch: 5090 Train ELBO: 68.2301 Val ELBO: 97.8820, Epoch Time (s): 0.08, Total Time (hrs): 0.1500
# ====> Epoch: 5091 Train ELBO: 63.7243 Val ELBO: 94.2425, Epoch Time (s): 0.08, Total Time (hrs): 0.1500
# ====> Epoch: 5092 Train ELBO: 63.1123 Val ELBO: 98.6788, Epoch Time (s): 0.08, Total Time (hrs): 0.1501
# ====> Epoch: 5093 Train ELBO: 65.5220 Val ELBO: 101.1518, Epoch Time (s): 0.09, Total Time (hrs): 0.1501
# ====> Epoch: 5094 Train ELBO: 67.8995 Val ELBO: 102.3294, Epoch Time (s): 0.09, Total Time (hrs): 0.1501
# ====> Epoch: 5095 Train ELBO: 67.6296 Val ELBO: 107.5018, Epoch Time (s): 0.08, Total Time (hrs): 0.1501
# ====> Epoch: 5096 Train ELBO: 68.6910 Val ELBO: 105.2748, Epoch Time (s): 0.09, Total Time (hrs): 0.1502
# ====> Epoch: 5097 Train ELBO: 69.2984 Val ELBO: 106.3755, Epoch Time (s): 0.08, Total Time (hrs): 0.1502
# ====> Epoch: 5098 Train ELBO: 69.6299 Val ELBO: 101.9219, Epoch Time (s): 0.08, Total Time (hrs): 0.1502
# ====> Epoch: 5099 Train ELBO: 65.5903 Val ELBO: 98.1413, Epoch Time (s): 0.09, Total Time (hrs): 0.1502
# ====> Epoch: 5100 Train ELBO: 61.5829 Val ELBO: 100.0494, Epoch Time (s): 0.08, Total Time (hrs): 0.1503
# ====> Epoch: 5101 Train ELBO: 65.3404 Val ELBO: 97.4188, Epoch Time (s): 0.08, Total Time (hrs): 0.1503
# ====> Epoch: 5102 Train ELBO: 63.9114 Val ELBO: 103.2958, Epoch Time (s): 0.08, Total Time (hrs): 0.1503
# ====> Epoch: 5103 Train ELBO: 67.1148 Val ELBO: 100.6868, Epoch Time (s): 0.08, Total Time (hrs): 0.1503
# ====> Epoch: 5104 Train ELBO: 66.7200 Val ELBO: 100.6803, Epoch Time (s): 0.09, Total Time (hrs): 0.1503
# ====> Epoch: 5105 Train ELBO: 64.7357 Val ELBO: 99.9514, Epoch Time (s): 0.10, Total Time (hrs): 0.1504
# ====> Epoch: 5106 Train ELBO: 65.6345 Val ELBO: 102.9601, Epoch Time (s): 0.08, Total Time (hrs): 0.1504
# ====> Epoch: 5107 Train ELBO: 61.4736 Val ELBO: 99.9099, Epoch Time (s): 0.08, Total Time (hrs): 0.1504
# ====> Epoch: 5108 Train ELBO: 62.3398 Val ELBO: 95.9721, Epoch Time (s): 0.08, Total Time (hrs): 0.1504
# ====> Epoch: 5109 Train ELBO: 63.5830 Val ELBO: 103.0926, Epoch Time (s): 0.08, Total Time (hrs): 0.1505
# ====> Epoch: 5110 Train ELBO: 66.3105 Val ELBO: 104.2272, Epoch Time (s): 0.08, Total Time (hrs): 0.1505
# ====> Epoch: 5111 Train ELBO: 66.3412 Val ELBO: 104.1845, Epoch Time (s): 0.09, Total Time (hrs): 0.1505
# ====> Epoch: 5112 Train ELBO: 64.8054 Val ELBO: 97.7894, Epoch Time (s): 0.08, Total Time (hrs): 0.1505
# ====> Epoch: 5113 Train ELBO: 66.7505 Val ELBO: 105.8406, Epoch Time (s): 0.07, Total Time (hrs): 0.1506
# ====> Epoch: 5114 Train ELBO: 63.0053 Val ELBO: 100.2783, Epoch Time (s): 0.08, Total Time (hrs): 0.1506
# ====> Epoch: 5115 Train ELBO: 66.7714 Val ELBO: 97.3889, Epoch Time (s): 0.07, Total Time (hrs): 0.1506
# ====> Epoch: 5116 Train ELBO: 66.0991 Val ELBO: 100.9758, Epoch Time (s): 0.08, Total Time (hrs): 0.1506
# ====> Epoch: 5117 Train ELBO: 67.9591 Val ELBO: 100.0357, Epoch Time (s): 0.08, Total Time (hrs): 0.1506
# ====> Epoch: 5118 Train ELBO: 61.8235 Val ELBO: 90.2001, Epoch Time (s): 0.09, Total Time (hrs): 0.1507
# ====> Epoch: 5119 Train ELBO: 63.2711 Val ELBO: 95.9429, Epoch Time (s): 0.08, Total Time (hrs): 0.1507
# ====> Epoch: 5120 Train ELBO: 64.7193 Val ELBO: 105.3838, Epoch Time (s): 0.08, Total Time (hrs): 0.1507
# ====> Epoch: 5121 Train ELBO: 66.9659 Val ELBO: 105.2505, Epoch Time (s): 0.08, Total Time (hrs): 0.1507
# ====> Epoch: 5122 Train ELBO: 67.5529 Val ELBO: 103.6336, Epoch Time (s): 0.08, Total Time (hrs): 0.1508
# ====> Epoch: 5123 Train ELBO: 65.5222 Val ELBO: 100.1564, Epoch Time (s): 0.09, Total Time (hrs): 0.1508
# ====> Epoch: 5124 Train ELBO: 63.3718 Val ELBO: 99.3050, Epoch Time (s): 0.08, Total Time (hrs): 0.1508
# ====> Epoch: 5125 Train ELBO: 66.4483 Val ELBO: 105.7915, Epoch Time (s): 0.08, Total Time (hrs): 0.1508
# ====> Epoch: 5126 Train ELBO: 66.2777 Val ELBO: 102.1201, Epoch Time (s): 0.08, Total Time (hrs): 0.1508
# ====> Epoch: 5127 Train ELBO: 67.8137 Val ELBO: 106.0904, Epoch Time (s): 0.08, Total Time (hrs): 0.1509
# ====> Epoch: 5128 Train ELBO: 69.1050 Val ELBO: 104.2974, Epoch Time (s): 0.08, Total Time (hrs): 0.1509
# ====> Epoch: 5129 Train ELBO: 66.7117 Val ELBO: 104.2954, Epoch Time (s): 0.09, Total Time (hrs): 0.1509
# ====> Epoch: 5130 Train ELBO: 67.4907 Val ELBO: 105.4850, Epoch Time (s): 0.08, Total Time (hrs): 0.1509
# ====> Epoch: 5131 Train ELBO: 68.6355 Val ELBO: 98.8406, Epoch Time (s): 0.09, Total Time (hrs): 0.1510
# ====> Epoch: 5132 Train ELBO: 65.8734 Val ELBO: 107.2025, Epoch Time (s): 0.08, Total Time (hrs): 0.1510
# ====> Epoch: 5133 Train ELBO: 65.7454 Val ELBO: 90.5730, Epoch Time (s): 0.08, Total Time (hrs): 0.1510
# ====> Epoch: 5134 Train ELBO: 50.4328 Val ELBO: 103.3468, Epoch Time (s): 0.08, Total Time (hrs): 0.1510
# ====> Epoch: 5135 Train ELBO: 58.1569 Val ELBO: 91.5188, Epoch Time (s): 0.08, Total Time (hrs): 0.1510
# ====> Epoch: 5136 Train ELBO: 62.4932 Val ELBO: 104.3766, Epoch Time (s): 0.08, Total Time (hrs): 0.1511
# ====> Epoch: 5137 Train ELBO: 68.3296 Val ELBO: 105.6791, Epoch Time (s): 0.08, Total Time (hrs): 0.1511
# ====> Epoch: 5138 Train ELBO: 66.3903 Val ELBO: 99.7397, Epoch Time (s): 0.09, Total Time (hrs): 0.1511
# ====> Epoch: 5139 Train ELBO: 67.3187 Val ELBO: 102.8164, Epoch Time (s): 0.08, Total Time (hrs): 0.1511
# ====> Epoch: 5140 Train ELBO: 67.9153 Val ELBO: 101.4963, Epoch Time (s): 0.08, Total Time (hrs): 0.1512
# ====> Epoch: 5141 Train ELBO: 67.0637 Val ELBO: 106.9971, Epoch Time (s): 0.09, Total Time (hrs): 0.1512
# ====> Epoch: 5142 Train ELBO: 68.5126 Val ELBO: 106.2709, Epoch Time (s): 0.08, Total Time (hrs): 0.1512
# ====> Epoch: 5143 Train ELBO: 69.8017 Val ELBO: 104.5465, Epoch Time (s): 0.09, Total Time (hrs): 0.1512
# ====> Epoch: 5144 Train ELBO: 66.8379 Val ELBO: 103.3893, Epoch Time (s): 0.09, Total Time (hrs): 0.1513
# ====> Epoch: 5145 Train ELBO: 68.2924 Val ELBO: 101.0231, Epoch Time (s): 0.08, Total Time (hrs): 0.1513
# ====> Epoch: 5146 Train ELBO: 64.4954 Val ELBO: 99.4896, Epoch Time (s): 0.08, Total Time (hrs): 0.1513
# ====> Epoch: 5147 Train ELBO: 62.7236 Val ELBO: 102.2855, Epoch Time (s): 0.09, Total Time (hrs): 0.1513
# ====> Epoch: 5148 Train ELBO: 62.9575 Val ELBO: 99.5109, Epoch Time (s): 0.08, Total Time (hrs): 0.1513
# ====> Epoch: 5149 Train ELBO: 63.6140 Val ELBO: 102.0548, Epoch Time (s): 0.08, Total Time (hrs): 0.1514
# ====> Epoch: 5150 Train ELBO: 64.0496 Val ELBO: 100.0412, Epoch Time (s): 0.09, Total Time (hrs): 0.1514
# ====> Epoch: 5151 Train ELBO: 67.8531 Val ELBO: 103.2368, Epoch Time (s): 0.13, Total Time (hrs): 0.1514
# ====> Epoch: 5152 Train ELBO: 67.3947 Val ELBO: 99.3985, Epoch Time (s): 0.12, Total Time (hrs): 0.1515
# ====> Epoch: 5153 Train ELBO: 66.3831 Val ELBO: 105.0974, Epoch Time (s): 0.11, Total Time (hrs): 0.1515
# ====> Epoch: 5154 Train ELBO: 67.3051 Val ELBO: 102.4336, Epoch Time (s): 0.14, Total Time (hrs): 0.1515
# ====> Epoch: 5155 Train ELBO: 65.1375 Val ELBO: 102.1457, Epoch Time (s): 0.11, Total Time (hrs): 0.1516
# ====> Epoch: 5156 Train ELBO: 61.4127 Val ELBO: 104.1884, Epoch Time (s): 0.12, Total Time (hrs): 0.1516
# ====> Epoch: 5157 Train ELBO: 65.2719 Val ELBO: 102.9269, Epoch Time (s): 0.11, Total Time (hrs): 0.1516
# ====> Epoch: 5158 Train ELBO: 63.7528 Val ELBO: 95.3383, Epoch Time (s): 0.14, Total Time (hrs): 0.1517
# ====> Epoch: 5159 Train ELBO: 57.3264 Val ELBO: 97.2569, Epoch Time (s): 0.11, Total Time (hrs): 0.1517
# ====> Epoch: 5160 Train ELBO: 65.1926 Val ELBO: 104.2185, Epoch Time (s): 0.13, Total Time (hrs): 0.1517
# ====> Epoch: 5161 Train ELBO: 66.3475 Val ELBO: 102.6348, Epoch Time (s): 0.11, Total Time (hrs): 0.1518
# ====> Epoch: 5162 Train ELBO: 62.0804 Val ELBO: 94.5381, Epoch Time (s): 0.12, Total Time (hrs): 0.1518
# ====> Epoch: 5163 Train ELBO: 62.7067 Val ELBO: 92.8028, Epoch Time (s): 0.13, Total Time (hrs): 0.1518
# ====> Epoch: 5164 Train ELBO: 63.7235 Val ELBO: 94.4689, Epoch Time (s): 0.12, Total Time (hrs): 0.1519
# ====> Epoch: 5165 Train ELBO: 64.7061 Val ELBO: 98.7292, Epoch Time (s): 0.11, Total Time (hrs): 0.1519
# ====> Epoch: 5166 Train ELBO: 64.6504 Val ELBO: 100.4080, Epoch Time (s): 0.12, Total Time (hrs): 0.1519
# ====> Epoch: 5167 Train ELBO: 66.8090 Val ELBO: 99.6666, Epoch Time (s): 0.11, Total Time (hrs): 0.1520
# ====> Epoch: 5168 Train ELBO: 55.3978 Val ELBO: 91.3570, Epoch Time (s): 0.12, Total Time (hrs): 0.1520
# ====> Epoch: 5169 Train ELBO: 60.7569 Val ELBO: 99.7572, Epoch Time (s): 0.11, Total Time (hrs): 0.1520
# ====> Epoch: 5170 Train ELBO: 62.1744 Val ELBO: 92.5255, Epoch Time (s): 0.13, Total Time (hrs): 0.1521
# ====> Epoch: 5171 Train ELBO: 58.5709 Val ELBO: 97.9602, Epoch Time (s): 0.12, Total Time (hrs): 0.1521
# ====> Epoch: 5172 Train ELBO: 48.7987 Val ELBO: 98.6695, Epoch Time (s): 0.15, Total Time (hrs): 0.1521
# ====> Epoch: 5173 Train ELBO: 49.8255 Val ELBO: 80.7309, Epoch Time (s): 0.12, Total Time (hrs): 0.1522
# ====> Epoch: 5174 Train ELBO: 58.1021 Val ELBO: 86.5470, Epoch Time (s): 0.14, Total Time (hrs): 0.1522
# ====> Epoch: 5175 Train ELBO: 55.1238 Val ELBO: 91.3691, Epoch Time (s): 0.13, Total Time (hrs): 0.1523
# ====> Epoch: 5176 Train ELBO: 43.0495 Val ELBO: 85.8715, Epoch Time (s): 0.14, Total Time (hrs): 0.1523
# ====> Epoch: 5177 Train ELBO: 54.0431 Val ELBO: 99.7058, Epoch Time (s): 0.10, Total Time (hrs): 0.1523
# ====> Epoch: 5178 Train ELBO: 60.4981 Val ELBO: 103.5880, Epoch Time (s): 0.08, Total Time (hrs): 0.1523
# ====> Epoch: 5179 Train ELBO: 64.9072 Val ELBO: 99.3907, Epoch Time (s): 0.09, Total Time (hrs): 0.1524
# ====> Epoch: 5180 Train ELBO: 65.9129 Val ELBO: 91.5912, Epoch Time (s): 0.08, Total Time (hrs): 0.1524
# ====> Epoch: 5181 Train ELBO: 60.8463 Val ELBO: 95.8745, Epoch Time (s): 0.08, Total Time (hrs): 0.1524
# ====> Epoch: 5182 Train ELBO: 55.2400 Val ELBO: 95.9091, Epoch Time (s): 0.10, Total Time (hrs): 0.1524
# ====> Epoch: 5183 Train ELBO: 62.4566 Val ELBO: 102.6545, Epoch Time (s): 0.08, Total Time (hrs): 0.1525
# ====> Epoch: 5184 Train ELBO: 68.0412 Val ELBO: 104.4198, Epoch Time (s): 0.09, Total Time (hrs): 0.1525
# ====> Epoch: 5185 Train ELBO: 67.8085 Val ELBO: 103.7776, Epoch Time (s): 0.09, Total Time (hrs): 0.1525
# ====> Epoch: 5186 Train ELBO: 64.0198 Val ELBO: 102.7924, Epoch Time (s): 0.08, Total Time (hrs): 0.1525
# ====> Epoch: 5187 Train ELBO: 62.7233 Val ELBO: 105.1543, Epoch Time (s): 0.08, Total Time (hrs): 0.1526
# ====> Epoch: 5188 Train ELBO: 65.7308 Val ELBO: 98.1221, Epoch Time (s): 0.09, Total Time (hrs): 0.1526
# ====> Epoch: 5189 Train ELBO: 65.6189 Val ELBO: 103.4397, Epoch Time (s): 0.08, Total Time (hrs): 0.1526
# ====> Epoch: 5190 Train ELBO: 67.3280 Val ELBO: 103.7378, Epoch Time (s): 0.08, Total Time (hrs): 0.1526
# ====> Epoch: 5191 Train ELBO: 67.4326 Val ELBO: 102.5257, Epoch Time (s): 0.08, Total Time (hrs): 0.1526
# ====> Epoch: 5192 Train ELBO: 68.5558 Val ELBO: 106.3728, Epoch Time (s): 0.08, Total Time (hrs): 0.1527
# ====> Epoch: 5193 Train ELBO: 66.7319 Val ELBO: 97.7612, Epoch Time (s): 0.08, Total Time (hrs): 0.1527
# ====> Epoch: 5194 Train ELBO: 63.1808 Val ELBO: 102.2852, Epoch Time (s): 0.10, Total Time (hrs): 0.1527
# ====> Epoch: 5195 Train ELBO: 66.1643 Val ELBO: 101.8030, Epoch Time (s): 0.08, Total Time (hrs): 0.1527
# ====> Epoch: 5196 Train ELBO: 65.0686 Val ELBO: 97.9622, Epoch Time (s): 0.08, Total Time (hrs): 0.1528
# ====> Epoch: 5197 Train ELBO: 64.7191 Val ELBO: 100.9638, Epoch Time (s): 0.09, Total Time (hrs): 0.1528
# ====> Epoch: 5198 Train ELBO: 65.2229 Val ELBO: 106.6026, Epoch Time (s): 0.08, Total Time (hrs): 0.1528
# ====> Epoch: 5199 Train ELBO: 65.8389 Val ELBO: 102.5817, Epoch Time (s): 0.08, Total Time (hrs): 0.1528
# ====> Epoch: 5200 Train ELBO: 66.1373 Val ELBO: 102.0538, Epoch Time (s): 0.09, Total Time (hrs): 0.1529
# ====> Epoch: 5201 Train ELBO: 67.6104 Val ELBO: 100.5048, Epoch Time (s): 0.08, Total Time (hrs): 0.1529
# ====> Epoch: 5202 Train ELBO: 64.8576 Val ELBO: 101.8989, Epoch Time (s): 0.08, Total Time (hrs): 0.1529
# ====> Epoch: 5203 Train ELBO: 65.2312 Val ELBO: 97.9784, Epoch Time (s): 0.09, Total Time (hrs): 0.1529
# ====> Epoch: 5204 Train ELBO: 63.4918 Val ELBO: 104.7294, Epoch Time (s): 0.08, Total Time (hrs): 0.1529
# ====> Epoch: 5205 Train ELBO: 62.6035 Val ELBO: 98.2521, Epoch Time (s): 0.08, Total Time (hrs): 0.1530
# ====> Epoch: 5206 Train ELBO: 62.3816 Val ELBO: 100.0260, Epoch Time (s): 0.08, Total Time (hrs): 0.1530
# ====> Epoch: 5207 Train ELBO: 61.6147 Val ELBO: 100.3176, Epoch Time (s): 0.09, Total Time (hrs): 0.1530
# ====> Epoch: 5208 Train ELBO: 64.4836 Val ELBO: 96.6489, Epoch Time (s): 0.08, Total Time (hrs): 0.1530
# ====> Epoch: 5209 Train ELBO: 64.3547 Val ELBO: 103.6019, Epoch Time (s): 0.09, Total Time (hrs): 0.1531
# ====> Epoch: 5210 Train ELBO: 68.1813 Val ELBO: 101.2443, Epoch Time (s): 0.08, Total Time (hrs): 0.1531
# ====> Epoch: 5211 Train ELBO: 66.3755 Val ELBO: 101.1172, Epoch Time (s): 0.08, Total Time (hrs): 0.1531
# ====> Epoch: 5212 Train ELBO: 67.6739 Val ELBO: 100.5566, Epoch Time (s): 0.09, Total Time (hrs): 0.1531
# ====> Epoch: 5213 Train ELBO: 66.6922 Val ELBO: 105.3749, Epoch Time (s): 0.08, Total Time (hrs): 0.1531
# ====> Epoch: 5214 Train ELBO: 66.4226 Val ELBO: 95.0696, Epoch Time (s): 0.08, Total Time (hrs): 0.1532
# ====> Epoch: 5215 Train ELBO: 61.6516 Val ELBO: 89.0256, Epoch Time (s): 0.09, Total Time (hrs): 0.1532
# ====> Epoch: 5216 Train ELBO: 56.1024 Val ELBO: 90.0445, Epoch Time (s): 0.08, Total Time (hrs): 0.1532
# ====> Epoch: 5217 Train ELBO: 59.2886 Val ELBO: 99.1393, Epoch Time (s): 0.08, Total Time (hrs): 0.1532
# ====> Epoch: 5218 Train ELBO: 68.2525 Val ELBO: 102.4445, Epoch Time (s): 0.08, Total Time (hrs): 0.1533
# ====> Epoch: 5219 Train ELBO: 66.2012 Val ELBO: 92.8891, Epoch Time (s): 0.09, Total Time (hrs): 0.1533
# ====> Epoch: 5220 Train ELBO: 66.5222 Val ELBO: 107.2970, Epoch Time (s): 0.08, Total Time (hrs): 0.1533
# ====> Epoch: 5221 Train ELBO: 65.9125 Val ELBO: 94.6971, Epoch Time (s): 0.08, Total Time (hrs): 0.1533
# ====> Epoch: 5222 Train ELBO: 63.0530 Val ELBO: 102.8806, Epoch Time (s): 0.08, Total Time (hrs): 0.1534
# ====> Epoch: 5223 Train ELBO: 60.5328 Val ELBO: 95.4519, Epoch Time (s): 0.08, Total Time (hrs): 0.1534
# ====> Epoch: 5224 Train ELBO: 63.8795 Val ELBO: 105.5554, Epoch Time (s): 0.09, Total Time (hrs): 0.1534
# ====> Epoch: 5225 Train ELBO: 64.3064 Val ELBO: 100.7298, Epoch Time (s): 0.08, Total Time (hrs): 0.1534
# ====> Epoch: 5226 Train ELBO: 61.6665 Val ELBO: 103.5848, Epoch Time (s): 0.08, Total Time (hrs): 0.1534
# ====> Epoch: 5227 Train ELBO: 63.9186 Val ELBO: 100.6050, Epoch Time (s): 0.09, Total Time (hrs): 0.1535
# ====> Epoch: 5228 Train ELBO: 65.7805 Val ELBO: 101.0513, Epoch Time (s): 0.08, Total Time (hrs): 0.1535
# ====> Epoch: 5229 Train ELBO: 64.1372 Val ELBO: 95.7735, Epoch Time (s): 0.08, Total Time (hrs): 0.1535
# ====> Epoch: 5230 Train ELBO: 64.1965 Val ELBO: 104.8849, Epoch Time (s): 0.09, Total Time (hrs): 0.1535
# ====> Epoch: 5231 Train ELBO: 67.8243 Val ELBO: 102.1967, Epoch Time (s): 0.08, Total Time (hrs): 0.1536
# ====> Epoch: 5232 Train ELBO: 67.2792 Val ELBO: 104.2202, Epoch Time (s): 0.09, Total Time (hrs): 0.1536
# ====> Epoch: 5233 Train ELBO: 66.2739 Val ELBO: 103.1895, Epoch Time (s): 0.09, Total Time (hrs): 0.1536
# ====> Epoch: 5234 Train ELBO: 67.4661 Val ELBO: 107.6435, Epoch Time (s): 0.08, Total Time (hrs): 0.1536
# ====> Epoch: 5235 Train ELBO: 68.2039 Val ELBO: 100.4036, Epoch Time (s): 0.08, Total Time (hrs): 0.1537
# ====> Epoch: 5236 Train ELBO: 66.5786 Val ELBO: 104.6168, Epoch Time (s): 0.09, Total Time (hrs): 0.1537
# ====> Epoch: 5237 Train ELBO: 66.4878 Val ELBO: 104.3775, Epoch Time (s): 0.08, Total Time (hrs): 0.1537
# ====> Epoch: 5238 Train ELBO: 63.2975 Val ELBO: 93.0146, Epoch Time (s): 0.08, Total Time (hrs): 0.1537
# ====> Epoch: 5239 Train ELBO: 59.3791 Val ELBO: 93.2313, Epoch Time (s): 0.09, Total Time (hrs): 0.1537
# ====> Epoch: 5240 Train ELBO: 54.3518 Val ELBO: 100.3426, Epoch Time (s): 0.08, Total Time (hrs): 0.1538
# ====> Epoch: 5241 Train ELBO: 65.0185 Val ELBO: 99.1208, Epoch Time (s): 0.08, Total Time (hrs): 0.1538
# ====> Epoch: 5242 Train ELBO: 64.5970 Val ELBO: 99.5374, Epoch Time (s): 0.08, Total Time (hrs): 0.1538
# ====> Epoch: 5243 Train ELBO: 65.0394 Val ELBO: 101.4752, Epoch Time (s): 0.08, Total Time (hrs): 0.1538
# ====> Epoch: 5244 Train ELBO: 63.3966 Val ELBO: 99.4838, Epoch Time (s): 0.09, Total Time (hrs): 0.1539
# ====> Epoch: 5245 Train ELBO: 66.2728 Val ELBO: 101.1718, Epoch Time (s): 0.08, Total Time (hrs): 0.1539
# ====> Epoch: 5246 Train ELBO: 61.3454 Val ELBO: 103.0055, Epoch Time (s): 0.07, Total Time (hrs): 0.1539
# ====> Epoch: 5247 Train ELBO: 65.4177 Val ELBO: 101.5599, Epoch Time (s): 0.08, Total Time (hrs): 0.1539
# ====> Epoch: 5248 Train ELBO: 69.5474 Val ELBO: 103.6582, Epoch Time (s): 0.09, Total Time (hrs): 0.1539
# ====> Epoch: 5249 Train ELBO: 66.7987 Val ELBO: 100.9656, Epoch Time (s): 0.08, Total Time (hrs): 0.1540
# ====> Epoch: 5250 Train ELBO: 64.4905 Val ELBO: 94.5844, Epoch Time (s): 0.10, Total Time (hrs): 0.1540
# ====> Epoch: 5251 Train ELBO: 64.6005 Val ELBO: 103.6422, Epoch Time (s): 0.09, Total Time (hrs): 0.1540
# ====> Epoch: 5252 Train ELBO: 68.3468 Val ELBO: 93.0033, Epoch Time (s): 0.08, Total Time (hrs): 0.1540
# ====> Epoch: 5253 Train ELBO: 63.6435 Val ELBO: 101.6604, Epoch Time (s): 0.08, Total Time (hrs): 0.1541
# ====> Epoch: 5254 Train ELBO: 62.7697 Val ELBO: 95.6614, Epoch Time (s): 0.08, Total Time (hrs): 0.1541
# ====> Epoch: 5255 Train ELBO: 67.8207 Val ELBO: 99.8601, Epoch Time (s): 0.08, Total Time (hrs): 0.1541
# ====> Epoch: 5256 Train ELBO: 69.0935 Val ELBO: 105.3733, Epoch Time (s): 0.08, Total Time (hrs): 0.1541
# ====> Epoch: 5257 Train ELBO: 68.5795 Val ELBO: 101.9612, Epoch Time (s): 0.10, Total Time (hrs): 0.1542
# ====> Epoch: 5258 Train ELBO: 66.7716 Val ELBO: 104.0651, Epoch Time (s): 0.08, Total Time (hrs): 0.1542
# ====> Epoch: 5259 Train ELBO: 67.9571 Val ELBO: 103.1135, Epoch Time (s): 0.08, Total Time (hrs): 0.1542
# ====> Epoch: 5260 Train ELBO: 68.2792 Val ELBO: 96.5778, Epoch Time (s): 0.08, Total Time (hrs): 0.1542
# ====> Epoch: 5261 Train ELBO: 61.2987 Val ELBO: 102.4927, Epoch Time (s): 0.08, Total Time (hrs): 0.1543
# ====> Epoch: 5262 Train ELBO: 67.5395 Val ELBO: 103.5352, Epoch Time (s): 0.07, Total Time (hrs): 0.1543
# ====> Epoch: 5263 Train ELBO: 68.2457 Val ELBO: 99.5786, Epoch Time (s): 0.09, Total Time (hrs): 0.1543
# ====> Epoch: 5264 Train ELBO: 66.7924 Val ELBO: 103.0924, Epoch Time (s): 0.08, Total Time (hrs): 0.1543
# ====> Epoch: 5265 Train ELBO: 67.6995 Val ELBO: 103.9957, Epoch Time (s): 0.08, Total Time (hrs): 0.1543
# ====> Epoch: 5266 Train ELBO: 65.2980 Val ELBO: 97.7277, Epoch Time (s): 0.09, Total Time (hrs): 0.1544
# ====> Epoch: 5267 Train ELBO: 65.7587 Val ELBO: 101.4436, Epoch Time (s): 0.08, Total Time (hrs): 0.1544
# ====> Epoch: 5268 Train ELBO: 67.8945 Val ELBO: 105.2743, Epoch Time (s): 0.08, Total Time (hrs): 0.1544
# ====> Epoch: 5269 Train ELBO: 68.6691 Val ELBO: 104.3642, Epoch Time (s): 0.10, Total Time (hrs): 0.1544
# ====> Epoch: 5270 Train ELBO: 63.7851 Val ELBO: 99.2396, Epoch Time (s): 0.08, Total Time (hrs): 0.1545
# ====> Epoch: 5271 Train ELBO: 63.1324 Val ELBO: 100.8366, Epoch Time (s): 0.08, Total Time (hrs): 0.1545
# ====> Epoch: 5272 Train ELBO: 68.8862 Val ELBO: 107.2114, Epoch Time (s): 0.09, Total Time (hrs): 0.1545
# ====> Epoch: 5273 Train ELBO: 68.1926 Val ELBO: 100.8334, Epoch Time (s): 0.08, Total Time (hrs): 0.1545
# ====> Epoch: 5274 Train ELBO: 67.1482 Val ELBO: 106.2235, Epoch Time (s): 0.08, Total Time (hrs): 0.1546
# ====> Epoch: 5275 Train ELBO: 71.2338 Val ELBO: 100.7495, Epoch Time (s): 0.09, Total Time (hrs): 0.1546
# ====> Epoch: 5276 Train ELBO: 70.5164 Val ELBO: 106.5423, Epoch Time (s): 0.08, Total Time (hrs): 0.1546
# ====> Epoch: 5277 Train ELBO: 67.9885 Val ELBO: 108.0551, Epoch Time (s): 0.08, Total Time (hrs): 0.1546
# ====> Epoch: 5278 Train ELBO: 69.1814 Val ELBO: 103.5883, Epoch Time (s): 0.09, Total Time (hrs): 0.1547
# ====> Epoch: 5279 Train ELBO: 64.8392 Val ELBO: 103.2512, Epoch Time (s): 0.08, Total Time (hrs): 0.1547
# ====> Epoch: 5280 Train ELBO: 65.2187 Val ELBO: 104.2150, Epoch Time (s): 0.08, Total Time (hrs): 0.1547
# ====> Epoch: 5281 Train ELBO: 66.1978 Val ELBO: 94.1895, Epoch Time (s): 0.11, Total Time (hrs): 0.1547
# ====> Epoch: 5282 Train ELBO: 62.5137 Val ELBO: 103.8791, Epoch Time (s): 0.08, Total Time (hrs): 0.1548
# ====> Epoch: 5283 Train ELBO: 68.3048 Val ELBO: 102.3461, Epoch Time (s): 0.08, Total Time (hrs): 0.1548
# ====> Epoch: 5284 Train ELBO: 67.3308 Val ELBO: 97.8063, Epoch Time (s): 0.09, Total Time (hrs): 0.1548
# ====> Epoch: 5285 Train ELBO: 66.8056 Val ELBO: 97.4077, Epoch Time (s): 0.08, Total Time (hrs): 0.1548
# ====> Epoch: 5286 Train ELBO: 64.6478 Val ELBO: 99.0885, Epoch Time (s): 0.08, Total Time (hrs): 0.1548
# ====> Epoch: 5287 Train ELBO: 66.3689 Val ELBO: 102.0440, Epoch Time (s): 0.09, Total Time (hrs): 0.1549
# ====> Epoch: 5288 Train ELBO: 65.9620 Val ELBO: 106.7158, Epoch Time (s): 0.08, Total Time (hrs): 0.1549
# ====> Epoch: 5289 Train ELBO: 67.1190 Val ELBO: 105.9481, Epoch Time (s): 0.08, Total Time (hrs): 0.1549
# ====> Epoch: 5290 Train ELBO: 67.5142 Val ELBO: 104.6137, Epoch Time (s): 0.08, Total Time (hrs): 0.1549
# ====> Epoch: 5291 Train ELBO: 64.5144 Val ELBO: 99.9333, Epoch Time (s): 0.08, Total Time (hrs): 0.1550
# ====> Epoch: 5292 Train ELBO: 59.8031 Val ELBO: 96.0686, Epoch Time (s): 0.08, Total Time (hrs): 0.1550
# ====> Epoch: 5293 Train ELBO: 64.1385 Val ELBO: 101.9589, Epoch Time (s): 0.09, Total Time (hrs): 0.1550
# ====> Epoch: 5294 Train ELBO: 61.0594 Val ELBO: 100.6633, Epoch Time (s): 0.09, Total Time (hrs): 0.1550
# ====> Epoch: 5295 Train ELBO: 60.2148 Val ELBO: 101.5774, Epoch Time (s): 0.08, Total Time (hrs): 0.1550
# ====> Epoch: 5296 Train ELBO: 56.2977 Val ELBO: 94.9097, Epoch Time (s): 0.09, Total Time (hrs): 0.1551
# ====> Epoch: 5297 Train ELBO: 62.0884 Val ELBO: 94.5640, Epoch Time (s): 0.10, Total Time (hrs): 0.1551
# ====> Epoch: 5298 Train ELBO: 60.9098 Val ELBO: 103.0148, Epoch Time (s): 0.14, Total Time (hrs): 0.1551
# ====> Epoch: 5299 Train ELBO: 64.6403 Val ELBO: 99.7313, Epoch Time (s): 0.12, Total Time (hrs): 0.1552
# ====> Epoch: 5300 Train ELBO: 62.8102 Val ELBO: 100.3831, Epoch Time (s): 0.13, Total Time (hrs): 0.1552
# ====> Epoch: 5301 Train ELBO: 62.2314 Val ELBO: 99.4325, Epoch Time (s): 0.11, Total Time (hrs): 0.1552
# ====> Epoch: 5302 Train ELBO: 58.5243 Val ELBO: 95.6229, Epoch Time (s): 0.12, Total Time (hrs): 0.1553
# ====> Epoch: 5303 Train ELBO: 60.8153 Val ELBO: 103.4714, Epoch Time (s): 0.13, Total Time (hrs): 0.1553
# ====> Epoch: 5304 Train ELBO: 67.8577 Val ELBO: 103.4519, Epoch Time (s): 0.12, Total Time (hrs): 0.1553
# ====> Epoch: 5305 Train ELBO: 68.3184 Val ELBO: 106.0850, Epoch Time (s): 0.11, Total Time (hrs): 0.1554
# ====> Epoch: 5306 Train ELBO: 66.9658 Val ELBO: 101.1346, Epoch Time (s): 0.12, Total Time (hrs): 0.1554
# ====> Epoch: 5307 Train ELBO: 68.5692 Val ELBO: 100.8461, Epoch Time (s): 0.11, Total Time (hrs): 0.1554
# ====> Epoch: 5308 Train ELBO: 66.6041 Val ELBO: 102.2569, Epoch Time (s): 0.11, Total Time (hrs): 0.1555
# ====> Epoch: 5309 Train ELBO: 67.9122 Val ELBO: 99.0600, Epoch Time (s): 0.12, Total Time (hrs): 0.1555
# ====> Epoch: 5310 Train ELBO: 65.7678 Val ELBO: 104.6352, Epoch Time (s): 0.12, Total Time (hrs): 0.1555
# ====> Epoch: 5311 Train ELBO: 67.4943 Val ELBO: 104.9227, Epoch Time (s): 0.11, Total Time (hrs): 0.1556
# ====> Epoch: 5312 Train ELBO: 62.8514 Val ELBO: 90.1399, Epoch Time (s): 0.12, Total Time (hrs): 0.1556
# ====> Epoch: 5313 Train ELBO: 58.0270 Val ELBO: 96.1720, Epoch Time (s): 0.13, Total Time (hrs): 0.1556
# ====> Epoch: 5314 Train ELBO: 57.1992 Val ELBO: 92.5342, Epoch Time (s): 0.11, Total Time (hrs): 0.1557
# ====> Epoch: 5315 Train ELBO: 63.1174 Val ELBO: 104.7779, Epoch Time (s): 0.11, Total Time (hrs): 0.1557
# ====> Epoch: 5316 Train ELBO: 65.9269 Val ELBO: 101.9161, Epoch Time (s): 0.11, Total Time (hrs): 0.1557
# ====> Epoch: 5317 Train ELBO: 66.3443 Val ELBO: 103.5601, Epoch Time (s): 0.12, Total Time (hrs): 0.1558
# ====> Epoch: 5318 Train ELBO: 65.5112 Val ELBO: 94.4404, Epoch Time (s): 0.13, Total Time (hrs): 0.1558
# ====> Epoch: 5319 Train ELBO: 61.3543 Val ELBO: 90.7897, Epoch Time (s): 0.13, Total Time (hrs): 0.1558
# ====> Epoch: 5320 Train ELBO: 61.2134 Val ELBO: 101.1616, Epoch Time (s): 0.13, Total Time (hrs): 0.1559
# ====> Epoch: 5321 Train ELBO: 58.7651 Val ELBO: 90.9528, Epoch Time (s): 0.13, Total Time (hrs): 0.1559
# ====> Epoch: 5322 Train ELBO: 62.4018 Val ELBO: 104.9098, Epoch Time (s): 0.15, Total Time (hrs): 0.1559
# ====> Epoch: 5323 Train ELBO: 64.3802 Val ELBO: 80.7313, Epoch Time (s): 0.13, Total Time (hrs): 0.1560
# ====> Epoch: 5324 Train ELBO: 55.6613 Val ELBO: 88.4439, Epoch Time (s): 0.12, Total Time (hrs): 0.1560
# ====> Epoch: 5325 Train ELBO: 52.4278 Val ELBO: 97.3082, Epoch Time (s): 0.08, Total Time (hrs): 0.1560
# ====> Epoch: 5326 Train ELBO: 55.5012 Val ELBO: 91.7754, Epoch Time (s): 0.08, Total Time (hrs): 0.1561
# ====> Epoch: 5327 Train ELBO: 48.6637 Val ELBO: 67.4059, Epoch Time (s): 0.08, Total Time (hrs): 0.1561
# ====> Epoch: 5328 Train ELBO: 51.0611 Val ELBO: 79.0194, Epoch Time (s): 0.08, Total Time (hrs): 0.1561
# ====> Epoch: 5329 Train ELBO: 61.7629 Val ELBO: 102.5812, Epoch Time (s): 0.08, Total Time (hrs): 0.1561
# ====> Epoch: 5330 Train ELBO: 68.4848 Val ELBO: 101.1800, Epoch Time (s): 0.08, Total Time (hrs): 0.1561
# ====> Epoch: 5331 Train ELBO: 67.0791 Val ELBO: 103.5458, Epoch Time (s): 0.08, Total Time (hrs): 0.1562
# ====> Epoch: 5332 Train ELBO: 63.2401 Val ELBO: 99.9708, Epoch Time (s): 0.09, Total Time (hrs): 0.1562
# ====> Epoch: 5333 Train ELBO: 66.1875 Val ELBO: 102.8673, Epoch Time (s): 0.09, Total Time (hrs): 0.1562
# ====> Epoch: 5334 Train ELBO: 61.9705 Val ELBO: 103.7488, Epoch Time (s): 0.08, Total Time (hrs): 0.1562
# ====> Epoch: 5335 Train ELBO: 67.0643 Val ELBO: 101.4784, Epoch Time (s): 0.08, Total Time (hrs): 0.1563
# ====> Epoch: 5336 Train ELBO: 63.0208 Val ELBO: 101.1310, Epoch Time (s): 0.08, Total Time (hrs): 0.1563
# ====> Epoch: 5337 Train ELBO: 67.5271 Val ELBO: 104.2002, Epoch Time (s): 0.08, Total Time (hrs): 0.1563
# ====> Epoch: 5338 Train ELBO: 67.1788 Val ELBO: 102.2794, Epoch Time (s): 0.08, Total Time (hrs): 0.1563
# ====> Epoch: 5339 Train ELBO: 67.8201 Val ELBO: 107.0197, Epoch Time (s): 0.08, Total Time (hrs): 0.1563
# ====> Epoch: 5340 Train ELBO: 65.1992 Val ELBO: 106.8297, Epoch Time (s): 0.08, Total Time (hrs): 0.1564
# ====> Epoch: 5341 Train ELBO: 66.5001 Val ELBO: 101.1071, Epoch Time (s): 0.08, Total Time (hrs): 0.1564
# ====> Epoch: 5342 Train ELBO: 66.7431 Val ELBO: 104.3814, Epoch Time (s): 0.09, Total Time (hrs): 0.1564
# ====> Epoch: 5343 Train ELBO: 68.5791 Val ELBO: 106.7252, Epoch Time (s): 0.08, Total Time (hrs): 0.1564
# ====> Epoch: 5344 Train ELBO: 70.0985 Val ELBO: 106.1046, Epoch Time (s): 0.08, Total Time (hrs): 0.1565
# ====> Epoch: 5345 Train ELBO: 70.2206 Val ELBO: 106.0102, Epoch Time (s): 0.10, Total Time (hrs): 0.1565
# ====> Epoch: 5346 Train ELBO: 68.1093 Val ELBO: 97.2780, Epoch Time (s): 0.08, Total Time (hrs): 0.1565
# ====> Epoch: 5347 Train ELBO: 67.9474 Val ELBO: 103.9653, Epoch Time (s): 0.08, Total Time (hrs): 0.1565
# ====> Epoch: 5348 Train ELBO: 66.8848 Val ELBO: 104.3168, Epoch Time (s): 0.08, Total Time (hrs): 0.1566
# ====> Epoch: 5349 Train ELBO: 70.2743 Val ELBO: 106.9295, Epoch Time (s): 0.08, Total Time (hrs): 0.1566
# ====> Epoch: 5350 Train ELBO: 64.4361 Val ELBO: 65.5411, Epoch Time (s): 0.08, Total Time (hrs): 0.1566
# ====> Epoch: 5351 Train ELBO: 43.2353 Val ELBO: 60.9225, Epoch Time (s): 0.08, Total Time (hrs): 0.1566
# ====> Epoch: 5352 Train ELBO: 33.3112 Val ELBO: 87.5159, Epoch Time (s): 0.08, Total Time (hrs): 0.1566
# ====> Epoch: 5353 Train ELBO: 47.4167 Val ELBO: 84.6207, Epoch Time (s): 0.08, Total Time (hrs): 0.1567
# ====> Epoch: 5354 Train ELBO: 60.3666 Val ELBO: 100.0565, Epoch Time (s): 0.09, Total Time (hrs): 0.1567
# ====> Epoch: 5355 Train ELBO: 61.8684 Val ELBO: 94.1103, Epoch Time (s): 0.08, Total Time (hrs): 0.1567
# ====> Epoch: 5356 Train ELBO: 65.8645 Val ELBO: 103.0188, Epoch Time (s): 0.08, Total Time (hrs): 0.1567
# ====> Epoch: 5357 Train ELBO: 66.3625 Val ELBO: 100.2812, Epoch Time (s): 0.09, Total Time (hrs): 0.1568
# ====> Epoch: 5358 Train ELBO: 67.9691 Val ELBO: 102.0107, Epoch Time (s): 0.09, Total Time (hrs): 0.1568
# ====> Epoch: 5359 Train ELBO: 67.3620 Val ELBO: 101.6523, Epoch Time (s): 0.08, Total Time (hrs): 0.1568
# ====> Epoch: 5360 Train ELBO: 61.2437 Val ELBO: 95.1757, Epoch Time (s): 0.09, Total Time (hrs): 0.1568
# ====> Epoch: 5361 Train ELBO: 60.8628 Val ELBO: 95.0018, Epoch Time (s): 0.07, Total Time (hrs): 0.1568
# ====> Epoch: 5362 Train ELBO: 62.8193 Val ELBO: 83.1465, Epoch Time (s): 0.07, Total Time (hrs): 0.1569
# ====> Epoch: 5363 Train ELBO: 48.0746 Val ELBO: 71.2424, Epoch Time (s): 0.08, Total Time (hrs): 0.1569
# ====> Epoch: 5364 Train ELBO: 55.3877 Val ELBO: 103.3830, Epoch Time (s): 0.07, Total Time (hrs): 0.1569
# ====> Epoch: 5365 Train ELBO: 48.5727 Val ELBO: 98.1595, Epoch Time (s): 0.08, Total Time (hrs): 0.1569
# ====> Epoch: 5366 Train ELBO: 60.8330 Val ELBO: 96.6748, Epoch Time (s): 0.09, Total Time (hrs): 0.1570
# ====> Epoch: 5367 Train ELBO: 67.1311 Val ELBO: 100.4364, Epoch Time (s): 0.08, Total Time (hrs): 0.1570
# ====> Epoch: 5368 Train ELBO: 68.0670 Val ELBO: 105.5820, Epoch Time (s): 0.08, Total Time (hrs): 0.1570
# ====> Epoch: 5369 Train ELBO: 65.5772 Val ELBO: 98.0455, Epoch Time (s): 0.08, Total Time (hrs): 0.1570
# ====> Epoch: 5370 Train ELBO: 64.1941 Val ELBO: 105.5835, Epoch Time (s): 0.08, Total Time (hrs): 0.1570
# ====> Epoch: 5371 Train ELBO: 65.6779 Val ELBO: 103.2629, Epoch Time (s): 0.09, Total Time (hrs): 0.1571
# ====> Epoch: 5372 Train ELBO: 65.4704 Val ELBO: 96.7215, Epoch Time (s): 0.08, Total Time (hrs): 0.1571
# ====> Epoch: 5373 Train ELBO: 64.8913 Val ELBO: 100.3767, Epoch Time (s): 0.08, Total Time (hrs): 0.1571
# ====> Epoch: 5374 Train ELBO: 62.7681 Val ELBO: 100.5741, Epoch Time (s): 0.08, Total Time (hrs): 0.1571
# ====> Epoch: 5375 Train ELBO: 67.3684 Val ELBO: 104.2389, Epoch Time (s): 0.08, Total Time (hrs): 0.1572
# ====> Epoch: 5376 Train ELBO: 67.4260 Val ELBO: 103.3871, Epoch Time (s): 0.08, Total Time (hrs): 0.1572
# ====> Epoch: 5377 Train ELBO: 60.9108 Val ELBO: 97.5744, Epoch Time (s): 0.08, Total Time (hrs): 0.1572
# ====> Epoch: 5378 Train ELBO: 59.2224 Val ELBO: 96.0812, Epoch Time (s): 0.09, Total Time (hrs): 0.1572
# ====> Epoch: 5379 Train ELBO: 66.2966 Val ELBO: 104.0638, Epoch Time (s): 0.08, Total Time (hrs): 0.1573
# ====> Epoch: 5380 Train ELBO: 66.9085 Val ELBO: 103.1254, Epoch Time (s): 0.08, Total Time (hrs): 0.1573
# ====> Epoch: 5381 Train ELBO: 67.5768 Val ELBO: 106.3772, Epoch Time (s): 0.09, Total Time (hrs): 0.1573
# ====> Epoch: 5382 Train ELBO: 69.3618 Val ELBO: 107.0745, Epoch Time (s): 0.08, Total Time (hrs): 0.1573
# ...
# ====> Epoch: 9851 Train ELBO: 83.6953 Val ELBO: 87.2068, Epoch Time (s): 0.09, Total Time (hrs): 0.2918
# ====> Epoch: 9852 Train ELBO: 91.9432 Val ELBO: 120.7714, Epoch Time (s): 0.10, Total Time (hrs): 0.2918
# ====> Epoch: 9853 Train ELBO: 103.7261 Val ELBO: 114.8187, Epoch Time (s): 0.08, Total Time (hrs): 0.2918
# ====> Epoch: 9854 Train ELBO: 95.4782 Val ELBO: 120.9416, Epoch Time (s): 0.09, Total Time (hrs): 0.2919
# ====> Epoch: 9855 Train ELBO: 100.6684 Val ELBO: 124.5472, Epoch Time (s): 0.08, Total Time (hrs): 0.2919
# ====> Epoch: 9856 Train ELBO: 105.1148 Val ELBO: 125.3089, Epoch Time (s): 0.08, Total Time (hrs): 0.2919
# ====> Epoch: 9857 Train ELBO: 107.4572 Val ELBO: 128.1920, Epoch Time (s): 0.10, Total Time (hrs): 0.2919
# ====> Epoch: 9858 Train ELBO: 106.6950 Val ELBO: 128.3214, Epoch Time (s): 0.08, Total Time (hrs): 0.2920
# ====> Epoch: 9859 Train ELBO: 106.9771 Val ELBO: 117.4666, Epoch Time (s): 0.08, Total Time (hrs): 0.2920
# ====> Epoch: 9860 Train ELBO: 99.8573 Val ELBO: 110.4874, Epoch Time (s): 0.10, Total Time (hrs): 0.2920
# ====> Epoch: 9861 Train ELBO: 95.3930 Val ELBO: 112.0166, Epoch Time (s): 0.08, Total Time (hrs): 0.2920
# ====> Epoch: 9862 Train ELBO: 104.8830 Val ELBO: 125.4532, Epoch Time (s): 0.08, Total Time (hrs): 0.2920
# ====> Epoch: 9863 Train ELBO: 105.5360 Val ELBO: 126.1219, Epoch Time (s): 0.10, Total Time (hrs): 0.2921
# ====> Epoch: 9864 Train ELBO: 105.8345 Val ELBO: 126.6281, Epoch Time (s): 0.09, Total Time (hrs): 0.2921
# ====> Epoch: 9865 Train ELBO: 108.3278 Val ELBO: 126.4357, Epoch Time (s): 0.08, Total Time (hrs): 0.2921
# ====> Epoch: 9866 Train ELBO: 107.8793 Val ELBO: 128.2415, Epoch Time (s): 0.09, Total Time (hrs): 0.2921
# ====> Epoch: 9867 Train ELBO: 109.5082 Val ELBO: 127.7956, Epoch Time (s): 0.08, Total Time (hrs): 0.2922
# ====> Epoch: 9868 Train ELBO: 107.0184 Val ELBO: 128.6545, Epoch Time (s): 0.08, Total Time (hrs): 0.2922
# ====> Epoch: 9869 Train ELBO: 110.3222 Val ELBO: 128.8905, Epoch Time (s): 0.09, Total Time (hrs): 0.2922
# ====> Epoch: 9870 Train ELBO: 107.7161 Val ELBO: 125.6150, Epoch Time (s): 0.08, Total Time (hrs): 0.2922
# ====> Epoch: 9871 Train ELBO: 107.5873 Val ELBO: 127.0133, Epoch Time (s): 0.08, Total Time (hrs): 0.2923
# ====> Epoch: 9872 Train ELBO: 109.2405 Val ELBO: 127.5337, Epoch Time (s): 0.10, Total Time (hrs): 0.2923
# ====> Epoch: 9873 Train ELBO: 107.5433 Val ELBO: 116.4590, Epoch Time (s): 0.09, Total Time (hrs): 0.2923
# ====> Epoch: 9874 Train ELBO: 101.9874 Val ELBO: 123.7721, Epoch Time (s): 0.08, Total Time (hrs): 0.2923
# ====> Epoch: 9875 Train ELBO: 107.5934 Val ELBO: 122.1857, Epoch Time (s): 0.09, Total Time (hrs): 0.2924
# ====> Epoch: 9876 Train ELBO: 106.0464 Val ELBO: 126.6892, Epoch Time (s): 0.09, Total Time (hrs): 0.2924
# ====> Epoch: 9877 Train ELBO: 109.8791 Val ELBO: 129.2337, Epoch Time (s): 0.08, Total Time (hrs): 0.2924
# ====> Epoch: 9878 Train ELBO: 108.8776 Val ELBO: 128.6622, Epoch Time (s): 0.09, Total Time (hrs): 0.2924
# ====> Epoch: 9879 Train ELBO: 108.2400 Val ELBO: 124.7057, Epoch Time (s): 0.08, Total Time (hrs): 0.2925
# ====> Epoch: 9880 Train ELBO: 105.2023 Val ELBO: 125.2333, Epoch Time (s): 0.08, Total Time (hrs): 0.2925
# ====> Epoch: 9881 Train ELBO: 106.0794 Val ELBO: 124.6585, Epoch Time (s): 0.09, Total Time (hrs): 0.2925
# ====> Epoch: 9882 Train ELBO: 103.9927 Val ELBO: 124.1401, Epoch Time (s): 0.08, Total Time (hrs): 0.2925
# ====> Epoch: 9883 Train ELBO: 109.5666 Val ELBO: 129.2114, Epoch Time (s): 0.08, Total Time (hrs): 0.2925
# ====> Epoch: 9884 Train ELBO: 109.2170 Val ELBO: 123.7027, Epoch Time (s): 0.09, Total Time (hrs): 0.2926
# ====> Epoch: 9885 Train ELBO: 106.8997 Val ELBO: 127.0670, Epoch Time (s): 0.08, Total Time (hrs): 0.2926
# ====> Epoch: 9886 Train ELBO: 107.8281 Val ELBO: 122.9498, Epoch Time (s): 0.08, Total Time (hrs): 0.2926
# ====> Epoch: 9887 Train ELBO: 97.7030 Val ELBO: 122.9300, Epoch Time (s): 0.09, Total Time (hrs): 0.2926
# ====> Epoch: 9888 Train ELBO: 104.1339 Val ELBO: 129.4637, Epoch Time (s): 0.09, Total Time (hrs): 0.2927
# ====> Epoch: 9889 Train ELBO: 109.5376 Val ELBO: 124.0398, Epoch Time (s): 0.08, Total Time (hrs): 0.2927
# ====> Epoch: 9890 Train ELBO: 104.8989 Val ELBO: 118.0256, Epoch Time (s): 0.09, Total Time (hrs): 0.2927
# ====> Epoch: 9891 Train ELBO: 105.4749 Val ELBO: 127.3910, Epoch Time (s): 0.08, Total Time (hrs): 0.2927
# ====> Epoch: 9892 Train ELBO: 106.5827 Val ELBO: 119.3015, Epoch Time (s): 0.08, Total Time (hrs): 0.2928
# ====> Epoch: 9893 Train ELBO: 105.8014 Val ELBO: 126.9072, Epoch Time (s): 0.10, Total Time (hrs): 0.2928
# ====> Epoch: 9894 Train ELBO: 109.9510 Val ELBO: 124.4341, Epoch Time (s): 0.09, Total Time (hrs): 0.2928
# ====> Epoch: 9895 Train ELBO: 107.9775 Val ELBO: 120.3924, Epoch Time (s): 0.08, Total Time (hrs): 0.2928
# ====> Epoch: 9896 Train ELBO: 106.5800 Val ELBO: 123.6233, Epoch Time (s): 0.10, Total Time (hrs): 0.2929
# ====> Epoch: 9897 Train ELBO: 107.2213 Val ELBO: 129.0029, Epoch Time (s): 0.08, Total Time (hrs): 0.2929
# ====> Epoch: 9898 Train ELBO: 108.8959 Val ELBO: 127.5383, Epoch Time (s): 0.08, Total Time (hrs): 0.2929
# ====> Epoch: 9899 Train ELBO: 108.6848 Val ELBO: 126.4668, Epoch Time (s): 0.09, Total Time (hrs): 0.2929
# ====> Epoch: 9900 Train ELBO: 108.7005 Val ELBO: 129.7122, Epoch Time (s): 0.09, Total Time (hrs): 0.2930
# ====> Epoch: 9901 Train ELBO: 111.0206 Val ELBO: 128.0981, Epoch Time (s): 0.08, Total Time (hrs): 0.2930
# ====> Epoch: 9902 Train ELBO: 109.7648 Val ELBO: 128.0916, Epoch Time (s): 0.09, Total Time (hrs): 0.2930
# ====> Epoch: 9903 Train ELBO: 107.3002 Val ELBO: 125.4862, Epoch Time (s): 0.08, Total Time (hrs): 0.2930
# ====> Epoch: 9904 Train ELBO: 108.8234 Val ELBO: 125.4004, Epoch Time (s): 0.09, Total Time (hrs): 0.2931
# ====> Epoch: 9905 Train ELBO: 107.9988 Val ELBO: 122.5178, Epoch Time (s): 0.11, Total Time (hrs): 0.2931
# ====> Epoch: 9906 Train ELBO: 105.3502 Val ELBO: 122.8287, Epoch Time (s): 0.09, Total Time (hrs): 0.2931
# ====> Epoch: 9907 Train ELBO: 107.0480 Val ELBO: 125.1254, Epoch Time (s): 0.10, Total Time (hrs): 0.2931
# ====> Epoch: 9908 Train ELBO: 105.6949 Val ELBO: 107.6021, Epoch Time (s): 0.10, Total Time (hrs): 0.2932
# ====> Epoch: 9909 Train ELBO: 101.2360 Val ELBO: 121.5319, Epoch Time (s): 0.08, Total Time (hrs): 0.2932
# ====> Epoch: 9910 Train ELBO: 100.8071 Val ELBO: 122.1341, Epoch Time (s): 0.08, Total Time (hrs): 0.2932
# ====> Epoch: 9911 Train ELBO: 102.7569 Val ELBO: 109.7325, Epoch Time (s): 0.14, Total Time (hrs): 0.2932
# ====> Epoch: 9912 Train ELBO: 102.1498 Val ELBO: 128.3014, Epoch Time (s): 0.08, Total Time (hrs): 0.2933
# ====> Epoch: 9913 Train ELBO: 101.1594 Val ELBO: 112.3590, Epoch Time (s): 0.08, Total Time (hrs): 0.2933
# ====> Epoch: 9914 Train ELBO: 91.0156 Val ELBO: 89.2276, Epoch Time (s): 0.10, Total Time (hrs): 0.2933
# ====> Epoch: 9915 Train ELBO: 78.7357 Val ELBO: 123.5172, Epoch Time (s): 0.09, Total Time (hrs): 0.2933
# ====> Epoch: 9916 Train ELBO: 99.7883 Val ELBO: 119.5830, Epoch Time (s): 0.13, Total Time (hrs): 0.2934
# ====> Epoch: 9917 Train ELBO: 105.1908 Val ELBO: 119.3050, Epoch Time (s): 0.09, Total Time (hrs): 0.2934
# ====> Epoch: 9918 Train ELBO: 106.0428 Val ELBO: 125.5377, Epoch Time (s): 0.08, Total Time (hrs): 0.2934
# ====> Epoch: 9919 Train ELBO: 108.8912 Val ELBO: 130.1526, Epoch Time (s): 0.09, Total Time (hrs): 0.2935
# ====> Epoch: 9920 Train ELBO: 109.4061 Val ELBO: 124.1515, Epoch Time (s): 0.08, Total Time (hrs): 0.2935
# ====> Epoch: 9921 Train ELBO: 106.7059 Val ELBO: 128.3422, Epoch Time (s): 0.08, Total Time (hrs): 0.2935
# ====> Epoch: 9922 Train ELBO: 108.6872 Val ELBO: 127.0804, Epoch Time (s): 0.11, Total Time (hrs): 0.2935
# ====> Epoch: 9923 Train ELBO: 106.1219 Val ELBO: 126.3972, Epoch Time (s): 0.08, Total Time (hrs): 0.2936
# ====> Epoch: 9924 Train ELBO: 108.6917 Val ELBO: 128.0816, Epoch Time (s): 0.08, Total Time (hrs): 0.2936
# ====> Epoch: 9925 Train ELBO: 108.7570 Val ELBO: 124.8272, Epoch Time (s): 0.09, Total Time (hrs): 0.2936
# ====> Epoch: 9926 Train ELBO: 105.5058 Val ELBO: 122.2710, Epoch Time (s): 0.08, Total Time (hrs): 0.2936
# ====> Epoch: 9927 Train ELBO: 107.0869 Val ELBO: 121.1120, Epoch Time (s): 0.08, Total Time (hrs): 0.2936
# ====> Epoch: 9928 Train ELBO: 107.4965 Val ELBO: 123.5737, Epoch Time (s): 0.09, Total Time (hrs): 0.2937
# ====> Epoch: 9929 Train ELBO: 109.2416 Val ELBO: 124.0560, Epoch Time (s): 0.08, Total Time (hrs): 0.2937
# ====> Epoch: 9930 Train ELBO: 107.1772 Val ELBO: 124.4015, Epoch Time (s): 0.08, Total Time (hrs): 0.2937
# ====> Epoch: 9931 Train ELBO: 105.5130 Val ELBO: 124.1354, Epoch Time (s): 0.09, Total Time (hrs): 0.2937
# ====> Epoch: 9932 Train ELBO: 107.1503 Val ELBO: 125.3490, Epoch Time (s): 0.08, Total Time (hrs): 0.2938
# ====> Epoch: 9933 Train ELBO: 109.3768 Val ELBO: 129.3131, Epoch Time (s): 0.08, Total Time (hrs): 0.2938
# ====> Epoch: 9934 Train ELBO: 108.6340 Val ELBO: 127.5225, Epoch Time (s): 0.09, Total Time (hrs): 0.2938
# ====> Epoch: 9935 Train ELBO: 107.8505 Val ELBO: 126.4666, Epoch Time (s): 0.09, Total Time (hrs): 0.2938
# ====> Epoch: 9936 Train ELBO: 110.4661 Val ELBO: 127.7509, Epoch Time (s): 0.08, Total Time (hrs): 0.2939
# ====> Epoch: 9937 Train ELBO: 108.4545 Val ELBO: 128.9095, Epoch Time (s): 0.10, Total Time (hrs): 0.2939
# ====> Epoch: 9938 Train ELBO: 110.3154 Val ELBO: 128.0840, Epoch Time (s): 0.08, Total Time (hrs): 0.2939
# ====> Epoch: 9939 Train ELBO: 108.5160 Val ELBO: 128.2993, Epoch Time (s): 0.08, Total Time (hrs): 0.2939
# ====> Epoch: 9940 Train ELBO: 109.0044 Val ELBO: 126.0576, Epoch Time (s): 0.10, Total Time (hrs): 0.2940
# ====> Epoch: 9941 Train ELBO: 106.9626 Val ELBO: 125.1037, Epoch Time (s): 0.08, Total Time (hrs): 0.2940
# ====> Epoch: 9942 Train ELBO: 107.0510 Val ELBO: 126.0527, Epoch Time (s): 0.08, Total Time (hrs): 0.2940
# ====> Epoch: 9943 Train ELBO: 110.9747 Val ELBO: 125.0121, Epoch Time (s): 0.09, Total Time (hrs): 0.2940
# ====> Epoch: 9944 Train ELBO: 109.3370 Val ELBO: 126.9789, Epoch Time (s): 0.08, Total Time (hrs): 0.2940
# ====> Epoch: 9945 Train ELBO: 111.1149 Val ELBO: 128.0060, Epoch Time (s): 0.08, Total Time (hrs): 0.2941
# ====> Epoch: 9946 Train ELBO: 109.7727 Val ELBO: 123.3785, Epoch Time (s): 0.09, Total Time (hrs): 0.2941
# ====> Epoch: 9947 Train ELBO: 108.0592 Val ELBO: 128.4891, Epoch Time (s): 0.09, Total Time (hrs): 0.2941
# ====> Epoch: 9948 Train ELBO: 111.7064 Val ELBO: 127.8484, Epoch Time (s): 0.08, Total Time (hrs): 0.2941
# ====> Epoch: 9949 Train ELBO: 110.4217 Val ELBO: 122.4847, Epoch Time (s): 0.09, Total Time (hrs): 0.2942
# ====> Epoch: 9950 Train ELBO: 105.6844 Val ELBO: 121.1893, Epoch Time (s): 0.08, Total Time (hrs): 0.2942
# ====> Epoch: 9951 Train ELBO: 105.7583 Val ELBO: 125.6811, Epoch Time (s): 0.08, Total Time (hrs): 0.2942
# ====> Epoch: 9952 Train ELBO: 110.1983 Val ELBO: 121.3695, Epoch Time (s): 0.10, Total Time (hrs): 0.2942
# ====> Epoch: 9953 Train ELBO: 109.2565 Val ELBO: 126.8449, Epoch Time (s): 0.09, Total Time (hrs): 0.2943
# ====> Epoch: 9954 Train ELBO: 108.7747 Val ELBO: 124.6495, Epoch Time (s): 0.08, Total Time (hrs): 0.2943
# ====> Epoch: 9955 Train ELBO: 108.6077 Val ELBO: 123.8037, Epoch Time (s): 0.09, Total Time (hrs): 0.2943
# ====> Epoch: 9956 Train ELBO: 106.9683 Val ELBO: 119.7410, Epoch Time (s): 0.08, Total Time (hrs): 0.2943
# ====> Epoch: 9957 Train ELBO: 109.2752 Val ELBO: 127.7237, Epoch Time (s): 0.08, Total Time (hrs): 0.2944
# ====> Epoch: 9958 Train ELBO: 107.6484 Val ELBO: 125.2397, Epoch Time (s): 0.09, Total Time (hrs): 0.2944
# ====> Epoch: 9959 Train ELBO: 107.4122 Val ELBO: 127.8806, Epoch Time (s): 0.09, Total Time (hrs): 0.2944
# ====> Epoch: 9960 Train ELBO: 109.1357 Val ELBO: 126.2782, Epoch Time (s): 0.08, Total Time (hrs): 0.2944
# ====> Epoch: 9961 Train ELBO: 112.4029 Val ELBO: 127.7781, Epoch Time (s): 0.09, Total Time (hrs): 0.2945
# ====> Epoch: 9962 Train ELBO: 111.4615 Val ELBO: 128.2939, Epoch Time (s): 0.09, Total Time (hrs): 0.2945
# ====> Epoch: 9963 Train ELBO: 109.9683 Val ELBO: 127.1849, Epoch Time (s): 0.14, Total Time (hrs): 0.2945
# ====> Epoch: 9964 Train ELBO: 110.1087 Val ELBO: 125.2847, Epoch Time (s): 0.12, Total Time (hrs): 0.2946
# ====> Epoch: 9965 Train ELBO: 110.1096 Val ELBO: 119.1778, Epoch Time (s): 0.12, Total Time (hrs): 0.2946
# ====> Epoch: 9966 Train ELBO: 103.7921 Val ELBO: 122.9594, Epoch Time (s): 0.11, Total Time (hrs): 0.2946
# ====> Epoch: 9967 Train ELBO: 104.4942 Val ELBO: 122.2946, Epoch Time (s): 0.12, Total Time (hrs): 0.2946
# ====> Epoch: 9968 Train ELBO: 105.9197 Val ELBO: 120.5551, Epoch Time (s): 0.12, Total Time (hrs): 0.2947
# ====> Epoch: 9969 Train ELBO: 107.1066 Val ELBO: 129.3404, Epoch Time (s): 0.12, Total Time (hrs): 0.2947
# ====> Epoch: 9970 Train ELBO: 109.1138 Val ELBO: 126.4669, Epoch Time (s): 0.12, Total Time (hrs): 0.2947
# ====> Epoch: 9971 Train ELBO: 110.5871 Val ELBO: 123.2285, Epoch Time (s): 0.12, Total Time (hrs): 0.2948
# ====> Epoch: 9972 Train ELBO: 108.8186 Val ELBO: 122.9609, Epoch Time (s): 0.13, Total Time (hrs): 0.2948
# ====> Epoch: 9973 Train ELBO: 104.6135 Val ELBO: 125.0389, Epoch Time (s): 0.12, Total Time (hrs): 0.2949
# ====> Epoch: 9974 Train ELBO: 102.9546 Val ELBO: 128.5494, Epoch Time (s): 0.11, Total Time (hrs): 0.2949
# ====> Epoch: 9975 Train ELBO: 109.3606 Val ELBO: 126.5716, Epoch Time (s): 0.13, Total Time (hrs): 0.2949
# ====> Epoch: 9976 Train ELBO: 108.5679 Val ELBO: 116.7560, Epoch Time (s): 0.12, Total Time (hrs): 0.2950
# ====> Epoch: 9977 Train ELBO: 107.6287 Val ELBO: 120.6450, Epoch Time (s): 0.14, Total Time (hrs): 0.2950
# ====> Epoch: 9978 Train ELBO: 108.0424 Val ELBO: 122.7565, Epoch Time (s): 0.13, Total Time (hrs): 0.2950
# ====> Epoch: 9979 Train ELBO: 102.8955 Val ELBO: 121.6353, Epoch Time (s): 0.12, Total Time (hrs): 0.2951
# ====> Epoch: 9980 Train ELBO: 103.2637 Val ELBO: 121.2368, Epoch Time (s): 0.11, Total Time (hrs): 0.2951
# ====> Epoch: 9981 Train ELBO: 108.5404 Val ELBO: 123.7061, Epoch Time (s): 0.11, Total Time (hrs): 0.2951
# ====> Epoch: 9982 Train ELBO: 107.0693 Val ELBO: 126.0749, Epoch Time (s): 0.11, Total Time (hrs): 0.2952
# ====> Epoch: 9983 Train ELBO: 106.6819 Val ELBO: 122.7801, Epoch Time (s): 0.12, Total Time (hrs): 0.2952
# ====> Epoch: 9984 Train ELBO: 105.1100 Val ELBO: 124.8334, Epoch Time (s): 0.12, Total Time (hrs): 0.2952
# ====> Epoch: 9985 Train ELBO: 105.4282 Val ELBO: 121.5042, Epoch Time (s): 0.13, Total Time (hrs): 0.2953
# ====> Epoch: 9986 Train ELBO: 106.6680 Val ELBO: 124.5655, Epoch Time (s): 0.15, Total Time (hrs): 0.2953
# ====> Epoch: 9987 Train ELBO: 105.7046 Val ELBO: 129.3422, Epoch Time (s): 0.12, Total Time (hrs): 0.2953
# ====> Epoch: 9988 Train ELBO: 105.1104 Val ELBO: 125.2545, Epoch Time (s): 0.13, Total Time (hrs): 0.2954
# ====> Epoch: 9989 Train ELBO: 107.2556 Val ELBO: 129.5346, Epoch Time (s): 0.13, Total Time (hrs): 0.2954
# ====> Epoch: 9990 Train ELBO: 109.8869 Val ELBO: 128.0804, Epoch Time (s): 0.13, Total Time (hrs): 0.2954
# ====> Epoch: 9991 Train ELBO: 110.4119 Val ELBO: 128.8539, Epoch Time (s): 0.11, Total Time (hrs): 0.2955
# ====> Epoch: 9992 Train ELBO: 108.1091 Val ELBO: 128.9435, Epoch Time (s): 0.08, Total Time (hrs): 0.2955
# ====> Epoch: 9993 Train ELBO: 110.6996 Val ELBO: 126.7049, Epoch Time (s): 0.08, Total Time (hrs): 0.2955
# ====> Epoch: 9994 Train ELBO: 110.8304 Val ELBO: 124.1077, Epoch Time (s): 0.09, Total Time (hrs): 0.2955
# ====> Epoch: 9995 Train ELBO: 102.8378 Val ELBO: 124.3240, Epoch Time (s): 0.08, Total Time (hrs): 0.2956
# ====> Epoch: 9996 Train ELBO: 107.6637 Val ELBO: 126.3158, Epoch Time (s): 0.09, Total Time (hrs): 0.2956
# ====> Epoch: 9997 Train ELBO: 110.0606 Val ELBO: 129.8414, Epoch Time (s): 0.09, Total Time (hrs): 0.2956
# ====> Epoch: 9998 Train ELBO: 108.4364 Val ELBO: 121.1213, Epoch Time (s): 0.08, Total Time (hrs): 0.2956
# ====> Epoch: 9999 Train ELBO: 103.4813 Val ELBO: 116.2909, Epoch Time (s): 0.08, Total Time (hrs): 0.2957
# Training took  0:17:44.360988
# Training data size 1024
# Fraction of downward curves: 0.7900390625
# Cluster 1 probability: 0.058084636926651
