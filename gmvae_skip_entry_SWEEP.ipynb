# %% [markdown]
# # Imports

# %% [markdown]
# TO RUN:
# - Make sure to select Runtime>Change Runtime Type>T4 GPU to use cuda
# - Install pytorch_lightning
# - clone in repo to read in common files

# %%
# !pip install pytorch_lightning
# Out:
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.6.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (2.9.0+cu126)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.67.1)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2025.3.0)
# Collecting torchmetrics>0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (25.0)
# Requirement already satisfied: typing-extensions>4.5.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.15.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.13.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.10.0->pytorch_lightning) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.5.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics>0.7.0->pytorch_lightning) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.22.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (3.0.3)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.11)
# Downloading pytorch_lightning-2.6.0-py3-none-any.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 15.8 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 16.3 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch_lightning
# Successfully installed lightning-utilities-0.15.2 pytorch_lightning-2.6.0 torchmetrics-1.8.2

# %%
import os
import random
import numpy as np
import torch
from pytorch_lightning import seed_everything

SEED = 42
seed_everything(SEED, workers=True)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

import torch.optim as optim
from torch.distributions import Normal
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import pathlib
from torch.utils.data import DataLoader
from pytorch_lightning import LightningDataModule
import seaborn as sns
import json
from tqdm.notebook import tqdm_notebook
from time import time
import time
from datetime import datetime, timedelta
import pickle
import matplotlib.lines as mlines
import sys
from sklearn.decomposition import PCA
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 42

# %%
# !git clone https://github.com/gcalkins64/piguid_training.git
# Out:
# Cloning into 'piguid_training'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 42 (delta 17), reused 31 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (42/42), 2.90 MiB | 7.95 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# !cd piguid_training && git pull
# Out:
# Already up to date.

# %%
sys.path.append('/content/piguid_training')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from gmvae_common import *

# %% [markdown]
# # Check Devices

# %%
# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set default tensor type to CUDA tensors
torch.set_default_tensor_type(torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor)
print(device)
# Out:
# cuda
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1275: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)

# %% [markdown]
# # Settings

# %%
n_train = 1024
n_val = 128
n_test = 128
# For testing small batches of data
# n_train = 400
# n_val = 50
# n_test = 50
# THREE LAYERS
hd1 = 36
hd2 = 18
hd3 = 9
hidden_dims = [hd1, hd2, hd3]
hidden_dims_r = [hd3, hd2, hd1]
# TWO LAYERS
# hd1 = 32
# hd2 = 16
# hd3 = None
# hidden_dims = [hd1, hd2]
# hidden_dims_r = [hd2, hd1]
lr = 1e-3
n_epochs = 10_000 # 30_000
batch_size = 128
em_reg = 1e-6
decoder_var = 1e-5

latent_dims = [3,4,5]
n_clustersS = [3,4,5,6]
skip_combos = []

plot_interval = 500
dpi = 300

D = 1  #num_modalities
downsampleNum = 36

loadFlag = False  # True to load in old case, False to run a new case

data = 'orion_mars_return_2500_data_alt_range_scaled_downsampled'
inds = 'orion_mars_return_2500_inds_alt_range_scaled_downsampled'
tag = 'orion_mars_return'

# %% [markdown]
# # LOOP GMVAE TRAINING

# %%
for latent_dim in latent_dims:
  for n_clusters in n_clustersS:
    if [latent_dim, n_clusters] in skip_combos:
      continue
    else:
      K = n_clusters
      Z = latent_dim

      timestr = datetime.strftime(datetime.now(), "%Y%m%d_%H%M%S")

      if loadFlag:  # Load in old data
          dirname = loaddirname
      else:  # generate new data
          dirname = os.path.join("drive", "MyDrive", "piguid", "gmvae_"+tag+"_"+timestr+"_L"+str(latent_dim)+"_C"+str(n_clusters))
      os.makedirs(dirname, exist_ok=True)
      print("Filepath directory: " + dirname)

      if loadFlag:  # load old data
          postfix = loadpostfix
      else:  # Generate new suffix
          if hd3 is not None:
              postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:d}_{9:f}_{10:d}_{11:f}_{12:f}_{13:f}_'.format(
                  SEED, n_train, n_val, n_test, hd1, hd2, hd3, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
          else:
              postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:f}_{9:d}_{10:f}_{11:f}_{12:f}_'.format(
                  SEED, n_train, n_val, n_test, hd1, hd2, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
      print("Filepath postfix: " + postfix)

      data_dir = os.path.join("drive", "MyDrive", "piguid", f"{data}.json")

      with open(os.path.join("drive", "MyDrive", "piguid", f"{inds}.json"), 'r') as f:
          sample_list_load = json.load(f)
          sample_list = [int(sample) for sample in sample_list_load['sample_list']]
      print(sample_list)

      data_module = AerocaptureDataModuleCUDA(data_dir=data_dir, n_train=n_train, n_val=n_val, n_test=n_test,
                                      train_batch=batch_size, val_batch=batch_size, test_batch=batch_size,
                                      num_workers=0)

      data_module.setup("fit", sample_list = sample_list)

      train_loader = data_module.train_dataloader()
      val_loader = data_module.val_dataloader()
      test_loader = data_module.test_dataloader()
      data_dim = len(train_loader.dataset[0][0])
      true_labels = ['capture', 'escape', 'miss']
      label_colors = ['C2', 'C3', 'C4']

      num_train_batches = len(train_loader)

      ts_plot = np.linspace(0,1,downsampleNum)
      seabornSettings()
      fig, ax = plt.subplots(figsize=(4, 4))
      for j in range(n_train):
          ax.plot(ts_plot, train_loader.dataset[j][0].cpu(), color=label_colors[train_loader.dataset[j][1].cpu()], alpha=0.3)

      eline = mlines.Line2D([], [], color='C2', label='Escape')
      cline = mlines.Line2D([], [], color='C3', label='Capture')
      iline = mlines.Line2D([], [], color='C4', label='Miss')
      plt.legend(handles=[eline, cline, iline])
      # plt.hlines(0, 0, ts_plot[-1], colors='r', linestyles='dashed')
      plt.xlabel("Downrange")
      plt.ylabel("Altitude")
      plt.title("Training Data")
      plt.tight_layout()
      fig.savefig(os.path.join(dirname, 'train_data'+postfix+'.png'), dpi=dpi)

      fig, ax = plt.subplots(figsize=(4.5, 4))
      for j in range(n_val):
          ax.plot(ts_plot, val_loader.dataset[j][0].cpu(), color=label_colors[val_loader.dataset[j][1].cpu()], alpha=0.3)
      plt.title("Validation Data")
      fig.savefig(os.path.join(dirname, 'val_data'+postfix+'.png'), dpi=dpi)

      fig, ax = plt.subplots(figsize=(4.5, 4))
      for j in range(n_test):
          ax.plot(ts_plot, test_loader.dataset[j][0].cpu(), color=label_colors[test_loader.dataset[j][1].cpu()], alpha=0.3)
      plt.title("Test Data")
      fig.savefig(os.path.join(dirname, 'test_data'+postfix+'.png'), dpi=dpi)


      # initialize latent GMM model parameters
      params = {}
      pi_variables = torch.zeros(K).clone().detach().requires_grad_(True)
      params['pi_c'] = torch.ones(K) / K
      params['mu_c'] = torch.rand((K, Z)) * 2.0 - 1.0
      params['logsigmasq_c'] = torch.zeros((K, Z))

      # initialize neural networks
      encoder_list = []
      decoder_list = []
      trainable_parameters = []
      trainable_parameters.append(pi_variables)

      for _ in range(D):
          encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims)
          decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var)
          encoder_list.append(encoder)
          decoder_list.append(decoder)
          trainable_parameters += list(encoder.parameters()) + list(decoder.parameters())

      train_loss = torch.zeros(n_epochs)
      train_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
      val_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
      val_loss = torch.zeros(n_epochs)
      pi_history = torch.zeros((n_epochs, K))
      train_mse_history = torch.zeros(n_epochs)
      val_mse_history = torch.zeros(n_epochs)
      min_val_loss = torch.inf
      trainEpochs = np.arange(0,n_epochs,1)


      # Training
      seabornSettings()
      text_labels = [f'Cluster {i}' for i in range((n_clusters))]
      label_colors = [f'C{i+1}' for i in range((n_clusters))]

      optimizer = optim.Adam(trainable_parameters, lr=lr)

      ts = time.time()
      tic = time.perf_counter()

      for epoch in trainEpochs:
          ti = time.time()
          for encoder in encoder_list:
              encoder.train()
          for decoder in decoder_list:
              decoder.train()

          train_elbo = 0
          train_mse = 0
          train_elbo_term = np.zeros(4)
          params['hist_weights'] = torch.zeros((K, 1))
          params['hist_mu_c'] = torch.zeros((K, latent_dim))
          params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))

          for (batch_idx, batch) in enumerate(train_loader):
              batch_x, _ = batch
              x_list = [batch_x]  # assume D=2 and each modality has data_dim
              optimizer.zero_grad()
              pi_c = torch.exp(pi_variables) / torch.sum(torch.exp(pi_variables))
              params['pi_c'] = pi_c

              mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
              sigma = torch.exp(0.5 * logsigmasq)
              eps = Normal(0, 1).sample(mu.shape)
              z = mu + eps * sigma

              with torch.no_grad():
                  gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
              params['mu_c'] = mu_c
              params['logsigmasq_c'] = logsigmasq_c

              elbo, sse, elbo_terms = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
              train_elbo += elbo.item()
              train_elbo_term += elbo_terms
              train_mse += sse.item()
              loss = - elbo / batch_x.shape[0]
              loss.backward()
              optimizer.step()

          for encoder in encoder_list:
              encoder.eval()
          for decoder in decoder_list:
              decoder.eval()

          if epoch % plot_interval == 0 or epoch == n_epochs:
              # Plot the first two dimensions of the latents
              with torch.no_grad():
                  means = []
                  samples = []
                  labels = []
                  for batch in train_loader:
                      batch_x, batch_label = batch
                      x_list = [batch_x]
                      mean, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                      sigma = torch.exp(0.5 * logsigmasq)
                      eps = Normal(0, 1).sample(mean.shape)
                      z = mean + eps * sigma
                      means.append(mean)
                      samples.append(z)
                      labels.append(batch_label)

              means = torch.vstack(means).cpu()
              samples = torch.vstack(samples).cpu()
              labels = torch.hstack(labels).cpu()

              savepath = os.path.join(dirname, "latent_samples_epoch_" + str(epoch) + postfix)
              plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)

              savepath = os.path.join(dirname, "latent_means_epoch_" + str(epoch) + postfix)
              plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)


              # plot samples from generative model
              n_gen = n_train
              cluster_probs = params['pi_c'].cpu().detach().numpy() #
              fig, ax = plt.subplots(figsize=(4.5, 4))
              for j in range(n_gen):
                  c = np.random.choice(K, p=cluster_probs)
                  mu_c = params['mu_c'][c].clone().detach()
                  sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).clone().detach()
                  z = Normal(0, 1).sample(mu_c.shape) * sigma_c + mu_c
                  mu_x = decoder.forward(z)[0]
                  ax.plot(mu_x.cpu().detach().numpy())
              fig.savefig(os.path.join(dirname, "generate_samples_" + str(epoch) + postfix+ '.png'), dpi=dpi)
              plt.close()


          val_elbo = 0
          val_mse = 0
          val_elbo_term = np.zeros(4)
          with torch.no_grad():
              for (batch_idx, batch) in enumerate(val_loader):
                  batch_x, _ = batch
                  x_list = [batch_x]
                  mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                  sigma = torch.exp(0.5 * logsigmasq)
                  eps = Normal(0, 1).sample(mu.shape)
                  z = mu + eps * sigma
                  with torch.no_grad():
                      gamma_c, _, _ = em_step(z, mu, logsigmasq, params, em_reg)
                  elbo, sse, elbo_items = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
                  val_elbo += elbo.item()
                  val_mse += sse.item()
                  val_elbo_term += elbo_items

          train_elbo /= len(train_loader.dataset)
          train_elbo_term = torch.tensor(train_elbo_term) / len(train_loader.dataset)
          val_elbo /= len(val_loader.dataset)
          val_elbo_term = torch.tensor(val_elbo_term) / len(val_loader.dataset)
          train_mse /= len(train_loader.dataset)
          val_mse /= len(val_loader.dataset)

          tf = time.time()
          toc = time.perf_counter()
          print('====> Epoch: {} Train ELBO: {:.4f} Val ELBO: {:.4f}, Epoch Time (s): {:.2f}, Total Time (hrs): {:.4f}'.format(epoch, train_elbo, val_elbo, tf-ti, (toc-tic)/60/60))

          train_loss[epoch] = - train_elbo
          val_loss[epoch] = - val_elbo
          train_elbo_terms[epoch,:] = - train_elbo_term
          val_elbo_terms[epoch,:] = - val_elbo_term
          pi_history[epoch] = params['pi_c']
          train_mse_history[epoch] = train_mse
          val_mse_history[epoch] = val_mse

          if - val_elbo < min_val_loss:
              min_val_loss = - val_elbo
              torch.save(params['pi_c'], os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
              torch.save(params['mu_c'], os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
              torch.save(params['logsigmasq_c'], os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
              torch.save(encoder.state_dict(), os.path.join(dirname, 'encoder'+ postfix + '.pt'))
              torch.save(decoder.state_dict(), os.path.join(dirname, 'decoder'+ postfix + '.pt'))

          if epoch % plot_interval == 0 or epoch == n_epochs:
            # Plot the training and validation loss vs. epoch number
            plt.figure(figsize=(4.5, 4))
            # const = min(min(train_loss), min(val_loss))
            train_loss_adjusted = train_loss
            val_loss_adjusted = val_loss
            plt.plot(train_loss_adjusted.cpu()[:epoch], label='train')
            # print(train_loss_adjusted.cpu()[:epoch])
            plt.plot(val_loss_adjusted.cpu()[:epoch], label='val')
            plt.yscale('symlog')
            plt.xlabel("number of epochs")
            plt.ylabel("loss")
            plt.title("Negative Loss")
            plt.legend()
            plt.tight_layout()
            plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
            plt.close()

            # Plot each term of the training loss and validation loss
            plt.figure(figsize=(4.5, 4))
            labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
            for ii in range(4):
                train_loss_adjusted = train_elbo_terms[:epoch, ii]
                val_loss_adjusted = val_elbo_terms[:epoch, ii]
                plt.plot(train_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Train")
                plt.plot(val_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Val", linestyle='--')
            plt.xlabel("number of epochs")
            plt.yscale('symlog')
            plt.ylabel("loss")
            plt.title("Negative Loss Terms")
            plt.legend()
            plt.tight_layout()
            plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
            plt.close()

            # Plot the training and validation mse vs. epoch number
            plt.figure(figsize=(4.5, 4))
            plt.semilogy(train_mse_history.cpu().detach().numpy()[:epoch], label='train')
            plt.semilogy(val_mse_history.cpu().detach().numpy()[:epoch], label='val')
            plt.xlabel("number of epochs")
            plt.legend()
            plt.tight_layout()
            plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
            plt.close()

            # Plot the history of pi
            plt.figure(figsize=(4.5, 4))
            for i in range(K):
                plt.plot(pi_history[:, i].cpu().detach().numpy()[:epoch], label=r'$\pi$' + str(i+1))
            plt.xlabel("number of epochs")
            plt.legend()
            plt.tight_layout()
            plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
            plt.close()


      te = time.time()
      duration = timedelta(seconds=te - ts)
      print("Training took ", duration)

      # Save off pi_history, train_loss, val_loss, train_mse_history, val_mse_history
      torch.save(pi_history, os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
      torch.save(train_loss, os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
      torch.save(val_loss, os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
      torch.save(train_elbo_terms, os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
      torch.save(val_elbo_terms, os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
      torch.save(train_mse_history, os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
      torch.save(val_mse_history, os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))

      params = {}
      encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims).to("cuda")
      decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var).to("cuda")


      encoder_list = [encoder]
      decoder_list = [decoder]

      device = next(encoder.parameters()).device
      # Load in training history metrics
      pi_history = torch.load(os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
      train_loss = torch.load(os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
      val_loss = torch.load(os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
      train_elbo_terms = torch.load(os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
      val_elbo_terms = torch.load(os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
      train_mse_history = torch.load(os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
      val_mse_history = torch.load(os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))


      text_labels = [f'Cluster {i}' for i in range((n_clusters))]
      label_colors = [f'C{i+1}' for i in range((n_clusters))]
      data_colors = label_colors

      # Plot training history
      # Plot the training and validation loss vs. epoch number
      plt.figure(figsize=(4, 4))
      const = min(min(train_loss), min(val_loss))
      # const = min(10, const)
      train_loss_adjusted = train_loss
      val_loss_adjusted = val_loss
      plt.plot(train_loss_adjusted.cpu(), label='Training')
      plt.plot(val_loss_adjusted.cpu(), label='Validation')
      plt.xlabel("Number of Epochs")
      plt.ylabel("Negative Loss")
      # plt.title("Negative Loss")
      plt.yscale('symlog')
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      # plt.close()


      # Plot each term of the training loss and validation loss
      plt.figure(figsize=(4.5, 4))
      labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
      for ii in range(4):
          # print(train_elbo_terms.cpu()[ii, :epoch])
          # print(len(train_elbo_terms.cpu()[ii, :epoch]))
          train_loss_adjusted = train_elbo_terms[:, ii]
          val_loss_adjusted = val_elbo_terms[:, ii]
      plt.plot(train_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Train")
      plt.plot(val_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Val", linestyle='--')
      plt.xlabel("number of epochs")
      plt.ylabel("loss")
      plt.title("Negative Loss Terms")
      plt.yscale('symlog')
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      # plt.close()


      # Plot the sum of each term of the training loss and validation loss
      plt.figure(figsize=(4.5, 4))
      # print(train_elbo_terms.cpu()[ii, :epoch])
      # print(len(train_elbo_terms.cpu()[ii, :epoch]))
      train_loss_adjusted = train_elbo_terms.sum(axis=1)
      val_loss_adjusted = val_elbo_terms.sum(axis=1)
      plt.plot(train_loss_adjusted.cpu()[:], label=f"Train")
      plt.plot(val_loss_adjusted.cpu()[:], label=f"Val", linestyle='--')
      plt.xlabel("number of epochs")
      plt.ylabel("loss")
      plt.title("Sum of ELBO Terms")
      plt.yscale('symlog')
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'elbo_terms_sum_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      # plt.close()

      # Plot the training and validation mse vs. epoch number
      plt.figure(figsize=(4.5, 4))
      plt.semilogy(train_mse_history.cpu().detach().numpy(), label='train')
      plt.semilogy(val_mse_history.cpu().detach().numpy(), label='val')
      plt.xlabel("number of epochs")
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      # plt.close()

      # Plot the history of pi
      plt.figure(figsize=(4, 4))
      for i in range(K):
          plt.plot(pi_history[:, i].cpu().detach().numpy(), label=text_labels[i]+r' $\pi$', color=label_colors[i])
      plt.xlabel("Number of Epochs")
      plt.ylabel("Predicted Cluster Probability")
      plt.axhline(y=0.05, color='C1', linestyle='--', label='True Escape Probability')
      plt.axhline(y=0.95, color='C3', linestyle='--', label='True Capture Probability')
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      # plt.close()

      # Load best model saved
      params['pi_c'] = torch.load(os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
      params['mu_c'] = torch.load(os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
      params['logsigmasq_c'] = torch.load(os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
      encoder.load_state_dict(torch.load(os.path.join(dirname, 'encoder'+ postfix + '.pt')))
      decoder.load_state_dict(torch.load(os.path.join(dirname, 'decoder'+ postfix + '.pt')))

      encoder.eval()
      decoder.eval()

      # run one last EM step and plot training data in latent space
      for encoder in encoder_list:
          encoder.eval()

      with torch.no_grad():
          means = []
          samples = []
          labels = []
          params['hist_weights'] = torch.zeros((K, 1))
          params['hist_mu_c'] = torch.zeros((K, latent_dim))
          params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))
          for batch in train_loader:
              batch_x, batch_label = batch
              x_list = [batch_x]
              mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
              sigma = torch.exp(0.5 * logsigmasq)
              eps = Normal(0, 1).sample(mu.shape)
              z = mu + eps * sigma
              with torch.no_grad():
                  gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
              params['mu_c'] = mu_c
              params['logsigmasq_c'] = logsigmasq_c

              means.append(mu)
              samples.append(z)
              labels.append(batch_label)

      means = torch.vstack(means).cpu()
      samples = torch.vstack(samples).cpu()
      labels = torch.hstack(labels).cpu()


      savepath = os.path.join(dirname, "BEST_latent_samples"+postfix)
      plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

      savepath = os.path.join(dirname, "BEST_latent_means"+postfix)
      plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

      # plot test data in latent space
      with torch.no_grad():
          test_means = []
          test_labels = []
          for batch in test_loader:
              batch_x, batch_label = batch
              x_list = [batch_x]
              mean, _ = encoder_step(x_list, encoder_list, decoder_list)
              test_means.append(mean)
              test_labels.append(batch_label)

      test_means = torch.vstack(test_means).cpu()
      test_labels = torch.hstack(test_labels).cpu()


      savepath = os.path.join(dirname, "BEST_test_latent_samples"+postfix)
      plot_latent_space_with_clusters(test_means, test_labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

      # plot decoding results from cluster means # todo: expand this function for multi-modal data
      fig, ax = plt.subplots(figsize=(4.5, 4))
      for i in range(K):
          # with torch.no_grad:
          x_mean = decoder.forward(params['mu_c'][i])[0]
          ax.plot(x_mean.cpu().detach().numpy(), label="decoded $\mu$"+str(i+1))
      ax.legend()
      plt.title("Decoded Means")
      fig.savefig(os.path.join(dirname, "BEST_decoded_means"+postfix+'.png'), dpi=dpi)
      # plt.close()

      # plot samples from generative model
      n_gen = n_train
      cluster_probs = params['pi_c'].cpu().detach().numpy()
      fig, ax = plt.subplots(figsize=(4.5, 4))
      for j in range(n_gen):
          c = np.random.choice(K, p=cluster_probs)
          # print(c)
          mu_c = params['mu_c'][c].cpu().clone().detach()
          sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).cpu().clone().detach()
          z = Normal(0, 1).sample(mu_c.shape).cpu().clone().detach() * sigma_c + mu_c
          # print(z)
          mu_x = decoder.forward(z.cuda())[0].cpu().clone().detach()
          sigma_x = torch.exp(0.5 * decoder.forward(z.cuda())[1])
          sample_x = Normal(0, 1).sample(mu_x.shape).cpu().clone().detach() * sigma_x.cpu().clone().detach() + mu_x
          ax.plot(sample_x.cpu().detach().numpy())
      plt.title("Generated Samples")
      fig.savefig(os.path.join(dirname, "BEST_generate_samples"+postfix+'.png'), dpi=dpi)
      # plt.close()

      np.savez(dirname + postfix, train_loss=train_loss.cpu().detach().numpy(), val_loss=val_loss.cpu().detach().numpy(),
          train_mse=train_mse_history.cpu().detach().numpy(), val_mse=val_mse_history.cpu().detach().numpy(),
          pi_history=pi_history.cpu().detach().numpy(),
          cluster_probs=params['pi_c'].cpu().detach().numpy(),
          cluster_means=params['mu_c'].cpu().detach().numpy(),
          cluster_vars=torch.exp(params['logsigmasq_c']).cpu().detach().numpy())


      print("Training data size", n_train)
      print("Fraction of downward curves:", (torch.sum(labels == 0) / n_train).item())
      print("Cluster 1 probability:", cluster_probs.min().item())
# Out:
# Filepath directory: drive/MyDrive/piguid/gmvae_orion_mars_return_20260111_170747_L3_C3
# Filepath postfix: _42_1024_128_128_36_18_9_3_3_0.001000_128_0.001000_0.000010_10000.000000_
# [1318, 2431, 629, 202, 2259, 1781, 468, 1986, 623, 2118, 2120, 2405, 397, 1770, 1714, 175, 2051, 860, 2106, 895, 854, 2368, 1837, 191, 1804, 951, 2222, 568, 184, 159, 1822, 447, 2337, 1360, 2137, 1800, 1113, 1298, 334, 2215, 986, 1435, 530, 1985, 326, 44, 534, 1989, 767, 2029, 279, 1229, 1427, 109, 734, 2145, 97, 1354, 2310, 1494, 817, 204, 866, 1487, 1291, 648, 944, 2020, 1554, 1139, 1098, 2303, 1984, 1860, 1353, 1170, 777, 2124, 1477, 392, 603, 2231, 810, 2014, 1978, 654, 166, 911, 289, 396, 1728, 1366, 2229, 1527, 1811, 2317, 2475, 1944, 103, 251, 853, 1571, 2411, 1195, 336, 500, 151, 1448, 1202, 39, 394, 1864, 121, 533, 2336, 2028, 1639, 18, 1046, 207, 2499, 1420, 1249, 1121, 1357, 1665, 1885, 269, 1164, 261, 2379, 490, 287, 2050, 1389, 1936, 528, 1694, 1957, 1269, 1760, 1850, 1211, 1475, 1730, 1150, 671, 1874, 1755, 929, 1014, 600, 1542, 1345, 746, 1620, 1495, 730, 1383, 248, 1780, 1387, 1938, 2160, 1982, 260, 2205, 2355, 673, 382, 2010, 1289, 867, 502, 1721, 1840, 1990, 2366, 2059, 464, 1675, 2453, 1897, 914, 322, 2176, 742, 494, 1931, 351, 1839, 1296, 683, 2228, 981, 9, 738, 540, 1685, 633, 2465, 754, 1141, 2463, 615, 380, 472, 1089, 2069, 1991, 65, 122, 1627, 1865, 1866, 1827, 1236, 613, 2003, 2441, 1470, 1607, 697, 1683, 1791, 1310, 1677, 1263, 950, 1939, 124, 2200, 230, 1329, 1433, 2346, 498, 350, 2225, 2078, 254, 137, 1367, 679, 180, 2006, 56, 399, 22, 900, 2497, 2490, 2286, 1725, 2143, 1709, 321, 575, 1023, 1517, 7, 1337, 1881, 1086, 1794, 786, 4, 2340, 2401, 247, 1224, 539, 1523, 717, 2198, 2419, 1574, 1951, 1188, 1441, 1557, 1895, 2406, 1323, 1266, 1142, 926, 576, 765, 1179, 55, 163, 2194, 364, 1782, 1238, 225, 1473, 1451, 640, 1393, 455, 463, 2378, 2391, 1209, 983, 2022, 1703, 1646, 1115, 2159, 2245, 749, 2292, 1649, 784, 2390, 939, 2421, 2443, 1592, 1316, 778, 899, 1455, 1916, 1371, 2454, 1870, 2377, 992, 1347, 1180, 770, 1610, 825, 2212, 59, 1586, 2258, 2474, 424, 1926, 2307, 505, 998, 1022, 1941, 1243, 2271, 1267, 385, 1924, 1563, 67, 649, 118, 2185, 1483, 1072, 2206, 462, 224, 1659, 1786, 1934, 1489, 1381, 1674, 2254, 2480, 1877, 1967, 1020, 1005, 779, 2387, 1060, 132, 655, 1069, 2156, 154, 86, 593, 960, 1273, 1184, 739, 470, 2116, 1538, 2262, 624, 234, 856, 676, 840, 1058, 1421, 2221, 706, 2320, 2306, 790, 1896, 1768, 837, 1821, 689, 452, 2048, 1160, 2086, 2164, 138, 606, 243, 323, 431, 1315, 646, 1949, 2325, 2260, 1698, 410, 904, 1342, 173, 1217, 1632, 119, 91, 2459, 1240, 1614, 1788, 1654, 2151, 2026, 741, 391, 2279, 2060, 62, 1465, 1817, 1206, 1580, 1609, 2153, 1712, 2084, 21, 1532, 1746, 1241, 1643, 112, 1161, 366, 2372, 2252, 563, 1838, 2064, 1964, 328, 1218, 1552, 1486, 1777, 1998, 1106, 2359, 1690, 1438, 1460, 1830, 1409, 1623, 1679, 849, 959, 943, 1884, 2129, 2442, 144, 1880, 418, 2385, 123, 2236, 1686, 2430, 1739, 988, 420, 1596, 771, 1908, 758, 2318, 2109, 548, 924, 1948, 2210, 53, 1275, 521, 493, 409, 1493, 1593, 1929, 1333, 1631, 1002, 1892, 2416, 1648, 1918, 29, 955, 1328, 769, 2322, 1341, 2170, 1215, 2298, 885, 700, 1088, 1006, 763, 580, 1019, 1423, 1729, 2158, 1710, 1030, 516, 677, 1159, 1292, 1570, 2333, 483, 1577, 228, 552, 1028, 1503, 1744, 2438, 1533, 1408, 722, 1650, 1297, 1656, 188, 1566, 1727, 346, 841, 1432, 620, 388, 48, 1611, 1251, 2472, 1719, 2295, 1524, 2451, 1603, 1187, 1288, 1672, 1178, 1994, 1434, 76, 139, 2226, 179, 2081, 1132, 1724, 1506, 227, 2345, 1711, 1752, 414, 2133, 972, 1153, 2038, 1260, 604, 1488, 2488, 256, 2253, 816, 1828, 2470, 785, 1081, 936, 644, 74, 1899, 1111, 370, 1171, 58, 1769, 993, 745, 756, 1068, 176, 2332, 1062, 1390, 449, 1321, 889, 19, 1759, 253, 2104, 2066, 596, 1348, 1736, 1450, 1923, 2189, 1128, 1903, 1995, 581, 1051, 674, 513, 1140, 85, 2249, 332, 2017, 874, 495, 319, 828, 719, 2404, 1074, 31, 2027, 1689, 252, 1617, 2192, 1625, 617, 1301, 1331, 211, 1511, 491, 2209, 2478, 421, 908, 1589, 647, 1754, 619, 918, 307, 973, 2191, 804, 1203, 2021, 222, 1499, 643, 1, 308, 467, 610, 2099, 1462, 750, 2113, 2199, 1101, 20, 1904, 2433, 2331, 2203, 2450, 538, 21 ...
# Loading File...
# ...File Loaded
# Sample List: [1318, 2431, 629, 202, 2259, 1781, 468, 1986, 623, 2118, 2120, 2405, 397, 1770, 1714, 175, 2051, 860, 2106, 895, 854, 2368, 1837, 191, 1804, 951, 2222, 568, 184, 159, 1822, 447, 2337, 1360, 2137, 1800, 1113, 1298, 334, 2215, 986, 1435, 530, 1985, 326, 44, 534, 1989, 767, 2029, 279, 1229, 1427, 109, 734, 2145, 97, 1354, 2310, 1494, 817, 204, 866, 1487, 1291, 648, 944, 2020, 1554, 1139, 1098, 2303, 1984, 1860, 1353, 1170, 777, 2124, 1477, 392, 603, 2231, 810, 2014, 1978, 654, 166, 911, 289, 396, 1728, 1366, 2229, 1527, 1811, 2317, 2475, 1944, 103, 251, 853, 1571, 2411, 1195, 336, 500, 151, 1448, 1202, 39, 394, 1864, 121, 533, 2336, 2028, 1639, 18, 1046, 207, 2499, 1420, 1249, 1121, 1357, 1665, 1885, 269, 1164, 261, 2379, 490, 287, 2050, 1389, 1936, 528, 1694, 1957, 1269, 1760, 1850, 1211, 1475, 1730, 1150, 671, 1874, 1755, 929, 1014, 600, 1542, 1345, 746, 1620, 1495, 730, 1383, 248, 1780, 1387, 1938, 2160, 1982, 260, 2205, 2355, 673, 382, 2010, 1289, 867, 502, 1721, 1840, 1990, 2366, 2059, 464, 1675, 2453, 1897, 914, 322, 2176, 742, 494, 1931, 351, 1839, 1296, 683, 2228, 981, 9, 738, 540, 1685, 633, 2465, 754, 1141, 2463, 615, 380, 472, 1089, 2069, 1991, 65, 122, 1627, 1865, 1866, 1827, 1236, 613, 2003, 2441, 1470, 1607, 697, 1683, 1791, 1310, 1677, 1263, 950, 1939, 124, 2200, 230, 1329, 1433, 2346, 498, 350, 2225, 2078, 254, 137, 1367, 679, 180, 2006, 56, 399, 22, 900, 2497, 2490, 2286, 1725, 2143, 1709, 321, 575, 1023, 1517, 7, 1337, 1881, 1086, 1794, 786, 4, 2340, 2401, 247, 1224, 539, 1523, 717, 2198, 2419, 1574, 1951, 1188, 1441, 1557, 1895, 2406, 1323, 1266, 1142, 926, 576, 765, 1179, 55, 163, 2194, 364, 1782, 1238, 225, 1473, 1451, 640, 1393, 455, 463, 2378, 2391, 1209, 983, 2022, 1703, 1646, 1115, 2159, 2245, 749, 2292, 1649, 784, 2390, 939, 2421, 2443, 1592, 1316, 778, 899, 1455, 1916, 1371, 2454, 1870, 2377, 992, 1347, 1180, 770, 1610, 825, 2212, 59, 1586, 2258, 2474, 424, 1926, 2307, 505, 998, 1022, 1941, 1243, 2271, 1267, 385, 1924, 1563, 67, 649, 118, 2185, 1483, 1072, 2206, 462, 224, 1659, 1786, 1934, 1489, 1381, 1674, 2254, 2480, 1877, 1967, 1020, 1005, 779, 2387, 1060, 132, 655, 1069, 2156, 154, 86, 593, 960, 1273, 1184, 739, 470, 2116, 1538, 2262, 624, 234, 856, 676, 840, 1058, 1421, 2221, 706, 2320, 2306, 790, 1896, 1768, 837, 1821, 689, 452, 2048, 1160, 2086, 2164, 138, 606, 243, 323, 431, 1315, 646, 1949, 2325, 2260, 1698, 410, 904, 1342, 173, 1217, 1632, 119, 91, 2459, 1240, 1614, 1788, 1654, 2151, 2026, 741, 391, 2279, 2060, 62, 1465, 1817, 1206, 1580, 1609, 2153, 1712, 2084, 21, 1532, 1746, 1241, 1643, 112, 1161, 366, 2372, 2252, 563, 1838, 2064, 1964, 328, 1218, 1552, 1486, 1777, 1998, 1106, 2359, 1690, 1438, 1460, 1830, 1409, 1623, 1679, 849, 959, 943, 1884, 2129, 2442, 144, 1880, 418, 2385, 123, 2236, 1686, 2430, 1739, 988, 420, 1596, 771, 1908, 758, 2318, 2109, 548, 924, 1948, 2210, 53, 1275, 521, 493, 409, 1493, 1593, 1929, 1333, 1631, 1002, 1892, 2416, 1648, 1918, 29, 955, 1328, 769, 2322, 1341, 2170, 1215, 2298, 885, 700, 1088, 1006, 763, 580, 1019, 1423, 1729, 2158, 1710, 1030, 516, 677, 1159, 1292, 1570, 2333, 483, 1577, 228, 552, 1028, 1503, 1744, 2438, 1533, 1408, 722, 1650, 1297, 1656, 188, 1566, 1727, 346, 841, 1432, 620, 388, 48, 1611, 1251, 2472, 1719, 2295, 1524, 2451, 1603, 1187, 1288, 1672, 1178, 1994, 1434, 76, 139, 2226, 179, 2081, 1132, 1724, 1506, 227, 2345, 1711, 1752, 414, 2133, 972, 1153, 2038, 1260, 604, 1488, 2488, 256, 2253, 816, 1828, 2470, 785, 1081, 936, 644, 74, 1899, 1111, 370, 1171, 58, 1769, 993, 745, 756, 1068, 176, 2332, 1062, 1390, 449, 1321, 889, 19, 1759, 253, 2104, 2066, 596, 1348, 1736, 1450, 1923, 2189, 1128, 1903, 1995, 581, 1051, 674, 513, 1140, 85, 2249, 332, 2017, 874, 495, 319, 828, 719, 2404, 1074, 31, 2027, 1689, 252, 1617, 2192, 1625, 617, 1301, 1331, 211, 1511, 491, 2209, 2478, 421, 908, 1589, 647, 1754, 619, 918, 307, 973, 2191, 804, 1203, 2021, 222, 1499, 643, 1, 308, 467, 610, 2099, 1462, 750, 2113, 2199, 1101, 20, 1904, 2433, 2331, 2203,  ...
# <>:496: SyntaxWarning: invalid escape sequence '\m'
# <>:496: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipython-input-568840050.py:496: SyntaxWarning: invalid escape sequence '\m'
#   ax.plot(x_mean.cpu().detach().numpy(), label="decoded $\mu$"+str(i+1))
#   0%|          | 0/1280 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# ====> Epoch: 5000 Train ELBO: 140.1674 Val ELBO: 144.1624, Epoch Time (s): 4.13, Total Time (hrs): 0.1583
# ====> Epoch: 5001 Train ELBO: 138.2486 Val ELBO: 143.2094, Epoch Time (s): 0.14, Total Time (hrs): 0.1589
# ====> Epoch: 5002 Train ELBO: 136.9423 Val ELBO: 140.5198, Epoch Time (s): 0.13, Total Time (hrs): 0.1589
# ====> Epoch: 5003 Train ELBO: 139.0047 Val ELBO: 139.7769, Epoch Time (s): 0.14, Total Time (hrs): 0.1589
# ====> Epoch: 5004 Train ELBO: 133.0303 Val ELBO: 134.2046, Epoch Time (s): 0.12, Total Time (hrs): 0.1590
# ====> Epoch: 5005 Train ELBO: 131.9534 Val ELBO: 139.1420, Epoch Time (s): 0.14, Total Time (hrs): 0.1590
# ====> Epoch: 5006 Train ELBO: 135.0828 Val ELBO: 126.8723, Epoch Time (s): 0.12, Total Time (hrs): 0.1590
# ====> Epoch: 5007 Train ELBO: 135.7650 Val ELBO: 136.9650, Epoch Time (s): 0.13, Total Time (hrs): 0.1591
# ====> Epoch: 5008 Train ELBO: 132.8434 Val ELBO: 133.9025, Epoch Time (s): 0.12, Total Time (hrs): 0.1591
# ====> Epoch: 5009 Train ELBO: 131.2449 Val ELBO: 139.3660, Epoch Time (s): 0.12, Total Time (hrs): 0.1591
# ====> Epoch: 5010 Train ELBO: 137.7840 Val ELBO: 142.7935, Epoch Time (s): 0.12, Total Time (hrs): 0.1592
# ====> Epoch: 5011 Train ELBO: 139.6435 Val ELBO: 144.8494, Epoch Time (s): 0.13, Total Time (hrs): 0.1592
# ====> Epoch: 5012 Train ELBO: 141.3471 Val ELBO: 142.3934, Epoch Time (s): 0.13, Total Time (hrs): 0.1592
# ====> Epoch: 5013 Train ELBO: 139.1935 Val ELBO: 145.4351, Epoch Time (s): 0.13, Total Time (hrs): 0.1593
# ====> Epoch: 5014 Train ELBO: 140.7118 Val ELBO: 133.8432, Epoch Time (s): 0.12, Total Time (hrs): 0.1593
# ====> Epoch: 5015 Train ELBO: 136.3951 Val ELBO: 144.0249, Epoch Time (s): 0.14, Total Time (hrs): 0.1594
# ====> Epoch: 5016 Train ELBO: 140.1338 Val ELBO: 142.5869, Epoch Time (s): 0.12, Total Time (hrs): 0.1594
# ====> Epoch: 5017 Train ELBO: 140.3235 Val ELBO: 143.0122, Epoch Time (s): 0.15, Total Time (hrs): 0.1594
# ====> Epoch: 5018 Train ELBO: 141.0380 Val ELBO: 145.6259, Epoch Time (s): 0.11, Total Time (hrs): 0.1595
# ====> Epoch: 5019 Train ELBO: 139.1170 Val ELBO: 137.6782, Epoch Time (s): 0.14, Total Time (hrs): 0.1595
# ====> Epoch: 5020 Train ELBO: 139.7829 Val ELBO: 143.6724, Epoch Time (s): 0.14, Total Time (hrs): 0.1595
# ====> Epoch: 5021 Train ELBO: 139.3699 Val ELBO: 143.9316, Epoch Time (s): 0.15, Total Time (hrs): 0.1596
# ====> Epoch: 5022 Train ELBO: 140.9805 Val ELBO: 139.9116, Epoch Time (s): 0.15, Total Time (hrs): 0.1596
# ====> Epoch: 5023 Train ELBO: 137.6947 Val ELBO: 136.5851, Epoch Time (s): 0.13, Total Time (hrs): 0.1597
# ====> Epoch: 5024 Train ELBO: 137.1746 Val ELBO: 143.8963, Epoch Time (s): 0.13, Total Time (hrs): 0.1597
# ====> Epoch: 5025 Train ELBO: 140.1298 Val ELBO: 144.7380, Epoch Time (s): 0.15, Total Time (hrs): 0.1597
# ====> Epoch: 5026 Train ELBO: 140.7317 Val ELBO: 142.7823, Epoch Time (s): 0.15, Total Time (hrs): 0.1598
# ====> Epoch: 5027 Train ELBO: 138.9899 Val ELBO: 140.0341, Epoch Time (s): 0.11, Total Time (hrs): 0.1598
# ====> Epoch: 5028 Train ELBO: 136.9365 Val ELBO: 137.1450, Epoch Time (s): 0.08, Total Time (hrs): 0.1598
# ====> Epoch: 5029 Train ELBO: 138.3688 Val ELBO: 143.1053, Epoch Time (s): 0.08, Total Time (hrs): 0.1598
# ====> Epoch: 5030 Train ELBO: 138.8599 Val ELBO: 136.6945, Epoch Time (s): 0.09, Total Time (hrs): 0.1599
# ====> Epoch: 5031 Train ELBO: 135.5104 Val ELBO: 142.8896, Epoch Time (s): 0.08, Total Time (hrs): 0.1599
# ====> Epoch: 5032 Train ELBO: 138.6642 Val ELBO: 134.4179, Epoch Time (s): 0.10, Total Time (hrs): 0.1599
# ====> Epoch: 5033 Train ELBO: 137.3592 Val ELBO: 144.1906, Epoch Time (s): 0.09, Total Time (hrs): 0.1599
# ====> Epoch: 5034 Train ELBO: 139.2687 Val ELBO: 144.1445, Epoch Time (s): 0.08, Total Time (hrs): 0.1600
# ====> Epoch: 5035 Train ELBO: 139.8808 Val ELBO: 143.1847, Epoch Time (s): 0.08, Total Time (hrs): 0.1600
# ====> Epoch: 5036 Train ELBO: 140.1818 Val ELBO: 142.9280, Epoch Time (s): 0.10, Total Time (hrs): 0.1600
# ====> Epoch: 5037 Train ELBO: 138.7580 Val ELBO: 145.5668, Epoch Time (s): 0.09, Total Time (hrs): 0.1600
# ====> Epoch: 5038 Train ELBO: 140.1241 Val ELBO: 144.5149, Epoch Time (s): 0.08, Total Time (hrs): 0.1601
# ====> Epoch: 5039 Train ELBO: 141.3599 Val ELBO: 144.1977, Epoch Time (s): 0.09, Total Time (hrs): 0.1601
# ====> Epoch: 5040 Train ELBO: 141.1338 Val ELBO: 140.7821, Epoch Time (s): 0.08, Total Time (hrs): 0.1601
# ====> Epoch: 5041 Train ELBO: 129.1711 Val ELBO: 136.4006, Epoch Time (s): 0.08, Total Time (hrs): 0.1601
# ====> Epoch: 5042 Train ELBO: 102.0758 Val ELBO: 81.6433, Epoch Time (s): 0.09, Total Time (hrs): 0.1602
# ====> Epoch: 5043 Train ELBO: 107.5571 Val ELBO: 123.2069, Epoch Time (s): 0.10, Total Time (hrs): 0.1602
# ====> Epoch: 5044 Train ELBO: 126.3396 Val ELBO: 127.8907, Epoch Time (s): 0.08, Total Time (hrs): 0.1602
# ====> Epoch: 5068 Train ELBO: 139.7234 Val ELBO: 145.5151, Epoch Time (s): 0.08, Total Time (hrs): 0.1608
# ====> Epoch: 5069 Train ELBO: 139.7661 Val ELBO: 146.1586, Epoch Time (s): 0.09, Total Time (hrs): 0.1608
# ====> Epoch: 5070 Train ELBO: 141.2038 Val ELBO: 141.4072, Epoch Time (s): 0.08, Total Time (hrs): 0.1609
# ====> Epoch: 5071 Train ELBO: 139.2214 Val ELBO: 140.5494, Epoch Time (s): 0.10, Total Time (hrs): 0.1609
# ====> Epoch: 5072 Train ELBO: 139.9714 Val ELBO: 143.8199, Epoch Time (s): 0.08, Total Time (hrs): 0.1609
# ====> Epoch: 5073 Train ELBO: 138.9755 Val ELBO: 140.6385, Epoch Time (s): 0.08, Total Time (hrs): 0.1609
# ====> Epoch: 5074 Train ELBO: 137.2154 Val ELBO: 142.0445, Epoch Time (s): 0.09, Total Time (hrs): 0.1610
# ====> Epoch: 5075 Train ELBO: 135.0234 Val ELBO: 129.0883, Epoch Time (s): 0.08, Total Time (hrs): 0.1610
# ====> Epoch: 5076 Train ELBO: 133.1607 Val ELBO: 130.8609, Epoch Time (s): 0.08, Total Time (hrs): 0.1610
# ====> Epoch: 5077 Train ELBO: 131.5649 Val ELBO: 140.4236, Epoch Time (s): 0.09, Total Time (hrs): 0.1610
# ====> Epoch: 5078 Train ELBO: 138.5491 Val ELBO: 143.9704, Epoch Time (s): 0.10, Total Time (hrs): 0.1611
# ====> Epoch: 5079 Train ELBO: 139.0972 Val ELBO: 145.2237, Epoch Time (s): 0.09, Total Time (hrs): 0.1611
# ====> Epoch: 5080 Train ELBO: 141.0658 Val ELBO: 145.4847, Epoch Time (s): 0.09, Total Time (hrs): 0.1611
# ====> Epoch: 5081 Train ELBO: 139.5958 Val ELBO: 144.7601, Epoch Time (s): 0.08, Total Time (hrs): 0.1611
# ====> Epoch: 5082 Train ELBO: 132.8735 Val ELBO: 127.1310, Epoch Time (s): 0.09, Total Time (hrs): 0.1612
# ====> Epoch: 5083 Train ELBO: 135.8089 Val ELBO: 135.0157, Epoch Time (s): 0.09, Total Time (hrs): 0.1612
# ====> Epoch: 5084 Train ELBO: 133.0978 Val ELBO: 145.0263, Epoch Time (s): 0.08, Total Time (hrs): 0.1612
# ====> Epoch: 5085 Train ELBO: 139.4589 Val ELBO: 140.3159, Epoch Time (s): 0.08, Total Time (hrs): 0.1612
# ====> Epoch: 5086 Train ELBO: 132.9304 Val ELBO: 145.3788, Epoch Time (s): 0.09, Total Time (hrs): 0.1613
# ====> Epoch: 5087 Train ELBO: 139.5532 Val ELBO: 143.6633, Epoch Time (s): 0.08, Total Time (hrs): 0.1613
# ====> Epoch: 5088 Train ELBO: 137.9936 Val ELBO: 141.3000, Epoch Time (s): 0.08, Total Time (hrs): 0.1613
# ====> Epoch: 5089 Train ELBO: 136.7118 Val ELBO: 142.0845, Epoch Time (s): 0.09, Total Time (hrs): 0.1613
# ====> Epoch: 5113 Train ELBO: 138.7931 Val ELBO: 141.9890, Epoch Time (s): 0.10, Total Time (hrs): 0.1619
# ====> Epoch: 5114 Train ELBO: 133.6319 Val ELBO: 135.5016, Epoch Time (s): 0.09, Total Time (hrs): 0.1619
# ====> Epoch: 5115 Train ELBO: 136.5807 Val ELBO: 138.6955, Epoch Time (s): 0.08, Total Time (hrs): 0.1620
# ====> Epoch: 5116 Train ELBO: 137.3992 Val ELBO: 141.4658, Epoch Time (s): 0.10, Total Time (hrs): 0.1620
# ====> Epoch: 5117 Train ELBO: 138.2233 Val ELBO: 137.5273, Epoch Time (s): 0.08, Total Time (hrs): 0.1620
# ====> Epoch: 5118 Train ELBO: 137.7854 Val ELBO: 143.4581, Epoch Time (s): 0.08, Total Time (hrs): 0.1620
# ====> Epoch: 5119 Train ELBO: 139.3869 Val ELBO: 138.0070, Epoch Time (s): 0.09, Total Time (hrs): 0.1621
# ====> Epoch: 5120 Train ELBO: 138.2681 Val ELBO: 137.9529, Epoch Time (s): 0.09, Total Time (hrs): 0.1621
# ====> Epoch: 5121 Train ELBO: 132.4750 Val ELBO: 141.9638, Epoch Time (s): 0.08, Total Time (hrs): 0.1621
# ====> Epoch: 5122 Train ELBO: 133.8710 Val ELBO: 134.6740, Epoch Time (s): 0.09, Total Time (hrs): 0.1621
# ====> Epoch: 5123 Train ELBO: 138.7450 Val ELBO: 144.8125, Epoch Time (s): 0.08, Total Time (hrs): 0.1622
# ====> Epoch: 5124 Train ELBO: 141.2287 Val ELBO: 144.2642, Epoch Time (s): 0.08, Total Time (hrs): 0.1622
# ====> Epoch: 5125 Train ELBO: 140.6810 Val ELBO: 144.7827, Epoch Time (s): 0.11, Total Time (hrs): 0.1622
# ====> Epoch: 5126 Train ELBO: 141.1368 Val ELBO: 144.5152, Epoch Time (s): 0.08, Total Time (hrs): 0.1622
# ====> Epoch: 5127 Train ELBO: 139.4533 Val ELBO: 144.0141, Epoch Time (s): 0.09, Total Time (hrs): 0.1623
# ====> Epoch: 5128 Train ELBO: 140.3187 Val ELBO: 141.5023, Epoch Time (s): 0.09, Total Time (hrs): 0.1623
# ====> Epoch: 5129 Train ELBO: 140.2548 Val ELBO: 142.7863, Epoch Time (s): 0.08, Total Time (hrs): 0.1623
# ====> Epoch: 5130 Train ELBO: 139.8593 Val ELBO: 141.4702, Epoch Time (s): 0.09, Total Time (hrs): 0.1623
# ====> Epoch: 5131 Train ELBO: 137.4460 Val ELBO: 140.1488, Epoch Time (s): 0.09, Total Time (hrs): 0.1624
# ====> Epoch: 5132 Train ELBO: 139.3328 Val ELBO: 140.7466, Epoch Time (s): 0.08, Total Time (hrs): 0.1624
# ====> Epoch: 5133 Train ELBO: 137.6901 Val ELBO: 142.4182, Epoch Time (s): 0.08, Total Time (hrs): 0.1624
# ====> Epoch: 5134 Train ELBO: 132.9738 Val ELBO: 143.2468, Epoch Time (s): 0.09, Total Time (hrs): 0.1624
# ====> Epoch: 5135 Train ELBO: 130.4103 Val ELBO: 130.2126, Epoch Time (s): 0.08, Total Time (hrs): 0.1625
# ====> Epoch: 5136 Train ELBO: 132.7229 Val ELBO: 139.0301, Epoch Time (s): 0.08, Total Time (hrs): 0.1625
# ====> Epoch: 5137 Train ELBO: 134.7139 Val ELBO: 140.1142, Epoch Time (s): 0.11, Total Time (hrs): 0.1625
# ====> Epoch: 5138 Train ELBO: 137.2448 Val ELBO: 140.9163, Epoch Time (s): 0.09, Total Time (hrs): 0.1625
# ====> Epoch: 5139 Train ELBO: 137.4927 Val ELBO: 141.1499, Epoch Time (s): 0.09, Total Time (hrs): 0.1626
# ====> Epoch: 5140 Train ELBO: 135.4279 Val ELBO: 143.9523, Epoch Time (s): 0.11, Total Time (hrs): 0.1626
# ====> Epoch: 5141 Train ELBO: 138.5290 Val ELBO: 144.8282, Epoch Time (s): 0.14, Total Time (hrs): 0.1626
# ====> Epoch: 5142 Train ELBO: 138.8058 Val ELBO: 142.9665, Epoch Time (s): 0.15, Total Time (hrs): 0.1627
# ====> Epoch: 5143 Train ELBO: 137.7925 Val ELBO: 141.8011, Epoch Time (s): 0.13, Total Time (hrs): 0.1627
# ====> Epoch: 5144 Train ELBO: 140.7512 Val ELBO: 140.7605, Epoch Time (s): 0.13, Total Time (hrs): 0.1627
# ====> Epoch: 5145 Train ELBO: 135.8325 Val ELBO: 140.5063, Epoch Time (s): 0.11, Total Time (hrs): 0.1628
# ====> Epoch: 5146 Train ELBO: 136.8527 Val ELBO: 141.0819, Epoch Time (s): 0.15, Total Time (hrs): 0.1628
# ====> Epoch: 5147 Train ELBO: 134.5058 Val ELBO: 130.0774, Epoch Time (s): 0.12, Total Time (hrs): 0.1628
# ====> Epoch: 5148 Train ELBO: 137.4870 Val ELBO: 145.5991, Epoch Time (s): 0.12, Total Time (hrs): 0.1629
# ====> Epoch: 5149 Train ELBO: 141.5616 Val ELBO: 144.4518, Epoch Time (s): 0.11, Total Time (hrs): 0.1629
# ====> Epoch: 5150 Train ELBO: 142.1115 Val ELBO: 145.0847, Epoch Time (s): 0.13, Total Time (hrs): 0.1629
# ====> Epoch: 5151 Train ELBO: 141.3313 Val ELBO: 142.3829, Epoch Time (s): 0.12, Total Time (hrs): 0.1630
# ====> Epoch: 5152 Train ELBO: 140.5470 Val ELBO: 141.3425, Epoch Time (s): 0.13, Total Time (hrs): 0.1630
# ====> Epoch: 5153 Train ELBO: 140.4626 Val ELBO: 143.5659, Epoch Time (s): 0.12, Total Time (hrs): 0.1631
# ====> Epoch: 5154 Train ELBO: 141.5897 Val ELBO: 144.4643, Epoch Time (s): 0.12, Total Time (hrs): 0.1631
# ====> Epoch: 5155 Train ELBO: 140.7283 Val ELBO: 140.0491, Epoch Time (s): 0.16, Total Time (hrs): 0.1631
# ====> Epoch: 5156 Train ELBO: 138.9076 Val ELBO: 138.3094, Epoch Time (s): 0.12, Total Time (hrs): 0.1632
# ====> Epoch: 5157 Train ELBO: 140.2852 Val ELBO: 143.2279, Epoch Time (s): 0.12, Total Time (hrs): 0.1632
# ====> Epoch: 5203 Train ELBO: 140.1876 Val ELBO: 143.6160, Epoch Time (s): 0.09, Total Time (hrs): 0.1645
# ====> Epoch: 5204 Train ELBO: 139.4642 Val ELBO: 142.8318, Epoch Time (s): 0.10, Total Time (hrs): 0.1645
# ====> Epoch: 5205 Train ELBO: 139.9941 Val ELBO: 142.1871, Epoch Time (s): 0.09, Total Time (hrs): 0.1645
# ====> Epoch: 5206 Train ELBO: 137.2603 Val ELBO: 144.7713, Epoch Time (s): 0.09, Total Time (hrs): 0.1645
# ====> Epoch: 5207 Train ELBO: 139.3141 Val ELBO: 145.1698, Epoch Time (s): 0.08, Total Time (hrs): 0.1646
# ====> Epoch: 5208 Train ELBO: 141.4356 Val ELBO: 143.0606, Epoch Time (s): 0.10, Total Time (hrs): 0.1646
# ====> Epoch: 5209 Train ELBO: 138.2671 Val ELBO: 138.9998, Epoch Time (s): 0.08, Total Time (hrs): 0.1646
# ====> Epoch: 5210 Train ELBO: 136.6179 Val ELBO: 143.8965, Epoch Time (s): 0.08, Total Time (hrs): 0.1646
# ====> Epoch: 5211 Train ELBO: 139.5869 Val ELBO: 142.3563, Epoch Time (s): 0.09, Total Time (hrs): 0.1647
# ====> Epoch: 5212 Train ELBO: 138.8513 Val ELBO: 140.2839, Epoch Time (s): 0.08, Total Time (hrs): 0.1647
# ====> Epoch: 5213 Train ELBO: 138.4818 Val ELBO: 143.4654, Epoch Time (s): 0.08, Total Time (hrs): 0.1647
# ====> Epoch: 5214 Train ELBO: 140.3324 Val ELBO: 145.1864, Epoch Time (s): 0.09, Total Time (hrs): 0.1647
# ====> Epoch: 5215 Train ELBO: 140.9949 Val ELBO: 139.3610, Epoch Time (s): 0.09, Total Time (hrs): 0.1648
# ====> Epoch: 5216 Train ELBO: 136.0745 Val ELBO: 133.7842, Epoch Time (s): 0.09, Total Time (hrs): 0.1648
# ====> Epoch: 5217 Train ELBO: 128.5132 Val ELBO: 138.6098, Epoch Time (s): 0.09, Total Time (hrs): 0.1648
# ====> Epoch: 5218 Train ELBO: 135.4865 Val ELBO: 138.4757, Epoch Time (s): 0.08, Total Time (hrs): 0.1648
# ====> Epoch: 5219 Train ELBO: 137.8762 Val ELBO: 144.3107, Epoch Time (s): 0.08, Total Time (hrs): 0.1648
# ====> Epoch: 5220 Train ELBO: 141.6383 Val ELBO: 143.7351, Epoch Time (s): 0.11, Total Time (hrs): 0.1649
# ====> Epoch: 5221 Train ELBO: 141.0296 Val ELBO: 145.0316, Epoch Time (s): 0.08, Total Time (hrs): 0.1649
# ====> Epoch: 5222 Train ELBO: 140.9954 Val ELBO: 144.7593, Epoch Time (s): 0.08, Total Time (hrs): 0.1649
# ====> Epoch: 5223 Train ELBO: 140.1760 Val ELBO: 140.8256, Epoch Time (s): 0.09, Total Time (hrs): 0.1649
# ====> Epoch: 5224 Train ELBO: 138.8501 Val ELBO: 137.7863, Epoch Time (s): 0.08, Total Time (hrs): 0.1650
# ====> Epoch: 5225 Train ELBO: 137.1375 Val ELBO: 144.7025, Epoch Time (s): 0.08, Total Time (hrs): 0.1650
# ====> Epoch: 5248 Train ELBO: 135.1287 Val ELBO: 144.0574, Epoch Time (s): 0.08, Total Time (hrs): 0.1656
# ====> Epoch: 5249 Train ELBO: 138.5127 Val ELBO: 142.1891, Epoch Time (s): 0.09, Total Time (hrs): 0.1656
# ====> Epoch: 5250 Train ELBO: 140.6071 Val ELBO: 143.8901, Epoch Time (s): 0.08, Total Time (hrs): 0.1656
# ====> Epoch: 5251 Train ELBO: 139.8821 Val ELBO: 134.0726, Epoch Time (s): 0.08, Total Time (hrs): 0.1656
# ====> Epoch: 5252 Train ELBO: 136.1184 Val ELBO: 141.0272, Epoch Time (s): 0.09, Total Time (hrs): 0.1657
# ====> Epoch: 5253 Train ELBO: 137.2615 Val ELBO: 144.3517, Epoch Time (s): 0.08, Total Time (hrs): 0.1657
# ====> Epoch: 5254 Train ELBO: 137.3513 Val ELBO: 139.6782, Epoch Time (s): 0.09, Total Time (hrs): 0.1657
# ====> Epoch: 5255 Train ELBO: 137.2543 Val ELBO: 138.9439, Epoch Time (s): 0.11, Total Time (hrs): 0.1658
# ====> Epoch: 5256 Train ELBO: 140.3628 Val ELBO: 143.1336, Epoch Time (s): 0.08, Total Time (hrs): 0.1658
# ====> Epoch: 5257 Train ELBO: 142.6823 Val ELBO: 146.0086, Epoch Time (s): 0.08, Total Time (hrs): 0.1658
# ====> Epoch: 5258 Train ELBO: 142.0285 Val ELBO: 143.1487, Epoch Time (s): 0.09, Total Time (hrs): 0.1658
# ====> Epoch: 5259 Train ELBO: 140.9098 Val ELBO: 143.5771, Epoch Time (s): 0.08, Total Time (hrs): 0.1658
# ====> Epoch: 5260 Train ELBO: 135.1740 Val ELBO: 142.1575, Epoch Time (s): 0.09, Total Time (hrs): 0.1659
# ====> Epoch: 5261 Train ELBO: 137.7792 Val ELBO: 142.6672, Epoch Time (s): 0.10, Total Time (hrs): 0.1659
# ====> Epoch: 5262 Train ELBO: 137.8464 Val ELBO: 143.9755, Epoch Time (s): 0.08, Total Time (hrs): 0.1659
# ====> Epoch: 5263 Train ELBO: 141.6169 Val ELBO: 141.9919, Epoch Time (s): 0.08, Total Time (hrs): 0.1659
# ====> Epoch: 5264 Train ELBO: 136.3305 Val ELBO: 142.8130, Epoch Time (s): 0.09, Total Time (hrs): 0.1660
# ====> Epoch: 5265 Train ELBO: 135.2055 Val ELBO: 140.3803, Epoch Time (s): 0.08, Total Time (hrs): 0.1660
# ====> Epoch: 5266 Train ELBO: 135.7087 Val ELBO: 142.7503, Epoch Time (s): 0.08, Total Time (hrs): 0.1660
# ====> Epoch: 5267 Train ELBO: 134.9285 Val ELBO: 124.5211, Epoch Time (s): 0.10, Total Time (hrs): 0.1660
# ====> Epoch: 5268 Train ELBO: 131.4206 Val ELBO: 138.7922, Epoch Time (s): 0.08, Total Time (hrs): 0.1661
# ====> Epoch: 5269 Train ELBO: 138.1938 Val ELBO: 139.9478, Epoch Time (s): 0.08, Total Time (hrs): 0.1661
# ====> Epoch: 5270 Train ELBO: 137.8791 Val ELBO: 144.2189, Epoch Time (s): 0.09, Total Time (hrs): 0.1661
# ====> Epoch: 5271 Train ELBO: 138.6846 Val ELBO: 141.4081, Epoch Time (s): 0.08, Total Time (hrs): 0.1661
# ====> Epoch: 5272 Train ELBO: 141.6779 Val ELBO: 145.0786, Epoch Time (s): 0.09, Total Time (hrs): 0.1662
# ====> Epoch: 5273 Train ELBO: 140.1102 Val ELBO: 137.1911, Epoch Time (s): 0.09, Total Time (hrs): 0.1662
# ====> Epoch: 5274 Train ELBO: 137.8467 Val ELBO: 145.1927, Epoch Time (s): 0.08, Total Time (hrs): 0.1662
# ====> Epoch: 5275 Train ELBO: 136.7281 Val ELBO: 130.6171, Epoch Time (s): 0.08, Total Time (hrs): 0.1662
# ====> Epoch: 5276 Train ELBO: 136.5736 Val ELBO: 144.8333, Epoch Time (s): 0.09, Total Time (hrs): 0.1663
# ====> Epoch: 5277 Train ELBO: 137.8743 Val ELBO: 129.8512, Epoch Time (s): 0.08, Total Time (hrs): 0.1663
# ====> Epoch: 5278 Train ELBO: 133.0426 Val ELBO: 142.9927, Epoch Time (s): 0.08, Total Time (hrs): 0.1663
# ====> Epoch: 5279 Train ELBO: 140.4303 Val ELBO: 144.6821, Epoch Time (s): 0.10, Total Time (hrs): 0.1663
# ====> Epoch: 5280 Train ELBO: 141.7182 Val ELBO: 143.1835, Epoch Time (s): 0.11, Total Time (hrs): 0.1664
# ====> Epoch: 5281 Train ELBO: 141.9924 Val ELBO: 145.4763, Epoch Time (s): 0.14, Total Time (hrs): 0.1664
# ====> Epoch: 5282 Train ELBO: 142.5700 Val ELBO: 145.0019, Epoch Time (s): 0.13, Total Time (hrs): 0.1664
# ====> Epoch: 5283 Train ELBO: 142.0322 Val ELBO: 146.0573, Epoch Time (s): 0.13, Total Time (hrs): 0.1665
# ====> Epoch: 5284 Train ELBO: 141.8546 Val ELBO: 145.1926, Epoch Time (s): 0.12, Total Time (hrs): 0.1665
# ====> Epoch: 5285 Train ELBO: 142.2086 Val ELBO: 144.8869, Epoch Time (s): 0.13, Total Time (hrs): 0.1665
# ====> Epoch: 5286 Train ELBO: 137.7268 Val ELBO: 137.9993, Epoch Time (s): 0.12, Total Time (hrs): 0.1666
# ====> Epoch: 5287 Train ELBO: 134.9037 Val ELBO: 141.5974, Epoch Time (s): 0.13, Total Time (hrs): 0.1666
# ====> Epoch: 5288 Train ELBO: 124.5834 Val ELBO: 116.7069, Epoch Time (s): 0.14, Total Time (hrs): 0.1666
# ====> Epoch: 5289 Train ELBO: 124.8434 Val ELBO: 141.1161, Epoch Time (s): 0.12, Total Time (hrs): 0.1667
# ====> Epoch: 5290 Train ELBO: 137.1601 Val ELBO: 130.9152, Epoch Time (s): 0.13, Total Time (hrs): 0.1667
# ====> Epoch: 5291 Train ELBO: 131.8927 Val ELBO: 141.1694, Epoch Time (s): 0.13, Total Time (hrs): 0.1668
# ====> Epoch: 5292 Train ELBO: 134.1730 Val ELBO: 143.1171, Epoch Time (s): 0.13, Total Time (hrs): 0.1668
# ====> Epoch: 5293 Train ELBO: 137.7101 Val ELBO: 140.1472, Epoch Time (s): 0.13, Total Time (hrs): 0.1668
# ====> Epoch: 5294 Train ELBO: 137.9595 Val ELBO: 143.4885, Epoch Time (s): 0.12, Total Time (hrs): 0.1669
# ====> Epoch: 5295 Train ELBO: 139.4679 Val ELBO: 142.7538, Epoch Time (s): 0.13, Total Time (hrs): 0.1669
# ====> Epoch: 5296 Train ELBO: 140.1667 Val ELBO: 145.0518, Epoch Time (s): 0.14, Total Time (hrs): 0.1669
# ====> Epoch: 5297 Train ELBO: 141.1671 Val ELBO: 145.7294, Epoch Time (s): 0.13, Total Time (hrs): 0.1670
# ====> Epoch: 5298 Train ELBO: 141.5787 Val ELBO: 144.3138, Epoch Time (s): 0.12, Total Time (hrs): 0.1670
# ====> Epoch: 5299 Train ELBO: 142.7982 Val ELBO: 147.0379, Epoch Time (s): 0.12, Total Time (hrs): 0.1670
# ====> Epoch: 5300 Train ELBO: 142.3137 Val ELBO: 144.2913, Epoch Time (s): 0.13, Total Time (hrs): 0.1671
# ====> Epoch: 5301 Train ELBO: 136.9954 Val ELBO: 143.0414, Epoch Time (s): 0.14, Total Time (hrs): 0.1671
# ====> Epoch: 5302 Train ELBO: 132.4314 Val ELBO: 130.2714, Epoch Time (s): 0.14, Total Time (hrs): 0.1672
# ====> Epoch: 5303 Train ELBO: 136.5344 Val ELBO: 137.9449, Epoch Time (s): 0.14, Total Time (hrs): 0.1672
# ====> Epoch: 5304 Train ELBO: 138.3026 Val ELBO: 144.7740, Epoch Time (s): 0.15, Total Time (hrs): 0.1672
# ====> Epoch: 5305 Train ELBO: 140.8571 Val ELBO: 141.3222, Epoch Time (s): 0.15, Total Time (hrs): 0.1673
# ====> Epoch: 5306 Train ELBO: 139.1859 Val ELBO: 139.5744, Epoch Time (s): 0.15, Total Time (hrs): 0.1673
# ====> Epoch: 5307 Train ELBO: 137.2478 Val ELBO: 144.9765, Epoch Time (s): 0.13, Total Time (hrs): 0.1674
# ====> Epoch: 5308 Train ELBO: 138.2366 Val ELBO: 140.2339, Epoch Time (s): 0.08, Total Time (hrs): 0.1674
# ====> Epoch: 5309 Train ELBO: 134.3750 Val ELBO: 124.0326, Epoch Time (s): 0.08, Total Time (hrs): 0.1674
# ====> Epoch: 5310 Train ELBO: 129.6151 Val ELBO: 143.9358, Epoch Time (s): 0.09, Total Time (hrs): 0.1674
# ====> Epoch: 5311 Train ELBO: 135.2446 Val ELBO: 137.9388, Epoch Time (s): 0.08, Total Time (hrs): 0.1675
# ====> Epoch: 5312 Train ELBO: 135.9238 Val ELBO: 141.0400, Epoch Time (s): 0.08, Total Time (hrs): 0.1675
# ====> Epoch: 5313 Train ELBO: 138.4158 Val ELBO: 143.1026, Epoch Time (s): 0.10, Total Time (hrs): 0.1675
# ====> Epoch: 5314 Train ELBO: 140.8699 Val ELBO: 140.2778, Epoch Time (s): 0.09, Total Time (hrs): 0.1675
# ====> Epoch: 5315 Train ELBO: 137.4915 Val ELBO: 140.0000, Epoch Time (s): 0.08, Total Time (hrs): 0.1676
# ====> Epoch: 5339 Train ELBO: 139.9864 Val ELBO: 146.6215, Epoch Time (s): 0.08, Total Time (hrs): 0.1682
# ====> Epoch: 5340 Train ELBO: 140.1488 Val ELBO: 142.8732, Epoch Time (s): 0.09, Total Time (hrs): 0.1682
# ====> Epoch: 5341 Train ELBO: 141.9764 Val ELBO: 143.1757, Epoch Time (s): 0.08, Total Time (hrs): 0.1682
# ====> Epoch: 5342 Train ELBO: 140.0640 Val ELBO: 145.8439, Epoch Time (s): 0.09, Total Time (hrs): 0.1682
# ====> Epoch: 5343 Train ELBO: 138.5759 Val ELBO: 142.4446, Epoch Time (s): 0.09, Total Time (hrs): 0.1682
# ====> Epoch: 5344 Train ELBO: 138.5993 Val ELBO: 139.9673, Epoch Time (s): 0.08, Total Time (hrs): 0.1683
# ====> Epoch: 5345 Train ELBO: 138.6316 Val ELBO: 142.8986, Epoch Time (s): 0.08, Total Time (hrs): 0.1683
# ====> Epoch: 5346 Train ELBO: 140.4904 Val ELBO: 137.9903, Epoch Time (s): 0.09, Total Time (hrs): 0.1683
# ====> Epoch: 5347 Train ELBO: 134.3861 Val ELBO: 140.0824, Epoch Time (s): 0.08, Total Time (hrs): 0.1683
# ====> Epoch: 5348 Train ELBO: 136.1540 Val ELBO: 144.6192, Epoch Time (s): 0.09, Total Time (hrs): 0.1684
# ====> Epoch: 5349 Train ELBO: 139.1757 Val ELBO: 139.3189, Epoch Time (s): 0.11, Total Time (hrs): 0.1684
# ====> Epoch: 5350 Train ELBO: 131.6849 Val ELBO: 97.5122, Epoch Time (s): 0.09, Total Time (hrs): 0.1684
# ====> Epoch: 5351 Train ELBO: 111.8926 Val ELBO: 139.1274, Epoch Time (s): 0.08, Total Time (hrs): 0.1684
# ====> Epoch: 5352 Train ELBO: 122.0277 Val ELBO: 142.9721, Epoch Time (s): 0.09, Total Time (hrs): 0.1685
# ====> Epoch: 5353 Train ELBO: 135.2814 Val ELBO: 141.4983, Epoch Time (s): 0.08, Total Time (hrs): 0.1685
# ====> Epoch: 5354 Train ELBO: 139.6423 Val ELBO: 143.5909, Epoch Time (s): 0.08, Total Time (hrs): 0.1685
# ====> Epoch: 5355 Train ELBO: 140.6718 Val ELBO: 139.4494, Epoch Time (s): 0.09, Total Time (hrs): 0.1685
# ====> Epoch: 5356 Train ELBO: 139.8827 Val ELBO: 145.3073, Epoch Time (s): 0.08, Total Time (hrs): 0.1686
# ====> Epoch: 5357 Train ELBO: 140.5933 Val ELBO: 143.2501, Epoch Time (s): 0.08, Total Time (hrs): 0.1686
# ====> Epoch: 5358 Train ELBO: 140.6588 Val ELBO: 144.7331, Epoch Time (s): 0.09, Total Time (hrs): 0.1686
# ====> Epoch: 5359 Train ELBO: 138.7143 Val ELBO: 144.2078, Epoch Time (s): 0.09, Total Time (hrs): 0.1686
# ====> Epoch: 5360 Train ELBO: 139.5044 Val ELBO: 143.0289, Epoch Time (s): 0.10, Total Time (hrs): 0.1687
# ====> Epoch: 5361 Train ELBO: 138.4836 Val ELBO: 145.5687, Epoch Time (s): 0.09, Total Time (hrs): 0.1687
# ====> Epoch: 5362 Train ELBO: 139.7496 Val ELBO: 143.1095, Epoch Time (s): 0.08, Total Time (hrs): 0.1687
# ====> Epoch: 5363 Train ELBO: 138.7160 Val ELBO: 142.2632, Epoch Time (s): 0.08, Total Time (hrs): 0.1687
# ====> Epoch: 5364 Train ELBO: 139.5348 Val ELBO: 142.2864, Epoch Time (s): 0.10, Total Time (hrs): 0.1688
# ====> Epoch: 5365 Train ELBO: 139.4313 Val ELBO: 143.1870, Epoch Time (s): 0.08, Total Time (hrs): 0.1688
# ====> Epoch: 5366 Train ELBO: 141.2175 Val ELBO: 139.1323, Epoch Time (s): 0.09, Total Time (hrs): 0.1688
# ====> Epoch: 5367 Train ELBO: 138.6241 Val ELBO: 146.2812, Epoch Time (s): 0.10, Total Time (hrs): 0.1688
# ====> Epoch: 5368 Train ELBO: 141.0006 Val ELBO: 143.8011, Epoch Time (s): 0.09, Total Time (hrs): 0.1689
# ====> Epoch: 5369 Train ELBO: 140.1785 Val ELBO: 144.6565, Epoch Time (s): 0.08, Total Time (hrs): 0.1689
# ====> Epoch: 5370 Train ELBO: 141.8888 Val ELBO: 145.3001, Epoch Time (s): 0.10, Total Time (hrs): 0.1689
# ====> Epoch: 5371 Train ELBO: 141.1581 Val ELBO: 146.5179, Epoch Time (s): 0.10, Total Time (hrs): 0.1690
# ...
# ====> Epoch: 9854 Train ELBO: 146.2922 Val ELBO: 150.3141, Epoch Time (s): 0.08, Total Time (hrs): 0.3064
# ====> Epoch: 9855 Train ELBO: 147.9125 Val ELBO: 150.3169, Epoch Time (s): 0.09, Total Time (hrs): 0.3064
# ====> Epoch: 9856 Train ELBO: 146.9886 Val ELBO: 147.7605, Epoch Time (s): 0.08, Total Time (hrs): 0.3064
# ====> Epoch: 9857 Train ELBO: 147.4993 Val ELBO: 152.4575, Epoch Time (s): 0.09, Total Time (hrs): 0.3064
# ====> Epoch: 9858 Train ELBO: 148.4029 Val ELBO: 149.7945, Epoch Time (s): 0.09, Total Time (hrs): 0.3065
# ====> Epoch: 9859 Train ELBO: 147.9052 Val ELBO: 149.3305, Epoch Time (s): 0.10, Total Time (hrs): 0.3065
# ====> Epoch: 9860 Train ELBO: 147.8458 Val ELBO: 150.6678, Epoch Time (s): 0.08, Total Time (hrs): 0.3065
# ====> Epoch: 9861 Train ELBO: 147.7270 Val ELBO: 147.7188, Epoch Time (s): 0.09, Total Time (hrs): 0.3066
# ====> Epoch: 9862 Train ELBO: 145.3311 Val ELBO: 150.5701, Epoch Time (s): 0.08, Total Time (hrs): 0.3066
# ====> Epoch: 9863 Train ELBO: 145.9891 Val ELBO: 152.2404, Epoch Time (s): 0.08, Total Time (hrs): 0.3066
# ====> Epoch: 9864 Train ELBO: 146.1486 Val ELBO: 150.7323, Epoch Time (s): 0.09, Total Time (hrs): 0.3066
# ====> Epoch: 9865 Train ELBO: 147.2606 Val ELBO: 149.9249, Epoch Time (s): 0.08, Total Time (hrs): 0.3066
# ====> Epoch: 9866 Train ELBO: 148.4712 Val ELBO: 152.4665, Epoch Time (s): 0.08, Total Time (hrs): 0.3067
# ====> Epoch: 9867 Train ELBO: 148.5783 Val ELBO: 151.0623, Epoch Time (s): 0.09, Total Time (hrs): 0.3067
# ====> Epoch: 9868 Train ELBO: 147.6711 Val ELBO: 150.6280, Epoch Time (s): 0.09, Total Time (hrs): 0.3067
# ====> Epoch: 9869 Train ELBO: 147.0981 Val ELBO: 150.0128, Epoch Time (s): 0.08, Total Time (hrs): 0.3068
# ====> Epoch: 9870 Train ELBO: 147.5540 Val ELBO: 151.1067, Epoch Time (s): 0.11, Total Time (hrs): 0.3068
# ====> Epoch: 9871 Train ELBO: 145.3301 Val ELBO: 143.0845, Epoch Time (s): 0.08, Total Time (hrs): 0.3068
# ====> Epoch: 9872 Train ELBO: 140.3430 Val ELBO: 148.2184, Epoch Time (s): 0.08, Total Time (hrs): 0.3068
# ====> Epoch: 9873 Train ELBO: 146.6479 Val ELBO: 147.4911, Epoch Time (s): 0.09, Total Time (hrs): 0.3069
# ====> Epoch: 9874 Train ELBO: 146.4734 Val ELBO: 149.1338, Epoch Time (s): 0.08, Total Time (hrs): 0.3069
# ====> Epoch: 9875 Train ELBO: 145.8992 Val ELBO: 144.0039, Epoch Time (s): 0.08, Total Time (hrs): 0.3069
# ====> Epoch: 9876 Train ELBO: 146.0290 Val ELBO: 150.4665, Epoch Time (s): 0.12, Total Time (hrs): 0.3069
# ====> Epoch: 9877 Train ELBO: 147.1527 Val ELBO: 148.0724, Epoch Time (s): 0.13, Total Time (hrs): 0.3070
# ====> Epoch: 9878 Train ELBO: 148.2120 Val ELBO: 149.8945, Epoch Time (s): 0.13, Total Time (hrs): 0.3070
# ====> Epoch: 9879 Train ELBO: 148.5191 Val ELBO: 149.1098, Epoch Time (s): 0.12, Total Time (hrs): 0.3070
# ====> Epoch: 9880 Train ELBO: 147.4976 Val ELBO: 150.9463, Epoch Time (s): 0.14, Total Time (hrs): 0.3071
# ====> Epoch: 9881 Train ELBO: 147.7843 Val ELBO: 148.1064, Epoch Time (s): 0.12, Total Time (hrs): 0.3071
# ====> Epoch: 9882 Train ELBO: 148.0790 Val ELBO: 147.4431, Epoch Time (s): 0.13, Total Time (hrs): 0.3072
# ====> Epoch: 9883 Train ELBO: 145.2645 Val ELBO: 144.1549, Epoch Time (s): 0.12, Total Time (hrs): 0.3072
# ====> Epoch: 9884 Train ELBO: 145.1384 Val ELBO: 150.2904, Epoch Time (s): 0.14, Total Time (hrs): 0.3072
# ====> Epoch: 9885 Train ELBO: 144.3939 Val ELBO: 149.5234, Epoch Time (s): 0.12, Total Time (hrs): 0.3073
# ====> Epoch: 9886 Train ELBO: 145.3116 Val ELBO: 150.5511, Epoch Time (s): 0.13, Total Time (hrs): 0.3073
# ====> Epoch: 9887 Train ELBO: 143.1219 Val ELBO: 148.8823, Epoch Time (s): 0.11, Total Time (hrs): 0.3073
# ====> Epoch: 9888 Train ELBO: 144.0284 Val ELBO: 148.0629, Epoch Time (s): 0.14, Total Time (hrs): 0.3074
# ====> Epoch: 9889 Train ELBO: 145.2133 Val ELBO: 141.0245, Epoch Time (s): 0.13, Total Time (hrs): 0.3074
# ====> Epoch: 9890 Train ELBO: 144.8498 Val ELBO: 149.0907, Epoch Time (s): 0.13, Total Time (hrs): 0.3074
# ====> Epoch: 9891 Train ELBO: 142.3649 Val ELBO: 135.2681, Epoch Time (s): 0.12, Total Time (hrs): 0.3075
# ====> Epoch: 9892 Train ELBO: 135.1014 Val ELBO: 141.3704, Epoch Time (s): 0.13, Total Time (hrs): 0.3075
# ====> Epoch: 9893 Train ELBO: 142.9049 Val ELBO: 149.3395, Epoch Time (s): 0.12, Total Time (hrs): 0.3075
# ====> Epoch: 9894 Train ELBO: 146.1573 Val ELBO: 147.5758, Epoch Time (s): 0.12, Total Time (hrs): 0.3076
# ====> Epoch: 9895 Train ELBO: 143.4559 Val ELBO: 146.6298, Epoch Time (s): 0.12, Total Time (hrs): 0.3076
# ====> Epoch: 9896 Train ELBO: 142.6630 Val ELBO: 147.5085, Epoch Time (s): 0.13, Total Time (hrs): 0.3076
# ====> Epoch: 9897 Train ELBO: 144.3169 Val ELBO: 150.5684, Epoch Time (s): 0.15, Total Time (hrs): 0.3077
# ====> Epoch: 9898 Train ELBO: 147.5179 Val ELBO: 151.9304, Epoch Time (s): 0.16, Total Time (hrs): 0.3077
# ====> Epoch: 9899 Train ELBO: 146.3055 Val ELBO: 141.1607, Epoch Time (s): 0.15, Total Time (hrs): 0.3078
# ====> Epoch: 9900 Train ELBO: 145.6846 Val ELBO: 150.8931, Epoch Time (s): 0.14, Total Time (hrs): 0.3078
# ====> Epoch: 9901 Train ELBO: 143.6855 Val ELBO: 151.0709, Epoch Time (s): 0.14, Total Time (hrs): 0.3078
# ====> Epoch: 9902 Train ELBO: 144.8546 Val ELBO: 150.1979, Epoch Time (s): 0.14, Total Time (hrs): 0.3079
# ====> Epoch: 9903 Train ELBO: 143.2302 Val ELBO: 147.3312, Epoch Time (s): 0.14, Total Time (hrs): 0.3079
# ====> Epoch: 9904 Train ELBO: 142.3240 Val ELBO: 136.2016, Epoch Time (s): 0.10, Total Time (hrs): 0.3079
# ====> Epoch: 9905 Train ELBO: 141.3699 Val ELBO: 143.5371, Epoch Time (s): 0.10, Total Time (hrs): 0.3080
# ====> Epoch: 9906 Train ELBO: 146.1942 Val ELBO: 145.7352, Epoch Time (s): 0.08, Total Time (hrs): 0.3080
# ====> Epoch: 9907 Train ELBO: 146.0224 Val ELBO: 150.1485, Epoch Time (s): 0.09, Total Time (hrs): 0.3080
# ====> Epoch: 9908 Train ELBO: 145.9776 Val ELBO: 150.5718, Epoch Time (s): 0.08, Total Time (hrs): 0.3080
# ====> Epoch: 9909 Train ELBO: 147.0567 Val ELBO: 152.1053, Epoch Time (s): 0.08, Total Time (hrs): 0.3081
# ====> Epoch: 9910 Train ELBO: 148.7932 Val ELBO: 151.3461, Epoch Time (s): 0.09, Total Time (hrs): 0.3081
# ====> Epoch: 9911 Train ELBO: 148.4157 Val ELBO: 150.3487, Epoch Time (s): 0.08, Total Time (hrs): 0.3081
# ====> Epoch: 9912 Train ELBO: 148.1609 Val ELBO: 150.5797, Epoch Time (s): 0.08, Total Time (hrs): 0.3081
# ====> Epoch: 9913 Train ELBO: 148.8551 Val ELBO: 151.5067, Epoch Time (s): 0.09, Total Time (hrs): 0.3082
# ====> Epoch: 9914 Train ELBO: 149.1148 Val ELBO: 150.8295, Epoch Time (s): 0.08, Total Time (hrs): 0.3082
# ====> Epoch: 9915 Train ELBO: 146.9629 Val ELBO: 150.6413, Epoch Time (s): 0.08, Total Time (hrs): 0.3082
# ====> Epoch: 9916 Train ELBO: 148.6133 Val ELBO: 151.7984, Epoch Time (s): 0.09, Total Time (hrs): 0.3082
# ====> Epoch: 9917 Train ELBO: 149.3926 Val ELBO: 150.3021, Epoch Time (s): 0.10, Total Time (hrs): 0.3083
# ====> Epoch: 9918 Train ELBO: 144.7557 Val ELBO: 140.6793, Epoch Time (s): 0.08, Total Time (hrs): 0.3083
# ====> Epoch: 9919 Train ELBO: 141.1559 Val ELBO: 151.2194, Epoch Time (s): 0.09, Total Time (hrs): 0.3083
# ====> Epoch: 9920 Train ELBO: 145.1697 Val ELBO: 147.1463, Epoch Time (s): 0.08, Total Time (hrs): 0.3083
# ====> Epoch: 9921 Train ELBO: 146.0202 Val ELBO: 150.3577, Epoch Time (s): 0.08, Total Time (hrs): 0.3084
# ====> Epoch: 9922 Train ELBO: 148.8912 Val ELBO: 151.5951, Epoch Time (s): 0.09, Total Time (hrs): 0.3084
# ====> Epoch: 9923 Train ELBO: 148.6526 Val ELBO: 151.6757, Epoch Time (s): 0.08, Total Time (hrs): 0.3084
# ====> Epoch: 9924 Train ELBO: 147.4283 Val ELBO: 146.6698, Epoch Time (s): 0.08, Total Time (hrs): 0.3084
# ====> Epoch: 9925 Train ELBO: 144.4478 Val ELBO: 149.5901, Epoch Time (s): 0.09, Total Time (hrs): 0.3084
# ====> Epoch: 9926 Train ELBO: 144.7821 Val ELBO: 151.3597, Epoch Time (s): 0.08, Total Time (hrs): 0.3085
# ====> Epoch: 9927 Train ELBO: 146.0415 Val ELBO: 149.3111, Epoch Time (s): 0.08, Total Time (hrs): 0.3085
# ====> Epoch: 9928 Train ELBO: 145.7332 Val ELBO: 147.5188, Epoch Time (s): 0.09, Total Time (hrs): 0.3085
# ====> Epoch: 9929 Train ELBO: 143.6380 Val ELBO: 145.9364, Epoch Time (s): 0.10, Total Time (hrs): 0.3085
# ====> Epoch: 9930 Train ELBO: 142.7158 Val ELBO: 140.9081, Epoch Time (s): 0.09, Total Time (hrs): 0.3086
# ====> Epoch: 9931 Train ELBO: 144.9390 Val ELBO: 149.8367, Epoch Time (s): 0.09, Total Time (hrs): 0.3086
# ====> Epoch: 9932 Train ELBO: 147.6525 Val ELBO: 150.7063, Epoch Time (s): 0.08, Total Time (hrs): 0.3086
# ====> Epoch: 9933 Train ELBO: 148.4819 Val ELBO: 150.9878, Epoch Time (s): 0.09, Total Time (hrs): 0.3086
# ====> Epoch: 9934 Train ELBO: 147.4487 Val ELBO: 150.7371, Epoch Time (s): 0.09, Total Time (hrs): 0.3087
# ====> Epoch: 9935 Train ELBO: 147.8805 Val ELBO: 149.9571, Epoch Time (s): 0.08, Total Time (hrs): 0.3087
# ====> Epoch: 9936 Train ELBO: 148.9001 Val ELBO: 151.3535, Epoch Time (s): 0.08, Total Time (hrs): 0.3087
# ====> Epoch: 9937 Train ELBO: 148.6437 Val ELBO: 151.0799, Epoch Time (s): 0.09, Total Time (hrs): 0.3087
# ====> Epoch: 9938 Train ELBO: 147.9749 Val ELBO: 151.5813, Epoch Time (s): 0.08, Total Time (hrs): 0.3088
# ====> Epoch: 9939 Train ELBO: 148.1029 Val ELBO: 150.0043, Epoch Time (s): 0.08, Total Time (hrs): 0.3088
# ====> Epoch: 9940 Train ELBO: 147.7334 Val ELBO: 148.9104, Epoch Time (s): 0.11, Total Time (hrs): 0.3088
# ====> Epoch: 9941 Train ELBO: 147.2062 Val ELBO: 150.1498, Epoch Time (s): 0.09, Total Time (hrs): 0.3088
# ====> Epoch: 9942 Train ELBO: 147.3420 Val ELBO: 137.8674, Epoch Time (s): 0.09, Total Time (hrs): 0.3089
# ====> Epoch: 9943 Train ELBO: 139.2930 Val ELBO: 143.4059, Epoch Time (s): 0.09, Total Time (hrs): 0.3089
# ====> Epoch: 9944 Train ELBO: 135.4669 Val ELBO: 125.0717, Epoch Time (s): 0.08, Total Time (hrs): 0.3089
# ====> Epoch: 9945 Train ELBO: 138.3092 Val ELBO: 150.9117, Epoch Time (s): 0.09, Total Time (hrs): 0.3089
# ====> Epoch: 9946 Train ELBO: 144.8986 Val ELBO: 149.7759, Epoch Time (s): 0.09, Total Time (hrs): 0.3090
# ====> Epoch: 9947 Train ELBO: 142.9534 Val ELBO: 145.1065, Epoch Time (s): 0.08, Total Time (hrs): 0.3090
# ====> Epoch: 9948 Train ELBO: 143.5321 Val ELBO: 149.5220, Epoch Time (s): 0.08, Total Time (hrs): 0.3090
# ====> Epoch: 9949 Train ELBO: 145.3533 Val ELBO: 149.2635, Epoch Time (s): 0.10, Total Time (hrs): 0.3090
# ====> Epoch: 9950 Train ELBO: 147.5429 Val ELBO: 150.2866, Epoch Time (s): 0.09, Total Time (hrs): 0.3091
# ====> Epoch: 9951 Train ELBO: 147.0939 Val ELBO: 152.1920, Epoch Time (s): 0.09, Total Time (hrs): 0.3091
# ====> Epoch: 9952 Train ELBO: 146.5918 Val ELBO: 147.1701, Epoch Time (s): 0.11, Total Time (hrs): 0.3091
# ====> Epoch: 9953 Train ELBO: 143.4562 Val ELBO: 148.3398, Epoch Time (s): 0.08, Total Time (hrs): 0.3091
# ====> Epoch: 9954 Train ELBO: 144.4714 Val ELBO: 143.5779, Epoch Time (s): 0.09, Total Time (hrs): 0.3092
# ====> Epoch: 9955 Train ELBO: 143.5554 Val ELBO: 148.8562, Epoch Time (s): 0.10, Total Time (hrs): 0.3092
# ====> Epoch: 9956 Train ELBO: 141.6065 Val ELBO: 143.6365, Epoch Time (s): 0.09, Total Time (hrs): 0.3092
# ====> Epoch: 9957 Train ELBO: 143.4947 Val ELBO: 148.3839, Epoch Time (s): 0.09, Total Time (hrs): 0.3092
# ====> Epoch: 9958 Train ELBO: 143.1851 Val ELBO: 148.2732, Epoch Time (s): 0.09, Total Time (hrs): 0.3093
# ====> Epoch: 9959 Train ELBO: 144.0582 Val ELBO: 138.9377, Epoch Time (s): 0.08, Total Time (hrs): 0.3093
# ====> Epoch: 9960 Train ELBO: 144.0003 Val ELBO: 149.0769, Epoch Time (s): 0.09, Total Time (hrs): 0.3093
# ====> Epoch: 9961 Train ELBO: 147.0583 Val ELBO: 147.4364, Epoch Time (s): 0.09, Total Time (hrs): 0.3093
# ====> Epoch: 9962 Train ELBO: 147.8539 Val ELBO: 149.4531, Epoch Time (s): 0.09, Total Time (hrs): 0.3094
# ====> Epoch: 9963 Train ELBO: 147.7329 Val ELBO: 149.9121, Epoch Time (s): 0.10, Total Time (hrs): 0.3094
# ====> Epoch: 9964 Train ELBO: 146.8574 Val ELBO: 152.2421, Epoch Time (s): 0.09, Total Time (hrs): 0.3094
# ====> Epoch: 9965 Train ELBO: 146.2402 Val ELBO: 148.3812, Epoch Time (s): 0.08, Total Time (hrs): 0.3094
# ====> Epoch: 9966 Train ELBO: 146.7187 Val ELBO: 148.9333, Epoch Time (s): 0.09, Total Time (hrs): 0.3095
# ====> Epoch: 9967 Train ELBO: 144.5917 Val ELBO: 150.1053, Epoch Time (s): 0.10, Total Time (hrs): 0.3095
# ====> Epoch: 9968 Train ELBO: 147.2890 Val ELBO: 152.0992, Epoch Time (s): 0.08, Total Time (hrs): 0.3095
# ====> Epoch: 9969 Train ELBO: 146.7365 Val ELBO: 151.9124, Epoch Time (s): 0.08, Total Time (hrs): 0.3095
# ====> Epoch: 9970 Train ELBO: 148.7468 Val ELBO: 150.4230, Epoch Time (s): 0.09, Total Time (hrs): 0.3096
# ====> Epoch: 9971 Train ELBO: 146.7200 Val ELBO: 151.0752, Epoch Time (s): 0.09, Total Time (hrs): 0.3096
# ====> Epoch: 9972 Train ELBO: 145.2852 Val ELBO: 150.7935, Epoch Time (s): 0.08, Total Time (hrs): 0.3096
# ====> Epoch: 9973 Train ELBO: 146.6741 Val ELBO: 146.6569, Epoch Time (s): 0.09, Total Time (hrs): 0.3096
# ====> Epoch: 9974 Train ELBO: 146.5484 Val ELBO: 148.6624, Epoch Time (s): 0.10, Total Time (hrs): 0.3097
# ====> Epoch: 9975 Train ELBO: 144.8940 Val ELBO: 146.9435, Epoch Time (s): 0.10, Total Time (hrs): 0.3097
# ====> Epoch: 9976 Train ELBO: 146.0552 Val ELBO: 149.5753, Epoch Time (s): 0.09, Total Time (hrs): 0.3097
# ====> Epoch: 9977 Train ELBO: 146.1512 Val ELBO: 148.5660, Epoch Time (s): 0.08, Total Time (hrs): 0.3097
# ====> Epoch: 9978 Train ELBO: 148.0337 Val ELBO: 147.4805, Epoch Time (s): 0.09, Total Time (hrs): 0.3098
# ====> Epoch: 9979 Train ELBO: 148.0591 Val ELBO: 149.6560, Epoch Time (s): 0.09, Total Time (hrs): 0.3098
# ====> Epoch: 9980 Train ELBO: 147.8026 Val ELBO: 150.8363, Epoch Time (s): 0.08, Total Time (hrs): 0.3098
# ====> Epoch: 9981 Train ELBO: 148.0992 Val ELBO: 148.6484, Epoch Time (s): 0.08, Total Time (hrs): 0.3098
# ====> Epoch: 9982 Train ELBO: 147.2687 Val ELBO: 149.4725, Epoch Time (s): 0.09, Total Time (hrs): 0.3099
# ====> Epoch: 9983 Train ELBO: 147.5765 Val ELBO: 152.5754, Epoch Time (s): 0.09, Total Time (hrs): 0.3099
# ====> Epoch: 9984 Train ELBO: 147.2735 Val ELBO: 151.1091, Epoch Time (s): 0.09, Total Time (hrs): 0.3099
# ====> Epoch: 9985 Train ELBO: 147.3976 Val ELBO: 141.2573, Epoch Time (s): 0.08, Total Time (hrs): 0.3099
# ====> Epoch: 9986 Train ELBO: 132.8762 Val ELBO: 139.0235, Epoch Time (s): 0.10, Total Time (hrs): 0.3100
# ====> Epoch: 9987 Train ELBO: 137.9395 Val ELBO: 141.6341, Epoch Time (s): 0.09, Total Time (hrs): 0.3100
# ====> Epoch: 9988 Train ELBO: 142.0814 Val ELBO: 137.2705, Epoch Time (s): 0.08, Total Time (hrs): 0.3100
# ====> Epoch: 9989 Train ELBO: 141.0352 Val ELBO: 140.3222, Epoch Time (s): 0.09, Total Time (hrs): 0.3100
# ====> Epoch: 9990 Train ELBO: 140.8286 Val ELBO: 145.9058, Epoch Time (s): 0.09, Total Time (hrs): 0.3101
# ====> Epoch: 9991 Train ELBO: 139.6327 Val ELBO: 144.8114, Epoch Time (s): 0.08, Total Time (hrs): 0.3101
# ====> Epoch: 9992 Train ELBO: 143.4083 Val ELBO: 147.3603, Epoch Time (s): 0.08, Total Time (hrs): 0.3101
# ====> Epoch: 9993 Train ELBO: 141.0594 Val ELBO: 137.4040, Epoch Time (s): 0.09, Total Time (hrs): 0.3101
# ====> Epoch: 9994 Train ELBO: 143.2438 Val ELBO: 146.5372, Epoch Time (s): 0.08, Total Time (hrs): 0.3102
# ====> Epoch: 9995 Train ELBO: 146.4604 Val ELBO: 150.8797, Epoch Time (s): 0.08, Total Time (hrs): 0.3102
# ====> Epoch: 9996 Train ELBO: 147.6190 Val ELBO: 149.3941, Epoch Time (s): 0.09, Total Time (hrs): 0.3102
# ====> Epoch: 9997 Train ELBO: 147.7989 Val ELBO: 149.2449, Epoch Time (s): 0.08, Total Time (hrs): 0.3102
# ====> Epoch: 9998 Train ELBO: 147.5524 Val ELBO: 148.0834, Epoch Time (s): 0.10, Total Time (hrs): 0.3103
# ====> Epoch: 9999 Train ELBO: 142.1306 Val ELBO: 142.2680, Epoch Time (s): 0.09, Total Time (hrs): 0.3103
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-568840050.py in <cell line: 0>()
#     309
#     310       te = time.time()
# --> 311       duration = datetime.timedelta(seconds=te - ts)
#     312       print("Training took ", duration)
#     313
#
# AttributeError: type object 'datetime.datetime' has no attribute 'timedelta'
